# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(5)

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
    
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)

        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s
        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        output = self.outlayer(y)
        return output
deg = 2

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
def generate_uniform_points_in_sphere(d,R,N):
    theta = torch.rand(N,d-1)
    r = torch.sqrt( 0.75* torch.rand(N) + 0.25 )
    x = torch.zeros(N,d)
    x[:,0] = r* torch.sin(2*pi*theta[:,0])
    x_r = r* torch.cos(2*pi*theta[:,0])
    for d_i in range(d-2):
        x[:,d_i+1] = x_r *  torch.sin(2*pi*theta[:,d_i+1])
        x_r = r* torch.cos(2*pi*theta[:,d_i+1])
    x[:,d-1] = x_r 
    return x

# %%
def sol_exact(x):
    norm_2 = torch.sum(x**2,dim=1).reshape([x.size()[0],1])
    N_u = torch.cos(norm_2-1)
    return N_u

# %%
def right(x):
    norm_2 = torch.sum(x**2,dim=1).reshape([x.size()[0],1])
    N_u = 2*dim_set*torch.sin(1-norm_2)
    N_u = N_u - 4*norm_2*torch.cos(1-norm_2)
    return N_u

# %%
Batch_size = 10000
dim_set = 2
def DGM():
    x = generate_uniform_points_in_sphere(dim_set,1,Batch_size).cuda()
    x.requires_grad = True
    u = model_u(x)
    du = model_p(x)
    v= torch.ones(u.shape).cuda()
    ux = torch.autograd.grad(u,x,grad_outputs=v,create_graph=True)[0]
    loss = torch.sum((ux-du)**2)/Batch_size
    uxx = torch.zeros(Batch_size,dim_set).cuda()
    for i in range(dim_set):
        ux_tem = du[:,i].reshape([x.size()[0],1])
        uxx_tem = torch.autograd.grad(ux_tem,x,grad_outputs=v,create_graph=True)[0]
        uxx[:,i] = uxx_tem[:,i]
    loss = loss + torch.sum((torch.sum(uxx,dim=1).reshape([x.size()[0],1])  - right(x))**2)/Batch_size
    return loss

# %%
model_u1 = ResNet(dim_set,10,1)
model_p1 = ResNet(dim_set,10,dim_set)

device=torch.device("cuda:5" )
model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=2, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (fc5): Linear(in_features=10, out_features=10, bias=True)
#   (fc6): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=2, bias=True)
# )

# %%
def model_p(x):
    x.requires_grad = True
    Np_x = model_p1(x)
    N_v = x
    G = -torch.sum(Np_x*N_v,dim=1).reshape([x.size()[0],1])/2
    norm_2 = torch.sum(x**2,dim=1).reshape([x.size()[0],1])
    L_N = norm_2-1
    v= torch.ones(L_N.shape).cuda()
    nabla_L_N = torch.autograd.grad(L_N,x,grad_outputs=v,create_graph=True)[0]
    return nabla_L_N*G + Np_x

# %%
def model_u(x):
    norm_2 = torch.sum(x**2,dim=1).reshape([x.size()[0],1])
    L_D = norm_2 -0.25 
    return L_D*model_u1(x)+ cos(-0.75)

# %%
def loss_error():
    notes_error = generate_uniform_points_in_sphere(dim_set,1,Batch_size).cuda()
    notes_error.requires_grad= True
    exact = sol_exact(notes_error)
    u_L2 = torch.sqrt(torch.sum(exact**2)/10000)
    predict= model_u(notes_error)
    value = torch.sqrt(torch.sum((predict[:,0] - exact[:,0])**2)/10000)/u_L2
    return value

# %%
traintime = 25000
error_save=np.zeros([traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()}
            ])
i = 0
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = DGM()
    error = loss_error()
    losses.backward()
    optimizer.step() 
    error_save[i]=float(error)
    i = i +1
    #scheduler.step()
    if i%500==1:
        print("i= ",i)
        print("error =",error)
        print("loss1 =",losses.detach())
        np.save("error_save_Mixed_s_2D_w10.npy", error_save)
np.save("error_save_Mixed_s_2D_w10.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = tensor(0.3657, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(5.9453, device='cuda:5')
# i=  501
# error = tensor(0.0180, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0032, device='cuda:5')
# i=  1001
# error = tensor(0.0060, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0010, device='cuda:5')
# i=  1501
# error = tensor(0.0028, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0006, device='cuda:5')
# i=  2001
# error = tensor(0.0026, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:5')
# i=  2501
# error = tensor(0.0022, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0003, device='cuda:5')
# i=  3001
# error = tensor(0.0023, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0002, device='cuda:5')
# i=  3501
# error = tensor(0.0019, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0002, device='cuda:5')
# i=  4001
# error = tensor(0.0021, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0002, device='cuda:5')
# i=  4501
# error = tensor(0.0020, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0001, device='cuda:5')
# i=  5001
# error = tensor(0.0019, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(9.8371e-05, device='cuda:5')
# i=  5501
# error = tensor(0.0016, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(7.5129e-05, device='cuda:5')
# i=  6001
# error = tensor(0.0014, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0002, device='cuda:5')
# i=  6501
# error = tensor(0.0011, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(7.8681e-05, device='cuda:5')
# i=  7001
# error = tensor(0.0015, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(4.1370e-05, device='cuda:5')
# i=  7501
# error = tensor(0.0011, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(4.3010e-05, device='cuda:5')
# i=  8001
# error = tensor(0.0011, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(3.6050e-05, device='cuda:5')
# i=  8501
# error = tensor(0.0011, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(3.5043e-05, device='cuda:5')
# i=  9001
# error = tensor(0.0010, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(2.6180e-05, device='cuda:5')
# i=  9501
# error = tensor(0.0010, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(3.1908e-05, device='cuda:5')
# i=  10001
# error = tensor(0.0010, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(2.2139e-05, device='cuda:5')
# i=  10501
# error = tensor(0.0012, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(7.4551e-05, device='cuda:5')
# i=  11001
# error = tensor(0.0009, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.8666e-05, device='cuda:5')
# i=  11501
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0001, device='cuda:5')
# i=  12001
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.5815e-05, device='cuda:5')
# i=  12501
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.5793e-05, device='cuda:5')
# i=  13001
# error = tensor(0.0010, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(5.3811e-05, device='cuda:5')
# i=  13501
# error = tensor(0.0009, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(2.8047e-05, device='cuda:5')
# i=  14001
# error = tensor(0.0012, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0001, device='cuda:5')
# i=  14501
# error = tensor(0.0007, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.9378e-05, device='cuda:5')
# i=  15001
# error = tensor(0.0009, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.9239e-05, device='cuda:5')
# i=  15501
# error = tensor(0.0007, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(2.4878e-05, device='cuda:5')
# i=  16001
# error = tensor(0.0007, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.2689e-05, device='cuda:5')
# i=  16501
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.1036e-05, device='cuda:5')
# i=  17001
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.1783e-05, device='cuda:5')
# i=  17501
# error = tensor(0.0010, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0001, device='cuda:5')
# i=  18001
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.0559e-05, device='cuda:5')
# i=  18501
# error = tensor(0.0005, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(3.9701e-05, device='cuda:5')
# i=  19001
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(9.7183e-06, device='cuda:5')
# i=  19501
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.2037e-05, device='cuda:5')
# i=  20001
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.5878e-05, device='cuda:5')
# i=  20501
# error = tensor(0.0007, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(2.1255e-05, device='cuda:5')
# i=  21001
# error = tensor(0.0007, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(4.2736e-05, device='cuda:5')
# i=  21501
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.1366e-05, device='cuda:5')
# i=  22001
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(2.0348e-05, device='cuda:5')
# i=  22501
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(9.9001e-06, device='cuda:5')
# i=  23001
# error = tensor(0.0006, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(7.6858e-06, device='cuda:5')
# i=  23501
# error = tensor(0.0011, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.6570e-05, device='cuda:5')
# i=  24001
# error = tensor(0.0007, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(1.0460e-05, device='cuda:5')
# i=  24501
# error = tensor(0.0011, device='cuda:5', grad_fn=<DivBackward0>)
# loss1 = tensor(2.0728e-05, device='cuda:5')
# time cost 1194.7262074947357 s
