# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        self.Ix[0,0] = 1
        self.Ix[1,1] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)

        
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y**deg)
        y = self.fc2(y)
        y = F.relu(y**deg)
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y**deg)
        y = self.fc4(y)
        y = F.relu(y**deg)
        y = y+s
        
        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    x_tem = torch.cos(pi*x[:,1:dim_set])
    sol = torch.sum(x_tem,dim=1).reshape([x.size()[0],1])
    return sol * x[:,0:1]*(1-x[:,0:1])

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],dim_set+1).cuda()
    sol[:,0:1] =  x[:,0:1]*(1-x[:,0:1])*torch.sum(torch.cos(pi*x[:,1:dim_set]),dim=1).reshape([x.size()[0],1])
    sol[:,1:2] = (1-2*x[:,0:1])*torch.sum(torch.cos(pi*x[:,1:dim_set]),dim=1).reshape([x.size()[0],1])
    sol[:,2:dim_set+1] = -pi*x[:,0:1]*(1-x[:,0:1])*torch.sin(pi*x[:,1:dim_set])
    return sol

# %%
def right(x):
    x_tem = torch.cos(pi*x[:,1:dim_set])
    f_tem = (-2-pi**2*x[:,0:1]*(1-x[:,0:1]))*torch.sum(x_tem,dim=1).reshape([x.size()[0],1])
    return f_tem

# %%
def BCDataGen(BatchSize):
    bound = torch.rand(BatchSize,1)
    perbd = int(BatchSize/2)
    bound[0:perbd,0]=1.
    bound[perbd:2*perbd,0]=0.
    return bound

# %%
dim_set = 8
Batch_size = 10000
def DRM1():
    x = torch.rand(Batch_size,dim_set).cuda()
    x.requires_grad = True
    u = model_u(x)
    du = model_p(x)
    v= torch.ones(u.shape).cuda()
    ux = torch.autograd.grad(u,x,grad_outputs=v,create_graph=True)[0]
    loss1 = torch.sum((ux-du)**2)/Batch_size
    return loss1

# %%
def DRM2():
    x = torch.rand(Batch_size,dim_set).cuda()
    x.requires_grad = True
    u = model_u(x)
    du = model_p(x)
    v= torch.ones(u.shape).cuda()
    uxx = torch.zeros(Batch_size,dim_set).cuda()
    for i in range(dim_set):
        ux_tem = du[:,i].reshape([x.size()[0],1])
        uxx_tem = torch.autograd.grad(ux_tem,x,grad_outputs=v,create_graph=True)[0]
        uxx[:,i] = uxx_tem[:,i]
    loss2 = torch.sum((torch.sum(uxx,dim=1).reshape([x.size()[0],1])  - right(x))**2)/Batch_size
    return loss2

# %%
def model_p(x):
    multi = x*(1-x)
    multi[:,0] = 1
    return model_p1(x)*multi

# %%
def model_u(x):
    return (1-x[:,0:1])*x[:,0:1]*model_u1(x)

# %%
model_u1 = ResNet(dim_set,15,1)
model_p1 = ResNet(dim_set,15,dim_set)

device=torch.device("cuda:0" )
model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=8, out_features=15, bias=True)
#   (fc2): Linear(in_features=15, out_features=15, bias=True)
#   (fc3): Linear(in_features=15, out_features=15, bias=True)
#   (fc4): Linear(in_features=15, out_features=15, bias=True)
#   (outlayer): Linear(in_features=15, out_features=8, bias=True)
# )

# %%
notes = torch.rand(10000,dim_set).cuda()
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
Du_L2 = sqrt(torch.sum(exact[:,1:dim_set+1]**2)/10000)
def loss_error():
    notes = torch.rand(10000,dim_set).cuda()
    predict = torch.zeros(10000,2*dim_set+2).cuda()
    predict[:,0]= model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1:dim_set+1]= model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((predict[:,0] - exact[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((predict[:,1:dim_set+1] - exact[:,1:dim_set+1])**2)/10000)/Du_L2
    return value1,value2

# %%
traintime = 50000
error_save=np.zeros([2,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()},
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses1 = DRM1()
    losses1.backward()
    optimizer.step() 
    optimizer.zero_grad()
    losses2 = DRM2()
    losses2.backward()
    optimizer.step() 
    error1,error2 = loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    #scheduler.step()
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss1 =",losses1.detach())
        print("loss2 =",losses2.detach())
        np.save("error_save_LDG_NBC_8D_v2.npy", error_save)
np.save("error_save_LDG_NBC_8D_v2.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 1.0376834091235059
# loss1 = tensor(0.0817, device='cuda:0')
# loss2 = tensor(45.6417, device='cuda:0')
# i=  501
# error = 0.15752863614645563
# loss1 = tensor(0.4480, device='cuda:0')
# loss2 = tensor(0.8800, device='cuda:0')
# i=  1001
# error = 0.1256533513565894
# loss1 = tensor(0.2167, device='cuda:0')
# loss2 = tensor(0.6862, device='cuda:0')
# i=  1501
# error = 0.10414467216550695
# loss1 = tensor(0.1148, device='cuda:0')
# loss2 = tensor(0.5750, device='cuda:0')
# i=  2001
# error = 0.0760544780807367
# loss1 = tensor(0.0816, device='cuda:0')
# loss2 = tensor(0.4841, device='cuda:0')
# i=  2501
# error = 0.04278180487792491
# loss1 = tensor(0.0765, device='cuda:0')
# loss2 = tensor(0.3881, device='cuda:0')
# i=  3001
# error = 0.039183193147925635
# loss1 = tensor(0.0780, device='cuda:0')
# loss2 = tensor(0.3371, device='cuda:0')
# i=  3501
# error = 0.04008764575770673
# loss1 = tensor(0.0745, device='cuda:0')
# loss2 = tensor(0.2995, device='cuda:0')
# i=  4001
# error = 0.03183941030852401
# loss1 = tensor(0.0774, device='cuda:0')
# loss2 = tensor(0.2397, device='cuda:0')
# i=  4501
# error = 0.054217637164990846
# loss1 = tensor(0.0766, device='cuda:0')
# loss2 = tensor(0.1682, device='cuda:0')
# i=  5001
# error = 0.03612890920454311
# loss1 = tensor(0.0727, device='cuda:0')
# loss2 = tensor(0.1228, device='cuda:0')
# i=  5501
# error = 0.03463918610571691
# loss1 = tensor(0.0661, device='cuda:0')
# loss2 = tensor(0.1050, device='cuda:0')
# i=  6001
# error = 0.0415942595865465
# loss1 = tensor(0.0687, device='cuda:0')
# loss2 = tensor(0.0950, device='cuda:0')
# i=  6501
# error = 0.03460112092523563
# loss1 = tensor(0.0585, device='cuda:0')
# loss2 = tensor(0.0706, device='cuda:0')
# i=  7001
# error = 0.026607867780565227
# loss1 = tensor(0.0537, device='cuda:0')
# loss2 = tensor(0.0697, device='cuda:0')
# i=  7501
# error = 0.03731184252914662
# loss1 = tensor(0.0536, device='cuda:0')
# loss2 = tensor(0.0571, device='cuda:0')
# i=  8001
# error = 0.028921582147554904
# loss1 = tensor(0.0517, device='cuda:0')
# loss2 = tensor(0.0694, device='cuda:0')
# i=  8501
# error = 0.01781407472688876
# loss1 = tensor(0.0458, device='cuda:0')
# loss2 = tensor(0.0497, device='cuda:0')
# i=  9001
# error = 0.0633810778107231
# loss1 = tensor(0.0506, device='cuda:0')
# loss2 = tensor(0.0614, device='cuda:0')
# i=  9501
# error = 0.021412707636368017
# loss1 = tensor(0.0433, device='cuda:0')
# loss2 = tensor(0.0433, device='cuda:0')
# i=  10001
# error = 0.025109100194294107
# loss1 = tensor(0.0419, device='cuda:0')
# loss2 = tensor(0.0451, device='cuda:0')
# i=  10501
# error = 0.017004055833062786
# loss1 = tensor(0.0415, device='cuda:0')
# loss2 = tensor(0.0394, device='cuda:0')
# i=  11001
# error = 0.04713353681622191
# loss1 = tensor(0.0448, device='cuda:0')
# loss2 = tensor(0.0408, device='cuda:0')
# i=  11501
# error = 0.02464978684773547
# loss1 = tensor(0.0385, device='cuda:0')
# loss2 = tensor(0.0375, device='cuda:0')
# i=  12001
# error = 0.016704277573640604
# loss1 = tensor(0.0382, device='cuda:0')
# loss2 = tensor(0.0388, device='cuda:0')
# i=  12501
# error = 0.022070609948443325
# loss1 = tensor(0.0385, device='cuda:0')
# loss2 = tensor(0.0341, device='cuda:0')
# i=  13001
# error = 0.029361306928894295
# loss1 = tensor(0.0364, device='cuda:0')
# loss2 = tensor(0.0473, device='cuda:0')
# i=  13501
# error = 0.023747644056067
# loss1 = tensor(0.0353, device='cuda:0')
# loss2 = tensor(0.0413, device='cuda:0')
# i=  14001
# error = 0.014368642033314212
# loss1 = tensor(0.0342, device='cuda:0')
# loss2 = tensor(0.0357, device='cuda:0')
# i=  14501
# error = 0.01307621523552409
# loss1 = tensor(0.0325, device='cuda:0')
# loss2 = tensor(0.0353, device='cuda:0')
# i=  15001
# error = 0.04212473798374453
# loss1 = tensor(0.0344, device='cuda:0')
# loss2 = tensor(0.0412, device='cuda:0')
# i=  15501
# error = 0.01259574203986212
# loss1 = tensor(0.0321, device='cuda:0')
# loss2 = tensor(0.0327, device='cuda:0')
# i=  16001
# error = 0.012051618336045535
# loss1 = tensor(0.0319, device='cuda:0')
# loss2 = tensor(0.0346, device='cuda:0')
# i=  16501
# error = 0.020046551009600008
# loss1 = tensor(0.0314, device='cuda:0')
# loss2 = tensor(0.0292, device='cuda:0')
# i=  17001
# error = 0.04146558147886173
# loss1 = tensor(0.0314, device='cuda:0')
# loss2 = tensor(0.0423, device='cuda:0')
# i=  17501
# error = 0.02992634033874593
# loss1 = tensor(0.0307, device='cuda:0')
# loss2 = tensor(0.0316, device='cuda:0')
# i=  18001
# error = 0.0148963434839614
# loss1 = tensor(0.0305, device='cuda:0')
# loss2 = tensor(0.0326, device='cuda:0')
# i=  18501
# error = 0.017227898019551612
# loss1 = tensor(0.0294, device='cuda:0')
# loss2 = tensor(0.0231, device='cuda:0')
# i=  19001
# error = 0.012758285290093
# loss1 = tensor(0.0294, device='cuda:0')
# loss2 = tensor(0.0202, device='cuda:0')
# i=  19501
# error = 0.02153186225854776
# loss1 = tensor(0.0292, device='cuda:0')
# loss2 = tensor(0.0233, device='cuda:0')
# i=  20001
# error = 0.031159193333199123
# loss1 = tensor(0.0296, device='cuda:0')
# loss2 = tensor(0.0390, device='cuda:0')
# i=  20501
# error = 0.021454861577655988
# loss1 = tensor(0.0291, device='cuda:0')
# loss2 = tensor(0.0224, device='cuda:0')
# i=  21001
# error = 0.013087364715356552
# loss1 = tensor(0.0286, device='cuda:0')
# loss2 = tensor(0.0494, device='cuda:0')
# i=  21501
# error = 0.021095196268215956
# loss1 = tensor(0.0289, device='cuda:0')
# loss2 = tensor(0.0177, device='cuda:0')
# i=  22001
# error = 0.01492946011309169
# loss1 = tensor(0.0280, device='cuda:0')
# loss2 = tensor(0.0267, device='cuda:0')
# i=  22501
# error = 0.009457010245527302
# loss1 = tensor(0.0274, device='cuda:0')
# loss2 = tensor(0.0188, device='cuda:0')
# i=  23001
# error = 0.01500035928599547
# loss1 = tensor(0.0269, device='cuda:0')
# loss2 = tensor(0.0197, device='cuda:0')
# i=  23501
# error = 0.013576728865473143
# loss1 = tensor(0.0277, device='cuda:0')
# loss2 = tensor(0.0202, device='cuda:0')
# i=  24001
# error = 0.010193271203181435
# loss1 = tensor(0.0275, device='cuda:0')
# loss2 = tensor(0.0282, device='cuda:0')
# i=  24501
# error = 0.013797362490650014
# loss1 = tensor(0.0279, device='cuda:0')
# loss2 = tensor(0.0259, device='cuda:0')
# i=  25001
# error = 0.017843473000405095
# loss1 = tensor(0.0266, device='cuda:0')
# loss2 = tensor(0.0182, device='cuda:0')
# i=  25501
# error = 0.015878198784907156
# loss1 = tensor(0.0267, device='cuda:0')
# loss2 = tensor(0.0184, device='cuda:0')
# i=  26001
# error = 0.009264102875970846
# loss1 = tensor(0.0265, device='cuda:0')
# loss2 = tensor(0.0197, device='cuda:0')
# i=  26501
# error = 0.022755810349828577
# loss1 = tensor(0.0275, device='cuda:0')
# loss2 = tensor(0.0166, device='cuda:0')
# i=  27001
# error = 0.03277842865249384
# loss1 = tensor(0.0280, device='cuda:0')
# loss2 = tensor(0.0216, device='cuda:0')
# i=  27501
# error = 0.015134503338708586
# loss1 = tensor(0.0267, device='cuda:0')
# loss2 = tensor(0.0176, device='cuda:0')
# i=  28001
# error = 0.010353499178294033
# loss1 = tensor(0.0265, device='cuda:0')
# loss2 = tensor(0.0127, device='cuda:0')
# i=  28501
# error = 0.023466585460655973
# loss1 = tensor(0.0282, device='cuda:0')
# loss2 = tensor(0.0203, device='cuda:0')
# i=  29001
# error = 0.009070182961623487
# loss1 = tensor(0.0268, device='cuda:0')
# loss2 = tensor(0.0240, device='cuda:0')
# i=  29501
# error = 0.013067693228184855
# loss1 = tensor(0.0261, device='cuda:0')
# loss2 = tensor(0.0204, device='cuda:0')
# i=  30001
# error = 0.01661295515816546
# loss1 = tensor(0.0264, device='cuda:0')
# loss2 = tensor(0.0143, device='cuda:0')
# i=  30501
# error = 0.015311593765495275
# loss1 = tensor(0.0259, device='cuda:0')
# loss2 = tensor(0.0116, device='cuda:0')
# i=  31001
# error = 0.01932643638691144
# loss1 = tensor(0.0268, device='cuda:0')
# loss2 = tensor(0.0322, device='cuda:0')
# i=  31501
# error = 0.01245181822319942
# loss1 = tensor(0.0272, device='cuda:0')
# loss2 = tensor(0.0129, device='cuda:0')
# i=  32001
# error = 0.038007587882094275
# loss1 = tensor(0.0276, device='cuda:0')
# loss2 = tensor(0.0238, device='cuda:0')
# i=  32501
# error = 0.026861403380970712
# loss1 = tensor(0.0268, device='cuda:0')
# loss2 = tensor(0.0311, device='cuda:0')
# i=  33001
# error = 0.01097503669266624
# loss1 = tensor(0.0274, device='cuda:0')
# loss2 = tensor(0.0231, device='cuda:0')
# i=  33501
# error = 0.013487776199831365
# loss1 = tensor(0.0258, device='cuda:0')
# loss2 = tensor(0.0148, device='cuda:0')
# i=  34001
# error = 0.00784951573240625
# loss1 = tensor(0.0260, device='cuda:0')
# loss2 = tensor(0.0112, device='cuda:0')
# i=  34501
# error = 0.007402734712204762
# loss1 = tensor(0.0253, device='cuda:0')
# loss2 = tensor(0.0186, device='cuda:0')
# i=  35001
# error = 0.0331891042643901
# loss1 = tensor(0.0270, device='cuda:0')
# loss2 = tensor(0.0213, device='cuda:0')
# i=  35501
# error = 0.006436490451837055
# loss1 = tensor(0.0255, device='cuda:0')
# loss2 = tensor(0.0094, device='cuda:0')
# i=  36001
# error = 0.010790830374603395
# loss1 = tensor(0.0258, device='cuda:0')
# loss2 = tensor(0.0117, device='cuda:0')
# i=  36501
# error = 0.019535180742014092
# loss1 = tensor(0.0259, device='cuda:0')
# loss2 = tensor(0.0101, device='cuda:0')
# i=  37001
# error = 0.012943233276818952
# loss1 = tensor(0.0250, device='cuda:0')
# loss2 = tensor(0.0081, device='cuda:0')
# i=  37501
# error = 0.00787304915607957
# loss1 = tensor(0.0251, device='cuda:0')
# loss2 = tensor(0.0117, device='cuda:0')
# i=  38001
# error = 0.016594726321144712
# loss1 = tensor(0.0264, device='cuda:0')
# loss2 = tensor(0.0355, device='cuda:0')
# i=  38501
# error = 0.012166934741244197
# loss1 = tensor(0.0250, device='cuda:0')
# loss2 = tensor(0.0101, device='cuda:0')
# i=  39001
# error = 0.014259259574188247
# loss1 = tensor(0.0256, device='cuda:0')
# loss2 = tensor(0.0187, device='cuda:0')
# i=  39501
# error = 0.015425035112256312
# loss1 = tensor(0.0266, device='cuda:0')
# loss2 = tensor(0.0154, device='cuda:0')
# i=  40001
# error = 0.00697912176400099
# loss1 = tensor(0.0255, device='cuda:0')
# loss2 = tensor(0.0076, device='cuda:0')
# i=  40501
# error = 0.009821143422759289
# loss1 = tensor(0.0253, device='cuda:0')
# loss2 = tensor(0.0102, device='cuda:0')
# i=  41001
# error = 0.007709808703419206
# loss1 = tensor(0.0248, device='cuda:0')
# loss2 = tensor(0.0111, device='cuda:0')
# i=  41501
# error = 0.021356015344525754
# loss1 = tensor(0.0256, device='cuda:0')
# loss2 = tensor(0.0091, device='cuda:0')
# i=  42001
# error = 0.01159663888248986
# loss1 = tensor(0.0256, device='cuda:0')
# loss2 = tensor(0.0092, device='cuda:0')
# i=  42501
# error = 0.02984315492966968
# loss1 = tensor(0.0260, device='cuda:0')
# loss2 = tensor(0.0259, device='cuda:0')
# i=  43001
# error = 0.011605616039879422
# loss1 = tensor(0.0248, device='cuda:0')
# loss2 = tensor(0.0160, device='cuda:0')
# i=  43501
# error = 0.006958307614589408
# loss1 = tensor(0.0245, device='cuda:0')
# loss2 = tensor(0.0075, device='cuda:0')
# i=  44001
# error = 0.00885030378923088
# loss1 = tensor(0.0254, device='cuda:0')
# loss2 = tensor(0.0066, device='cuda:0')
# i=  44501
# error = 0.009919249318533488
# loss1 = tensor(0.0251, device='cuda:0')
# loss2 = tensor(0.0067, device='cuda:0')
# i=  45001
# error = 0.01063809707365613
# loss1 = tensor(0.0246, device='cuda:0')
# loss2 = tensor(0.0085, device='cuda:0')
# i=  45501
# error = 0.01980633212566972
# loss1 = tensor(0.0252, device='cuda:0')
# loss2 = tensor(0.0083, device='cuda:0')
# i=  46001
# error = 0.007070226609144018
# loss1 = tensor(0.0248, device='cuda:0')
# loss2 = tensor(0.0091, device='cuda:0')
# i=  46501
# error = 0.02179945131060923
# loss1 = tensor(0.0255, device='cuda:0')
# loss2 = tensor(0.0094, device='cuda:0')
# i=  47001
# error = 0.006401516821222399
# loss1 = tensor(0.0245, device='cuda:0')
# loss2 = tensor(0.0091, device='cuda:0')
# i=  47501
# error = 0.011826452816118804
# loss1 = tensor(0.0248, device='cuda:0')
# loss2 = tensor(0.0074, device='cuda:0')
# i=  48001
# error = 0.017612105974702797
# loss1 = tensor(0.0255, device='cuda:0')
# loss2 = tensor(0.0173, device='cuda:0')
# i=  48501
# error = 0.007827880587620956
# loss1 = tensor(0.0245, device='cuda:0')
# loss2 = tensor(0.0063, device='cuda:0')
# i=  49001
# error = 0.030055972055378636
# loss1 = tensor(0.0258, device='cuda:0')
# loss2 = tensor(0.0225, device='cuda:0')

# %%
import matplotlib.pyplot as plt

# %%
index = np.arange(0,50000,10)
plt.plot(np.log10(error_save[index]))

# %%
def model_u(x):
    return sol_exact_H1(x)[:,0:1]
def model_p(x):
    return sol_exact_H1(x)[:,1:dim_set+1]
