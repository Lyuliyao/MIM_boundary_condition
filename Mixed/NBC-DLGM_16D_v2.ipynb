# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        self.Ix[0,0] = 1
        self.Ix[1,1] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)

        
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y**deg)
        y = self.fc2(y)
        y = F.relu(y**deg)
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y**deg)
        y = self.fc4(y)
        y = F.relu(y**deg)
        y = y+s
        
        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    x_tem = torch.cos(pi*x[:,1:dim_set])
    sol = torch.sum(x_tem,dim=1).reshape([x.size()[0],1])
    return sol * x[:,0:1]*(1-x[:,0:1])

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],dim_set+1).cuda()
    sol[:,0:1] =  x[:,0:1]*(1-x[:,0:1])*torch.sum(torch.cos(pi*x[:,1:dim_set]),dim=1).reshape([x.size()[0],1])
    sol[:,1:2] = (1-2*x[:,0:1])*torch.sum(torch.cos(pi*x[:,1:dim_set]),dim=1).reshape([x.size()[0],1])
    sol[:,2:dim_set+1] = -pi*x[:,0:1]*(1-x[:,0:1])*torch.sin(pi*x[:,1:dim_set])
    return sol

# %%
def right(x):
    x_tem = torch.cos(pi*x[:,1:dim_set])
    f_tem = (-2-pi**2*x[:,0:1]*(1-x[:,0:1]))*torch.sum(x_tem,dim=1).reshape([x.size()[0],1])
    return f_tem

# %%
def BCDataGen(BatchSize):
    bound = torch.rand(BatchSize,1)
    perbd = int(BatchSize/2)
    bound[0:perbd,0]=1.
    bound[perbd:2*perbd,0]=0.
    return bound

# %%
dim_set = 16
Batch_size = 50000
def DRM1():
    x = torch.rand(Batch_size,dim_set).cuda()
    x.requires_grad = True
    u = model_u(x)
    du = model_p(x)
    v= torch.ones(u.shape).cuda()
    ux = torch.autograd.grad(u,x,grad_outputs=v,create_graph=True)[0]
    loss1 = torch.sum((ux-du)**2)/Batch_size
    return loss1

# %%
def DRM2():
    x = torch.rand(Batch_size,dim_set).cuda()
    x.requires_grad = True
    u = model_u(x)
    du = model_p(x)
    v= torch.ones(u.shape).cuda()
    uxx = torch.zeros(Batch_size,dim_set).cuda()
    for i in range(dim_set):
        ux_tem = du[:,i].reshape([x.size()[0],1])
        uxx_tem = torch.autograd.grad(ux_tem,x,grad_outputs=v,create_graph=True)[0]
        uxx[:,i] = uxx_tem[:,i]
    loss2 = torch.sum((torch.sum(uxx,dim=1).reshape([x.size()[0],1])  - right(x))**2)/Batch_size
    return loss2

# %%
def model_p(x):
    multi = x*(1-x)
    multi[:,0] = 1
    return model_p1(x)*multi

# %%
def model_u(x):
    return (1-x[:,0:1])*x[:,0:1]*model_u1(x)

# %%
model_u1 = ResNet(dim_set,24,1)
model_p1 = ResNet(dim_set,24,dim_set)

device=torch.device("cuda:1" )
model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=16, out_features=24, bias=True)
#   (fc2): Linear(in_features=24, out_features=24, bias=True)
#   (fc3): Linear(in_features=24, out_features=24, bias=True)
#   (fc4): Linear(in_features=24, out_features=24, bias=True)
#   (outlayer): Linear(in_features=24, out_features=16, bias=True)
# )

# %%
notes = torch.rand(10000,dim_set).cuda()
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
Du_L2 = sqrt(torch.sum(exact[:,1:dim_set+1]**2)/10000)
def loss_error():
    notes = torch.rand(10000,dim_set).cuda()
    predict = torch.zeros(10000,2*dim_set+2).cuda()
    predict[:,0]= model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1:dim_set+1]= model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((predict[:,0] - exact[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((predict[:,1:dim_set+1] - exact[:,1:dim_set+1])**2)/10000)/Du_L2
    return value1,value2

# %%
traintime = 50000
error_save=np.zeros([2,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()},
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses1 = DRM1()
    losses1.backward()
    optimizer.step() 
    optimizer.zero_grad()
    losses2 = DRM2()
    losses2.backward()
    optimizer.step() 
    error1,error2 = loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    #scheduler.step()
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss1 =",losses1.detach())
        print("loss2 =",losses2.detach())
        np.save("error_save_LDG_NBC_16D_v2.npy", error_save)
np.save("error_save_LDG_NBC_16D_v2.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 1.0045090007891433
# loss1 = tensor(0.0441, device='cuda:1')
# loss2 = tensor(104.4639, device='cuda:1')
# i=  501
# error = 0.17784066943112814
# loss1 = tensor(1.5755, device='cuda:1')
# loss2 = tensor(2.1340, device='cuda:1')
# i=  1001
# error = 0.14914972892366554
# loss1 = tensor(0.5205, device='cuda:1')
# loss2 = tensor(1.5739, device='cuda:1')
# i=  1501
# error = 0.13966713546045254
# loss1 = tensor(0.3286, device='cuda:1')
# loss2 = tensor(1.4181, device='cuda:1')
# i=  2001
# error = 0.12138413906010159
# loss1 = tensor(0.2808, device='cuda:1')
# loss2 = tensor(1.4530, device='cuda:1')
# i=  2501
# error = 0.1161072298973604
# loss1 = tensor(0.2687, device='cuda:1')
# loss2 = tensor(1.2818, device='cuda:1')
# i=  3001
# error = 0.10912333834049756
# loss1 = tensor(0.2697, device='cuda:1')
# loss2 = tensor(1.2112, device='cuda:1')
# i=  3501
# error = 0.10146187032903584
# loss1 = tensor(0.2790, device='cuda:1')
# loss2 = tensor(1.1470, device='cuda:1')
# i=  4001
# error = 0.10085786505756245
# loss1 = tensor(0.2788, device='cuda:1')
# loss2 = tensor(1.0460, device='cuda:1')
# i=  4501
# error = 0.09340468398792878
# loss1 = tensor(0.2716, device='cuda:1')
# loss2 = tensor(0.9773, device='cuda:1')
# i=  5001
# error = 0.08922836863682665
# loss1 = tensor(0.2529, device='cuda:1')
# loss2 = tensor(0.8500, device='cuda:1')
# i=  5501
# error = 0.08428749164284932
# loss1 = tensor(0.2347, device='cuda:1')
# loss2 = tensor(0.7985, device='cuda:1')
# i=  6001
# error = 0.0790909321908007
# loss1 = tensor(0.2224, device='cuda:1')
# loss2 = tensor(0.7585, device='cuda:1')
# i=  6501
# error = 0.07437667956585572
# loss1 = tensor(0.2145, device='cuda:1')
# loss2 = tensor(0.7175, device='cuda:1')
# i=  7001
# error = 0.07377992223618421
# loss1 = tensor(0.2137, device='cuda:1')
# loss2 = tensor(0.6500, device='cuda:1')
# i=  7501
# error = 0.07172763900440578
# loss1 = tensor(0.2156, device='cuda:1')
# loss2 = tensor(0.5836, device='cuda:1')
# i=  8001
# error = 0.07326561943254226
# loss1 = tensor(0.2152, device='cuda:1')
# loss2 = tensor(0.5315, device='cuda:1')
# i=  8501
# error = 0.07553763425731325
# loss1 = tensor(0.2166, device='cuda:1')
# loss2 = tensor(0.5081, device='cuda:1')
# i=  9001
# error = 0.07981127437449331
# loss1 = tensor(0.2100, device='cuda:1')
# loss2 = tensor(0.4856, device='cuda:1')
# i=  9501
# error = 0.07641998028637516
# loss1 = tensor(0.2147, device='cuda:1')
# loss2 = tensor(0.4752, device='cuda:1')
# i=  10001
# error = 0.0726452152407837
# loss1 = tensor(0.2100, device='cuda:1')
# loss2 = tensor(0.4350, device='cuda:1')
# i=  10501
# error = 0.07387526256788865
# loss1 = tensor(0.2090, device='cuda:1')
# loss2 = tensor(0.3990, device='cuda:1')
# i=  11001
# error = 0.07124484052934774
# loss1 = tensor(0.2099, device='cuda:1')
# loss2 = tensor(0.3614, device='cuda:1')
# i=  11501
# error = 0.07244046688444838
# loss1 = tensor(0.2120, device='cuda:1')
# loss2 = tensor(0.3206, device='cuda:1')
# i=  12001
# error = 0.06684704538775131
# loss1 = tensor(0.1903, device='cuda:1')
# loss2 = tensor(0.2810, device='cuda:1')
# i=  12501
# error = 0.07031231374105887
# loss1 = tensor(0.1897, device='cuda:1')
# loss2 = tensor(0.2732, device='cuda:1')
# i=  13001
# error = 0.07923753918510298
# loss1 = tensor(0.1923, device='cuda:1')
# loss2 = tensor(0.2120, device='cuda:1')
# i=  13501
# error = 0.07393752081729538
# loss1 = tensor(0.1862, device='cuda:1')
# loss2 = tensor(0.2136, device='cuda:1')
# i=  14001
# error = 0.06847648248410527
# loss1 = tensor(0.1832, device='cuda:1')
# loss2 = tensor(0.1518, device='cuda:1')
# i=  14501
# error = 0.058270405618599246
# loss1 = tensor(0.1731, device='cuda:1')
# loss2 = tensor(0.1176, device='cuda:1')
# i=  15001
# error = 0.05714699601178366
# loss1 = tensor(0.1709, device='cuda:1')
# loss2 = tensor(0.0891, device='cuda:1')
# i=  15501
# error = 0.061847559327436914
# loss1 = tensor(0.1589, device='cuda:1')
# loss2 = tensor(0.0633, device='cuda:1')
# i=  16001
# error = 0.047240522863003453
# loss1 = tensor(0.1459, device='cuda:1')
# loss2 = tensor(0.0485, device='cuda:1')
# i=  16501
# error = 0.04583695460342768
# loss1 = tensor(0.1420, device='cuda:1')
# loss2 = tensor(0.0424, device='cuda:1')
# i=  17001
# error = 0.046436642334139785
# loss1 = tensor(0.1358, device='cuda:1')
# loss2 = tensor(0.0382, device='cuda:1')
# i=  17501
# error = 0.044123905447687455
# loss1 = tensor(0.1298, device='cuda:1')
# loss2 = tensor(0.0343, device='cuda:1')
# i=  18001
# error = 0.042412104432660996
# loss1 = tensor(0.1236, device='cuda:1')
# loss2 = tensor(0.0311, device='cuda:1')
# i=  18501
# error = 0.029222323191764203
# loss1 = tensor(0.1043, device='cuda:1')
# loss2 = tensor(0.0433, device='cuda:1')
# i=  19001
# error = 0.032815644766832235
# loss1 = tensor(0.0977, device='cuda:1')
# loss2 = tensor(0.0294, device='cuda:1')
# i=  19501
# error = 0.022950008677683036
# loss1 = tensor(0.0930, device='cuda:1')
# loss2 = tensor(0.0282, device='cuda:1')
# i=  20001
# error = 0.04526083986906119
# loss1 = tensor(0.0934, device='cuda:1')
# loss2 = tensor(0.0300, device='cuda:1')
# i=  20501
# error = 0.08258725408335263
# loss1 = tensor(0.0968, device='cuda:1')
# loss2 = tensor(0.0412, device='cuda:1')
# i=  21001
# error = 0.020426638562398763
# loss1 = tensor(0.0878, device='cuda:1')
# loss2 = tensor(0.0469, device='cuda:1')
# i=  21501
# error = 0.03562842486781298
# loss1 = tensor(0.0886, device='cuda:1')
# loss2 = tensor(0.0198, device='cuda:1')
# i=  22001
# error = 0.02113156042359481
# loss1 = tensor(0.0850, device='cuda:1')
# loss2 = tensor(0.0197, device='cuda:1')
# i=  22501
# error = 0.019288935916805583
# loss1 = tensor(0.0843, device='cuda:1')
# loss2 = tensor(0.0617, device='cuda:1')
# i=  23001
# error = 0.018384754880258095
# loss1 = tensor(0.0827, device='cuda:1')
# loss2 = tensor(0.0228, device='cuda:1')
# i=  23501
# error = 0.09326534877041082
# loss1 = tensor(0.0956, device='cuda:1')
# loss2 = tensor(0.0257, device='cuda:1')
# i=  24001
# error = 0.028207729943509525
# loss1 = tensor(0.0817, device='cuda:1')
# loss2 = tensor(0.0268, device='cuda:1')
# i=  24501
# error = 0.02949767886740039
# loss1 = tensor(0.0800, device='cuda:1')
# loss2 = tensor(0.0242, device='cuda:1')
# i=  25001
# error = 0.01783682622648849
# loss1 = tensor(0.0786, device='cuda:1')
# loss2 = tensor(0.0166, device='cuda:1')
# i=  25501
# error = 0.014723333649135709
# loss1 = tensor(0.0773, device='cuda:1')
# loss2 = tensor(0.0155, device='cuda:1')
# i=  26001
# error = 0.014872567641509767
# loss1 = tensor(0.0764, device='cuda:1')
# loss2 = tensor(0.0152, device='cuda:1')
# i=  26501
# error = 0.017436834620248958
# loss1 = tensor(0.0764, device='cuda:1')
# loss2 = tensor(0.0149, device='cuda:1')
# i=  27001
# error = 0.01971924398307126
# loss1 = tensor(0.0764, device='cuda:1')
# loss2 = tensor(0.0291, device='cuda:1')
# i=  27501
# error = 0.02738848072191198
# loss1 = tensor(0.0814, device='cuda:1')
# loss2 = tensor(0.0659, device='cuda:1')
# i=  28001
# error = 0.015525656594226542
# loss1 = tensor(0.0737, device='cuda:1')
# loss2 = tensor(0.0139, device='cuda:1')
# i=  28501
# error = 0.024579892720937958
# loss1 = tensor(0.0760, device='cuda:1')
# loss2 = tensor(0.0218, device='cuda:1')
# i=  29001
# error = 0.018031599366468254
# loss1 = tensor(0.0755, device='cuda:1')
# loss2 = tensor(0.0455, device='cuda:1')
# i=  29501
# error = 0.022159115976932327
# loss1 = tensor(0.0739, device='cuda:1')
# loss2 = tensor(0.0130, device='cuda:1')
# i=  30001
# error = 0.018272643425048966
# loss1 = tensor(0.0733, device='cuda:1')
# loss2 = tensor(0.0136, device='cuda:1')
# i=  30501
# error = 0.0465682577687388
# loss1 = tensor(0.0788, device='cuda:1')
# loss2 = tensor(0.0200, device='cuda:1')
# i=  31001
# error = 0.04412711017096642
# loss1 = tensor(0.0799, device='cuda:1')
# loss2 = tensor(0.0216, device='cuda:1')
# i=  31501
# error = 0.07239885524698622
# loss1 = tensor(0.0821, device='cuda:1')
# loss2 = tensor(0.0325, device='cuda:1')
# i=  32001
# error = 0.06261165658447498
# loss1 = tensor(0.0818, device='cuda:1')
# loss2 = tensor(0.0365, device='cuda:1')
# i=  32501
# error = 0.01721354508736775
# loss1 = tensor(0.0717, device='cuda:1')
# loss2 = tensor(0.0112, device='cuda:1')
# i=  33001
# error = 0.01974640885835906
# loss1 = tensor(0.0731, device='cuda:1')
# loss2 = tensor(0.0143, device='cuda:1')
# i=  33501
# error = 0.054589755067151156
# loss1 = tensor(0.0769, device='cuda:1')
# loss2 = tensor(0.0269, device='cuda:1')
# i=  34001
# error = 0.03738508318801343
# loss1 = tensor(0.0757, device='cuda:1')
# loss2 = tensor(0.0156, device='cuda:1')
# i=  34501
# error = 0.014887517101102216
# loss1 = tensor(0.0713, device='cuda:1')
# loss2 = tensor(0.0111, device='cuda:1')
# i=  35001
# error = 0.018505616950575458
# loss1 = tensor(0.0717, device='cuda:1')
# loss2 = tensor(0.0107, device='cuda:1')
# i=  35501
# error = 0.012528659751516001
# loss1 = tensor(0.0708, device='cuda:1')
# loss2 = tensor(0.0124, device='cuda:1')
# i=  36001
# error = 0.020332319640133486
# loss1 = tensor(0.0719, device='cuda:1')
# loss2 = tensor(0.0127, device='cuda:1')
# i=  36501
# error = 0.012286540062784476
# loss1 = tensor(0.0713, device='cuda:1')
# loss2 = tensor(0.0121, device='cuda:1')
# i=  37001
# error = 0.0317743876100114
# loss1 = tensor(0.0725, device='cuda:1')
# loss2 = tensor(0.0118, device='cuda:1')
# i=  37501
# error = 0.011580677883197795
# loss1 = tensor(0.0702, device='cuda:1')
# loss2 = tensor(0.0154, device='cuda:1')
# i=  38001
# error = 0.01316459056253818
# loss1 = tensor(0.0706, device='cuda:1')
# loss2 = tensor(0.0100, device='cuda:1')
# i=  38501
# error = 0.011030678289388729
# loss1 = tensor(0.0705, device='cuda:1')
# loss2 = tensor(0.0144, device='cuda:1')
# i=  39001
# error = 0.03843484761896063
# loss1 = tensor(0.0746, device='cuda:1')
# loss2 = tensor(0.0184, device='cuda:1')
# i=  39501
# error = 0.022295820181940453
# loss1 = tensor(0.0711, device='cuda:1')
# loss2 = tensor(0.0332, device='cuda:1')
# i=  40001
# error = 0.017580899478323187
# loss1 = tensor(0.0709, device='cuda:1')
# loss2 = tensor(0.0146, device='cuda:1')
# i=  40501
# error = 0.015359793860031687
# loss1 = tensor(0.0710, device='cuda:1')
# loss2 = tensor(0.0176, device='cuda:1')
# i=  41001
# error = 0.013593674146251815
# loss1 = tensor(0.0701, device='cuda:1')
# loss2 = tensor(0.0139, device='cuda:1')
# i=  41501
# error = 0.011969574615685633
# loss1 = tensor(0.0708, device='cuda:1')
# loss2 = tensor(0.0118, device='cuda:1')
# i=  42001
# error = 0.01262911081492018
# loss1 = tensor(0.0705, device='cuda:1')
# loss2 = tensor(0.0093, device='cuda:1')
# i=  42501
# error = 0.014607098522572205
# loss1 = tensor(0.0704, device='cuda:1')
# loss2 = tensor(0.0141, device='cuda:1')
# i=  43001
# error = 0.03062870118981105
# loss1 = tensor(0.0718, device='cuda:1')
# loss2 = tensor(0.0250, device='cuda:1')
# i=  43501
# error = 0.010574991016473936
# loss1 = tensor(0.0692, device='cuda:1')
# loss2 = tensor(0.0109, device='cuda:1')
# i=  44001
# error = 0.05481356012092642
# loss1 = tensor(0.0805, device='cuda:1')
# loss2 = tensor(0.0683, device='cuda:1')
# i=  44501
# error = 0.013814668504633762
# loss1 = tensor(0.0698, device='cuda:1')
# loss2 = tensor(0.0082, device='cuda:1')
# i=  45001
# error = 0.03358840818095866
# loss1 = tensor(0.0799, device='cuda:1')
# loss2 = tensor(0.0193, device='cuda:1')
# i=  45501
# error = 0.010441306018935833
# loss1 = tensor(0.0696, device='cuda:1')
# loss2 = tensor(0.0077, device='cuda:1')
# i=  46001
# error = 0.011436643126432697
# loss1 = tensor(0.0698, device='cuda:1')
# loss2 = tensor(0.0083, device='cuda:1')
# i=  46501
# error = 0.05816650581297349
# loss1 = tensor(0.0776, device='cuda:1')
# loss2 = tensor(0.0314, device='cuda:1')
# i=  47001
# error = 0.01623353202777944
# loss1 = tensor(0.0710, device='cuda:1')
# loss2 = tensor(0.0259, device='cuda:1')
# i=  47501
# error = 0.02003080371049356
# loss1 = tensor(0.0705, device='cuda:1')
# loss2 = tensor(0.0079, device='cuda:1')
# i=  48001
# error = 0.00993459730223013
# loss1 = tensor(0.0692, device='cuda:1')
# loss2 = tensor(0.0091, device='cuda:1')
# i=  48501
# error = 0.009984137139601997
# loss1 = tensor(0.0691, device='cuda:1')
# loss2 = tensor(0.0076, device='cuda:1')
# i=  49001
# error = 0.009858250137565784
# loss1 = tensor(0.0691, device='cuda:1')
# loss2 = tensor(0.0087, device='cuda:1')
# i=  49501
# error = 0.011947173007396563
# loss1 = tensor(0.0689, device='cuda:1')
# loss2 = tensor(0.0155, device='cuda:1')
# time cost 13136.297905683517 s

# %%
import matplotlib.pyplot as plt

# %%
index = np.arange(0,50000,10)
plt.plot(np.log10(error_save[index]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-fbcae071b50b> in <module>
#       1 index = np.arange(0,50000,10)
# ----> 2 plt.plot(np.log10(error_save[index]))
#
# IndexError: index 10 is out of bounds for axis 0 with size 2

# %%
def model_u(x):
    return sol_exact_H1(x)[:,0:1]
def model_p(x):
    return sol_exact_H1(x)[:,1:dim_set+1]
