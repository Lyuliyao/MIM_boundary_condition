# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        self.Ix[0,0] = 1
        self.Ix[1,1] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)

        
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y**deg)
        y = self.fc2(y)
        y = F.relu(y**deg)
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y**deg)
        y = self.fc4(y)
        y = F.relu(y**deg)
        y = y+s
        
        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    x_tem = torch.cos(pi*x[:,1:dim_set])
    sol = torch.sum(x_tem,dim=1).reshape([x.size()[0],1])
    return sol * x[:,0:1]*(1-x[:,0:1])

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],3).cuda()
    sol[:,0:1] =  x[:,0:1]*(1-x[:,0:1])*torch.sum(torch.cos(pi*x[:,1:dim_set]),dim=1).reshape([x.size()[0],1])
    sol[:,1:2] = (1-2*x[:,0:1])*torch.sum(torch.cos(pi*x[:,1:dim_set]),dim=1).reshape([x.size()[0],1])
    sol[:,2:dim_set+1] = -pi*x[:,0:1]*(1-x[:,0:1])*torch.sin(pi*x[:,1:dim_set])
    return sol

# %%
def right(x):
    x_tem = torch.cos(pi*x[:,1:dim_set])
    f_tem = (-2-pi**2*x[:,0:1]*(1-x[:,0:1]))*torch.sum(x_tem,dim=1).reshape([x.size()[0],1])
    return f_tem

# %%
def BCDataGen(BatchSize):
    bound = torch.rand(BatchSize,1)
    perbd = int(BatchSize/2)
    bound[0:perbd,0]=1.
    bound[perbd:2*perbd,0]=0.
    return bound

# %%
dim_set = 2
Batch_size = 10000
def DRM1():
    x = torch.rand(Batch_size,dim_set).cuda()
    x.requires_grad = True
    u = model_u(x)
    du = model_p(x)
    v= torch.ones(u.shape).cuda()
    ux = torch.autograd.grad(u,x,grad_outputs=v,create_graph=True)[0]
    loss1 = torch.sum((ux-du)**2)/Batch_size
    return loss1

# %%
def DRM2():
    x = torch.rand(Batch_size,dim_set).cuda()
    x.requires_grad = True
    u = model_u(x)
    du = model_p(x)
    v= torch.ones(u.shape).cuda()
    uxx = torch.zeros(Batch_size,dim_set).cuda()
    for i in range(dim_set):
        ux_tem = du[:,i].reshape([x.size()[0],1])
        uxx_tem = torch.autograd.grad(ux_tem,x,grad_outputs=v,create_graph=True)[0]
        uxx[:,i] = uxx_tem[:,i]
    loss2 = torch.sum((torch.sum(uxx,dim=1).reshape([x.size()[0],1])  - right(x))**2)/Batch_size
    return loss2

# %%
def model_p(x):
    multi = x*(1-x)
    multi[:,0] = 1
    return model_p1(x)*multi

# %%
def model_u1(x):
    return (1-x[:,0:1])*x[:,0:1]*model_u1(x)

# %%
model_u1 = ResNet(dim_set,5,1)
model_p1 = ResNet(dim_set,5,dim_set)

device=torch.device("cuda:0" )
model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=2, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=5, bias=True)
#   (fc3): Linear(in_features=5, out_features=5, bias=True)
#   (fc4): Linear(in_features=5, out_features=5, bias=True)
#   (outlayer): Linear(in_features=5, out_features=2, bias=True)
# )

# %%
notes = torch.rand(10000,dim_set).cuda()
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
Du_L2 = sqrt(torch.sum(exact[:,1:3]**2)/10000)
def loss_error():
    notes = torch.rand(10000,dim_set).cuda()
    predict = torch.zeros(10000,2*dim_set+2).cuda()
    predict[:,0]= model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1:dim_set+1]= model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((predict[:,0] - exact[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((predict[:,1:3] - exact[:,1:3])**2)/10000)/Du_L2
    return value1,value2

# %%
traintime = 50000
error_save=np.zeros([2,traintime])
optimizer = optim.Adam([
                {'params': model_u.parameters()},
                {'params': model_p1.parameters()},
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses1 = DRM1()
    losses1.backward()
    optimizer.step() 
    optimizer.zero_grad()
    losses2 = DRM2()
    losses2.backward()
    optimizer.step() 
    error1,error2 = loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    #scheduler.step()
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss1 =",losses1.detach())
        print("loss2 =",losses2.detach())
        np.save("error_save_LDG_NBC_2D_v2.npy", error_save)
np.save("error_save_LDG_NBC_2D_v2.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.9795389663453655
# loss1 = tensor(0.2261, device='cuda:0')
# loss2 = tensor(380.8882, device='cuda:0')
# i=  501
# error = 0.09828126311591645
# loss1 = tensor(1.2910, device='cuda:0')
# loss2 = tensor(0.5591, device='cuda:0')
# i=  1001
# error = 0.0458408690016665
# loss1 = tensor(0.2999, device='cuda:0')
# loss2 = tensor(0.1220, device='cuda:0')
# i=  1501
# error = 0.02135053339386136
# loss1 = tensor(0.1017, device='cuda:0')
# loss2 = tensor(0.0297, device='cuda:0')
# i=  2001
# error = 0.009721610165890827
# loss1 = tensor(0.0266, device='cuda:0')
# loss2 = tensor(0.0080, device='cuda:0')
# i=  2501
# error = 0.0063826069336087995
# loss1 = tensor(0.0132, device='cuda:0')
# loss2 = tensor(0.0042, device='cuda:0')
# i=  3001
# error = 0.004910323034786405
# loss1 = tensor(0.0078, device='cuda:0')
# loss2 = tensor(0.0028, device='cuda:0')
# i=  3501
# error = 0.004119379842159279
# loss1 = tensor(0.0058, device='cuda:0')
# loss2 = tensor(0.0018, device='cuda:0')
# i=  4001
# error = 0.0033809672969282102
# loss1 = tensor(0.0041, device='cuda:0')
# loss2 = tensor(0.0036, device='cuda:0')
# i=  4501
# error = 0.003212976271523486
# loss1 = tensor(0.0031, device='cuda:0')
# loss2 = tensor(0.0010, device='cuda:0')
# i=  5001
# error = 0.002522890607235168
# loss1 = tensor(0.0023, device='cuda:0')
# loss2 = tensor(0.0007, device='cuda:0')
# i=  5501
# error = 0.0022042211414858614
# loss1 = tensor(0.0018, device='cuda:0')
# loss2 = tensor(0.0005, device='cuda:0')
# i=  6001
# error = 0.0019205054751376786
# loss1 = tensor(0.0014, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  6501
# error = 0.0019841056472119072
# loss1 = tensor(0.0011, device='cuda:0')
# loss2 = tensor(0.0053, device='cuda:0')
# i=  7001
# error = 0.00158315541594847
# loss1 = tensor(0.0008, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  7501
# error = 0.0014328682774875621
# loss1 = tensor(0.0007, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  8001
# error = 0.0013242812975781642
# loss1 = tensor(0.0006, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  8501
# error = 0.0012204024862963703
# loss1 = tensor(0.0005, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  9001
# error = 0.001262979894995691
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(0.0041, device='cuda:0')
# i=  9501
# error = 0.0015923095787702308
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  10001
# error = 0.0009667927684727043
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(7.2545e-05, device='cuda:0')
# i=  10501
# error = 0.0009330845388295231
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0009, device='cuda:0')
# i=  11001
# error = 0.0008422551047677307
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  11501
# error = 0.0008253231676316719
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  12001
# error = 0.0008265109248236318
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  12501
# error = 0.000731618974176483
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  13001
# error = 0.0007698579704452083
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0051, device='cuda:0')
# i=  13501
# error = 0.0006841764796202143
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(7.0308e-05, device='cuda:0')
# i=  14001
# error = 0.0006873306437191849
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(3.5740e-05, device='cuda:0')
# i=  14501
# error = 0.0007488304798998549
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  15001
# error = 0.0006400368706667448
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  15501
# error = 0.0006343847965876675
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(4.8110e-05, device='cuda:0')
# i=  16001
# error = 0.000715048251002281
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0015, device='cuda:0')
# i=  16501
# error = 0.0005968865153075574
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(6.7268e-05, device='cuda:0')
# i=  17001
# error = 0.000606653651723271
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  17501
# error = 0.0015999705807186384
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0108, device='cuda:0')
# i=  18001
# error = 0.0005726792297454567
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(3.7541e-05, device='cuda:0')
# i=  18501
# error = 0.0005882827995382482
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0012, device='cuda:0')
# i=  19001
# error = 0.0005751878068907726
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  19501
# error = 0.0005641493190401201
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(8.7261e-05, device='cuda:0')
# i=  20001
# error = 0.0011518786186293364
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0252, device='cuda:0')
# i=  20501
# error = 0.0006033409662986361
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(4.5279e-05, device='cuda:0')
# i=  21001
# error = 0.0005690232247692167
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0038, device='cuda:0')
# i=  21501
# error = 0.0005855793503167082
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  22001
# error = 0.0006770332555375646
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(3.8117e-05, device='cuda:0')
# i=  22501
# error = 0.000614147503694364
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0007, device='cuda:0')
# i=  23001
# error = 0.00117720236763378
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0057, device='cuda:0')
# i=  23501
# error = 0.0005395685650440299
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(3.2705e-05, device='cuda:0')
# i=  24001
# error = 0.0006795340624812829
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0190, device='cuda:0')
# i=  24501
# error = 0.000719636580496701
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  25001
# error = 0.0005363873764259685
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(2.5279e-05, device='cuda:0')
# i=  25501
# error = 0.0008954761203296439
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0130, device='cuda:0')
# i=  26001
# error = 0.0005770923232045592
# loss1 = tensor(9.9679e-05, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  26501
# error = 0.000536367117457009
# loss1 = tensor(9.9632e-05, device='cuda:0')
# loss2 = tensor(3.7359e-05, device='cuda:0')
# i=  27001
# error = 0.0005351926405690578
# loss1 = tensor(9.8085e-05, device='cuda:0')
# loss2 = tensor(2.8138e-05, device='cuda:0')
# i=  27501
# error = 0.0006954157264168962
# loss1 = tensor(9.9155e-05, device='cuda:0')
# loss2 = tensor(0.0008, device='cuda:0')
# i=  28001
# error = 0.0005710262191212671
# loss1 = tensor(9.9389e-05, device='cuda:0')
# loss2 = tensor(0.0017, device='cuda:0')
# i=  28501
# error = 0.0005715542127817518
# loss1 = tensor(9.6708e-05, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  29001
# error = 0.0006570237805501323
# loss1 = tensor(9.9101e-05, device='cuda:0')
# loss2 = tensor(0.0008, device='cuda:0')
# i=  29501
# error = 0.0006065449271387004
# loss1 = tensor(9.7053e-05, device='cuda:0')
# loss2 = tensor(0.0007, device='cuda:0')
# i=  30001
# error = 0.000652726671905635
# loss1 = tensor(9.4209e-05, device='cuda:0')
# loss2 = tensor(0.0010, device='cuda:0')
# i=  30501
# error = 0.0005258688173221353
# loss1 = tensor(9.4272e-05, device='cuda:0')
# loss2 = tensor(5.4253e-05, device='cuda:0')
# i=  31001
# error = 0.000509655773516361
# loss1 = tensor(9.6250e-05, device='cuda:0')
# loss2 = tensor(2.3777e-05, device='cuda:0')
# i=  31501
# error = 0.0005357849671339587
# loss1 = tensor(9.5816e-05, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  32001
# error = 0.0005071502440161367
# loss1 = tensor(9.5276e-05, device='cuda:0')
# loss2 = tensor(2.6366e-05, device='cuda:0')
# i=  32501
# error = 0.0005884235977874751
# loss1 = tensor(9.1490e-05, device='cuda:0')
# loss2 = tensor(0.0038, device='cuda:0')
# i=  33001
# error = 0.0007578138253724751
# loss1 = tensor(8.8918e-05, device='cuda:0')
# loss2 = tensor(0.0021, device='cuda:0')
# i=  33501
# error = 0.0008023878676953342
# loss1 = tensor(9.5217e-05, device='cuda:0')
# loss2 = tensor(0.0044, device='cuda:0')
# i=  34001
# error = 0.0011276282506949425
# loss1 = tensor(9.9608e-05, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  34501
# error = 0.0004996287404763376
# loss1 = tensor(9.5571e-05, device='cuda:0')
# loss2 = tensor(2.1807e-05, device='cuda:0')
# i=  35001
# error = 0.0006168012193148219
# loss1 = tensor(9.5376e-05, device='cuda:0')
# loss2 = tensor(0.0008, device='cuda:0')
# i=  35501
# error = 0.0005959594769274796
# loss1 = tensor(9.3414e-05, device='cuda:0')
# loss2 = tensor(0.0005, device='cuda:0')
# i=  36001
# error = 0.0008432841136613729
# loss1 = tensor(9.5611e-05, device='cuda:0')
# loss2 = tensor(0.0017, device='cuda:0')
# i=  36501
# error = 0.0005146112975653903
# loss1 = tensor(8.6630e-05, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  37001
# error = 0.0005223703210069987
# loss1 = tensor(9.0279e-05, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  37501
# error = 0.0005011560851018142
# loss1 = tensor(9.2559e-05, device='cuda:0')
# loss2 = tensor(3.3599e-05, device='cuda:0')
# i=  38001
# error = 0.0005926540440014117
# loss1 = tensor(8.8979e-05, device='cuda:0')
# loss2 = tensor(0.0014, device='cuda:0')
# i=  38501
# error = 0.0004987808933522324
# loss1 = tensor(8.8143e-05, device='cuda:0')
# loss2 = tensor(1.5501e-05, device='cuda:0')
# i=  39001
# error = 0.0005070957042961239
# loss1 = tensor(9.0417e-05, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  39501
# error = 0.0005004420599464834
# loss1 = tensor(8.5708e-05, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  40001
# error = 0.0005068036396899022
# loss1 = tensor(8.4667e-05, device='cuda:0')
# loss2 = tensor(1.8123e-05, device='cuda:0')
# i=  40501
# error = 0.0006688507561921469
# loss1 = tensor(9.2350e-05, device='cuda:0')
# loss2 = tensor(0.0015, device='cuda:0')
# i=  41001
# error = 0.00048450911585942827
# loss1 = tensor(8.6418e-05, device='cuda:0')
# loss2 = tensor(1.6690e-05, device='cuda:0')
# i=  41501
# error = 0.00050196330219777
# loss1 = tensor(8.8524e-05, device='cuda:0')
# loss2 = tensor(3.8604e-05, device='cuda:0')
# i=  42001
# error = 0.0004808460104157438
# loss1 = tensor(8.3167e-05, device='cuda:0')
# loss2 = tensor(1.5612e-05, device='cuda:0')
# i=  42501
# error = 0.00055098368278653
# loss1 = tensor(8.4008e-05, device='cuda:0')
# loss2 = tensor(0.0007, device='cuda:0')
# i=  43001
# error = 0.0005387595120668495
# loss1 = tensor(8.9098e-05, device='cuda:0')
# loss2 = tensor(8.2059e-05, device='cuda:0')
# i=  43501
# error = 0.00048971900867317
# loss1 = tensor(8.5577e-05, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  44001
# error = 0.0005075488299333552
# loss1 = tensor(8.6036e-05, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  44501
# error = 0.0006059851937519539
# loss1 = tensor(8.7035e-05, device='cuda:0')
# loss2 = tensor(0.0109, device='cuda:0')
# i=  45001
# error = 0.00047679582897523136
# loss1 = tensor(8.2875e-05, device='cuda:0')
# loss2 = tensor(2.0063e-05, device='cuda:0')
# i=  45501
# error = 0.0004819432010245747
# loss1 = tensor(8.1938e-05, device='cuda:0')
# loss2 = tensor(8.4627e-05, device='cuda:0')
# i=  46001
# error = 0.0009450755369965734
# loss1 = tensor(8.6171e-05, device='cuda:0')
# loss2 = tensor(0.0045, device='cuda:0')
# i=  46501
# error = 0.0005072620757914061
# loss1 = tensor(8.2748e-05, device='cuda:0')
# loss2 = tensor(0.0017, device='cuda:0')
# i=  47001
# error = 0.00047026868740872893
# loss1 = tensor(8.0044e-05, device='cuda:0')
# loss2 = tensor(6.4452e-05, device='cuda:0')
# i=  47501
# error = 0.0004754796518574478
# loss1 = tensor(7.8250e-05, device='cuda:0')
# loss2 = tensor(5.7991e-05, device='cuda:0')
# i=  48001
# error = 0.00046404372064132626
# loss1 = tensor(7.6344e-05, device='cuda:0')
# loss2 = tensor(1.2550e-05, device='cuda:0')
# i=  48501
# error = 0.0009076314639508127
# loss1 = tensor(7.8553e-05, device='cuda:0')
# loss2 = tensor(0.0044, device='cuda:0')
# i=  49001
# error = 0.0004713797414294904
# loss1 = tensor(7.7273e-05, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  49501
# error = 0.0004689832867569241
# loss1 = tensor(7.8896e-05, device='cuda:0')
# loss2 = tensor(2.6319e-05, device='cuda:0')
# time cost 2059.63352060318 s

# %%
import matplotlib.pyplot as plt

# %%
index = np.arange(0,50000,10)
plt.plot(np.log10(error_save[index]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-fbcae071b50b> in <module>
#       1 index = np.arange(0,50000,10)
# ----> 2 plt.plot(np.log10(error_save[index]))
#
# IndexError: index 10 is out of bounds for axis 0 with size 2

# %%
def model_u(x):
    return sol_exact_H1(x)[:,0:1]
def model_p(x):
    return sol_exact_H1(x)[:,1:dim_set+1]
# Out:
# tensor(8.5892e-32, device='cuda:0', grad_fn=<DivBackward0>)
