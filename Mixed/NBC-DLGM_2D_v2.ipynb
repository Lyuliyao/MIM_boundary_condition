# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        self.Ix[0,0] = 1
        self.Ix[1,1] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)

        
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y**deg)
        y = self.fc2(y)
        y = F.relu(y**deg)
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y**deg)
        y = self.fc4(y)
        y = F.relu(y**deg)
        y = y+s
        
        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    x_tem = torch.cos(pi*x[:,1:dim_set])
    sol = torch.sum(x_tem,dim=1).reshape([x.size()[0],1])
    return sol * x[:,0:1]*(1-x[:,0:1])

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],3).cuda()
    sol[:,0:1] =  x[:,0:1]*(1-x[:,0:1])*torch.sum(torch.cos(pi*x[:,1:dim_set]),dim=1).reshape([x.size()[0],1])
    sol[:,1:2] = (1-2*x[:,0:1])*torch.sum(torch.cos(pi*x[:,1:dim_set]),dim=1).reshape([x.size()[0],1])
    sol[:,2:dim_set+1] = -pi*x[:,0:1]*(1-x[:,0:1])*torch.sin(pi*x[:,1:dim_set])
    return sol

# %%
def right(x):
    x_tem = torch.cos(pi*x[:,1:dim_set])
    f_tem = (-2-pi**2*x[:,0:1]*(1-x[:,0:1]))*torch.sum(x_tem,dim=1).reshape([x.size()[0],1])
    return f_tem

# %%
def BCDataGen(BatchSize):
    bound = torch.rand(BatchSize,1)
    perbd = int(BatchSize/2)
    bound[0:perbd,0]=1.
    bound[perbd:2*perbd,0]=0.
    return bound

# %%
dim_set = 2
Batch_size = 10000
def DRM1():
    x = torch.rand(Batch_size,dim_set).cuda()
    x.requires_grad = True
    u = model_u(x)
    du = model_p(x)
    v= torch.ones(u.shape).cuda()
    ux = torch.autograd.grad(u,x,grad_outputs=v,create_graph=True)[0]
    loss1 = torch.sum((ux-du)**2)/Batch_size
    return loss1

# %%
def DRM2():
    x = torch.rand(Batch_size,dim_set).cuda()
    x.requires_grad = True
    u = model_u(x)
    du = model_p(x)
    v= torch.ones(u.shape).cuda()
    uxx = torch.zeros(Batch_size,dim_set).cuda()
    for i in range(dim_set):
        ux_tem = du[:,i].reshape([x.size()[0],1])
        uxx_tem = torch.autograd.grad(ux_tem,x,grad_outputs=v,create_graph=True)[0]
        uxx[:,i] = uxx_tem[:,i]
    loss2 = torch.sum((torch.sum(uxx,dim=1).reshape([x.size()[0],1])  - right(x))**2)/Batch_size
    return loss2

# %%
def model_p(x):
    multi = x*(1-x)
    multi[:,0] = 1
    return model_p1(x)*multi

# %%
def model_u(x):
    return (1-x[:,0:1])*x[:,0:1]*model_u1(x)

# %%
model_u1 = ResNet(dim_set,5,1)
model_p1 = ResNet(dim_set,5,dim_set)

device=torch.device("cuda:0" )
model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=2, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=5, bias=True)
#   (fc3): Linear(in_features=5, out_features=5, bias=True)
#   (fc4): Linear(in_features=5, out_features=5, bias=True)
#   (outlayer): Linear(in_features=5, out_features=2, bias=True)
# )

# %%
notes = torch.rand(10000,dim_set).cuda()
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
Du_L2 = sqrt(torch.sum(exact[:,1:3]**2)/10000)
def loss_error():
    notes = torch.rand(10000,dim_set).cuda()
    predict = torch.zeros(10000,2*dim_set+2).cuda()
    predict[:,0]= model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1:dim_set+1]= model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((predict[:,0] - exact[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((predict[:,1:3] - exact[:,1:3])**2)/10000)/Du_L2
    return value1,value2

# %%
traintime = 50000
error_save=np.zeros([2,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()},
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses1 = DRM1()
    losses1.backward()
    optimizer.step() 
    optimizer.zero_grad()
    losses2 = DRM2()
    losses2.backward()
    optimizer.step() 
    error1,error2 = loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    #scheduler.step()
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss1 =",losses1.detach())
        print("loss2 =",losses2.detach())
        np.save("error_save_LDG_NBC_2D_v2.npy", error_save)
np.save("error_save_LDG_NBC_2D_v2.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.8429456037700288
# loss1 = tensor(0.0359, device='cuda:0')
# loss2 = tensor(7.8512, device='cuda:0')
# i=  501
# error = 0.012971746076383694
# loss1 = tensor(0.0263, device='cuda:0')
# loss2 = tensor(0.0168, device='cuda:0')
# i=  1001
# error = 0.007350485747484159
# loss1 = tensor(0.0188, device='cuda:0')
# loss2 = tensor(0.0028, device='cuda:0')
# i=  1501
# error = 0.004104982054124289
# loss1 = tensor(0.0150, device='cuda:0')
# loss2 = tensor(0.0013, device='cuda:0')
# i=  2001
# error = 0.004410881482440915
# loss1 = tensor(0.0096, device='cuda:0')
# loss2 = tensor(0.0011, device='cuda:0')
# i=  2501
# error = 0.005639773405616111
# loss1 = tensor(0.0041, device='cuda:0')
# loss2 = tensor(0.0009, device='cuda:0')
# i=  3001
# error = 0.006682144692697631
# loss1 = tensor(0.0031, device='cuda:0')
# loss2 = tensor(0.0008, device='cuda:0')
# i=  3501
# error = 0.003563665694177356
# loss1 = tensor(0.0029, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  4001
# error = 0.0029419790918125254
# loss1 = tensor(0.0027, device='cuda:0')
# loss2 = tensor(0.0015, device='cuda:0')
# i=  4501
# error = 0.0016071603263052498
# loss1 = tensor(0.0027, device='cuda:0')
# loss2 = tensor(0.0018, device='cuda:0')
# i=  5001
# error = 0.003553369411896695
# loss1 = tensor(0.0026, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  5501
# error = 0.007769807895375344
# loss1 = tensor(0.0024, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  6001
# error = 0.007549587108822326
# loss1 = tensor(0.0023, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  6501
# error = 0.001163625900603802
# loss1 = tensor(0.0021, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  7001
# error = 0.002910702849163617
# loss1 = tensor(0.0020, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  7501
# error = 0.001990207438094331
# loss1 = tensor(0.0019, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  8001
# error = 0.004222491435333834
# loss1 = tensor(0.0018, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  8501
# error = 0.0017460407514964366
# loss1 = tensor(0.0016, device='cuda:0')
# loss2 = tensor(0.0008, device='cuda:0')
# i=  9001
# error = 0.003183250924675912
# loss1 = tensor(0.0016, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  9501
# error = 0.0011282235015602777
# loss1 = tensor(0.0014, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  10001
# error = 0.006313394436663683
# loss1 = tensor(0.0014, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  10501
# error = 0.004282706067822467
# loss1 = tensor(0.0013, device='cuda:0')
# loss2 = tensor(0.0011, device='cuda:0')
# i=  11001
# error = 0.0029044177021872422
# loss1 = tensor(0.0012, device='cuda:0')
# loss2 = tensor(0.0005, device='cuda:0')
# i=  11501
# error = 0.005809067457700406
# loss1 = tensor(0.0011, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  12001
# error = 0.003920588161087004
# loss1 = tensor(0.0011, device='cuda:0')
# loss2 = tensor(0.0007, device='cuda:0')
# i=  12501
# error = 0.003099785028796704
# loss1 = tensor(0.0010, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  13001
# error = 0.006194499011207629
# loss1 = tensor(0.0009, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  13501
# error = 0.0030413499018005982
# loss1 = tensor(0.0009, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  14001
# error = 0.005502466446340899
# loss1 = tensor(0.0008, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  14501
# error = 0.001804387262950568
# loss1 = tensor(0.0008, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  15001
# error = 0.004524781085057467
# loss1 = tensor(0.0007, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  15501
# error = 0.00246719626490982
# loss1 = tensor(0.0007, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  16001
# error = 0.005928680145564524
# loss1 = tensor(0.0007, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  16501
# error = 0.008964803357488314
# loss1 = tensor(0.0007, device='cuda:0')
# loss2 = tensor(0.0009, device='cuda:0')
# i=  17001
# error = 0.0014121910647567181
# loss1 = tensor(0.0006, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  17501
# error = 0.0038498124686594526
# loss1 = tensor(0.0006, device='cuda:0')
# loss2 = tensor(0.0010, device='cuda:0')
# i=  18001
# error = 0.0010845552122335953
# loss1 = tensor(0.0006, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  18501
# error = 0.0021128584246697312
# loss1 = tensor(0.0006, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  19001
# error = 0.005433989737275649
# loss1 = tensor(0.0006, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  19501
# error = 0.0012718861044057077
# loss1 = tensor(0.0005, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  20001
# error = 0.0017003742688149787
# loss1 = tensor(0.0005, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  20501
# error = 0.005704140012515964
# loss1 = tensor(0.0005, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  21001
# error = 0.002505461895678891
# loss1 = tensor(0.0005, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  21501
# error = 0.0018229425742054325
# loss1 = tensor(0.0005, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  22001
# error = 0.0024806424738813403
# loss1 = tensor(0.0005, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  22501
# error = 0.0025135280756778955
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(0.0005, device='cuda:0')
# i=  23001
# error = 0.0016185109400642563
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  23501
# error = 0.003391158003510053
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  24001
# error = 0.006328024280321383
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(0.0008, device='cuda:0')
# i=  24501
# error = 0.0027361142796447696
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  25001
# error = 0.0031838478331600605
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  25501
# error = 0.0027412829203200674
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(8.4391e-05, device='cuda:0')
# i=  26001
# error = 0.0023058883505589797
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  26501
# error = 0.003867323053375125
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  27001
# error = 0.0022995127342071825
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  27501
# error = 0.00212981417614204
# loss1 = tensor(0.0004, device='cuda:0')
# loss2 = tensor(9.3557e-05, device='cuda:0')
# i=  28001
# error = 0.0011757931017971762
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(8.7008e-05, device='cuda:0')
# i=  28501
# error = 0.0016260923344413244
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  29001
# error = 0.002168019562612739
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(7.9704e-05, device='cuda:0')
# i=  29501
# error = 0.0012895944415939051
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  30001
# error = 0.005152281925566829
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  30501
# error = 0.004699235926583775
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  31001
# error = 0.001166471643856242
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(9.3654e-05, device='cuda:0')
# i=  31501
# error = 0.0007350027707101247
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  32001
# error = 0.0011734496570551425
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(0.0008, device='cuda:0')
# i=  32501
# error = 0.0030088330306088443
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  33001
# error = 0.0033749070651675544
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(8.9237e-05, device='cuda:0')
# i=  33501
# error = 0.0023829728615921116
# loss1 = tensor(0.0003, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  34001
# error = 0.0006782415572450609
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(9.0631e-05, device='cuda:0')
# i=  34501
# error = 0.0032358869045354052
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(7.4816e-05, device='cuda:0')
# i=  35001
# error = 0.0015472946421628774
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  35501
# error = 0.0013556039461196552
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  36001
# error = 0.0010409357840665703
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  36501
# error = 0.0007314926357955455
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(6.0256e-05, device='cuda:0')
# i=  37001
# error = 0.0019740175695569253
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  37501
# error = 0.001306652552672234
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  38001
# error = 0.0008374251450659165
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0005, device='cuda:0')
# i=  38501
# error = 0.0018941088221287922
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(8.2732e-05, device='cuda:0')
# i=  39001
# error = 0.0020521322636580706
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  39501
# error = 0.001311939363237617
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(8.3242e-05, device='cuda:0')
# i=  40001
# error = 0.004255936639737712
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  40501
# error = 0.0019313516698093545
# loss1 = tensor(0.0002, device='cuda:0')
# loss2 = tensor(7.5911e-05, device='cuda:0')
# i=  41001
# error = 0.0010845995261805983
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(5.3473e-05, device='cuda:0')
# i=  41501
# error = 0.0018563768431511295
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(6.2127e-05, device='cuda:0')
# i=  42001
# error = 0.0007861737407069882
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  42501
# error = 0.0018661909196212663
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  43001
# error = 0.0005013844710456244
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  43501
# error = 0.004187685395939563
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  44001
# error = 0.002191904105712427
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  44501
# error = 0.0008370307162284651
# loss1 = tensor(9.9414e-05, device='cuda:0')
# loss2 = tensor(4.9825e-05, device='cuda:0')
# i=  45001
# error = 0.0013059139277045615
# loss1 = tensor(0.0001, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  45501
# error = 0.0013028909974885298
# loss1 = tensor(9.1949e-05, device='cuda:0')
# loss2 = tensor(0.0001, device='cuda:0')
# i=  46001
# error = 0.00048110415770437305
# loss1 = tensor(8.5712e-05, device='cuda:0')
# loss2 = tensor(5.4119e-05, device='cuda:0')
# i=  46501
# error = 0.0008559728057194359
# loss1 = tensor(8.0131e-05, device='cuda:0')
# loss2 = tensor(3.1871e-05, device='cuda:0')
# i=  47001
# error = 0.000585840254138434
# loss1 = tensor(7.9174e-05, device='cuda:0')
# loss2 = tensor(4.1132e-05, device='cuda:0')
# i=  47501
# error = 0.0013153894654469311
# loss1 = tensor(7.9820e-05, device='cuda:0')
# loss2 = tensor(0.0004, device='cuda:0')
# i=  48001
# error = 0.0018441869207756027
# loss1 = tensor(9.9808e-05, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  48501
# error = 0.0023280673656921012
# loss1 = tensor(7.5664e-05, device='cuda:0')
# loss2 = tensor(0.0002, device='cuda:0')
# i=  49001
# error = 0.004767729675797742
# loss1 = tensor(9.5471e-05, device='cuda:0')
# loss2 = tensor(0.0003, device='cuda:0')
# i=  49501
# error = 0.0014310777161733743
# loss1 = tensor(6.9560e-05, device='cuda:0')
# loss2 = tensor(9.2711e-05, device='cuda:0')
# time cost 2571.71191906929 s

# %%
import matplotlib.pyplot as plt

# %%
index = np.arange(0,50000,10)
plt.plot(np.log10(error_save[index]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-fbcae071b50b> in <module>
#       1 index = np.arange(0,50000,10)
# ----> 2 plt.plot(np.log10(error_save[index]))
#
# IndexError: index 10 is out of bounds for axis 0 with size 2

# %%
def model_u(x):
    return sol_exact_H1(x)[:,0:1]
def model_p(x):
    return sol_exact_H1(x)[:,1:dim_set+1]
