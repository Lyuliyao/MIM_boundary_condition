# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib.ticker as ticker

# %%
error1 = np.load("error_save_LDG_NBC_2D_v2.npy")[0]
error2 = np.load("error_save_LDG_NBC_4D_v2.npy")[0]
error3 = np.load("error_save_LDG_NBC_8D_v2.npy")[0]
error4 = np.load("error_save_LDG_NBC_16D_v2.npy")[0]
error5 = np.load("error_save_LDG_NBC_32D_v2.npy")[0]
error6 = np.load("error_save_LDG_NBC_64D_v2.npy")[0]
error7 = np.load("error_save_LDG_NBC_128D_v2.npy")[0]

# %%
index1 = np.arange(0,np.size(error1),np.size(error1)//100)
index = np.arange(0,np.size(error2),np.size(error2)//100)

fig, ax = plt.subplots(1, 1, figsize=(5,5))
ax.semilogy(index1,error1[index1],label="2D")
ax.semilogy(index,error2[index],label="4D")
ax.semilogy(index,error3[index],label="8D")
ax.semilogy(index,error4[index],label="16D")
ax.semilogy(index,error5[index],label="32D")
ax.semilogy(index,error6[index],label="64D")
ax.semilogy(index,error7[index],label="128D")


ax.legend(fontsize=12,ncol=2)
ax.set_xticks(np.arange(0,np.size(error2)+1,5000))
ax.tick_params(labelsize=20)
plt.ylabel('relative error',fontsize=20)
plt.xlabel('iterations',fontsize=20)
plt.subplots_adjust(left=0.3,right=0.9,top=0.85,bottom=0.25)
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax.xaxis.set_major_formatter(formatter) 
plt.savefig(r"C:\\Users\\lyupi\\Documents\\boundary condition\\JCP\\figure\\Neumann1_1.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
error1 = np.load("error_save_DG_NBC_2D_v2.npy")
error2 = np.load("error_save_DG_NBC_4D_v2.npy")
error3 = np.load("error_save_DG_NBC_8D_v2.npy")
error4 = np.load("error_save_DG_NBC_16D_v2.npy")
error5 = np.load("error_save_DG_NBC_32D_v2.npy")

# %%
index1 = np.arange(0,np.size(error1),np.size(error1)//100)
index = np.arange(0,np.size(error2),np.size(error2)//100)

fig, ax = plt.subplots(1, 1, figsize=(5,5))
ax.semilogy(index1,error1[index1],label="2D")
ax.semilogy(index,error2[index],label="4D")
ax.semilogy(index,error3[index],label="8D")
ax.semilogy(index,error4[index],label="16D")
ax.semilogy(index,error5[index],label="32D")


ax.legend(fontsize=15,ncol=1)
ax.set_xticks(np.arange(0,np.size(error2)+1,5000))
ax.tick_params(labelsize=20)
plt.ylabel('relative error',fontsize=20)
plt.xlabel('iterations',fontsize=20)
plt.subplots_adjust(left=0.3,right=0.9,top=0.85,bottom=0.25)
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax.xaxis.set_major_formatter(formatter) 
plt.savefig(r"C:\\Users\\lyupi\\Documents\\boundary condition\\JCP\\figure\\Neumann1_2.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
error = np.load("error_save_LDG_NBC_2D_v2.npy")
plt.plot(np.log10(error[0]))
np.average(error[0,10000-100:10000])
# Out:
# 2.861260955011952e-05

# %%
error = np.load("error_save_LDG_NBC_4D_v2.npy")
plt.plot(np.log10(error[0]))
np.average(error[0,10000-100:10000])
# Out:
# 0.0006235806704089229

# %%
error = np.load("error_save_LDG_NBC_8D_v2.npy")
plt.plot(np.log10(error[0]))
np.average(error[0,10000-100:10000])
# Out:
# 0.0017021175319452675

# %%
error = np.load("error_save_LDG_NBC_16D_v2.npy")
plt.plot(np.log10(error[0]))
np.average(error[0,10000-100:10000])
# Out:
# 0.0025546264345852696

# %%
error = np.load("error_save_LDG_NBC_32D_v2.npy")
plt.plot(np.log10(error[0]))
np.average(error[0,10000-1000:10000])
# Out:
# 0.0030803968871092754

# %%
error = np.load("error_save_LDG_NBC_64D_v2.npy")
plt.plot(np.log10(error[0]))
np.average(error[0,10000-100:10000])
# Out:
# 0.0024367015473196517

# %%
error = np.load("error_save_LDG_NBC_128D_v2.npy")
plt.plot(np.log10(error[0]))
np.average(error[0,10000-100:10000])
# Out:
# 0.003611858956812752
