# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib.ticker as ticker

# %%
error1 = np.load("error_save_Neumann_MIM_s_2D_w10.npy")
error2 = np.load("error_save_Neumann_MIM_s_4D_w15.npy")
error3 = np.load("error_save_Neumann_MIM_s_8D_w20.npy")
error4 = np.load("error_save_Neumann_MIM_s_16D_w25.npy")

# %%
index1 = np.arange(0,np.size(error1),np.size(error1)//100)
index = np.arange(0,np.size(error2),np.size(error2)//100)

fig, ax = plt.subplots(1, 1, figsize=(5,5))
ax.semilogy(index1,error1[index1],label="2D")
ax.semilogy(index,error2[index],label="4D")
ax.semilogy(index,error3[index],label="8D")
ax.semilogy(index,error4[index],label="16D")
ax.legend(fontsize=12)
ax.set_xticks(np.arange(0,np.size(error2)+1,20000))
ax.tick_params(labelsize=20)
plt.ylabel('relative error',fontsize=20)
plt.xlabel('iterations',fontsize=20)
plt.subplots_adjust(left=0.3,right=0.9,top=0.85,bottom=0.25)
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax.xaxis.set_major_formatter(formatter) 
plt.savefig(r"C:\\Users\\lyupi\\Documents\\boundary condition\\JCP\\figure\\Neumann12_1.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
error1 = np.load("error_save_Neumann_s_2D_w10.npy")
error2 = np.load("error_save_Neumann_s_4D_w15.npy")
error3 = np.load("error_save_Neumann_s_8D_w20.npy")
error4 = np.load("error_save_Neumann_s_16D_w25.npy")

# %%
index1 = np.arange(0,np.size(error1),np.size(error1)//100)
index = np.arange(0,np.size(error2),np.size(error2)//100)

fig, ax = plt.subplots(1, 1, figsize=(5,5))
ax.semilogy(index1,error1[index1],label="2D")
ax.semilogy(index,error2[index],label="4D")
ax.semilogy(index,error3[index],label="8D")
ax.semilogy(index,error4[index],label="16D")
ax.legend(fontsize=12)
ax.set_xticks(np.arange(0,np.size(error2)+1,20000))
ax.tick_params(labelsize=20)
plt.ylabel('relative error',fontsize=20)
plt.xlabel('iterations',fontsize=20)
plt.subplots_adjust(left=0.3,right=0.9,top=0.85,bottom=0.25)
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax.xaxis.set_major_formatter(formatter) 
plt.savefig(r"C:\\Users\\lyupi\\Documents\\boundary condition\\JCP\\figure\\Neumann12_2.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
error1 = np.load("error_save_Neumann_s_2D_w10.npy")
error2 = np.load("error_save_Neumann_MIM_s_2D_w10.npy")

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))

print(np.average(error1[100000-1000:100000]))
print(np.average(error2[100000-1000:100000]))
# Out:
# 0.001015607780981854
# 0.0005193337265701399

# %%
error1 = np.load("error_save_Neumann_s_4D_w15.npy")
error2 = np.load("error_save_Neumann_MIM_s_4D_w15.npy")

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))

print(np.average(error1[100000-1000:100000]))
print(np.average(error2[100000-1000:100000]))
# Out:
# 0.0006530945624036436
# 0.0003608895963120994

# %%
error1 = np.load("error_save_Neumann_s_8D_w20.npy")
error2 = np.load("error_save_Neumann_MIM_s_8D_w20.npy")

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))

print(np.average(error1[100000-1000:100000]))
print(np.average(error2[100000-1000:100000]))
# Out:
# 0.006004352865093123
# 0.0005847573150604717

# %%
error1 = np.load("error_save_Neumann_s_16D_w25.npy")
error2 = np.load("error_save_Neumann_MIM_s_16D_w25.npy")

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))

print(np.average(error1[100000-1000:100000]))
print(np.average(error2[100000-1000:100000]))
# Out:
# 0.00997273086526836
# 0.0011433163396029611
