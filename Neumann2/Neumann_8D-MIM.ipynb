# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(7)

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
    
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)

        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s
        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        output = self.outlayer(y)
        return output
deg = 2

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
def generate_uniform_points_in_sphere(d,R,N):
    points = torch.randn(N,d)
    scales = (R*torch.rand(N))**(1/d)
    notes = points/(torch.sqrt(torch.sum(points**2,dim=1))/scales).reshape(N,1)*torch.ones(N ,d)
    return notes

# %%
def sol_exact(x):
    norm_2 = torch.sum(x**2,dim=1).reshape([x.size()[0],1])
    N_u = torch.cos(norm_2-1)
    return N_u

# %%
def right(x):
    norm_2 = torch.sum(x**2,dim=1).reshape([x.size()[0],1])
    N_u = 2*dim_set*torch.sin(1-norm_2)
    N_u = N_u - 4*norm_2*torch.cos(1-norm_2)
    return N_u

# %%
Batch_size = 10000
dim_set = 8
def DGM():
    x = generate_uniform_points_in_sphere(dim_set,1,Batch_size).cuda()
    x.requires_grad = True
    u = model_u(x)
    du = model_p(x)
    v= torch.ones(u.shape).cuda()
    ux = torch.autograd.grad(u,x,grad_outputs=v,create_graph=True)[0]
    loss = torch.sum((ux-du)**2)/Batch_size
    uxx = torch.zeros(Batch_size,dim_set).cuda()
    for i in range(dim_set):
        ux_tem = du[:,i].reshape([x.size()[0],1])
        uxx_tem = torch.autograd.grad(ux_tem,x,grad_outputs=v,create_graph=True)[0]
        uxx[:,i] = uxx_tem[:,i]
    loss = loss + torch.sum((torch.sum(uxx,dim=1).reshape([x.size()[0],1])+ u - sol_exact(x)  - right(x))**2)/Batch_size
    return loss

# %%
model_u = ResNet(dim_set,20,1)
model_p1 = ResNet(dim_set,20,dim_set)

device=torch.device("cuda:7" )
model_u.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=8, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=20, bias=True)
#   (fc3): Linear(in_features=20, out_features=20, bias=True)
#   (fc4): Linear(in_features=20, out_features=20, bias=True)
#   (fc5): Linear(in_features=20, out_features=20, bias=True)
#   (fc6): Linear(in_features=20, out_features=20, bias=True)
#   (outlayer): Linear(in_features=20, out_features=8, bias=True)
# )

# %%
def model_p(x):
    x.requires_grad = True
    Np_x = model_p1(x)
    N_v = x
    G = -torch.sum(Np_x*N_v,dim=1).reshape([x.size()[0],1])/2
    norm_2 = torch.sum(x**2,dim=1).reshape([x.size()[0],1])
    L_N = norm_2-1
    v= torch.ones(L_N.shape).cuda()
    nabla_L_N = torch.autograd.grad(L_N,x,grad_outputs=v,create_graph=True)[0]
    return nabla_L_N*G + Np_x

# %%
def loss_error():
    notes_error = generate_uniform_points_in_sphere(dim_set,1,Batch_size).cuda()
    notes_error.requires_grad= True
    exact = sol_exact(notes_error)
    u_L2 = torch.sqrt(torch.sum(exact**2)/10000)
    predict= model_u(notes_error)
    value = torch.sqrt(torch.sum((predict[:,0] - exact[:,0])**2)/10000)/u_L2
    return value

# %%
traintime = 100000
error_save=np.zeros([traintime])
optimizer = optim.Adam([
                {'params': model_u.parameters()},
                {'params': model_p1.parameters()}
            ])
i = 0
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = DGM()
    error = loss_error()
    losses.backward()
    optimizer.step() 
    error_save[i]=float(error)
    i = i +1
    #scheduler.step()
    if i%500==1:
        print("i= ",i)
        print("error =",error)
        print("loss1 =",losses.detach())
        np.save("error_save_Neumann_MIM_s_8D_w20.npy", error_save)
np.save("error_save_Neumann_MIM_s_8D_w20.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = tensor(1.0510, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(13.8709, device='cuda:7')
# i=  501
# error = tensor(0.0269, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0751, device='cuda:7')
# i=  1001
# error = tensor(0.0066, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0109, device='cuda:7')
# i=  1501
# error = tensor(0.0031, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0063, device='cuda:7')
# i=  2001
# error = tensor(0.0025, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0058, device='cuda:7')
# i=  2501
# error = tensor(0.0018, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0051, device='cuda:7')
# i=  3001
# error = tensor(0.0016, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0043, device='cuda:7')
# i=  3501
# error = tensor(0.0018, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0037, device='cuda:7')
# i=  4001
# error = tensor(0.0013, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0041, device='cuda:7')
# i=  4501
# error = tensor(0.0013, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0033, device='cuda:7')
# i=  5001
# error = tensor(0.0013, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0031, device='cuda:7')
# i=  5501
# error = tensor(0.0012, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0060, device='cuda:7')
# i=  6001
# error = tensor(0.0015, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0160, device='cuda:7')
# i=  6501
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0028, device='cuda:7')
# i=  7001
# error = tensor(0.0014, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0049, device='cuda:7')
# i=  7501
# error = tensor(0.0009, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0027, device='cuda:7')
# i=  8001
# error = tensor(0.0011, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0040, device='cuda:7')
# i=  8501
# error = tensor(0.0011, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0032, device='cuda:7')
# i=  9001
# error = tensor(0.0011, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0035, device='cuda:7')
# i=  9501
# error = tensor(0.0009, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0026, device='cuda:7')
# i=  10001
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0030, device='cuda:7')
# i=  10501
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0034, device='cuda:7')
# i=  11001
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0035, device='cuda:7')
# i=  11501
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0021, device='cuda:7')
# i=  12001
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0021, device='cuda:7')
# i=  12501
# error = tensor(0.0014, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0031, device='cuda:7')
# i=  13001
# error = tensor(0.0011, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0025, device='cuda:7')
# i=  13501
# error = tensor(0.0011, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0028, device='cuda:7')
# i=  14001
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0023, device='cuda:7')
# i=  14501
# error = tensor(0.0015, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0044, device='cuda:7')
# i=  15001
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0025, device='cuda:7')
# i=  15501
# error = tensor(0.0009, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0029, device='cuda:7')
# i=  16001
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0023, device='cuda:7')
# i=  16501
# error = tensor(0.0014, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0029, device='cuda:7')
# i=  17001
# error = tensor(0.0009, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0027, device='cuda:7')
# i=  17501
# error = tensor(0.0011, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0028, device='cuda:7')
# i=  18001
# error = tensor(0.0012, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0021, device='cuda:7')
# i=  18501
# error = tensor(0.0011, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0019, device='cuda:7')
# i=  19001
# error = tensor(0.0020, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0021, device='cuda:7')
# i=  19501
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0021, device='cuda:7')
# i=  20001
# error = tensor(0.0012, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0020, device='cuda:7')
# i=  20501
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0022, device='cuda:7')
# i=  21001
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0029, device='cuda:7')
# i=  21501
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0021, device='cuda:7')
# i=  22001
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0023, device='cuda:7')
# i=  22501
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0027, device='cuda:7')
# i=  23001
# error = tensor(0.0009, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0018, device='cuda:7')
# i=  23501
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0033, device='cuda:7')
# i=  24001
# error = tensor(0.0011, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0025, device='cuda:7')
# i=  24501
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0024, device='cuda:7')
# i=  25001
# error = tensor(0.0009, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0023, device='cuda:7')
# i=  25501
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0034, device='cuda:7')
# i=  26001
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0033, device='cuda:7')
# i=  26501
# error = tensor(0.0013, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0033, device='cuda:7')
# i=  27001
# error = tensor(0.0015, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0026, device='cuda:7')
# i=  27501
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0018, device='cuda:7')
# i=  28001
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0023, device='cuda:7')
# i=  28501
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0031, device='cuda:7')
# i=  29001
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0015, device='cuda:7')
# i=  29501
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0022, device='cuda:7')
# i=  30001
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0019, device='cuda:7')
# i=  30501
# error = tensor(0.0013, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0018, device='cuda:7')
# i=  31001
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0019, device='cuda:7')
# i=  31501
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0020, device='cuda:7')
# i=  32001
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0020, device='cuda:7')
# i=  32501
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0034, device='cuda:7')
# i=  33001
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0023, device='cuda:7')
# i=  33501
# error = tensor(0.0009, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0018, device='cuda:7')
# i=  34001
# error = tensor(0.0012, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0018, device='cuda:7')
# i=  34501
# error = tensor(0.0013, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0018, device='cuda:7')
# i=  35001
# error = tensor(0.0009, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0027, device='cuda:7')
# i=  35501
# error = tensor(0.0014, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0015, device='cuda:7')
# i=  36001
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0023, device='cuda:7')
# i=  36501
# error = tensor(0.0014, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0030, device='cuda:7')
# i=  37001
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0026, device='cuda:7')
# i=  37501
# error = tensor(0.0012, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0017, device='cuda:7')
# i=  38001
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0015, device='cuda:7')
# i=  38501
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0016, device='cuda:7')
# i=  39001
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0019, device='cuda:7')
# i=  39501
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0017, device='cuda:7')
# i=  40001
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0015, device='cuda:7')
# i=  40501
# error = tensor(0.0013, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0021, device='cuda:7')
# i=  41001
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0016, device='cuda:7')
# i=  41501
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0018, device='cuda:7')
# i=  42001
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0027, device='cuda:7')
# i=  42501
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0016, device='cuda:7')
# i=  43001
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0011, device='cuda:7')
# i=  43501
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0018, device='cuda:7')
# i=  44001
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0011, device='cuda:7')
# i=  44501
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0014, device='cuda:7')
# i=  45001
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0012, device='cuda:7')
# i=  45501
# error = tensor(0.0012, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0016, device='cuda:7')
# i=  46001
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0015, device='cuda:7')
# i=  46501
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0011, device='cuda:7')
# i=  47001
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0020, device='cuda:7')
# i=  47501
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0012, device='cuda:7')
# i=  48001
# error = tensor(0.0012, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0014, device='cuda:7')
# i=  48501
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0015, device='cuda:7')
# i=  49001
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0011, device='cuda:7')
# i=  49501
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0011, device='cuda:7')
# i=  50001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0009, device='cuda:7')
# i=  50501
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0008, device='cuda:7')
# i=  51001
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0009, device='cuda:7')
# i=  51501
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0008, device='cuda:7')
# i=  52001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0009, device='cuda:7')
# i=  52501
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0007, device='cuda:7')
# i=  53001
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0013, device='cuda:7')
# i=  53501
# error = tensor(0.0012, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0010, device='cuda:7')
# i=  54001
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0008, device='cuda:7')
# i=  54501
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0012, device='cuda:7')
# i=  55001
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0015, device='cuda:7')
# i=  55501
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0010, device='cuda:7')
# i=  56001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0006, device='cuda:7')
# i=  56501
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0008, device='cuda:7')
# i=  57001
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0021, device='cuda:7')
# i=  57501
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0010, device='cuda:7')
# i=  58001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0009, device='cuda:7')
# i=  58501
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0009, device='cuda:7')
# i=  59001
# error = tensor(0.0009, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0009, device='cuda:7')
# i=  59501
# error = tensor(0.0022, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0020, device='cuda:7')
# i=  60001
# error = tensor(0.0018, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0009, device='cuda:7')
# i=  60501
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0012, device='cuda:7')
# i=  61001
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0006, device='cuda:7')
# i=  61501
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  62001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0007, device='cuda:7')
# i=  62501
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  63001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0006, device='cuda:7')
# i=  63501
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  64001
# error = tensor(0.0011, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0019, device='cuda:7')
# i=  64501
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  65001
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0014, device='cuda:7')
# i=  65501
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  66001
# error = tensor(0.0010, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  66501
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0006, device='cuda:7')
# i=  67001
# error = tensor(0.0015, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0017, device='cuda:7')
# i=  67501
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  68001
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0006, device='cuda:7')
# i=  68501
# error = tensor(0.0011, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0010, device='cuda:7')
# i=  69001
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0007, device='cuda:7')
# i=  69501
# error = tensor(0.0011, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0007, device='cuda:7')
# i=  70001
# error = tensor(0.0016, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0008, device='cuda:7')
# i=  70501
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0006, device='cuda:7')
# i=  71001
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  71501
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  72001
# error = tensor(0.0014, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  72501
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0007, device='cuda:7')
# i=  73001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  73501
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0010, device='cuda:7')
# i=  74001
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  74501
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0007, device='cuda:7')
# i=  75001
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0003, device='cuda:7')
# i=  75501
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  76001
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  76501
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0007, device='cuda:7')
# i=  77001
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0009, device='cuda:7')
# i=  77501
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0011, device='cuda:7')
# i=  78001
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0007, device='cuda:7')
# i=  78501
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0008, device='cuda:7')
# i=  79001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  79501
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0014, device='cuda:7')
# i=  80001
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  80501
# error = tensor(0.0013, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0009, device='cuda:7')
# i=  81001
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  81501
# error = tensor(0.0011, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0007, device='cuda:7')
# i=  82001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0008, device='cuda:7')
# i=  82501
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  83001
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0015, device='cuda:7')
# i=  83501
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  84001
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  84501
# error = tensor(0.0012, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0013, device='cuda:7')
# i=  85001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  85501
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  86001
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  86501
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  87001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0003, device='cuda:7')
# i=  87501
# error = tensor(0.0009, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0016, device='cuda:7')
# i=  88001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0006, device='cuda:7')
# i=  88501
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0006, device='cuda:7')
# i=  89001
# error = tensor(0.0007, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0012, device='cuda:7')
# i=  89501
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0003, device='cuda:7')
# i=  90001
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  90501
# error = tensor(0.0006, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0007, device='cuda:7')
# i=  91001
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0006, device='cuda:7')
# i=  91501
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  92001
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0003, device='cuda:7')
# i=  92501
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  93001
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  93501
# error = tensor(0.0009, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0008, device='cuda:7')
# i=  94001
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  94501
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0009, device='cuda:7')
# i=  95001
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0008, device='cuda:7')
# i=  95501
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0009, device='cuda:7')
# i=  96001
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  96501
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0003, device='cuda:7')
# i=  97001
# error = tensor(0.0014, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0023, device='cuda:7')
# i=  97501
# error = tensor(0.0012, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# i=  98001
# error = tensor(0.0008, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0006, device='cuda:7')
# i=  98501
# error = tensor(0.0005, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  99001
# error = tensor(0.0003, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0004, device='cuda:7')
# i=  99501
# error = tensor(0.0004, device='cuda:7', grad_fn=<DivBackward0>)
# loss1 = tensor(0.0005, device='cuda:7')
# time cost 13696.722294330597 s
