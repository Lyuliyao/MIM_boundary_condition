# %% [markdown]
# ### Numerical example
# ### Consider the following problem over $\Omega = {(-1, 1)}^d$:
# ### $$-\Delta u + \pi^2 u = f,$$
# ### with periodic condition
# ### $$ u(x_1 + p_1,\cdots,x_{k} + p_k,\cdots,x_d + p_d) = u(x_1,\cdots,x_{k},\cdots,x_d) $$
# ### Assume $u(x) = \sum_{i = 1}^d \cos(\pi x_i) + \cos(2 \pi x_i) $, we can get $f(x)$ and $p_1 = \cdots = p_d = 2$.
# ### Network structure
# ### construct a transform $x^{\prime} = \text{transform} (x)$ before the first fully connected layer of our neural network
# ### $$x = (x_1,\cdots,x_d) \in R^d \Rightarrow x^{\prime} \in R^{2d}$$
# ### where $x^{\prime}_{2i - 1} = \sin(2\pi x_i / p_i)$ and $x^{\prime}_{2i} = \cos(2\pi x_i / p_i)$ for $i = 1, 2, \cdots, d$.

# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import matplotlib.pyplot as plt
from math import *
import time

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
# activation function
def activation(x):
    return x * torch.sigmoid(x)

# %%
def transform(x):
    x_transform = torch.zeros(len(x), 2*d)
    for index in range(d):
        x_transform[:, 2*index] = torch.sin(2*pi*x[:, index] / 2)
        x_transform[:, 2*index+1] = torch.cos(2*pi*x[:, index] / 2)
    return x_transform

# %%
# exact solution
def u_ex(x):  
#     x_temp_1 = torch.cos(pi*x)
#     u_temp_1 = (x_temp_1.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) # summation by row for x_temp
#     x_temp_2 = torch.cos(2*pi*x)
#     u_temp_2 = (x_temp_2.sum(1)).reshape([x.size()[0], 1]) 
#     x_temp_3 = torch.cos(4*pi*x)
#     u_temp_3 = (x_temp_3.sum(1)).reshape([x.size()[0], 1]) 
#     x_temp_4 = torch.cos(8*pi*x)
#     u_temp_4 = (x_temp_4.sum(1)).reshape([x.size()[0], 1]) 
#     u_temp = u_temp_1 + u_temp_2 + u_temp_3 + u_temp_4
    
    x_temp_1 = torch.cos(pi*x)
    u_temp_1 = (x_temp_1.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) # summation by row for x_temp
    x_temp_2 = torch.cos(2*pi*x)
    u_temp_2 = (x_temp_2.sum(1)).reshape([x.size()[0], 1]) 
   
    u_temp = u_temp_1 + u_temp_2 
    return u_temp

# %%
def f(x):
#     x_temp_1 = torch.cos(pi*x)
#     f_temp_1 = pi**2 * (x_temp_1.sum(1)).reshape([x.size()[0], 1]) 
#     x_temp_2 = torch.cos(2*pi*x)
#     f_temp_2 = (2*pi)**2 * (x_temp_2.sum(1)).reshape([x.size()[0], 1]) 
#     x_temp_3 = torch.cos(4*pi*x)
#     f_temp_3 = (4*pi)**2 * (x_temp_3.sum(1)).reshape([x.size()[0], 1]) 
#     x_temp_4 = torch.cos(8*pi*x)
#     f_temp_4 = (8*pi)**2 * (x_temp_4.sum(1)).reshape([x.size()[0], 1]) 
#     f_temp = f_temp_1 + f_temp_2 + f_temp_3 + f_temp_4 + pi**2 * u_ex(x)
    
    x_temp_1 = torch.cos(pi*x)
    f_temp_1 = pi**2 * (x_temp_1.sum(1)).reshape([x.size()[0], 1]) 
    x_temp_2 = torch.cos(2*pi*x)
    f_temp_2 = (2*pi)**2 * (x_temp_2.sum(1)).reshape([x.size()[0], 1]) 
    f_temp = f_temp_1 + f_temp_2 + pi**2 * u_ex(x)
    return f_temp

# %%
# build ResNet with three blocks
class Net(nn.Module):
    def __init__(self,input_size,width,output_size):
        super(Net,self).__init__()
        self.layer_in = nn.Linear(input_size,width)
        self.layer_1 = nn.Linear(width,width)
        self.layer_2 = nn.Linear(width,width)
        self.layer_3 = nn.Linear(width,width)
        self.layer_4 = nn.Linear(width,width)
        self.layer_5 = nn.Linear(width,width)
        self.layer_6 = nn.Linear(width,width)
        self.layer_out = nn.Linear(width,output_size)
    def forward(self,x):
        output = self.layer_in(transform(x)) # transform for periodic
        output = output + activation(self.layer_2(activation(self.layer_1(output)))) # residual block 1
        output = output + activation(self.layer_4(activation(self.layer_3(output)))) # residual block 2
        output = output + activation(self.layer_6(activation(self.layer_5(output)))) # residual block 3
        output = self.layer_out(output)
        return output

# %%
d = 2 # dimension of input
input_size = d * 2
width_1 = 8
width_2 = 8
output_size_1 = 1
output_size_2 = d
data_size = 1000

# %%
CUDA = torch.cuda.is_available()
# print('CUDA is: ', CUDA)
if CUDA:
    net_1 = Net(input_size, width_1, output_size_1).cuda() # network for u on gpu
    net_2 = Net(input_size, width_2, output_size_2).cuda() # network for grad u on gpu
else:
    net_1 = Net(input_size, width_1, output_size_1) # network for u on cpu
    net_2 = Net(input_size, width_2, output_size_2) # network for grad u on cpu

# %%
def generate_sample(data_size_temp):
    sample_temp = 2.0 * torch.rand(data_size_temp, d) - 1.0
    return sample_temp

# %%
def relative_l2_error():
    data_size_temp = 500
    x = generate_sample(data_size_temp) # cuda
    predict = net_1(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact)**2))/torch.sqrt(torch.sum((exact)**2))
    return value

# %%
# Xavier normal initialization for weights:
#             mean = 0 std = gain * sqrt(2 / fan_in + fan_out)
# zero initialization for biases
def initialize_weights(self):
    for m in self.modules():
        if isinstance(m,nn.Linear):
            nn.init.xavier_normal_(m.weight.data)
            if m.bias is not None:
                m.bias.data.zero_()

# %%
initialize_weights(net_1)
initialize_weights(net_2)

# %%
# number of net_1 and net_2
param_num_1 = sum(x.numel() for x in net_1.parameters())
param_num_2 = sum(x.numel() for x in net_2.parameters())
# print(param_num_1)
# print(param_num_2)

# %%
def loss_function(x):
#     x = generate_sample(data_size)
#     x.requires_grad = True
    u_hat = net_1(x)
    grad_u_hat = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = torch.ones(u_hat.shape), create_graph = True)
    p_hat = net_2(x)
    part_1 = torch.sum((grad_u_hat[0] - p_hat)**2) / len(x)
    laplace_u = torch.zeros([len(p_hat), 1])
    for index in range(d):
        p_temp = p_hat[:, index].reshape([len(p_hat), 1])
        temp = torch.autograd.grad(outputs = p_temp, inputs = x, grad_outputs = torch.ones(p_temp.shape), create_graph = True, allow_unused = True)[0]
        laplace_u = temp[:, index].reshape([len(p_hat), 1]) + laplace_u
    part_2 = torch.sum((-laplace_u + pi**2 * u_hat - f(x))**2)  / len(x)
    return part_1 + part_2

# %%
optimizer = optim.Adam([
                {'params': net_1.parameters()},
                {'params': net_2.parameters()},
            ])

# %%
epoch = 20000
loss_record = np.zeros(epoch)
error_record = np.zeros(epoch)
time_start = time.time()
for i in range(epoch):
    optimizer.zero_grad()
    x = generate_sample(data_size) # cuda
    x.requires_grad = True
    loss = loss_function(x)
    loss_record[i] = float(loss)
    error = relative_l2_error()
    error_record[i] = float(error)
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", loss.detach())
        print("current error is: ", error.detach())
    loss.backward()
    optimizer.step() 
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(2514.0347)
# current error is:  tensor(0.7671)
# current epoch is:  50
# current loss is:  tensor(2269.8381)
# current error is:  tensor(0.8121)
# current epoch is:  100
# current loss is:  tensor(1506.9640)
# current error is:  tensor(1.0614)
# current epoch is:  150
# current loss is:  tensor(768.5473)
# current error is:  tensor(1.1566)
# current epoch is:  200
# current loss is:  tensor(287.2739)
# current error is:  tensor(0.8885)
# current epoch is:  250
# current loss is:  tensor(141.5396)
# current error is:  tensor(0.6352)
# current epoch is:  300
# current loss is:  tensor(67.9022)
# current error is:  tensor(0.4318)
# current epoch is:  350
# current loss is:  tensor(37.3923)
# current error is:  tensor(0.3133)
# current epoch is:  400
# current loss is:  tensor(25.5020)
# current error is:  tensor(0.2301)
# current epoch is:  450
# current loss is:  tensor(19.0528)
# current error is:  tensor(0.1934)
# current epoch is:  500
# current loss is:  tensor(15.2866)
# current error is:  tensor(0.1788)
# current epoch is:  550
# current loss is:  tensor(11.6536)
# current error is:  tensor(0.1636)
# current epoch is:  600
# current loss is:  tensor(9.5774)
# current error is:  tensor(0.1413)
# current epoch is:  650
# current loss is:  tensor(8.2865)
# current error is:  tensor(0.1352)
# current epoch is:  700
# current loss is:  tensor(7.0382)
# current error is:  tensor(0.1218)
# current epoch is:  750
# current loss is:  tensor(6.3824)
# current error is:  tensor(0.1093)
# current epoch is:  800
# current loss is:  tensor(5.2335)
# current error is:  tensor(0.1014)
# current epoch is:  850
# current loss is:  tensor(4.5504)
# current error is:  tensor(0.0829)
# current epoch is:  900
# current loss is:  tensor(3.7881)
# current error is:  tensor(0.0751)
# current epoch is:  950
# current loss is:  tensor(3.5507)
# current error is:  tensor(0.0726)
# current epoch is:  1000
# current loss is:  tensor(3.3433)
# current error is:  tensor(0.0773)
# current epoch is:  1050
# current loss is:  tensor(2.8932)
# current error is:  tensor(0.0636)
# current epoch is:  1100
# current loss is:  tensor(2.6947)
# current error is:  tensor(0.0631)
# current epoch is:  1150
# current loss is:  tensor(2.3676)
# current error is:  tensor(0.0603)
# current epoch is:  1200
# current loss is:  tensor(2.3670)
# current error is:  tensor(0.0546)
# current epoch is:  1250
# current loss is:  tensor(2.1526)
# current error is:  tensor(0.0583)
# current epoch is:  1300
# current loss is:  tensor(2.0416)
# current error is:  tensor(0.0574)
# current epoch is:  1350
# current loss is:  tensor(1.7669)
# current error is:  tensor(0.0540)
# current epoch is:  1400
# current loss is:  tensor(1.7136)
# current error is:  tensor(0.0475)
# current epoch is:  1450
# current loss is:  tensor(1.6075)
# current error is:  tensor(0.0480)
# current epoch is:  1500
# current loss is:  tensor(1.5560)
# current error is:  tensor(0.0431)
# current epoch is:  1550
# current loss is:  tensor(1.4484)
# current error is:  tensor(0.0408)
# current epoch is:  1600
# current loss is:  tensor(1.2991)
# current error is:  tensor(0.0410)
# current epoch is:  1650
# current loss is:  tensor(1.3041)
# current error is:  tensor(0.0371)
# current epoch is:  1700
# current loss is:  tensor(1.2589)
# current error is:  tensor(0.0401)
# current epoch is:  1750
# current loss is:  tensor(1.1812)
# current error is:  tensor(0.0361)
# current epoch is:  1800
# current loss is:  tensor(1.1493)
# current error is:  tensor(0.0362)
# current epoch is:  1850
# current loss is:  tensor(1.0482)
# current error is:  tensor(0.0354)
# current epoch is:  1900
# current loss is:  tensor(0.9980)
# current error is:  tensor(0.0317)
# current epoch is:  1950
# current loss is:  tensor(0.9797)
# current error is:  tensor(0.0315)
# current epoch is:  2000
# current loss is:  tensor(0.8638)
# current error is:  tensor(0.0313)
# current epoch is:  2050
# current loss is:  tensor(0.8972)
# current error is:  tensor(0.0329)
# current epoch is:  2100
# current loss is:  tensor(0.8380)
# current error is:  tensor(0.0291)
# current loss is:  tensor(0.0965)
# current error is:  tensor(0.0074)
# current epoch is:  5750
# current loss is:  tensor(0.1035)
# current error is:  tensor(0.0077)
# current epoch is:  5800
# current loss is:  tensor(0.1012)
# current error is:  tensor(0.0081)
# current epoch is:  5850
# current loss is:  tensor(0.0889)
# current error is:  tensor(0.0079)
# current epoch is:  5900
# current loss is:  tensor(0.0839)
# current error is:  tensor(0.0069)
# current epoch is:  5950
# current loss is:  tensor(0.0845)
# current error is:  tensor(0.0072)
# current epoch is:  6000
# current loss is:  tensor(0.0859)
# current error is:  tensor(0.0073)
# current epoch is:  6050
# current loss is:  tensor(0.0853)
# current error is:  tensor(0.0065)
# current epoch is:  6100
# current loss is:  tensor(0.0767)
# current error is:  tensor(0.0072)
# current epoch is:  6150
# current loss is:  tensor(0.0735)
# current error is:  tensor(0.0072)
# current epoch is:  6200
# current loss is:  tensor(0.0764)
# current error is:  tensor(0.0062)
# current epoch is:  6250
# current loss is:  tensor(0.0777)
# current error is:  tensor(0.0068)
# current epoch is:  6300
# current loss is:  tensor(0.0704)
# current error is:  tensor(0.0070)
# current epoch is:  6350
# current loss is:  tensor(0.0753)
# current error is:  tensor(0.0081)
# current epoch is:  6400
# current loss is:  tensor(0.0704)
# current error is:  tensor(0.0066)
# current epoch is:  6450
# current loss is:  tensor(0.0665)
# current error is:  tensor(0.0061)
# current epoch is:  6500
# current loss is:  tensor(0.0638)
# current error is:  tensor(0.0059)
# current epoch is:  6550
# current loss is:  tensor(0.0612)
# current error is:  tensor(0.0059)
# current epoch is:  6600
# current loss is:  tensor(0.0603)
# current error is:  tensor(0.0064)
# current epoch is:  6650
# current loss is:  tensor(0.0639)
# current error is:  tensor(0.0064)
# current epoch is:  6700
# current loss is:  tensor(0.0736)
# current error is:  tensor(0.0086)
# current epoch is:  6750
# current loss is:  tensor(0.0574)
# current error is:  tensor(0.0060)
# current epoch is:  6800
# current loss is:  tensor(0.0610)
# current error is:  tensor(0.0057)
# current epoch is:  6850
# current loss is:  tensor(0.0595)
# current error is:  tensor(0.0057)
# current epoch is:  6900
# current loss is:  tensor(0.0559)
# current error is:  tensor(0.0056)
# current epoch is:  6950
# current loss is:  tensor(0.0538)
# current error is:  tensor(0.0056)
# current epoch is:  7000
# current loss is:  tensor(0.0529)
# current error is:  tensor(0.0052)
# current epoch is:  7050
# current loss is:  tensor(0.0508)
# current error is:  tensor(0.0054)
# current epoch is:  7100
# current loss is:  tensor(0.0507)
# current error is:  tensor(0.0060)
# current epoch is:  7150
# current loss is:  tensor(0.0522)
# current error is:  tensor(0.0054)
# current epoch is:  7200
# current loss is:  tensor(0.0487)
# current error is:  tensor(0.0053)
# current epoch is:  7250
# current loss is:  tensor(0.0476)
# current error is:  tensor(0.0051)
# current epoch is:  7300
# current loss is:  tensor(0.0646)
# current error is:  tensor(0.0089)
# current epoch is:  7350
# current loss is:  tensor(0.0459)
# current error is:  tensor(0.0045)
# current epoch is:  7400
# current loss is:  tensor(0.0437)
# current error is:  tensor(0.0049)
# current epoch is:  7450
# current loss is:  tensor(0.0507)
# current error is:  tensor(0.0047)
# current epoch is:  7500
# current loss is:  tensor(0.0434)
# current error is:  tensor(0.0047)
# current epoch is:  7550
# current loss is:  tensor(0.0394)
# current error is:  tensor(0.0048)
# current epoch is:  7600
# current loss is:  tensor(0.0505)
# current error is:  tensor(0.0074)
# current epoch is:  7650
# current loss is:  tensor(0.0383)
# current error is:  tensor(0.0046)
# current epoch is:  7700
# current loss is:  tensor(0.0451)
# current error is:  tensor(0.0054)
# current epoch is:  7750
# current loss is:  tensor(0.0426)
# current error is:  tensor(0.0049)
# current epoch is:  7800
# current loss is:  tensor(0.0386)
# current error is:  tensor(0.0041)
# current epoch is:  7850
# current loss is:  tensor(0.0367)
# current error is:  tensor(0.0045)
# current epoch is:  7900
# current loss is:  tensor(0.0393)
# current error is:  tensor(0.0049)
# current epoch is:  7950
# current loss is:  tensor(0.0347)
# current error is:  tensor(0.0045)
# current epoch is:  8000
# current loss is:  tensor(0.0361)
# current error is:  tensor(0.0041)
# current epoch is:  8050
# current loss is:  tensor(0.0363)
# current error is:  tensor(0.0045)
# current epoch is:  8100
# current loss is:  tensor(0.0398)
# current error is:  tensor(0.0037)
# current epoch is:  8150
# current loss is:  tensor(0.0336)
# current error is:  tensor(0.0039)
# current epoch is:  8200
# current loss is:  tensor(0.0357)
# current error is:  tensor(0.0053)
# current epoch is:  8250
# current loss is:  tensor(0.0322)
# current error is:  tensor(0.0038)
# current epoch is:  8300
# current loss is:  tensor(0.0311)
# current error is:  tensor(0.0043)
# current epoch is:  8350
# current loss is:  tensor(0.0325)
# current error is:  tensor(0.0042)
# current epoch is:  8400
# current loss is:  tensor(0.0308)
# current error is:  tensor(0.0038)
# current epoch is:  8450
# current loss is:  tensor(0.0298)
# current error is:  tensor(0.0037)
# current epoch is:  8500
# current loss is:  tensor(0.0295)
# current error is:  tensor(0.0039)
# current epoch is:  8550
# current loss is:  tensor(0.0305)
# current error is:  tensor(0.0042)
# current epoch is:  8600
# current loss is:  tensor(0.0397)
# current error is:  tensor(0.0058)
# current epoch is:  8650
# current loss is:  tensor(0.0363)
# current error is:  tensor(0.0048)
# current epoch is:  8700
# current loss is:  tensor(0.0526)
# current error is:  tensor(0.0068)
# current epoch is:  8750
# current loss is:  tensor(0.0290)
# current error is:  tensor(0.0038)
# current epoch is:  8800
# current loss is:  tensor(0.0279)
# current error is:  tensor(0.0038)
# current epoch is:  8850
# current loss is:  tensor(0.0267)
# current error is:  tensor(0.0039)
# current epoch is:  8900
# current loss is:  tensor(0.0430)
# current error is:  tensor(0.0048)
# current epoch is:  8950
# current loss is:  tensor(0.0330)
# current error is:  tensor(0.0058)
# current epoch is:  9000
# current loss is:  tensor(0.0384)
# current error is:  tensor(0.0079)
# current epoch is:  9050
# current loss is:  tensor(0.0279)
# current error is:  tensor(0.0044)
# current epoch is:  9100
# current loss is:  tensor(0.0267)
# current error is:  tensor(0.0037)
# current epoch is:  9150
# current loss is:  tensor(0.0271)
# current error is:  tensor(0.0041)
# current epoch is:  9200
# current loss is:  tensor(0.0232)
# current error is:  tensor(0.0030)
# current epoch is:  9250
# current loss is:  tensor(0.0233)
# current error is:  tensor(0.0036)
# current error is:  tensor(0.0021)
# current epoch is:  18250
# current loss is:  tensor(0.0079)
# current error is:  tensor(0.0017)
# current epoch is:  18300
# current loss is:  tensor(0.0088)
# current error is:  tensor(0.0021)
# current epoch is:  18350
# current loss is:  tensor(0.0088)
# current error is:  tensor(0.0020)
# current epoch is:  18400
# current loss is:  tensor(0.0082)
# current error is:  tensor(0.0022)
# current epoch is:  18450
# current loss is:  tensor(0.0075)
# current error is:  tensor(0.0015)
# current epoch is:  18500
# current loss is:  tensor(0.0182)
# current error is:  tensor(0.0039)
# current epoch is:  18550
# current loss is:  tensor(0.0174)
# current error is:  tensor(0.0057)
# current epoch is:  18600
# current loss is:  tensor(0.0165)
# current error is:  tensor(0.0043)
# current epoch is:  18650
# current loss is:  tensor(0.0099)
# current error is:  tensor(0.0022)
# current epoch is:  18700
# current loss is:  tensor(0.0066)
# current error is:  tensor(0.0016)
# current epoch is:  18750
# current loss is:  tensor(0.0079)
# current error is:  tensor(0.0017)
# current epoch is:  18800
# current loss is:  tensor(0.0084)
# current error is:  tensor(0.0017)
# current epoch is:  18850
# current loss is:  tensor(0.0088)
# current error is:  tensor(0.0028)
# current epoch is:  18900
# current loss is:  tensor(0.0068)
# current error is:  tensor(0.0016)
# current epoch is:  18950
# current loss is:  tensor(0.0147)
# current error is:  tensor(0.0043)
# current epoch is:  19000
# current loss is:  tensor(0.0156)
# current error is:  tensor(0.0042)
# current epoch is:  19050
# current loss is:  tensor(0.0103)
# current error is:  tensor(0.0023)
# current epoch is:  19100
# current loss is:  tensor(0.0080)
# current error is:  tensor(0.0020)
# current epoch is:  19150
# current loss is:  tensor(0.0072)
# current error is:  tensor(0.0016)
# current epoch is:  19200
# current loss is:  tensor(0.0095)
# current error is:  tensor(0.0032)
# current epoch is:  19250
# current loss is:  tensor(0.0103)
# current error is:  tensor(0.0037)
# current epoch is:  19300
# current loss is:  tensor(0.0093)
# current error is:  tensor(0.0032)
# current epoch is:  19350
# current loss is:  tensor(0.0100)
# current error is:  tensor(0.0019)
# current epoch is:  19400
# current loss is:  tensor(0.0069)
# current error is:  tensor(0.0015)
# current epoch is:  19450
# current loss is:  tensor(0.0073)
# current error is:  tensor(0.0018)
# current epoch is:  19500
# current loss is:  tensor(0.0098)
# current error is:  tensor(0.0029)
# current epoch is:  19550
# current loss is:  tensor(0.0087)
# current error is:  tensor(0.0022)
# current epoch is:  19600
# current loss is:  tensor(0.0100)
# current error is:  tensor(0.0017)
# current epoch is:  19650
# current loss is:  tensor(0.0099)
# current error is:  tensor(0.0026)
# current epoch is:  19700
# current loss is:  tensor(0.0102)
# current error is:  tensor(0.0031)
# current epoch is:  19750
# current loss is:  tensor(0.0076)
# current error is:  tensor(0.0021)
# current epoch is:  19800
# current loss is:  tensor(0.0144)
# current error is:  tensor(0.0043)
# current epoch is:  19850
# current loss is:  tensor(0.0075)
# current error is:  tensor(0.0019)
# current epoch is:  19900
# current loss is:  tensor(0.0074)
# current error is:  tensor(0.0018)
# current epoch is:  19950
# current loss is:  tensor(0.0071)
# current error is:  tensor(0.0016)
# total time is:  365.83139085769653 seconds
