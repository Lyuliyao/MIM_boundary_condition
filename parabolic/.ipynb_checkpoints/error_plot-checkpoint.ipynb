# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
df1 = np.load('MIM_error_parabolic_12d.npy')
df2 = np.load('MIM2_error_parabolic_12d.npy')
df3 = np.load('DGM_error_parabolic_12d.npy')

# %%
index1 = np.arange(0,np.size(error1),np.size(error1)//100)
index = np.arange(0,np.size(error2),np.size(error2)//100)

fig, ax = plt.subplots(1, 1, figsize=(5,5))
ax.semilogy(index1,error1[index1],label="MIM1")
ax.semilogy(index,error2[index],label="MIM2")
ax.semilogy(index,error3[index],label="DGM")


ax.legend(fontsize=15)
ax.set_xticks(np.arange(0,np.size(error2)+1,5000))
ax.tick_params(labelsize=20)
plt.ylabel('relative error',fontsize=20)
plt.xlabel('iterations',fontsize=20)
plt.subplots_adjust(left=0.3,right=0.9,top=0.85,bottom=0.25)
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax.xaxis.set_major_formatter(formatter) 
plt.savefig(r"C:\\Users\\lyupi\\Documents\\boundary condition\\JCP\\figure\\error_12D.eps")

# %%
epoch = [i for i in range(len(df1))]

# %%
Epoch = list(epoch[:])[::200]
MIM_error = list(df1[:])[::200]
MIM2_error = list(df2[:])[::200]
DGM_error = list(df3[:])[::200]

# %%
plt.style.use("seaborn-dark") # print(plt.style.available)
plt.gcf().set_facecolor(np.ones(3) * 240/255) 

fig, ax1 = plt.subplots(figsize = (12, 10))
ax1.plot(Epoch, MIM_error, color = "g", linestyle= "-", marker = ".", linewidth = 1.0 , label = "MIM1 (12D)")
ax1.plot(Epoch, MIM2_error, color = "b", linestyle= "-", marker = "+", linewidth = 1.0 , label = "MIM2 (12D)")
ax1.plot(Epoch, DGM_error, color = "r", linestyle= "-", marker = "*", linewidth = 1.0 , label = "DGM (12D)")
plt.xlabel('iterations', fontsize = 20)
plt.ylabel('relative error', fontsize = 20)

plt.legend(loc = 'upper left', bbox_to_anchor = (0.85, 0.95))
plt.grid(True, linestyle = '-')


plt.savefig("error_12D.eps", dpi = 120)

# %%
df1 = np.load('MIM_error_parabolic_2d.npy')
df2 = np.load('MIM2_error_parabolic_2d.npy')
df3 = np.load('DGM_error_parabolic_2d.npy')

# %%
epoch = [i for i in range(len(df1))]

# %%
Epoch = list(epoch[:])[::100]
MIM_error = list(df1[:])[::100]
MIM2_error0 = list(df2[:])[::100]
MIM2_error = MIM2_error0[0:len(MIM_error)]
DGM_error = list(df3[:])[::100]

# %%
plt.style.use("seaborn-dark") # print(plt.style.available)
plt.gcf().set_facecolor(np.ones(3) * 240/255) 

fig, ax1 = plt.subplots(figsize = (12, 10))
ax1.plot(Epoch, MIM_error, color = "g", linestyle= "-", marker = ".", linewidth = 1.0 , label = "MIM1 (2D)")
ax1.plot(Epoch, MIM2_error, color = "b", linestyle= "-", marker = "+", linewidth = 1.0 , label = "MIM2 (2D)")
ax1.plot(Epoch, DGM_error, color = "r", linestyle= "-", marker = "*", linewidth = 1.0 , label = "DGM (2D)")
plt.xlabel('iterations', fontsize = 20)
plt.ylabel('relative error', fontsize = 20)

plt.legend(loc = 'upper left', bbox_to_anchor = (0.85, 0.95))
plt.grid(True, linestyle = '-')


plt.savefig("error_2D.eps", dpi = 120)

# %%
df1 = np.load('MIM_error_parabolic_3d.npy')
df2 = np.load('MIM2_error_parabolic_3d.npy')
df3 = np.load('DGM_error_parabolic_3d.npy')

# %%
epoch = [i for i in range(len(df1))]

# %%
Epoch = list(epoch[:])[::100]
MIM_error = list(df1[:])[::100]
MIM2_error0 = list(df2[:])[::100]
MIM2_error = MIM2_error0[0:len(MIM_error)]
DGM_error0 = list(df3[:])[::100]
DGM_error = DGM_error0[0:len(MIM_error)]

# %%
plt.style.use("seaborn-dark") # print(plt.style.available)
plt.gcf().set_facecolor(np.ones(3) * 240/255) 

fig, ax1 = plt.subplots(figsize = (12, 10))
ax1.plot(Epoch, MIM_error, color = "g", linestyle= "-", marker = ".", linewidth = 1.0 , label = "MIM1 (3D)")
ax1.plot(Epoch, MIM2_error, color = "b", linestyle= "-", marker = "+", linewidth = 1.0 , label = "MIM2 (3D)")
ax1.plot(Epoch, DGM_error, color = "r", linestyle= "-", marker = "*", linewidth = 1.0 , label = "DGM (3D)")
plt.xlabel('iterations', fontsize = 20)
plt.ylabel('relative error', fontsize = 20)

plt.legend(loc = 'upper left', bbox_to_anchor = (0.85, 0.95))
plt.grid(True, linestyle = '-')


plt.savefig("error_3D.eps", dpi = 120)

# %%
df1 = np.load('MIM_error_parabolic_5d.npy')
df2 = np.load('MIM2_error_parabolic_5d.npy')
df3 = np.load('DGM_error_parabolic_5d.npy')

# %%
epoch = [i for i in range(len(df1))]

# %%
Epoch = list(epoch[:])[::100]
MIM_error = list(df1[:])[::100]
MIM2_error0 = list(df2[:])[::100]
MIM2_error = MIM2_error0[0:len(MIM_error)]
DGM_error = list(df3[:])[::100]

# %%
plt.style.use("seaborn-dark") # print(plt.style.available)
plt.gcf().set_facecolor(np.ones(3) * 240/255) 

fig, ax1 = plt.subplots(figsize = (12, 10))
ax1.plot(Epoch, MIM_error, color = "g", linestyle= "-", marker = ".", linewidth = 1.0 , label = "MIM1 (5D)")
ax1.plot(Epoch, MIM2_error, color = "b", linestyle= "-", marker = "+", linewidth = 1.0 , label = "MIM2 (5D)")
ax1.plot(Epoch, DGM_error, color = "r", linestyle= "-", marker = "*", linewidth = 1.0 , label = "DGM (5D)")
plt.xlabel('iterations', fontsize = 20)
plt.ylabel('relative error', fontsize = 20)

plt.legend(loc = 'upper left', bbox_to_anchor = (0.85, 0.95))
plt.grid(True, linestyle = '-')


plt.savefig("error_5D.eps", dpi = 120)

# %%
df1 = np.load('MIM_error_parabolic_10d.npy')
df2 = np.load('MIM2_error_parabolic_10d.npy')
df3 = np.load('DGM_error_parabolic_10d.npy')

# %%
plt.style.use("seaborn-dark") # print(plt.style.available)
plt.gcf().set_facecolor(np.ones(3) * 240/255) 

fig, ax1 = plt.subplots(figsize = (12, 10))
ax1.plot(Epoch, MIM_error, color = "g", linestyle= "-", marker = ".", linewidth = 1.0 , label = "MIM1 (10D)")
ax1.plot(Epoch, MIM2_error, color = "b", linestyle= "-", marker = "+", linewidth = 1.0 , label = "MIM2 (10D)")
ax1.plot(Epoch, DGM_error, color = "r", linestyle= "-", marker = "*", linewidth = 1.0 , label = "DGM (10D)")
plt.xlabel('iterations', fontsize = 20)
plt.ylabel('relative error', fontsize = 20)

plt.legend(loc = 'upper left', bbox_to_anchor = (0.85, 0.95))
plt.grid(True, linestyle = '-')


plt.savefig("error_10D.eps", dpi = 120)
