# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
error = np.load("error_save_LDG_Robin_2D_w5.npy")
plt.plot(np.log10(error[0]))  
np.average(error[0,20000-1000:20000])
# Out:
# 9.478986482083662e-05

# %%
error = np.load("error_save_LDG_Robin_4D_w10.npy")
plt.plot(np.log10(error[0]))  
np.average(error[0,20000-1000:20000])
# Out:
# 7.38720411304938e-05

# %%
error = np.load("error_save_LDG_Robin_8D_w20.npy")
plt.plot(np.log10(error[0]))  
np.average(error[0,20000-1000:20000])
# Out:
# 4.79845031708148e-05

# %%
error = np.load("error_save_LDG_Robin_16D_w40.npy")
plt.plot(np.log10(error[0]))  
np.average(error[0,20000-1000:20000])
# Out:
# 3.803198806051706e-05

# %%
error = np.load("error_save_LDG_Robin_32D_w40.npy")
plt.plot(np.log10(error[0]))  
np.average(error[0,20000-1000:20000])
# Out:
# 4.322642733510035e-05

# %%
error = np.load("error_save_LDG_Robin_64D_w80.npy")
plt.plot(np.log10(error[0]))  
np.average(error[0,20000-1000:20000])
# Out:
# 3.390015236144639e-05
