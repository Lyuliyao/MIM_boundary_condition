# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
errorMIM_new = np.load("error_save_LDG_wave_2D_s_w10.npy")
errorDGM = np.load("error_save_DGM_wave_2D_s_w10.npy")
errorMIM = np.load("error_save_LDG_wave_2D_s_w10_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]
plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0070397802979490125
# 0.12564280720659898
# 0.005204154534137595

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]
plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.05187602555763717
# 0.49818945039523793
# 0.048657721792695854

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]
plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.02428868388332666
# 0.22550585085592711
# 0.035217141922563075

# %%
errorMIM_new = np.load("error_save_LDG_wave_2D_q_w10.npy")
errorDGM = np.load("error_save_DGM_wave_2D_q_w10.npy")
errorMIM = np.load("error_save_LDG_wave_2D_q_w10_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.006896713707512443
# 0.017947528964036685
# 0.01238428064097699

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.03741791625640487
# 0.0961785803692103
# 0.02976900328983436

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.020015372280706396
# 0.036671570028208596
# 0.018837274175880145

# %%
errorMIM_new = np.load("error_save_LDG_wave_2D_s_w20.npy")
errorDGM = np.load("error_save_DGM_wave_2D_s_w20.npy")
errorMIM = np.load("error_save_LDG_wave_2D_s_w20_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0037189221119227718
# 0.04581578288433222
# 0.004052980739435072

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.02713521578455127
# 0.2514321334871947
# 0.015179797370326977

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.015181666385055914
# 0.09112870820244907
# 0.013662911829407227

# %%
errorMIM_new = np.load("error_save_LDG_wave_2D_q_w20.npy")
errorDGM = np.load("error_save_DGM_wave_2D_q_w20.npy")
errorMIM = np.load("error_save_LDG_wave_2D_q_w20_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.003197588302484105
# 0.018769643757493567
# 0.0011993132802113591

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.013261889681085652
# 0.13797751397892385
# 0.00692721241485401

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.009031084825320465
# 0.0471892099313348
# 0.008750889889299085

# %%
errorMIM_new = np.load("error_save_LDG_wave_2D_s_w40.npy")
errorDGM = np.load("error_save_DGM_wave_2D_s_w40.npy")
errorMIM = np.load("error_save_LDG_wave_2D_s_w40_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.00277144697675687
# 0.0277674606662668
# 0.0016726198230437967

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.009053687013126598
# 0.15587316250461566
# 0.003682346724607565

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.006900893706085036
# 0.054565741423747184
# 0.00607702002216662

# %%
errorMIM_new = np.load("error_save_LDG_wave_2D_q_w40.npy")
errorDGM = np.load("error_save_DGM_wave_2D_q_w40.npy")
errorMIM = np.load("error_save_LDG_wave_2D_q_w40_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0016725856823410876
# 0.004918540212282388
# 0.001332579495499261

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0072207347260250165
# 0.03553497833197218
# 0.005076424507899121

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.005468792646615894
# 0.016009716486550654
# 0.006393902430819098

# %%
errorMIM_new = np.load("error_save_LDG_wave_3D_s_w10.npy")
errorDGM = np.load("error_save_DGM_wave_3D_s_w10.npy")
errorMIM = np.load("error_save_LDG_wave_3D_s_w10_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]
plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.016413532325219436
# 0.20543292255587292
# 0.027150271807040206

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]
plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.5077827824412232
# 0.5771932361832944
# 0.3865848394587432

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]
plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.1947345550211868
# 0.1990212562849955
# 0.18646899257519187

# %%
errorMIM_new = np.load("error_save_LDG_wave_3D_q_w10.npy")
errorDGM = np.load("error_save_DGM_wave_3D_q_w10.npy")
errorMIM = np.load("error_save_LDG_wave_3D_q_w10_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.02342364130156258
# 0.13415557192844405
# 0.0513879753493116

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.2147351569914527
# 0.43019709847943716
# 0.14323160266366744

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.09234846865079765
# 0.17160454494521657
# 0.1170247632806562

# %%
errorMIM_new = np.load("error_save_LDG_wave_3D_s_w20.npy")
errorDGM = np.load("error_save_DGM_wave_3D_s_w20.npy")
errorMIM = np.load("error_save_LDG_wave_3D_s_w20_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.01572855195147274
# 0.15461416736867153
# 0.043045502903330715

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.13997313146859508
# 0.5895588120489321
# 0.344338748792307

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.05755155916685706
# 0.17017931822938803
# 0.17308940468834152

# %%
errorMIM_new = np.load("error_save_LDG_wave_3D_q_w20.npy")
errorDGM = np.load("error_save_DGM_wave_3D_q_w20.npy")
errorMIM = np.load("error_save_LDG_wave_3D_q_w20_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.020247782482814357
# 0.056638955701882605
# 0.022317834142869804

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.08247718950315636
# 0.19016409268510165
# 0.027586853349102467

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.04758162249955949
# 0.09395464524231147
# 0.03982839570578366

# %%
errorMIM_new = np.load("error_save_LDG_wave_3D_s_w40.npy")
errorDGM = np.load("error_save_DGM_wave_3D_s_w40.npy")
errorMIM = np.load("error_save_LDG_wave_3D_s_w40_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.010298346946645076
# 0.05982580652702752
# 0.034737662395159165

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.04349650469660173
# 0.15090789775905875
# 0.21360834750079083

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.020330110692955806
# 0.06930542395904328
# 0.12732138118412417

# %%
errorMIM_new = np.load("error_save_LDG_wave_3D_q_w40.npy")
errorDGM = np.load("error_save_DGM_wave_3D_q_w40.npy")
errorMIM = np.load("error_save_LDG_wave_3D_q_w40_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0032792067818146063
# 0.01747170413805294
# 0.004018043294841933

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.025322177842539092
# 0.08544835518078636
# 0.00875156591814931

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.013913953301302068
# 0.03641103910730558
# 0.016743731884349508
