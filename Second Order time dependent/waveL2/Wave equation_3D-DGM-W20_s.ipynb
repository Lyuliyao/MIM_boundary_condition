# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x2 = torch.rand(1000,4).cuda()
    x3 = torch.rand(1000,4).cuda()
    x4 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    x4[:,3:4] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    loss = loss + torch.sum(model_u(x4)**2)/1000
    return loss

# %%
model_u = ResNet(4,20)
device=torch.device("cuda:1" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=20, bias=True)
#   (fc3): Linear(in_features=20, out_features=20, bias=True)
#   (fc4): Linear(in_features=20, out_features=20, bias=True)
#   (outlayer): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:4].reshape(x.size()[0],3)
    return p

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_3D_s_w20.npy", error_save)
np.save("error_save_DGM_wave_3D_s_w20.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 1.4093878866981013
# loss = tensor(27.3067, device='cuda:1')
# i=  501
# error = 0.27093809841514527
# loss = tensor(0.2651, device='cuda:1')
# i=  1001
# error = 0.23858680371971738
# loss = tensor(0.1321, device='cuda:1')
# i=  1501
# error = 0.2004309857256597
# loss = tensor(0.0958, device='cuda:1')
# i=  2001
# error = 0.2105174897181129
# loss = tensor(0.0716, device='cuda:1')
# i=  2501
# error = 0.18436444627930124
# loss = tensor(0.0634, device='cuda:1')
# i=  3001
# error = 0.2135255394661786
# loss = tensor(0.0520, device='cuda:1')
# i=  3501
# error = 0.19054171845211623
# loss = tensor(0.0453, device='cuda:1')
# i=  4001
# error = 0.1868174540648486
# loss = tensor(0.0386, device='cuda:1')
# i=  4501
# error = 0.18791032001829974
# loss = tensor(0.0353, device='cuda:1')
# i=  5001
# error = 0.18914571064772545
# loss = tensor(0.0339, device='cuda:1')
# i=  5501
# error = 0.1868532854360644
# loss = tensor(0.0309, device='cuda:1')
# i=  6001
# error = 0.1769960253890861
# loss = tensor(0.0289, device='cuda:1')
# i=  6501
# error = 0.17561640694710015
# loss = tensor(0.0276, device='cuda:1')
# i=  7001
# error = 0.18991624636222174
# loss = tensor(0.0354, device='cuda:1')
# i=  7501
# error = 0.16669818614993495
# loss = tensor(0.0274, device='cuda:1')
# i=  8001
# error = 0.17467719719183575
# loss = tensor(0.0264, device='cuda:1')
# i=  8501
# error = 0.1882225297028498
# loss = tensor(0.0294, device='cuda:1')
# i=  9001
# error = 0.17078254234677154
# loss = tensor(0.0254, device='cuda:1')
# i=  9501
# error = 0.1743457728556992
# loss = tensor(0.0244, device='cuda:1')
# i=  10001
# error = 0.16092118121358334
# loss = tensor(0.0261, device='cuda:1')
# i=  10501
# error = 0.18915648119679584
# loss = tensor(0.0270, device='cuda:1')
# i=  11001
# error = 0.17138034109732253
# loss = tensor(0.0243, device='cuda:1')
# i=  11501
# error = 0.1662020979689945
# loss = tensor(0.0244, device='cuda:1')
# i=  12001
# error = 0.16484831760099763
# loss = tensor(0.0241, device='cuda:1')
# i=  12501
# error = 0.15317063659403243
# loss = tensor(0.0251, device='cuda:1')
# i=  13001
# error = 0.164725023910924
# loss = tensor(0.0226, device='cuda:1')
# i=  13501
# error = 0.16849033379078776
# loss = tensor(0.0249, device='cuda:1')
# i=  14001
# error = 0.15588738729044854
# loss = tensor(0.0219, device='cuda:1')
# i=  14501
# error = 0.17039376446580715
# loss = tensor(0.0241, device='cuda:1')
# i=  15001
# error = 0.16956347197737723
# loss = tensor(0.0231, device='cuda:1')
# i=  15501
# error = 0.16867892290444664
# loss = tensor(0.0252, device='cuda:1')
# i=  16001
# error = 0.17039744456733943
# loss = tensor(0.0235, device='cuda:1')
# i=  16501
# error = 0.15758780375100992
# loss = tensor(0.0205, device='cuda:1')
# i=  17001
# error = 0.15501381998389946
# loss = tensor(0.0193, device='cuda:1')
# i=  17501
# error = 0.1453064778642858
# loss = tensor(0.0199, device='cuda:1')
# i=  18001
# error = 0.15341821317318247
# loss = tensor(0.0198, device='cuda:1')
# i=  18501
# error = 0.1555557715532116
# loss = tensor(0.0196, device='cuda:1')
# i=  19001
# error = 0.15151541821339679
# loss = tensor(0.0207, device='cuda:1')
# i=  19501
# error = 0.152500282467782
# loss = tensor(0.0219, device='cuda:1')
# i=  20001
# error = 0.14972541599440864
# loss = tensor(0.0214, device='cuda:1')
# i=  20501
# error = 0.14486369863704596
# loss = tensor(0.0228, device='cuda:1')
# i=  21001
# error = 0.15223230770587362
# loss = tensor(0.0208, device='cuda:1')
# i=  21501
# error = 0.1335611544108327
# loss = tensor(0.0225, device='cuda:1')
# i=  22001
# error = 0.14287444537254476
# loss = tensor(0.0200, device='cuda:1')
# i=  22501
# error = 0.1469874513244429
# loss = tensor(0.0189, device='cuda:1')
# i=  23001
# error = 0.15367171505871266
# loss = tensor(0.0190, device='cuda:1')
# i=  23501
# error = 0.128154392251398
# loss = tensor(0.0176, device='cuda:1')
# i=  24001
# error = 0.13252289786214244
# loss = tensor(0.0185, device='cuda:1')
# i=  24501
# error = 0.13918559974624534
# loss = tensor(0.0157, device='cuda:1')
# i=  25001
# error = 0.1383438216277532
# loss = tensor(0.0158, device='cuda:1')
# i=  25501
# error = 0.1394902029921132
# loss = tensor(0.0159, device='cuda:1')
# i=  26001
# error = 0.13543919589637515
# loss = tensor(0.0153, device='cuda:1')
# i=  26501
# error = 0.13496989850218719
# loss = tensor(0.0147, device='cuda:1')
# i=  27001
# error = 0.15351777704716932
# loss = tensor(0.0179, device='cuda:1')
# i=  27501
# error = 0.13158620618401623
# loss = tensor(0.0159, device='cuda:1')
# i=  28001
# error = 0.12967151910649727
# loss = tensor(0.0145, device='cuda:1')
# i=  28501
# error = 0.14326063525759933
# loss = tensor(0.0161, device='cuda:1')
# i=  29001
# error = 0.13544562556135556
# loss = tensor(0.0138, device='cuda:1')
# i=  29501
# error = 0.13067146273445732
# loss = tensor(0.0140, device='cuda:1')
# i=  30001
# error = 0.12619175762900986
# loss = tensor(0.0146, device='cuda:1')
# i=  30501
# error = 0.13942471356724753
# loss = tensor(0.0148, device='cuda:1')
# i=  31001
# error = 0.1356550270967481
# loss = tensor(0.0132, device='cuda:1')
# i=  31501
# error = 0.12660998876808485
# loss = tensor(0.0129, device='cuda:1')
# i=  32001
# error = 0.13662998041497962
# loss = tensor(0.0132, device='cuda:1')
# i=  32501
# error = 0.12479344497730109
# loss = tensor(0.0127, device='cuda:1')
# i=  33001
# error = 0.11718877301801417
# loss = tensor(0.0135, device='cuda:1')
# i=  33501
# error = 0.11830681794661195
# loss = tensor(0.0150, device='cuda:1')
# i=  34001
# error = 0.1368125261400767
# loss = tensor(0.0138, device='cuda:1')
# i=  34501
# error = 0.13743074386737392
# loss = tensor(0.0144, device='cuda:1')
# i=  35001
# error = 0.12411452230197073
# loss = tensor(0.0122, device='cuda:1')
# i=  35501
# error = 0.12932439040182203
# loss = tensor(0.0131, device='cuda:1')
# i=  36001
# error = 0.1333473001634946
# loss = tensor(0.0136, device='cuda:1')
# i=  36501
# error = 0.12327062261381602
# loss = tensor(0.0129, device='cuda:1')
# i=  37001
# error = 0.12428682120396813
# loss = tensor(0.0126, device='cuda:1')
# i=  37501
# error = 0.12606227066015568
# loss = tensor(0.0127, device='cuda:1')
# i=  38001
# error = 0.12628668602132218
# loss = tensor(0.0124, device='cuda:1')
# i=  38501
# error = 0.12656838970384243
# loss = tensor(0.0119, device='cuda:1')
# i=  39001
# error = 0.12324527923193311
# loss = tensor(0.0123, device='cuda:1')
# i=  39501
# error = 0.12705617110253986
# loss = tensor(0.0116, device='cuda:1')
# i=  40001
# error = 0.1267291566847535
# loss = tensor(0.0127, device='cuda:1')
# i=  40501
# error = 0.13303079315505015
# loss = tensor(0.0129, device='cuda:1')
# i=  41001
# error = 0.13158446272352806
# loss = tensor(0.0124, device='cuda:1')
# i=  41501
# error = 0.11297288222023144
# loss = tensor(0.0121, device='cuda:1')
# i=  42001
# error = 0.11979593422256758
# loss = tensor(0.0111, device='cuda:1')
# i=  42501
# error = 0.11703012035106748
# loss = tensor(0.0118, device='cuda:1')
# i=  43001
# error = 0.12303717452899496
# loss = tensor(0.0108, device='cuda:1')
# i=  43501
# error = 0.12188179747168358
# loss = tensor(0.0107, device='cuda:1')
# i=  44001
# error = 0.11733118715853214
# loss = tensor(0.0106, device='cuda:1')
# i=  44501
# error = 0.10884112385463608
# loss = tensor(0.0107, device='cuda:1')
# i=  45001
# error = 0.11044643729559468
# loss = tensor(0.0106, device='cuda:1')
# i=  45501
# error = 0.11905735170223769
# loss = tensor(0.0104, device='cuda:1')
# i=  46001
# error = 0.11306478276259557
# loss = tensor(0.0104, device='cuda:1')
# i=  46501
# error = 0.12397630604365814
# loss = tensor(0.0117, device='cuda:1')
# i=  47001
# error = 0.11288457291383977
# loss = tensor(0.0117, device='cuda:1')
# i=  47501
# error = 0.17559242857521726
# loss = tensor(0.0335, device='cuda:1')
# i=  48001
# error = 0.16811987913808354
# loss = tensor(0.0292, device='cuda:1')
# i=  48501
# error = 0.1658148888933366
# loss = tensor(0.0246, device='cuda:1')
# i=  49001
# error = 0.14752105084477296
# loss = tensor(0.0239, device='cuda:1')
# i=  49501
# error = 0.141618312111668
# loss = tensor(0.0221, device='cuda:1')
# time cost 20433.841380357742 s
