# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    Np = Du[:,1:4].reshape(x.size()[0],3)
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss =  torch.sum( (Np-p)**2 )/50000 + torch.sum( (v_t - uxx - source(x))**2 )/50000
    return loss

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    loss = torch.sum(model_v(x1)**2)/1000
    return loss

# %%
model_u1 = ResNet(4,10,1)
model_p1 = ResNet(4,10,3)
device=torch.device("cuda:0" )

model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=3, bias=True)
# )

# %%
def model_u(x):
    return x[:,0:1]*(x*(1-x))[:,1:2]*(x*(1-x))[:,2:3]*(x*(1-x))[:,3:4]*model_u1(x)
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v
def model_p(x):
    return model_p1(x)

# %%
def initparam(model,sigma):
    for m in model.modules():
        if isinstance(m,nn.Linear):
            m.weight.data.uniform_(-sigma,sigma)#全连接层参数初始化
            m.bias.data.uniform_(0,sigma)
    return model

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()}
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss =",losses.detach())
        np.save("error_save_LDG_wave_3D_s_w10_v1.npy", error_save)
np.save("error_save_LDG_wave_3D_s_w10_v1.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.9956406089350589
# loss = tensor(30.8290, device='cuda:0')
# i=  501
# error = 0.23727686204972823
# loss = tensor(0.8015, device='cuda:0')
# i=  1001
# error = 0.07419190204034944
# loss = tensor(0.3581, device='cuda:0')
# i=  1501
# error = 0.06276494943175265
# loss = tensor(0.2942, device='cuda:0')
# i=  2001
# error = 0.05226082991081213
# loss = tensor(0.2651, device='cuda:0')
# i=  2501
# error = 0.04844353899061759
# loss = tensor(0.2350, device='cuda:0')
# i=  3001
# error = 0.04222986587681191
# loss = tensor(0.2178, device='cuda:0')
# i=  3501
# error = 0.03836230316861514
# loss = tensor(0.1994, device='cuda:0')
# i=  4001
# error = 0.03308252077520234
# loss = tensor(0.1851, device='cuda:0')
# i=  4501
# error = 0.033184748252332835
# loss = tensor(0.1710, device='cuda:0')
# i=  5001
# error = 0.030617252142730363
# loss = tensor(0.1632, device='cuda:0')
# i=  5501
# error = 0.027417395460902022
# loss = tensor(0.1592, device='cuda:0')
# i=  6001
# error = 0.02571459976698423
# loss = tensor(0.1515, device='cuda:0')
# i=  6501
# error = 0.02544044384713664
# loss = tensor(0.1466, device='cuda:0')
# i=  7001
# error = 0.026796235421943163
# loss = tensor(0.1486, device='cuda:0')
# i=  7501
# error = 0.026990292472089384
# loss = tensor(0.1397, device='cuda:0')
# i=  8001
# error = 0.024381291512386997
# loss = tensor(0.1398, device='cuda:0')
# i=  8501
# error = 0.029522726979274695
# loss = tensor(0.1287, device='cuda:0')
# i=  9001
# error = 0.027130988801059887
# loss = tensor(0.1274, device='cuda:0')
# i=  9501
# error = 0.02791423831927173
# loss = tensor(0.1248, device='cuda:0')
# i=  10001
# error = 0.028811419209661723
# loss = tensor(0.1173, device='cuda:0')
# i=  10501
# error = 0.02584905291044577
# loss = tensor(0.1170, device='cuda:0')
# i=  11001
# error = 0.02876316319366007
# loss = tensor(0.1117, device='cuda:0')
# i=  11501
# error = 0.024497410450912704
# loss = tensor(0.1119, device='cuda:0')
# i=  12001
# error = 0.027604745218698303
# loss = tensor(0.1060, device='cuda:0')
# i=  12501
# error = 0.04154110764724334
# loss = tensor(0.1108, device='cuda:0')
# i=  13001
# error = 0.09059270048812136
# loss = tensor(0.1364, device='cuda:0')
# i=  13501
# error = 0.047631251617998846
# loss = tensor(0.1101, device='cuda:0')
# i=  14001
# error = 0.06011917154060753
# loss = tensor(0.1167, device='cuda:0')
# i=  14501
# error = 0.05794828525998355
# loss = tensor(0.1148, device='cuda:0')
# i=  15001
# error = 0.05431880142833839
# loss = tensor(0.1071, device='cuda:0')
# i=  15501
# error = 0.05034514076070439
# loss = tensor(0.1034, device='cuda:0')
# i=  16001
# error = 0.04836714623452077
# loss = tensor(0.1006, device='cuda:0')
# i=  16501
# error = 0.0420026418935212
# loss = tensor(0.0963, device='cuda:0')
# i=  17001
# error = 0.04204046813685255
# loss = tensor(0.0938, device='cuda:0')
# i=  17501
# error = 0.04887058025098135
# loss = tensor(0.0977, device='cuda:0')
# i=  18001
# error = 0.04226591447970747
# loss = tensor(0.0941, device='cuda:0')
# i=  18501
# error = 0.04211911783958858
# loss = tensor(0.0936, device='cuda:0')
# i=  19001
# error = 0.04394475290910106
# loss = tensor(0.0916, device='cuda:0')
# i=  19501
# error = 0.03814680461053363
# loss = tensor(0.0878, device='cuda:0')
# i=  20001
# error = 0.03514967486440958
# loss = tensor(0.0897, device='cuda:0')
# i=  20501
# error = 0.03426020666224019
# loss = tensor(0.0848, device='cuda:0')
# i=  21001
# error = 0.03412682100997222
# loss = tensor(0.0857, device='cuda:0')
# i=  21501
# error = 0.03228659312318237
# loss = tensor(0.0827, device='cuda:0')
# i=  22001
# error = 0.03426568185106356
# loss = tensor(0.0829, device='cuda:0')
# i=  22501
# error = 0.03163030495584912
# loss = tensor(0.0808, device='cuda:0')
# i=  23001
# error = 0.02892348038154706
# loss = tensor(0.0844, device='cuda:0')
# i=  23501
# error = 0.03104119032790026
# loss = tensor(0.0789, device='cuda:0')
# i=  24001
# error = 0.02890070066848228
# loss = tensor(0.0783, device='cuda:0')
# i=  24501
# error = 0.03319770535682038
# loss = tensor(0.0791, device='cuda:0')
# i=  25001
# error = 0.02834036455208639
# loss = tensor(0.0762, device='cuda:0')
# i=  25501
# error = 0.029711967443224446
# loss = tensor(0.0759, device='cuda:0')
# i=  26001
# error = 0.02727965203180749
# loss = tensor(0.0771, device='cuda:0')
# i=  26501
# error = 0.027961624882680555
# loss = tensor(0.0740, device='cuda:0')
# i=  27001
# error = 0.027605456041441292
# loss = tensor(0.0717, device='cuda:0')
# i=  27501
# error = 0.026423061265972842
# loss = tensor(0.0714, device='cuda:0')
# i=  28001
# error = 0.02962494594523704
# loss = tensor(0.0709, device='cuda:0')
# i=  28501
# error = 0.027991791779180028
# loss = tensor(0.0793, device='cuda:0')
# i=  29001
# error = 0.027636636690781032
# loss = tensor(0.0696, device='cuda:0')
# i=  29501
# error = 0.02923915377112621
# loss = tensor(0.0705, device='cuda:0')
# i=  30001
# error = 0.027356688270643498
# loss = tensor(0.0679, device='cuda:0')
# i=  30501
# error = 0.029064556592091718
# loss = tensor(0.0670, device='cuda:0')
# i=  31001
# error = 0.027841066536624916
# loss = tensor(0.0681, device='cuda:0')
# i=  31501
# error = 0.027569841168778364
# loss = tensor(0.0665, device='cuda:0')
# i=  32001
# error = 0.02510628646354222
# loss = tensor(0.0700, device='cuda:0')
# i=  32501
# error = 0.026428869871790436
# loss = tensor(0.0640, device='cuda:0')
# i=  33001
# error = 0.025748573887535237
# loss = tensor(0.0632, device='cuda:0')
# i=  33501
# error = 0.0259753277308226
# loss = tensor(0.0629, device='cuda:0')
# i=  34001
# error = 0.025146498279395475
# loss = tensor(0.0628, device='cuda:0')
# i=  34501
# error = 0.024894722746493604
# loss = tensor(0.0696, device='cuda:0')
# i=  35001
# error = 0.02705954257074238
# loss = tensor(0.0643, device='cuda:0')
# i=  35501
# error = 0.02469416097498156
# loss = tensor(0.0640, device='cuda:0')
# i=  36001
# error = 0.025561092969828645
# loss = tensor(0.0606, device='cuda:0')
# i=  36501
# error = 0.02573270009565898
# loss = tensor(0.0607, device='cuda:0')
# i=  37001
# error = 0.02523232619320187
# loss = tensor(0.0588, device='cuda:0')
# i=  37501
# error = 0.02561252511515526
# loss = tensor(0.0588, device='cuda:0')
# i=  38001
# error = 0.024962675996882486
# loss = tensor(0.0603, device='cuda:0')
# i=  38501
# error = 0.024987276869447496
# loss = tensor(0.0587, device='cuda:0')
# i=  39001
# error = 0.02524946094292615
# loss = tensor(0.0580, device='cuda:0')
# i=  39501
# error = 0.02465320319705987
# loss = tensor(0.0569, device='cuda:0')
# i=  40001
# error = 0.025467933487356115
# loss = tensor(0.0566, device='cuda:0')
# i=  40501
# error = 0.025217545350483164
# loss = tensor(0.0624, device='cuda:0')
# i=  41001
# error = 0.023506379935655384
# loss = tensor(0.0586, device='cuda:0')
# i=  41501
# error = 0.027315529128908476
# loss = tensor(0.0595, device='cuda:0')
# i=  42001
# error = 0.024740444778808577
# loss = tensor(0.0557, device='cuda:0')
# i=  42501
# error = 0.023729527982911336
# loss = tensor(0.0572, device='cuda:0')
# i=  43001
# error = 0.02488284780249118
# loss = tensor(0.0536, device='cuda:0')
# i=  43501
# error = 0.02606094879084023
# loss = tensor(0.0524, device='cuda:0')
# i=  44001
# error = 0.02549695067715676
# loss = tensor(0.0545, device='cuda:0')
# i=  44501
# error = 0.026047987653058165
# loss = tensor(0.0544, device='cuda:0')
# i=  45001
# error = 0.025086241586221834
# loss = tensor(0.0515, device='cuda:0')
# i=  45501
# error = 0.024686478633333377
# loss = tensor(0.0518, device='cuda:0')
# i=  46001
# error = 0.02749640868829864
# loss = tensor(0.0517, device='cuda:0')
# i=  46501
# error = 0.02540791606510179
# loss = tensor(0.0510, device='cuda:0')
# i=  47001
# error = 0.02668754870655989
# loss = tensor(0.0498, device='cuda:0')
# i=  47501
# error = 0.027480738074985085
# loss = tensor(0.0527, device='cuda:0')
# i=  48001
# error = 0.024612555886156285
# loss = tensor(0.0505, device='cuda:0')
# i=  48501
# error = 0.028215986777986535
# loss = tensor(0.0524, device='cuda:0')
# i=  49001
# error = 0.02750756497600323
# loss = tensor(0.0495, device='cuda:0')
# i=  49501
# error = 0.028504676992638377
# loss = tensor(0.0488, device='cuda:0')
# time cost 5355.883450508118 s

# %%
plt.plot(np.log10(error[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3c7ba7478601> in <module>
# ----> 1 plt.plot(np.log10(error[1]))
#
# NameError: name 'plt' is not defined

# %%
plt.plot(np.log10(error[0]))

# %%
plt.plot(np.log10(error[2]))
