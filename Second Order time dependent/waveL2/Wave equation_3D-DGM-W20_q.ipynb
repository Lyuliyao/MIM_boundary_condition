# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        
        output = self.outlayer(y)
        return output
deg = 3

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x2 = torch.rand(1000,4).cuda()
    x3 = torch.rand(1000,4).cuda()
    x4 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    x4[:,3:4] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    loss = loss + torch.sum(model_u(x4)**2)/1000
    return loss

# %%
model_u = ResNet(4,20)
device=torch.device("cuda:0" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=20, bias=True)
#   (fc3): Linear(in_features=20, out_features=20, bias=True)
#   (fc4): Linear(in_features=20, out_features=20, bias=True)
#   (outlayer): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:4].reshape(x.size()[0],3)
    return p

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_3D_q_w20.npy", error_save)
np.save("error_save_DGM_wave_3D_q_w20.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 1.8059198475068206
# loss = tensor(26.3173, device='cuda:0')
# i=  501
# error = 0.980208821082449
# loss = tensor(1.0874, device='cuda:0')
# i=  1001
# error = 0.5590576276812509
# loss = tensor(0.2099, device='cuda:0')
# i=  1501
# error = 0.3696850410610442
# loss = tensor(0.0896, device='cuda:0')
# i=  2001
# error = 0.3048956457387914
# loss = tensor(0.0605, device='cuda:0')
# i=  2501
# error = 0.2665091214830078
# loss = tensor(0.0434, device='cuda:0')
# i=  3001
# error = 0.2342567540562031
# loss = tensor(0.0339, device='cuda:0')
# i=  3501
# error = 0.20626001647930722
# loss = tensor(0.0270, device='cuda:0')
# i=  4001
# error = 0.18548780127815434
# loss = tensor(0.0231, device='cuda:0')
# i=  4501
# error = 0.1761529069667311
# loss = tensor(0.0204, device='cuda:0')
# i=  5001
# error = 0.1615438172790111
# loss = tensor(0.0184, device='cuda:0')
# i=  5501
# error = 0.15302928057557824
# loss = tensor(0.0182, device='cuda:0')
# i=  6001
# error = 0.15283150475515545
# loss = tensor(0.0157, device='cuda:0')
# i=  6501
# error = 0.13996859153473373
# loss = tensor(0.0142, device='cuda:0')
# i=  7001
# error = 0.13458394991742814
# loss = tensor(0.0125, device='cuda:0')
# i=  7501
# error = 0.12727621786936308
# loss = tensor(0.0136, device='cuda:0')
# i=  8001
# error = 0.1418613053751571
# loss = tensor(0.0207, device='cuda:0')
# i=  8501
# error = 0.12637739983517313
# loss = tensor(0.0097, device='cuda:0')
# i=  9001
# error = 0.11493039160376126
# loss = tensor(0.0182, device='cuda:0')
# i=  9501
# error = 0.12072039663341991
# loss = tensor(0.0087, device='cuda:0')
# i=  10001
# error = 0.1093749073002178
# loss = tensor(0.0090, device='cuda:0')
# i=  10501
# error = 0.11802972986308413
# loss = tensor(0.0079, device='cuda:0')
# i=  11001
# error = 0.11134410000959054
# loss = tensor(0.0080, device='cuda:0')
# i=  11501
# error = 0.1109042580387938
# loss = tensor(0.0071, device='cuda:0')
# i=  12001
# error = 0.10900977642645905
# loss = tensor(0.0082, device='cuda:0')
# i=  12501
# error = 0.10126105971936065
# loss = tensor(0.0074, device='cuda:0')
# i=  13001
# error = 0.10304196703498232
# loss = tensor(0.0060, device='cuda:0')
# i=  13501
# error = 0.09749497645188111
# loss = tensor(0.0060, device='cuda:0')
# i=  14001
# error = 0.10059434030918377
# loss = tensor(0.0055, device='cuda:0')
# i=  14501
# error = 0.1029801654110122
# loss = tensor(0.0060, device='cuda:0')
# i=  15001
# error = 0.09420926980810165
# loss = tensor(0.0052, device='cuda:0')
# i=  15501
# error = 0.09318791926399818
# loss = tensor(0.0052, device='cuda:0')
# i=  16001
# error = 0.08899605338238974
# loss = tensor(0.0052, device='cuda:0')
# i=  16501
# error = 0.10107876456122857
# loss = tensor(0.0088, device='cuda:0')
# i=  17001
# error = 0.09479209411152326
# loss = tensor(0.0083, device='cuda:0')
# i=  17501
# error = 0.09171506240954151
# loss = tensor(0.0046, device='cuda:0')
# i=  18001
# error = 0.08739181896901836
# loss = tensor(0.0041, device='cuda:0')
# i=  18501
# error = 0.08885080103842255
# loss = tensor(0.0042, device='cuda:0')
# i=  19001
# error = 0.08412094386289215
# loss = tensor(0.0038, device='cuda:0')
# i=  19501
# error = 0.07744632345660869
# loss = tensor(0.0046, device='cuda:0')
# i=  20001
# error = 0.08816108225753987
# loss = tensor(0.0038, device='cuda:0')
# i=  20501
# error = 0.08300701785710368
# loss = tensor(0.0036, device='cuda:0')
# i=  21001
# error = 0.08137812746698375
# loss = tensor(0.0045, device='cuda:0')
# i=  21501
# error = 0.08012967291915889
# loss = tensor(0.0036, device='cuda:0')
# i=  22001
# error = 0.08090647484876536
# loss = tensor(0.0036, device='cuda:0')
# i=  22501
# error = 0.0781081521941978
# loss = tensor(0.0036, device='cuda:0')
# i=  23001
# error = 0.07572127797074225
# loss = tensor(0.0066, device='cuda:0')
# i=  23501
# error = 0.08421715772756531
# loss = tensor(0.0079, device='cuda:0')
# i=  24001
# error = 0.08916785216594765
# loss = tensor(0.0064, device='cuda:0')
# i=  24501
# error = 0.06803810203359939
# loss = tensor(0.0056, device='cuda:0')
# i=  25001
# error = 0.0735789974523107
# loss = tensor(0.0029, device='cuda:0')
# i=  25501
# error = 0.07913086529409405
# loss = tensor(0.0033, device='cuda:0')
# i=  26001
# error = 0.07724777160308408
# loss = tensor(0.0032, device='cuda:0')
# i=  26501
# error = 0.07031248951101474
# loss = tensor(0.0029, device='cuda:0')
# i=  27001
# error = 0.0720149401022823
# loss = tensor(0.0030, device='cuda:0')
# i=  27501
# error = 0.07312745614888995
# loss = tensor(0.0042, device='cuda:0')
# i=  28001
# error = 0.06944280498149119
# loss = tensor(0.0029, device='cuda:0')
# i=  28501
# error = 0.07635913976967378
# loss = tensor(0.0034, device='cuda:0')
# i=  29001
# error = 0.07557408728779229
# loss = tensor(0.0046, device='cuda:0')
# i=  29501
# error = 0.0702418631578894
# loss = tensor(0.0105, device='cuda:0')
# i=  30001
# error = 0.06738626843102936
# loss = tensor(0.0024, device='cuda:0')
# i=  30501
# error = 0.0620849256593106
# loss = tensor(0.0038, device='cuda:0')
# i=  31001
# error = 0.0680760419817253
# loss = tensor(0.0024, device='cuda:0')
# i=  31501
# error = 0.06653311075284378
# loss = tensor(0.0024, device='cuda:0')
# i=  32001
# error = 0.06409577691640372
# loss = tensor(0.0026, device='cuda:0')
# i=  32501
# error = 0.06663539961205671
# loss = tensor(0.0027, device='cuda:0')
# i=  33001
# error = 0.06458197857137629
# loss = tensor(0.0026, device='cuda:0')
# i=  33501
# error = 0.06609227507437572
# loss = tensor(0.0022, device='cuda:0')
# i=  34001
# error = 0.06239223085956457
# loss = tensor(0.0027, device='cuda:0')
# i=  34501
# error = 0.06843196978010396
# loss = tensor(0.0026, device='cuda:0')
# i=  35001
# error = 0.07413114350153527
# loss = tensor(0.0056, device='cuda:0')
# i=  35501
# error = 0.06826847574182886
# loss = tensor(0.0042, device='cuda:0')
# i=  36001
# error = 0.07084213598524762
# loss = tensor(0.0035, device='cuda:0')
# i=  36501
# error = 0.06288575622426246
# loss = tensor(0.0024, device='cuda:0')
# i=  37001
# error = 0.06516835266456572
# loss = tensor(0.0020, device='cuda:0')
# i=  37501
# error = 0.0610276349813609
# loss = tensor(0.0024, device='cuda:0')
# i=  38001
# error = 0.06452733686838225
# loss = tensor(0.0023, device='cuda:0')
# i=  38501
# error = 0.06531192320955946
# loss = tensor(0.0032, device='cuda:0')
# i=  39001
# error = 0.05642930519178267
# loss = tensor(0.0029, device='cuda:0')
# i=  39501
# error = 0.05993416856720585
# loss = tensor(0.0020, device='cuda:0')
# i=  40001
# error = 0.0598965311562215
# loss = tensor(0.0023, device='cuda:0')
# i=  40501
# error = 0.06192942512269924
# loss = tensor(0.0027, device='cuda:0')
# i=  41001
# error = 0.061339541430939115
# loss = tensor(0.0026, device='cuda:0')
# i=  41501
# error = 0.05662150393054459
# loss = tensor(0.0028, device='cuda:0')
# i=  42001
# error = 0.06089310029561004
# loss = tensor(0.0020, device='cuda:0')
# i=  42501
# error = 0.056665929737741774
# loss = tensor(0.0020, device='cuda:0')
# i=  43001
# error = 0.06912755290255802
# loss = tensor(0.0038, device='cuda:0')
# i=  43501
# error = 0.05787662668791178
# loss = tensor(0.0019, device='cuda:0')
# i=  44001
# error = 0.05855798686305108
# loss = tensor(0.0021, device='cuda:0')
# i=  44501
# error = 0.06077172843927996
# loss = tensor(0.0022, device='cuda:0')
# i=  45001
# error = 0.059473899227243866
# loss = tensor(0.0018, device='cuda:0')
# i=  45501
# error = 0.05972914155067708
# loss = tensor(0.0054, device='cuda:0')
# i=  46001
# error = 0.060751403601362275
# loss = tensor(0.0022, device='cuda:0')
# i=  46501
# error = 0.05627737757053759
# loss = tensor(0.0017, device='cuda:0')
# i=  47001
# error = 0.05728309166949027
# loss = tensor(0.0018, device='cuda:0')
# i=  47501
# error = 0.05747139862902329
# loss = tensor(0.0025, device='cuda:0')
# i=  48001
# error = 0.06294101557977552
# loss = tensor(0.0022, device='cuda:0')
# i=  48501
# error = 0.05491101772040894
# loss = tensor(0.0018, device='cuda:0')
# i=  49001
# error = 0.05035974030286622
# loss = tensor(0.0048, device='cuda:0')
# i=  49501
# error = 0.05495692580354866
# loss = tensor(0.0018, device='cuda:0')
# time cost 11785.317733049393 s
