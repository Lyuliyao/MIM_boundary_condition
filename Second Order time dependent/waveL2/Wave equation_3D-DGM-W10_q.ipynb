# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        
        output = self.outlayer(y)
        return output
deg = 3

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x2 = torch.rand(1000,4).cuda()
    x3 = torch.rand(1000,4).cuda()
    x4 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    x4[:,3:4] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    loss = loss + torch.sum(model_u(x4)**2)/1000
    return loss

# %%
model_u = ResNet(4,10)
device=torch.device("cuda:0" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:4].reshape(x.size()[0],3)
    return p

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_3D_q_w10.npy", error_save)
np.save("error_save_DGM_wave_3D_q_w10.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 1.1545626628670198
# loss = tensor(29.3105, device='cuda:0')
# i=  501
# error = 0.5147446259637509
# loss = tensor(0.7056, device='cuda:0')
# i=  1001
# error = 0.29343110645141124
# loss = tensor(0.1938, device='cuda:0')
# i=  1501
# error = 0.21924791836843271
# loss = tensor(0.1164, device='cuda:0')
# i=  2001
# error = 0.19325827305085463
# loss = tensor(0.0895, device='cuda:0')
# i=  2501
# error = 0.1873172244528571
# loss = tensor(0.0721, device='cuda:0')
# i=  3001
# error = 0.1831973937603226
# loss = tensor(0.0605, device='cuda:0')
# i=  3501
# error = 0.1829147311897261
# loss = tensor(0.0540, device='cuda:0')
# i=  4001
# error = 0.17628621259498437
# loss = tensor(0.0485, device='cuda:0')
# i=  4501
# error = 0.1746316413508152
# loss = tensor(0.0434, device='cuda:0')
# i=  5001
# error = 0.17438096632751607
# loss = tensor(0.0398, device='cuda:0')
# i=  5501
# error = 0.16911946580421758
# loss = tensor(0.0374, device='cuda:0')
# i=  6001
# error = 0.17830027709176358
# loss = tensor(0.0348, device='cuda:0')
# i=  6501
# error = 0.19019466285036146
# loss = tensor(0.0369, device='cuda:0')
# i=  7001
# error = 0.1775670995195244
# loss = tensor(0.0316, device='cuda:0')
# i=  7501
# error = 0.17011338891362102
# loss = tensor(0.0282, device='cuda:0')
# i=  8001
# error = 0.1675675447514401
# loss = tensor(0.0276, device='cuda:0')
# i=  8501
# error = 0.18761617825043922
# loss = tensor(0.0283, device='cuda:0')
# i=  9001
# error = 0.17120502165217868
# loss = tensor(0.0236, device='cuda:0')
# i=  9501
# error = 0.16776185530612034
# loss = tensor(0.0220, device='cuda:0')
# i=  10001
# error = 0.1765379360296119
# loss = tensor(0.0224, device='cuda:0')
# i=  10501
# error = 0.1592097475864586
# loss = tensor(0.0199, device='cuda:0')
# i=  11001
# error = 0.15514128471021882
# loss = tensor(0.0203, device='cuda:0')
# i=  11501
# error = 0.1705452074801822
# loss = tensor(0.0184, device='cuda:0')
# i=  12001
# error = 0.16548951247112434
# loss = tensor(0.0174, device='cuda:0')
# i=  12501
# error = 0.15634912480070573
# loss = tensor(0.0185, device='cuda:0')
# i=  13001
# error = 0.16736562583336798
# loss = tensor(0.0173, device='cuda:0')
# i=  13501
# error = 0.15990683339228845
# loss = tensor(0.0162, device='cuda:0')
# i=  14001
# error = 0.1562301020567397
# loss = tensor(0.0161, device='cuda:0')
# i=  14501
# error = 0.15125090084562118
# loss = tensor(0.0166, device='cuda:0')
# i=  15001
# error = 0.15937366441672485
# loss = tensor(0.0159, device='cuda:0')
# i=  15501
# error = 0.14274065013889672
# loss = tensor(0.0170, device='cuda:0')
# i=  16001
# error = 0.15479519356544477
# loss = tensor(0.0146, device='cuda:0')
# i=  16501
# error = 0.1549958634075462
# loss = tensor(0.0142, device='cuda:0')
# i=  17001
# error = 0.1593650451845934
# loss = tensor(0.0142, device='cuda:0')
# i=  17501
# error = 0.14391673083548637
# loss = tensor(0.0146, device='cuda:0')
# i=  18001
# error = 0.15432687127835285
# loss = tensor(0.0136, device='cuda:0')
# i=  18501
# error = 0.1494412269856338
# loss = tensor(0.0134, device='cuda:0')
# i=  19001
# error = 0.1390148604125728
# loss = tensor(0.0143, device='cuda:0')
# i=  19501
# error = 0.1448585952655159
# loss = tensor(0.0131, device='cuda:0')
# i=  20001
# error = 0.13729218497986184
# loss = tensor(0.0150, device='cuda:0')
# i=  20501
# error = 0.1519353002031403
# loss = tensor(0.0129, device='cuda:0')
# i=  21001
# error = 0.14043636865995276
# loss = tensor(0.0146, device='cuda:0')
# i=  21501
# error = 0.14838025798504448
# loss = tensor(0.0127, device='cuda:0')
# i=  22001
# error = 0.1525815430493933
# loss = tensor(0.0143, device='cuda:0')
# i=  22501
# error = 0.14987473955671493
# loss = tensor(0.0124, device='cuda:0')
# i=  23001
# error = 0.15480120065446282
# loss = tensor(0.0133, device='cuda:0')
# i=  23501
# error = 0.15505423202937954
# loss = tensor(0.0138, device='cuda:0')
# i=  24001
# error = 0.14478582798183282
# loss = tensor(0.0119, device='cuda:0')
# i=  24501
# error = 0.14289217128376297
# loss = tensor(0.0116, device='cuda:0')
# i=  25001
# error = 0.14796973490509102
# loss = tensor(0.0121, device='cuda:0')
# i=  25501
# error = 0.14255607056403433
# loss = tensor(0.0114, device='cuda:0')
# i=  26001
# error = 0.13619167831729181
# loss = tensor(0.0118, device='cuda:0')
# i=  26501
# error = 0.13600887926398836
# loss = tensor(0.0115, device='cuda:0')
# i=  27001
# error = 0.14497485075196584
# loss = tensor(0.0107, device='cuda:0')
# i=  27501
# error = 0.13903806346592967
# loss = tensor(0.0110, device='cuda:0')
# i=  28001
# error = 0.1474511669095569
# loss = tensor(0.0121, device='cuda:0')
# i=  28501
# error = 0.13004395049247539
# loss = tensor(0.0126, device='cuda:0')
# i=  29001
# error = 0.14478854354765308
# loss = tensor(0.0111, device='cuda:0')
# i=  29501
# error = 0.1413429679271936
# loss = tensor(0.0106, device='cuda:0')
# i=  30001
# error = 0.1458427057699317
# loss = tensor(0.0107, device='cuda:0')
# i=  30501
# error = 0.1410830705632104
# loss = tensor(0.0101, device='cuda:0')
# i=  31001
# error = 0.13716097229919208
# loss = tensor(0.0101, device='cuda:0')
# i=  31501
# error = 0.14346225411066457
# loss = tensor(0.0107, device='cuda:0')
# i=  32001
# error = 0.13450241198990576
# loss = tensor(0.0105, device='cuda:0')
# i=  32501
# error = 0.1413386808204408
# loss = tensor(0.0099, device='cuda:0')
# i=  33001
# error = 0.15289243701786948
# loss = tensor(0.0129, device='cuda:0')
# i=  33501
# error = 0.13760422552540066
# loss = tensor(0.0097, device='cuda:0')
# i=  34001
# error = 0.15071469131009424
# loss = tensor(0.0104, device='cuda:0')
# i=  34501
# error = 0.13379795842586797
# loss = tensor(0.0104, device='cuda:0')
# i=  35001
# error = 0.12543697688949063
# loss = tensor(0.0119, device='cuda:0')
# i=  35501
# error = 0.14017703077396335
# loss = tensor(0.0099, device='cuda:0')
# i=  36001
# error = 0.14020662700532568
# loss = tensor(0.0097, device='cuda:0')
# i=  36501
# error = 0.1453997015796379
# loss = tensor(0.0106, device='cuda:0')
# i=  37001
# error = 0.13582958929252825
# loss = tensor(0.0096, device='cuda:0')
# i=  37501
# error = 0.14100769466089214
# loss = tensor(0.0098, device='cuda:0')
# i=  38001
# error = 0.13761260453237448
# loss = tensor(0.0092, device='cuda:0')
# i=  38501
# error = 0.11751712263519878
# loss = tensor(0.0187, device='cuda:0')
# i=  39001
# error = 0.13678803562425845
# loss = tensor(0.0092, device='cuda:0')
# i=  39501
# error = 0.14011910623287155
# loss = tensor(0.0091, device='cuda:0')
# i=  40001
# error = 0.12533240628074865
# loss = tensor(0.0113, device='cuda:0')
# i=  40501
# error = 0.12924060584568411
# loss = tensor(0.0096, device='cuda:0')
# i=  41001
# error = 0.14843479286274266
# loss = tensor(0.0133, device='cuda:0')
# i=  41501
# error = 0.13858359765248165
# loss = tensor(0.0090, device='cuda:0')
# i=  42001
# error = 0.14436744403555782
# loss = tensor(0.0100, device='cuda:0')
# i=  42501
# error = 0.13676771835811885
# loss = tensor(0.0088, device='cuda:0')
# i=  43001
# error = 0.11353602199269987
# loss = tensor(0.0208, device='cuda:0')
# i=  43501
# error = 0.16285813002007912
# loss = tensor(0.0309, device='cuda:0')
# i=  44001
# error = 0.12838540096485615
# loss = tensor(0.0094, device='cuda:0')
# i=  44501
# error = 0.14114106627453024
# loss = tensor(0.0106, device='cuda:0')
# i=  45001
# error = 0.1280783287978886
# loss = tensor(0.0090, device='cuda:0')
# i=  45501
# error = 0.1406179203774873
# loss = tensor(0.0090, device='cuda:0')
# i=  46001
# error = 0.12577421286663076
# loss = tensor(0.0095, device='cuda:0')
# i=  46501
# error = 0.12634602713257026
# loss = tensor(0.0090, device='cuda:0')
# i=  47001
# error = 0.1379824886297286
# loss = tensor(0.0082, device='cuda:0')
# i=  47501
# error = 0.1371165418844662
# loss = tensor(0.0086, device='cuda:0')
# i=  48001
# error = 0.1216405256950273
# loss = tensor(0.0106, device='cuda:0')
# i=  48501
# error = 0.1378363820194358
# loss = tensor(0.0084, device='cuda:0')
# i=  49001
# error = 0.13513688044066718
# loss = tensor(0.0081, device='cuda:0')
# i=  49501
# error = 0.13803173805923968
# loss = tensor(0.0082, device='cuda:0')
# time cost 10792.73188996315 s
