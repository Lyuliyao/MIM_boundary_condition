# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        
        output = self.outlayer(y)
        return output
deg = 3

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    Np = Du[:,1:4].reshape(x.size()[0],3)
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss =  torch.sum( (Np-p)**2 )/50000 + torch.sum( (v_t - uxx - source(x))**2 )/50000
    return loss

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    loss = torch.sum(model_v(x1)**2)/1000
    return loss

# %%
model_u1 = ResNet(4,10,1)
model_p1 = ResNet(4,10,3)
device=torch.device("cuda:0" )

model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=3, bias=True)
# )

# %%
def model_u(x):
    return x[:,0:1]*(x*(1-x))[:,1:2]*(x*(1-x))[:,2:3]*(x*(1-x))[:,3:4]*model_u1(x)
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v
def model_p(x):
    return model_p1(x)

# %%
def initparam(model,sigma):
    for m in model.modules():
        if isinstance(m,nn.Linear):
            m.weight.data.uniform_(-sigma,sigma)#全连接层参数初始化
            m.bias.data.uniform_(0,sigma)
    return model

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()}
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss =",losses.detach())
        np.save("error_save_LDG_wave_3D_q_w10_v1.npy", error_save)
np.save("error_save_LDG_wave_3D_q_w10_v1.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.9981471003255393
# loss = tensor(25.2342, device='cuda:0')
# i=  501
# error = 0.13252511138260403
# loss = tensor(0.5095, device='cuda:0')
# i=  1001
# error = 0.05470381004701203
# loss = tensor(0.2272, device='cuda:0')
# i=  1501
# error = 0.04457586863651216
# loss = tensor(0.1566, device='cuda:0')
# i=  2001
# error = 0.04377054290469934
# loss = tensor(0.1130, device='cuda:0')
# i=  2501
# error = 0.03877152010935349
# loss = tensor(0.0887, device='cuda:0')
# i=  3001
# error = 0.03469695617477734
# loss = tensor(0.0773, device='cuda:0')
# i=  3501
# error = 0.03889532730416371
# loss = tensor(0.0563, device='cuda:0')
# i=  4001
# error = 0.045100440958888675
# loss = tensor(0.0503, device='cuda:0')
# i=  4501
# error = 0.037971083874305284
# loss = tensor(0.0463, device='cuda:0')
# i=  5001
# error = 0.04011444018034213
# loss = tensor(0.0426, device='cuda:0')
# i=  5501
# error = 0.04362676408469754
# loss = tensor(0.0387, device='cuda:0')
# i=  6001
# error = 0.04933973990004724
# loss = tensor(0.0377, device='cuda:0')
# i=  6501
# error = 0.04519073070198187
# loss = tensor(0.0340, device='cuda:0')
# i=  7001
# error = 0.046106758303740614
# loss = tensor(0.0323, device='cuda:0')
# i=  7501
# error = 0.04647850214153052
# loss = tensor(0.0304, device='cuda:0')
# i=  8001
# error = 0.04754211417017947
# loss = tensor(0.0284, device='cuda:0')
# i=  8501
# error = 0.04990967328763285
# loss = tensor(0.0277, device='cuda:0')
# i=  9001
# error = 0.04609068329861159
# loss = tensor(0.0262, device='cuda:0')
# i=  9501
# error = 0.05369183252948684
# loss = tensor(0.0279, device='cuda:0')
# i=  10001
# error = 0.042801926765440194
# loss = tensor(0.0273, device='cuda:0')
# i=  10501
# error = 0.05621137627447736
# loss = tensor(0.0281, device='cuda:0')
# i=  11001
# error = 0.045754287776891174
# loss = tensor(0.0228, device='cuda:0')
# i=  11501
# error = 0.0497789073801414
# loss = tensor(0.0226, device='cuda:0')
# i=  12001
# error = 0.047315881681775876
# loss = tensor(0.0213, device='cuda:0')
# i=  12501
# error = 0.050775421413854036
# loss = tensor(0.0215, device='cuda:0')
# i=  13001
# error = 0.039480421042956244
# loss = tensor(0.0262, device='cuda:0')
# i=  13501
# error = 0.05287529670073831
# loss = tensor(0.0201, device='cuda:0')
# i=  14001
# error = 0.05513329618797513
# loss = tensor(0.0225, device='cuda:0')
# i=  14501
# error = 0.0484171349011603
# loss = tensor(0.0184, device='cuda:0')
# i=  15001
# error = 0.05050998613433324
# loss = tensor(0.0183, device='cuda:0')
# i=  15501
# error = 0.060578258136224215
# loss = tensor(0.0252, device='cuda:0')
# i=  16001
# error = 0.04423298078997127
# loss = tensor(0.0181, device='cuda:0')
# i=  16501
# error = 0.05010683941360301
# loss = tensor(0.0182, device='cuda:0')
# i=  17001
# error = 0.053622365159106865
# loss = tensor(0.0173, device='cuda:0')
# i=  17501
# error = 0.04954992315575497
# loss = tensor(0.0166, device='cuda:0')
# i=  18001
# error = 0.051278477432991854
# loss = tensor(0.0164, device='cuda:0')
# i=  18501
# error = 0.05148344417478873
# loss = tensor(0.0160, device='cuda:0')
# i=  19001
# error = 0.04647044747660736
# loss = tensor(0.0183, device='cuda:0')
# i=  19501
# error = 0.050970465750338395
# loss = tensor(0.0152, device='cuda:0')
# i=  20001
# error = 0.04968770031188649
# loss = tensor(0.0150, device='cuda:0')
# i=  20501
# error = 0.0489473021878164
# loss = tensor(0.0154, device='cuda:0')
# i=  21001
# error = 0.05051823956803047
# loss = tensor(0.0147, device='cuda:0')
# i=  21501
# error = 0.043505003497198366
# loss = tensor(0.0172, device='cuda:0')
# i=  22001
# error = 0.061635396417296755
# loss = tensor(0.0188, device='cuda:0')
# i=  22501
# error = 0.050290381432788925
# loss = tensor(0.0142, device='cuda:0')
# i=  23001
# error = 0.048236564694301855
# loss = tensor(0.0144, device='cuda:0')
# i=  23501
# error = 0.049013699018900944
# loss = tensor(0.0136, device='cuda:0')
# i=  24001
# error = 0.05293830480323799
# loss = tensor(0.0134, device='cuda:0')
# i=  24501
# error = 0.054382589778016195
# loss = tensor(0.0141, device='cuda:0')
# i=  25001
# error = 0.04698455054346951
# loss = tensor(0.0150, device='cuda:0')
# i=  25501
# error = 0.057809493215599216
# loss = tensor(0.0171, device='cuda:0')
# i=  26001
# error = 0.04602787183878458
# loss = tensor(0.0151, device='cuda:0')
# i=  26501
# error = 0.052128166986373674
# loss = tensor(0.0125, device='cuda:0')
# i=  27001
# error = 0.05436887292796331
# loss = tensor(0.0126, device='cuda:0')
# i=  27501
# error = 0.048424666506258825
# loss = tensor(0.0121, device='cuda:0')
# i=  28001
# error = 0.04744551071682484
# loss = tensor(0.0146, device='cuda:0')
# i=  28501
# error = 0.046466378951890916
# loss = tensor(0.0137, device='cuda:0')
# i=  29001
# error = 0.05155176843356408
# loss = tensor(0.0123, device='cuda:0')
# i=  29501
# error = 0.0489209546486547
# loss = tensor(0.0126, device='cuda:0')
# i=  30001
# error = 0.050776341159028474
# loss = tensor(0.0115, device='cuda:0')
# i=  30501
# error = 0.05247251814656361
# loss = tensor(0.0120, device='cuda:0')
# i=  31001
# error = 0.057493189823001056
# loss = tensor(0.0162, device='cuda:0')
# i=  31501
# error = 0.05265509518374341
# loss = tensor(0.0111, device='cuda:0')
# i=  32001
# error = 0.050657663178309234
# loss = tensor(0.0109, device='cuda:0')
# i=  32501
# error = 0.05233453683432748
# loss = tensor(0.0110, device='cuda:0')
# i=  33001
# error = 0.04523659190370411
# loss = tensor(0.0141, device='cuda:0')
# i=  33501
# error = 0.054973781996963414
# loss = tensor(0.0122, device='cuda:0')
# i=  34001
# error = 0.050539872465835
# loss = tensor(0.0108, device='cuda:0')
# i=  34501
# error = 0.04717216491625133
# loss = tensor(0.0111, device='cuda:0')
# i=  35001
# error = 0.052396068628457984
# loss = tensor(0.0110, device='cuda:0')
# i=  35501
# error = 0.05262130958525361
# loss = tensor(0.0105, device='cuda:0')
# i=  36001
# error = 0.052658854590028586
# loss = tensor(0.0106, device='cuda:0')
# i=  36501
# error = 0.049668796649144066
# loss = tensor(0.0102, device='cuda:0')
# i=  37001
# error = 0.05154695008145053
# loss = tensor(0.0101, device='cuda:0')
# i=  37501
# error = 0.05342092008670114
# loss = tensor(0.0102, device='cuda:0')
# i=  38001
# error = 0.052033080816606486
# loss = tensor(0.0099, device='cuda:0')
# i=  38501
# error = 0.05990004910848881
# loss = tensor(0.0191, device='cuda:0')
# i=  39001
# error = 0.052087786618740826
# loss = tensor(0.0099, device='cuda:0')
# i=  39501
# error = 0.04672622894860156
# loss = tensor(0.0169, device='cuda:0')
# i=  40001
# error = 0.05255576453075451
# loss = tensor(0.0097, device='cuda:0')
# i=  40501
# error = 0.05526102604329529
# loss = tensor(0.0106, device='cuda:0')
# i=  41001
# error = 0.04917925699094257
# loss = tensor(0.0107, device='cuda:0')
# i=  41501
# error = 0.051211232899596185
# loss = tensor(0.0097, device='cuda:0')
# i=  42001
# error = 0.059429779812502755
# loss = tensor(0.0183, device='cuda:0')
# i=  42501
# error = 0.052676126126037344
# loss = tensor(0.0096, device='cuda:0')
# i=  43001
# error = 0.048343358887752805
# loss = tensor(0.0137, device='cuda:0')
# i=  43501
# error = 0.051235490172969106
# loss = tensor(0.0096, device='cuda:0')
# i=  44001
# error = 0.049359957542311775
# loss = tensor(0.0116, device='cuda:0')
# i=  44501
# error = 0.055193588386441755
# loss = tensor(0.0096, device='cuda:0')
# i=  45001
# error = 0.052288520691220024
# loss = tensor(0.0092, device='cuda:0')
# i=  45501
# error = 0.04620276076560275
# loss = tensor(0.0102, device='cuda:0')
# i=  46001
# error = 0.05291103127245576
# loss = tensor(0.0100, device='cuda:0')
# i=  46501
# error = 0.05620893507361631
# loss = tensor(0.0162, device='cuda:0')
# i=  47001
# error = 0.04794304532811186
# loss = tensor(0.0122, device='cuda:0')
# i=  47501
# error = 0.049694884115563824
# loss = tensor(0.0091, device='cuda:0')
# i=  48001
# error = 0.05250273408578165
# loss = tensor(0.0109, device='cuda:0')
# i=  48501
# error = 0.047316401381941556
# loss = tensor(0.0107, device='cuda:0')
# i=  49001
# error = 0.051235419668472906
# loss = tensor(0.0090, device='cuda:0')
# i=  49501
# error = 0.05385767927201258
# loss = tensor(0.0112, device='cuda:0')
# time cost 17516.632865428925 s

# %%
plt.plot(np.log10(error[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3c7ba7478601> in <module>
# ----> 1 plt.plot(np.log10(error[1]))
#
# NameError: name 'plt' is not defined

# %%
plt.plot(np.log10(error[0]))

# %%
plt.plot(np.log10(error[2]))
