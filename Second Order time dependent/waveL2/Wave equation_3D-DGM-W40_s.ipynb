# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x2 = torch.rand(1000,4).cuda()
    x3 = torch.rand(1000,4).cuda()
    x4 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    x4[:,3:4] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    loss = loss + torch.sum(model_u(x4)**2)/1000
    return loss

# %%
model_u = ResNet(4,40)
device=torch.device("cuda:1" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=40, bias=True)
#   (fc2): Linear(in_features=40, out_features=40, bias=True)
#   (fc3): Linear(in_features=40, out_features=40, bias=True)
#   (fc4): Linear(in_features=40, out_features=40, bias=True)
#   (outlayer): Linear(in_features=40, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:4].reshape(x.size()[0],3)
    return p

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_3D_s_w40.npy", error_save)
np.save("error_save_DGM_wave_3D_s_w40.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 1.181668483865854
# loss = tensor(27.6036, device='cuda:1')
# i=  501
# error = 0.25609994290271226
# loss = tensor(0.1576, device='cuda:1')
# i=  1001
# error = 0.23382145941426216
# loss = tensor(0.0859, device='cuda:1')
# i=  1501
# error = 0.21941657292949557
# loss = tensor(0.0600, device='cuda:1')
# i=  2001
# error = 0.19595071323245827
# loss = tensor(0.0516, device='cuda:1')
# i=  2501
# error = 0.19944784575660826
# loss = tensor(0.0413, device='cuda:1')
# i=  3001
# error = 0.18947381422426354
# loss = tensor(0.0388, device='cuda:1')
# i=  3501
# error = 0.183600203857871
# loss = tensor(0.0375, device='cuda:1')
# i=  4001
# error = 0.19090752274665973
# loss = tensor(0.0325, device='cuda:1')
# i=  4501
# error = 0.17745866925922021
# loss = tensor(0.0313, device='cuda:1')
# i=  5001
# error = 0.1714202137449377
# loss = tensor(0.0259, device='cuda:1')
# i=  5501
# error = 0.1816115747457974
# loss = tensor(0.0241, device='cuda:1')
# i=  6001
# error = 0.17752806302756313
# loss = tensor(0.0202, device='cuda:1')
# i=  6501
# error = 0.16576329387172303
# loss = tensor(0.0187, device='cuda:1')
# i=  7001
# error = 0.16174783471644144
# loss = tensor(0.0171, device='cuda:1')
# i=  7501
# error = 0.16367533579423452
# loss = tensor(0.0166, device='cuda:1')
# i=  8001
# error = 0.15100560609614175
# loss = tensor(0.0194, device='cuda:1')
# i=  8501
# error = 0.15057571990877341
# loss = tensor(0.0150, device='cuda:1')
# i=  9001
# error = 0.16306422319936217
# loss = tensor(0.0142, device='cuda:1')
# i=  9501
# error = 0.14557967701235297
# loss = tensor(0.0140, device='cuda:1')
# i=  10001
# error = 0.16258765192414493
# loss = tensor(0.0179, device='cuda:1')
# i=  10501
# error = 0.14020954009629918
# loss = tensor(0.0128, device='cuda:1')
# i=  11001
# error = 0.14373002394697157
# loss = tensor(0.0127, device='cuda:1')
# i=  11501
# error = 0.13982559030520617
# loss = tensor(0.0114, device='cuda:1')
# i=  12001
# error = 0.12366656266191642
# loss = tensor(0.0111, device='cuda:1')
# i=  12501
# error = 0.1311987923219886
# loss = tensor(0.0096, device='cuda:1')
# i=  13001
# error = 0.1487623637063656
# loss = tensor(0.0173, device='cuda:1')
# i=  13501
# error = 0.11976481042229316
# loss = tensor(0.0093, device='cuda:1')
# i=  14001
# error = 0.1179149528068512
# loss = tensor(0.0086, device='cuda:1')
# i=  14501
# error = 0.11339493103380711
# loss = tensor(0.0087, device='cuda:1')
# i=  15001
# error = 0.11935233662147063
# loss = tensor(0.0080, device='cuda:1')
# i=  15501
# error = 0.1094221752954323
# loss = tensor(0.0082, device='cuda:1')
# i=  16001
# error = 0.13952594657436646
# loss = tensor(0.0149, device='cuda:1')
# i=  16501
# error = 0.1117244716731937
# loss = tensor(0.0093, device='cuda:1')
# i=  17001
# error = 0.11629622143520964
# loss = tensor(0.0085, device='cuda:1')
# i=  17501
# error = 0.11538053581052425
# loss = tensor(0.0088, device='cuda:1')
# i=  18001
# error = 0.10940307066796118
# loss = tensor(0.0089, device='cuda:1')
# i=  18501
# error = 0.1155488820156276
# loss = tensor(0.0092, device='cuda:1')
# i=  19001
# error = 0.10262737338135143
# loss = tensor(0.0086, device='cuda:1')
# i=  19501
# error = 0.11106479357663977
# loss = tensor(0.0085, device='cuda:1')
# i=  20001
# error = 0.10587862216919221
# loss = tensor(0.0080, device='cuda:1')
# i=  20501
# error = 0.11106954901420461
# loss = tensor(0.0078, device='cuda:1')
# i=  21001
# error = 0.11041963598246816
# loss = tensor(0.0087, device='cuda:1')
# i=  21501
# error = 0.10425447263353822
# loss = tensor(0.0072, device='cuda:1')
# i=  22001
# error = 0.116688183064199
# loss = tensor(0.0084, device='cuda:1')
# i=  22501
# error = 0.1022224009930429
# loss = tensor(0.0069, device='cuda:1')
# i=  23001
# error = 0.10223539357593579
# loss = tensor(0.0076, device='cuda:1')
# i=  23501
# error = 0.10482040462756913
# loss = tensor(0.0083, device='cuda:1')
# i=  24001
# error = 0.10485275439507186
# loss = tensor(0.0095, device='cuda:1')
# i=  24501
# error = 0.1039304660486378
# loss = tensor(0.0086, device='cuda:1')
# i=  25001
# error = 0.09970073890675953
# loss = tensor(0.0087, device='cuda:1')
# i=  25501
# error = 0.0987610984735348
# loss = tensor(0.0085, device='cuda:1')
# i=  26001
# error = 0.11178636983241971
# loss = tensor(0.0087, device='cuda:1')
# i=  26501
# error = 0.10321022620889654
# loss = tensor(0.0083, device='cuda:1')
# i=  27001
# error = 0.10426682262487078
# loss = tensor(0.0075, device='cuda:1')
# i=  27501
# error = 0.0954001472294105
# loss = tensor(0.0081, device='cuda:1')
# i=  28001
# error = 0.09628106751994073
# loss = tensor(0.0071, device='cuda:1')
# i=  28501
# error = 0.09205129166219833
# loss = tensor(0.0078, device='cuda:1')
# i=  29001
# error = 0.09291189259265742
# loss = tensor(0.0065, device='cuda:1')
# i=  29501
# error = 0.0938994190553479
# loss = tensor(0.0063, device='cuda:1')
# i=  30001
# error = 0.09800413054467978
# loss = tensor(0.0074, device='cuda:1')
# i=  30501
# error = 0.09016039198789927
# loss = tensor(0.0065, device='cuda:1')
# i=  31001
# error = 0.09039013148425461
# loss = tensor(0.0068, device='cuda:1')
# i=  31501
# error = 0.09199031569528385
# loss = tensor(0.0071, device='cuda:1')
# i=  32001
# error = 0.09798606908464436
# loss = tensor(0.0082, device='cuda:1')
# i=  32501
# error = 0.10167229940672003
# loss = tensor(0.0087, device='cuda:1')
# i=  33001
# error = 0.09943969516364681
# loss = tensor(0.0095, device='cuda:1')
# i=  33501
# error = 0.10156379520044462
# loss = tensor(0.0101, device='cuda:1')
# i=  34001
# error = 0.09497745539775133
# loss = tensor(0.0089, device='cuda:1')
# i=  34501
# error = 0.09825109897841013
# loss = tensor(0.0084, device='cuda:1')
# i=  35001
# error = 0.09645102421521186
# loss = tensor(0.0084, device='cuda:1')
# i=  35501
# error = 0.09795796027052002
# loss = tensor(0.0078, device='cuda:1')
# i=  36001
# error = 0.09395044803098884
# loss = tensor(0.0075, device='cuda:1')
# i=  36501
# error = 0.10051345071256093
# loss = tensor(0.0075, device='cuda:1')
# i=  37001
# error = 0.09108538613664015
# loss = tensor(0.0060, device='cuda:1')
# i=  37501
# error = 0.0881836401743251
# loss = tensor(0.0059, device='cuda:1')
# i=  38001
# error = 0.08301110472057181
# loss = tensor(0.0057, device='cuda:1')
# i=  38501
# error = 0.08616960387801686
# loss = tensor(0.0053, device='cuda:1')
# i=  39001
# error = 0.08106017391368547
# loss = tensor(0.0080, device='cuda:1')
# i=  39501
# error = 0.08108224483549402
# loss = tensor(0.0051, device='cuda:1')
# i=  40001
# error = 0.09794372381634063
# loss = tensor(0.0058, device='cuda:1')
# i=  40501
# error = 0.08462457193212324
# loss = tensor(0.0053, device='cuda:1')
# i=  41001
# error = 0.0866841466665653
# loss = tensor(0.0057, device='cuda:1')
# i=  41501
# error = 0.08930168141229733
# loss = tensor(0.0054, device='cuda:1')
# i=  42001
# error = 0.08895204501750269
# loss = tensor(0.0052, device='cuda:1')
# i=  42501
# error = 0.08757075194806832
# loss = tensor(0.0052, device='cuda:1')
# i=  43001
# error = 0.07924174204683002
# loss = tensor(0.0042, device='cuda:1')
# i=  43501
# error = 0.07703257153717458
# loss = tensor(0.0045, device='cuda:1')
# i=  44001
# error = 0.07606211205213273
# loss = tensor(0.0040, device='cuda:1')
# i=  44501
# error = 0.08013582759018306
# loss = tensor(0.0041, device='cuda:1')
# i=  45001
# error = 0.07617287147099092
# loss = tensor(0.0037, device='cuda:1')
# i=  45501
# error = 0.07834016155349838
# loss = tensor(0.0038, device='cuda:1')
# i=  46001
# error = 0.06271652314202057
# loss = tensor(0.0058, device='cuda:1')
# i=  46501
# error = 0.07149980459793784
# loss = tensor(0.0034, device='cuda:1')
# i=  47001
# error = 0.06444735705333816
# loss = tensor(0.0032, device='cuda:1')
# i=  47501
# error = 0.07332084690367666
# loss = tensor(0.0057, device='cuda:1')
# i=  48001
# error = 0.0695085888550385
# loss = tensor(0.0042, device='cuda:1')
# i=  48501
# error = 0.057887915991975875
# loss = tensor(0.0041, device='cuda:1')
# i=  49001
# error = 0.06729263342541346
# loss = tensor(0.0036, device='cuda:1')
# i=  49501
# error = 0.054831561863657056
# loss = tensor(0.0033, device='cuda:1')
# time cost 21354.58535695076 s
