# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    Np = Du[:,1:4].reshape(x.size()[0],3)
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss =  torch.sum( (Np-p)**2 )/50000 + torch.sum( (v_t - uxx - source(x))**2 )/50000
    return loss

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    loss = torch.sum(model_v(x1)**2)/1000
    return loss

# %%
model_u1 = ResNet(4,10,1)
model_p1 = ResNet(4,10,3)
device=torch.device("cuda:0" )

model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=3, bias=True)
# )

# %%
def model_u(x):
    return x[:,0:1]*(x*(1-x))[:,1:2]*(x*(1-x))[:,2:3]*(x*(1-x))[:,3:4]*model_u1(x)
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v
def model_p(x):
    return model_p1(x)

# %%
def initparam(model,sigma):
    for m in model.modules():
        if isinstance(m,nn.Linear):
            m.weight.data.uniform_(-sigma,sigma)#全连接层参数初始化
            m.bias.data.uniform_(0,sigma)
    return model

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()}
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss =",losses.detach())
        np.save("error_save_LDG_wave_3D_s_w20_v1.npy", error_save)
np.save("error_save_LDG_wave_3D_s_w20_v1.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 1.0065260767691766
# loss = tensor(27.4974, device='cuda:0')
# i=  501
# error = 0.9725744667042495
# loss = tensor(2.5338, device='cuda:0')
# i=  1001
# error = 0.23523243064123725
# loss = tensor(0.5421, device='cuda:0')
# i=  1501
# error = 0.13179464563088808
# loss = tensor(0.3282, device='cuda:0')
# i=  2001
# error = 0.09079141020956698
# loss = tensor(0.2413, device='cuda:0')
# i=  2501
# error = 0.07053070530899085
# loss = tensor(0.2198, device='cuda:0')
# i=  3001
# error = 0.06115555133001079
# loss = tensor(0.1996, device='cuda:0')
# i=  3501
# error = 0.057913202045145204
# loss = tensor(0.1851, device='cuda:0')
# i=  4001
# error = 0.05613124321114666
# loss = tensor(0.1775, device='cuda:0')
# i=  4501
# error = 0.05600294102769101
# loss = tensor(0.1658, device='cuda:0')
# i=  5001
# error = 0.0560068305736789
# loss = tensor(0.1654, device='cuda:0')
# i=  5501
# error = 0.0548619198155627
# loss = tensor(0.1536, device='cuda:0')
# i=  6001
# error = 0.05581870059162075
# loss = tensor(0.1484, device='cuda:0')
# i=  6501
# error = 0.055193854533652185
# loss = tensor(0.1429, device='cuda:0')
# i=  7001
# error = 0.05553718203940401
# loss = tensor(0.1395, device='cuda:0')
# i=  7501
# error = 0.05534269293190652
# loss = tensor(0.1370, device='cuda:0')
# i=  8001
# error = 0.05483859743201119
# loss = tensor(0.1485, device='cuda:0')
# i=  8501
# error = 0.053430151433335044
# loss = tensor(0.1306, device='cuda:0')
# i=  9001
# error = 0.05365091021006682
# loss = tensor(0.1311, device='cuda:0')
# i=  9501
# error = 0.052713594371424276
# loss = tensor(0.1263, device='cuda:0')
# i=  10001
# error = 0.05090636019777779
# loss = tensor(0.1217, device='cuda:0')
# i=  10501
# error = 0.05067352339889119
# loss = tensor(0.1143, device='cuda:0')
# i=  11001
# error = 0.04890321434890715
# loss = tensor(0.1089, device='cuda:0')
# i=  11501
# error = 0.04791063881408241
# loss = tensor(0.1082, device='cuda:0')
# i=  12001
# error = 0.04739662488861701
# loss = tensor(0.1029, device='cuda:0')
# i=  12501
# error = 0.046196321192719936
# loss = tensor(0.0984, device='cuda:0')
# i=  13001
# error = 0.046242842677013916
# loss = tensor(0.0951, device='cuda:0')
# i=  13501
# error = 0.04475451468315736
# loss = tensor(0.0924, device='cuda:0')
# i=  14001
# error = 0.04397686492691232
# loss = tensor(0.0879, device='cuda:0')
# i=  14501
# error = 0.04364129485896997
# loss = tensor(0.0849, device='cuda:0')
# i=  15001
# error = 0.0422793948215207
# loss = tensor(0.0820, device='cuda:0')
# i=  15501
# error = 0.042038903616694955
# loss = tensor(0.0790, device='cuda:0')
# i=  16001
# error = 0.040995896039898505
# loss = tensor(0.0771, device='cuda:0')
# i=  16501
# error = 0.04116955554395812
# loss = tensor(0.0739, device='cuda:0')
# i=  17001
# error = 0.033262794601897516
# loss = tensor(0.0818, device='cuda:0')
# i=  17501
# error = 0.026412570082417368
# loss = tensor(0.0674, device='cuda:0')
# i=  18001
# error = 0.023911210639633928
# loss = tensor(0.0653, device='cuda:0')
# i=  18501
# error = 0.031827814017602686
# loss = tensor(0.0680, device='cuda:0')
# i=  19001
# error = 0.025288673663693324
# loss = tensor(0.0620, device='cuda:0')
# i=  19501
# error = 0.023290845735963517
# loss = tensor(0.0628, device='cuda:0')
# i=  20001
# error = 0.02583424049620674
# loss = tensor(0.0609, device='cuda:0')
# i=  20501
# error = 0.025434664470223863
# loss = tensor(0.0594, device='cuda:0')
# i=  21001
# error = 0.030741613095900525
# loss = tensor(0.0578, device='cuda:0')
# i=  21501
# error = 0.023551296240491373
# loss = tensor(0.0612, device='cuda:0')
# i=  22001
# error = 0.02661249023689519
# loss = tensor(0.0559, device='cuda:0')
# i=  22501
# error = 0.028879912308149507
# loss = tensor(0.0541, device='cuda:0')
# i=  23001
# error = 0.03621206417453988
# loss = tensor(0.0687, device='cuda:0')
# i=  23501
# error = 0.0338102244553489
# loss = tensor(0.0538, device='cuda:0')
# i=  24001
# error = 0.02887996495921355
# loss = tensor(0.0532, device='cuda:0')
# i=  24501
# error = 0.030614266885090783
# loss = tensor(0.0524, device='cuda:0')
# i=  25001
# error = 0.03290775325696063
# loss = tensor(0.0515, device='cuda:0')
# i=  25501
# error = 0.034002934642901
# loss = tensor(0.0519, device='cuda:0')
# i=  26001
# error = 0.04016020354897591
# loss = tensor(0.0554, device='cuda:0')
# i=  26501
# error = 0.03196371582849941
# loss = tensor(0.0507, device='cuda:0')
# i=  27001
# error = 0.034576353421431054
# loss = tensor(0.0494, device='cuda:0')
# i=  27501
# error = 0.035665544812218494
# loss = tensor(0.0492, device='cuda:0')
# i=  28001
# error = 0.032488042105782294
# loss = tensor(0.0488, device='cuda:0')
# i=  28501
# error = 0.04056291734412127
# loss = tensor(0.0499, device='cuda:0')
# i=  29001
# error = 0.02275360462486449
# loss = tensor(0.0918, device='cuda:0')
# i=  29501
# error = 0.031468434561571036
# loss = tensor(0.0550, device='cuda:0')
# i=  30001
# error = 0.040589129961652946
# loss = tensor(0.0483, device='cuda:0')
# i=  30501
# error = 0.035759978736746675
# loss = tensor(0.0474, device='cuda:0')
# i=  31001
# error = 0.03483496960127473
# loss = tensor(0.0490, device='cuda:0')
# i=  31501
# error = 0.040190390304757795
# loss = tensor(0.0460, device='cuda:0')
# i=  32001
# error = 0.037541558275480134
# loss = tensor(0.0465, device='cuda:0')
# i=  32501
# error = 0.041844187791806355
# loss = tensor(0.0462, device='cuda:0')
# i=  33001
# error = 0.03956819338103558
# loss = tensor(0.0463, device='cuda:0')
# i=  33501
# error = 0.03652188341171685
# loss = tensor(0.0458, device='cuda:0')
# i=  34001
# error = 0.03828946884422648
# loss = tensor(0.0442, device='cuda:0')
# i=  34501
# error = 0.0424493886448056
# loss = tensor(0.0467, device='cuda:0')
# i=  35001
# error = 0.04325077304698495
# loss = tensor(0.0450, device='cuda:0')
# i=  35501
# error = 0.03964121799866647
# loss = tensor(0.0443, device='cuda:0')
# i=  36001
# error = 0.03778000955432092
# loss = tensor(0.0463, device='cuda:0')
# i=  36501
# error = 0.0419059976448343
# loss = tensor(0.0443, device='cuda:0')
# i=  37001
# error = 0.03572702031091199
# loss = tensor(0.0481, device='cuda:0')
# i=  37501
# error = 0.04184098816855743
# loss = tensor(0.0452, device='cuda:0')
# i=  38001
# error = 0.04006585893755808
# loss = tensor(0.0437, device='cuda:0')
# i=  38501
# error = 0.04147342521305893
# loss = tensor(0.0492, device='cuda:0')
# i=  39001
# error = 0.045060738274099565
# loss = tensor(0.0442, device='cuda:0')
# i=  39501
# error = 0.037623784209200366
# loss = tensor(0.0459, device='cuda:0')
# i=  40001
# error = 0.044092121905539815
# loss = tensor(0.0433, device='cuda:0')
# i=  40501
# error = 0.046169885192123165
# loss = tensor(0.0668, device='cuda:0')
# i=  41001
# error = 0.040589580315321616
# loss = tensor(0.0424, device='cuda:0')
# i=  41501
# error = 0.041694502475343564
# loss = tensor(0.0411, device='cuda:0')
# i=  42001
# error = 0.038333631754357146
# loss = tensor(0.0420, device='cuda:0')
# i=  42501
# error = 0.041250044544537255
# loss = tensor(0.0415, device='cuda:0')
# i=  43001
# error = 0.04132968526765709
# loss = tensor(0.0405, device='cuda:0')
# i=  43501
# error = 0.04423273676545048
# loss = tensor(0.0445, device='cuda:0')
# i=  44001
# error = 0.042307043181876565
# loss = tensor(0.0414, device='cuda:0')
# i=  44501
# error = 0.04177735477058114
# loss = tensor(0.0404, device='cuda:0')
# i=  45001
# error = 0.03680304969860654
# loss = tensor(0.0495, device='cuda:0')
# i=  45501
# error = 0.04548320267461182
# loss = tensor(0.0411, device='cuda:0')
# i=  46001
# error = 0.0391712232295162
# loss = tensor(0.0424, device='cuda:0')
# i=  46501
# error = 0.04146052149503532
# loss = tensor(0.0413, device='cuda:0')
# i=  47001
# error = 0.03928502688234561
# loss = tensor(0.0418, device='cuda:0')
# i=  47501
# error = 0.041881861126801964
# loss = tensor(0.0394, device='cuda:0')
# i=  48001
# error = 0.044698163482790314
# loss = tensor(0.0415, device='cuda:0')
# i=  48501
# error = 0.04163244378743477
# loss = tensor(0.0403, device='cuda:0')
# i=  49001
# error = 0.0429909795509164
# loss = tensor(0.0397, device='cuda:0')
# i=  49501
# error = 0.04119986586166263
# loss = tensor(0.0395, device='cuda:0')
# time cost 5324.844535589218 s

# %%
plt.plot(np.log10(error[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3c7ba7478601> in <module>
# ----> 1 plt.plot(np.log10(error[1]))
#
# NameError: name 'plt' is not defined

# %%
plt.plot(np.log10(error[0]))

# %%
plt.plot(np.log10(error[2]))
