# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        
        output = self.outlayer(y)
        return output
deg = 3

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    Np = Du[:,1:4].reshape(x.size()[0],3)
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss =  torch.sum( (Np-p)**2 )/50000 + torch.sum( (v_t - uxx - source(x))**2 )/50000
    return loss

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    loss = torch.sum(model_v(x1)**2)/1000
    return loss

# %%
model_u1 = ResNet(4,20,1)
model_p1 = ResNet(4,20,3)
device=torch.device("cuda:0" )

model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=20, bias=True)
#   (fc3): Linear(in_features=20, out_features=20, bias=True)
#   (fc4): Linear(in_features=20, out_features=20, bias=True)
#   (outlayer): Linear(in_features=20, out_features=3, bias=True)
# )

# %%
def model_u(x):
    return x[:,0:1]*(x*(1-x))[:,1:2]*(x*(1-x))[:,2:3]*(x*(1-x))[:,3:4]*model_u1(x)
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v
def model_p(x):
    return model_p1(x)

# %%
def initparam(model,sigma):
    for m in model.modules():
        if isinstance(m,nn.Linear):
            m.weight.data.uniform_(-sigma,sigma)#全连接层参数初始化
            m.bias.data.uniform_(0,sigma)
    return model

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()}
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss =",losses.detach())
        np.save("error_save_LDG_wave_3D_q_w20_v1.npy", error_save)
np.save("error_save_LDG_wave_3D_q_w20_v1.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.9925212094836634
# loss = tensor(25.5380, device='cuda:0')
# i=  501
# error = 0.07002507816713688
# loss = tensor(0.2246, device='cuda:0')
# i=  1001
# error = 0.07732089979859498
# loss = tensor(0.0889, device='cuda:0')
# i=  1501
# error = 0.07721404048151695
# loss = tensor(0.0563, device='cuda:0')
# i=  2001
# error = 0.08208162657929335
# loss = tensor(0.0365, device='cuda:0')
# i=  2501
# error = 0.07658943368670638
# loss = tensor(0.0286, device='cuda:0')
# i=  3001
# error = 0.0741561083084879
# loss = tensor(0.0233, device='cuda:0')
# i=  3501
# error = 0.07183196978185108
# loss = tensor(0.0200, device='cuda:0')
# i=  4001
# error = 0.06862550195605685
# loss = tensor(0.0175, device='cuda:0')
# i=  4501
# error = 0.06464111820803524
# loss = tensor(0.0153, device='cuda:0')
# i=  5001
# error = 0.06098634625609133
# loss = tensor(0.0137, device='cuda:0')
# i=  5501
# error = 0.056360833368028176
# loss = tensor(0.0142, device='cuda:0')
# i=  6001
# error = 0.06019781161458012
# loss = tensor(0.0142, device='cuda:0')
# i=  6501
# error = 0.05626104421537264
# loss = tensor(0.0101, device='cuda:0')
# i=  7001
# error = 0.062205303612709796
# loss = tensor(0.0142, device='cuda:0')
# i=  7501
# error = 0.05318253662459977
# loss = tensor(0.0087, device='cuda:0')
# i=  8001
# error = 0.0534727053048439
# loss = tensor(0.0085, device='cuda:0')
# i=  8501
# error = 0.04777766625704088
# loss = tensor(0.0089, device='cuda:0')
# i=  9001
# error = 0.04816995759245943
# loss = tensor(0.0081, device='cuda:0')
# i=  9501
# error = 0.04788812341716696
# loss = tensor(0.0072, device='cuda:0')
# i=  10001
# error = 0.045807728943539454
# loss = tensor(0.0069, device='cuda:0')
# i=  10501
# error = 0.048119282199911136
# loss = tensor(0.0070, device='cuda:0')
# i=  11001
# error = 0.04521410454915716
# loss = tensor(0.0063, device='cuda:0')
# i=  11501
# error = 0.04498041200918688
# loss = tensor(0.0060, device='cuda:0')
# i=  12001
# error = 0.0416475340507859
# loss = tensor(0.0058, device='cuda:0')
# i=  12501
# error = 0.04298797995149646
# loss = tensor(0.0054, device='cuda:0')
# i=  13001
# error = 0.04369221202685607
# loss = tensor(0.0053, device='cuda:0')
# i=  13501
# error = 0.04236676622410387
# loss = tensor(0.0055, device='cuda:0')
# i=  14001
# error = 0.04177860853440679
# loss = tensor(0.0056, device='cuda:0')
# i=  14501
# error = 0.041055076754149315
# loss = tensor(0.0049, device='cuda:0')
# i=  15001
# error = 0.0399725675011291
# loss = tensor(0.0046, device='cuda:0')
# i=  15501
# error = 0.03913456725418891
# loss = tensor(0.0046, device='cuda:0')
# i=  16001
# error = 0.03998747380022292
# loss = tensor(0.0044, device='cuda:0')
# i=  16501
# error = 0.03775610415196149
# loss = tensor(0.0051, device='cuda:0')
# i=  17001
# error = 0.034950046969467456
# loss = tensor(0.0051, device='cuda:0')
# i=  17501
# error = 0.03868571809395845
# loss = tensor(0.0040, device='cuda:0')
# i=  18001
# error = 0.03540769935638547
# loss = tensor(0.0039, device='cuda:0')
# i=  18501
# error = 0.03700841755368485
# loss = tensor(0.0044, device='cuda:0')
# i=  19001
# error = 0.036010875762787775
# loss = tensor(0.0038, device='cuda:0')
# i=  19501
# error = 0.03487842238152324
# loss = tensor(0.0037, device='cuda:0')
# i=  20001
# error = 0.033765481531693585
# loss = tensor(0.0036, device='cuda:0')
# i=  20501
# error = 0.03447297449223826
# loss = tensor(0.0036, device='cuda:0')
# i=  21001
# error = 0.03289313113818691
# loss = tensor(0.0034, device='cuda:0')
# i=  21501
# error = 0.03245706005765519
# loss = tensor(0.0034, device='cuda:0')
# i=  22001
# error = 0.031012629529551323
# loss = tensor(0.0034, device='cuda:0')
# i=  22501
# error = 0.03200480608548773
# loss = tensor(0.0033, device='cuda:0')
# i=  23001
# error = 0.0310381589836478
# loss = tensor(0.0035, device='cuda:0')
# i=  23501
# error = 0.031806293848621256
# loss = tensor(0.0031, device='cuda:0')
# i=  24001
# error = 0.028755428312411072
# loss = tensor(0.0036, device='cuda:0')
# i=  24501
# error = 0.029695088053707776
# loss = tensor(0.0030, device='cuda:0')
# i=  25001
# error = 0.03631237266308126
# loss = tensor(0.0134, device='cuda:0')
# i=  25501
# error = 0.030098188778967853
# loss = tensor(0.0028, device='cuda:0')
# i=  26001
# error = 0.029251813634456107
# loss = tensor(0.0029, device='cuda:0')
# i=  26501
# error = 0.028433589060966134
# loss = tensor(0.0028, device='cuda:0')
# i=  27001
# error = 0.029463063348513008
# loss = tensor(0.0029, device='cuda:0')
# i=  27501
# error = 0.026846943699920845
# loss = tensor(0.0028, device='cuda:0')
# i=  28001
# error = 0.03334914767355264
# loss = tensor(0.0066, device='cuda:0')
# i=  28501
# error = 0.028345340610840784
# loss = tensor(0.0026, device='cuda:0')
# i=  29001
# error = 0.03021086542893567
# loss = tensor(0.0036, device='cuda:0')
# i=  29501
# error = 0.029191944444664792
# loss = tensor(0.0026, device='cuda:0')
# i=  30001
# error = 0.025020090210548296
# loss = tensor(0.0045, device='cuda:0')
# i=  30501
# error = 0.027131787377862055
# loss = tensor(0.0027, device='cuda:0')
# i=  31001
# error = 0.027617067452783264
# loss = tensor(0.0027, device='cuda:0')
# i=  31501
# error = 0.027502947832479852
# loss = tensor(0.0024, device='cuda:0')
# i=  32001
# error = 0.025770482989041547
# loss = tensor(0.0024, device='cuda:0')
# i=  32501
# error = 0.026965012024227658
# loss = tensor(0.0024, device='cuda:0')
# i=  33001
# error = 0.026332510830646135
# loss = tensor(0.0023, device='cuda:0')
# i=  33501
# error = 0.024714556824839713
# loss = tensor(0.0026, device='cuda:0')
# i=  34001
# error = 0.0265784443914253
# loss = tensor(0.0026, device='cuda:0')
# i=  34501
# error = 0.024391727617441596
# loss = tensor(0.0026, device='cuda:0')
# i=  35001
# error = 0.024538191214984566
# loss = tensor(0.0024, device='cuda:0')
# i=  35501
# error = 0.02568308861727076
# loss = tensor(0.0021, device='cuda:0')
# i=  36001
# error = 0.024678183207709734
# loss = tensor(0.0021, device='cuda:0')
# i=  36501
# error = 0.025059333219759148
# loss = tensor(0.0021, device='cuda:0')
# i=  37001
# error = 0.02596683351912831
# loss = tensor(0.0023, device='cuda:0')
# i=  37501
# error = 0.02372659440050669
# loss = tensor(0.0029, device='cuda:0')
# i=  38001
# error = 0.024451013916677335
# loss = tensor(0.0020, device='cuda:0')
# i=  38501
# error = 0.02431382491060804
# loss = tensor(0.0020, device='cuda:0')
# i=  39001
# error = 0.02487740724901915
# loss = tensor(0.0020, device='cuda:0')
# i=  39501
# error = 0.0243859427475057
# loss = tensor(0.0020, device='cuda:0')
# i=  40001
# error = 0.024348801073550464
# loss = tensor(0.0020, device='cuda:0')
# i=  40501
# error = 0.024424679251639634
# loss = tensor(0.0021, device='cuda:0')
# i=  41001
# error = 0.024746565009850528
# loss = tensor(0.0025, device='cuda:0')
# i=  41501
# error = 0.02476305304691095
# loss = tensor(0.0022, device='cuda:0')
# i=  42001
# error = 0.02417324800805133
# loss = tensor(0.0018, device='cuda:0')
# i=  42501
# error = 0.02438324286236285
# loss = tensor(0.0019, device='cuda:0')
# i=  43001
# error = 0.023266446338012954
# loss = tensor(0.0018, device='cuda:0')
# i=  43501
# error = 0.021747944717489538
# loss = tensor(0.0024, device='cuda:0')
# i=  44001
# error = 0.02329292251762396
# loss = tensor(0.0018, device='cuda:0')
# i=  44501
# error = 0.022858926538263033
# loss = tensor(0.0018, device='cuda:0')
# i=  45001
# error = 0.02365174536711357
# loss = tensor(0.0018, device='cuda:0')
# i=  45501
# error = 0.024388998667906663
# loss = tensor(0.0022, device='cuda:0')
# i=  46001
# error = 0.0222502134125901
# loss = tensor(0.0017, device='cuda:0')
# i=  46501
# error = 0.023957800707024114
# loss = tensor(0.0018, device='cuda:0')
# i=  47001
# error = 0.025484097171879647
# loss = tensor(0.0028, device='cuda:0')
# i=  47501
# error = 0.024163801573362474
# loss = tensor(0.0018, device='cuda:0')
# i=  48001
# error = 0.02283281149255268
# loss = tensor(0.0016, device='cuda:0')
# i=  48501
# error = 0.020053761349836514
# loss = tensor(0.0036, device='cuda:0')
# i=  49001
# error = 0.02553576109160843
# loss = tensor(0.0053, device='cuda:0')
# i=  49501
# error = 0.021914483229321578
# loss = tensor(0.0018, device='cuda:0')
# time cost 19168.615154266357 s

# %%
plt.plot(np.log10(error[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3c7ba7478601> in <module>
# ----> 1 plt.plot(np.log10(error[1]))
#
# NameError: name 'plt' is not defined

# %%
plt.plot(np.log10(error[0]))

# %%
plt.plot(np.log10(error[2]))
