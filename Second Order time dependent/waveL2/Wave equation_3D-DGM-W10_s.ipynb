# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x2 = torch.rand(1000,4).cuda()
    x3 = torch.rand(1000,4).cuda()
    x4 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    x4[:,3:4] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    loss = loss + torch.sum(model_u(x4)**2)/1000
    return loss

# %%
model_u = ResNet(4,10)
device=torch.device("cuda:1" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:4].reshape(x.size()[0],3)
    return p

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_3D_s_w10.npy", error_save)
np.save("error_save_DGM_wave_3D_s_w10.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.9761989242361727
# loss = tensor(27.2035, device='cuda:1')
# i=  501
# error = 0.3917793302329782
# loss = tensor(0.7431, device='cuda:1')
# i=  1001
# error = 0.2907692510734137
# loss = tensor(0.3929, device='cuda:1')
# i=  1501
# error = 0.28744700691619435
# loss = tensor(0.3574, device='cuda:1')
# i=  2001
# error = 0.3113327893067337
# loss = tensor(0.3662, device='cuda:1')
# i=  2501
# error = 0.36866896810869526
# loss = tensor(0.2597, device='cuda:1')
# i=  3001
# error = 0.34358929930152937
# loss = tensor(0.2048, device='cuda:1')
# i=  3501
# error = 0.34658813618906553
# loss = tensor(0.1700, device='cuda:1')
# i=  4001
# error = 0.3366681810113893
# loss = tensor(0.1301, device='cuda:1')
# i=  4501
# error = 0.341560158645361
# loss = tensor(0.1042, device='cuda:1')
# i=  5001
# error = 0.32044705125250716
# loss = tensor(0.0921, device='cuda:1')
# i=  5501
# error = 0.31137558240687946
# loss = tensor(0.0833, device='cuda:1')
# i=  6001
# error = 0.2775341087954709
# loss = tensor(0.0743, device='cuda:1')
# i=  6501
# error = 0.26759216307319506
# loss = tensor(0.0661, device='cuda:1')
# i=  7001
# error = 0.26088439696250054
# loss = tensor(0.0619, device='cuda:1')
# i=  7501
# error = 0.2478529022054451
# loss = tensor(0.0571, device='cuda:1')
# i=  8001
# error = 0.25676183116971835
# loss = tensor(0.0533, device='cuda:1')
# i=  8501
# error = 0.24049489050467435
# loss = tensor(0.0494, device='cuda:1')
# i=  9001
# error = 0.2446740761593119
# loss = tensor(0.0464, device='cuda:1')
# i=  9501
# error = 0.23339688522304844
# loss = tensor(0.0458, device='cuda:1')
# i=  10001
# error = 0.23218387238597107
# loss = tensor(0.0424, device='cuda:1')
# i=  10501
# error = 0.23987408479465272
# loss = tensor(0.0412, device='cuda:1')
# i=  11001
# error = 0.2421175674188545
# loss = tensor(0.0416, device='cuda:1')
# i=  11501
# error = 0.23006661771533962
# loss = tensor(0.0387, device='cuda:1')
# i=  12001
# error = 0.23141569646375212
# loss = tensor(0.0370, device='cuda:1')
# i=  12501
# error = 0.23298394259375863
# loss = tensor(0.0357, device='cuda:1')
# i=  13001
# error = 0.21574969697124372
# loss = tensor(0.0375, device='cuda:1')
# i=  13501
# error = 0.2281832100162376
# loss = tensor(0.0341, device='cuda:1')
# i=  14001
# error = 0.24969729766402102
# loss = tensor(0.0386, device='cuda:1')
# i=  14501
# error = 0.24612120211795904
# loss = tensor(0.0359, device='cuda:1')
# i=  15001
# error = 0.22925013956330764
# loss = tensor(0.0317, device='cuda:1')
# i=  15501
# error = 0.23809172244353438
# loss = tensor(0.0343, device='cuda:1')
# i=  16001
# error = 0.22807111751481896
# loss = tensor(0.0351, device='cuda:1')
# i=  16501
# error = 0.22464023501618127
# loss = tensor(0.0459, device='cuda:1')
# i=  17001
# error = 0.22876534312440358
# loss = tensor(0.0673, device='cuda:1')
# i=  17501
# error = 0.21090382661676732
# loss = tensor(0.0767, device='cuda:1')
# i=  18001
# error = 0.22949825951276184
# loss = tensor(0.0765, device='cuda:1')
# i=  18501
# error = 0.22555520159193052
# loss = tensor(0.1143, device='cuda:1')
# i=  19001
# error = 0.21697465545768568
# loss = tensor(0.0989, device='cuda:1')
# i=  19501
# error = 0.22866063251018318
# loss = tensor(0.0811, device='cuda:1')
# i=  20001
# error = 0.2451285340611231
# loss = tensor(0.0696, device='cuda:1')
# i=  20501
# error = 0.2360608464526732
# loss = tensor(0.0626, device='cuda:1')
# i=  21001
# error = 0.22611105046037877
# loss = tensor(0.0562, device='cuda:1')
# i=  21501
# error = 0.24301973809643573
# loss = tensor(0.0521, device='cuda:1')
# i=  22001
# error = 0.21948729917058687
# loss = tensor(0.0446, device='cuda:1')
# i=  22501
# error = 0.2109528053847737
# loss = tensor(0.0422, device='cuda:1')
# i=  23001
# error = 0.21978609324301188
# loss = tensor(0.0385, device='cuda:1')
# i=  23501
# error = 0.22326961553818986
# loss = tensor(0.0380, device='cuda:1')
# i=  24001
# error = 0.2210529827331893
# loss = tensor(0.0358, device='cuda:1')
# i=  24501
# error = 0.23451272772398943
# loss = tensor(0.0377, device='cuda:1')
# i=  25001
# error = 0.21813995685642218
# loss = tensor(0.0337, device='cuda:1')
# i=  25501
# error = 0.22161006540055456
# loss = tensor(0.0337, device='cuda:1')
# i=  26001
# error = 0.23469135330923646
# loss = tensor(0.0329, device='cuda:1')
# i=  26501
# error = 0.235757731946907
# loss = tensor(0.0302, device='cuda:1')
# i=  27001
# error = 0.23690628477813638
# loss = tensor(0.0303, device='cuda:1')
# i=  27501
# error = 0.23100318122889102
# loss = tensor(0.0285, device='cuda:1')
# i=  28001
# error = 0.23310450203801852
# loss = tensor(0.0275, device='cuda:1')
# i=  28501
# error = 0.21263684532164046
# loss = tensor(0.0328, device='cuda:1')
# i=  29001
# error = 0.22480483174127788
# loss = tensor(0.0270, device='cuda:1')
# i=  29501
# error = 0.23158846932602226
# loss = tensor(0.0269, device='cuda:1')
# i=  30001
# error = 0.2210015041954016
# loss = tensor(0.0283, device='cuda:1')
# i=  30501
# error = 0.2382459130711239
# loss = tensor(0.0275, device='cuda:1')
# i=  31001
# error = 0.22430956117734555
# loss = tensor(0.0256, device='cuda:1')
# i=  31501
# error = 0.2171752449636315
# loss = tensor(0.0265, device='cuda:1')
# i=  32001
# error = 0.22381195639683174
# loss = tensor(0.0254, device='cuda:1')
# i=  32501
# error = 0.2217996627668767
# loss = tensor(0.0261, device='cuda:1')
# i=  33001
# error = 0.2127946700366364
# loss = tensor(0.0271, device='cuda:1')
# i=  33501
# error = 0.22561147158934727
# loss = tensor(0.0247, device='cuda:1')
# i=  34001
# error = 0.22263170870812335
# loss = tensor(0.0241, device='cuda:1')
# i=  34501
# error = 0.22189553353035507
# loss = tensor(0.0242, device='cuda:1')
# i=  35001
# error = 0.2213893467138155
# loss = tensor(0.0233, device='cuda:1')
# i=  35501
# error = 0.21513809616616617
# loss = tensor(0.0235, device='cuda:1')
# i=  36001
# error = 0.2165912443913487
# loss = tensor(0.0222, device='cuda:1')
# i=  36501
# error = 0.22212359811828988
# loss = tensor(0.0244, device='cuda:1')
# i=  37001
# error = 0.21698776188061977
# loss = tensor(0.0224, device='cuda:1')
# i=  37501
# error = 0.19620102024293137
# loss = tensor(0.0260, device='cuda:1')
# i=  38001
# error = 0.22033570797500757
# loss = tensor(0.0213, device='cuda:1')
# i=  38501
# error = 0.20957358319984318
# loss = tensor(0.0216, device='cuda:1')
# i=  39001
# error = 0.20608056455996876
# loss = tensor(0.0222, device='cuda:1')
# i=  39501
# error = 0.21394611911982184
# loss = tensor(0.0212, device='cuda:1')
# i=  40001
# error = 0.21846702932999854
# loss = tensor(0.0218, device='cuda:1')
# i=  40501
# error = 0.21820201039148487
# loss = tensor(0.0212, device='cuda:1')
# i=  41001
# error = 0.2183689543094149
# loss = tensor(0.0210, device='cuda:1')
# i=  41501
# error = 0.21866198760441444
# loss = tensor(0.0211, device='cuda:1')
# i=  42001
# error = 0.2199096067148679
# loss = tensor(0.0215, device='cuda:1')
# i=  42501
# error = 0.20996985468505203
# loss = tensor(0.0211, device='cuda:1')
# i=  43001
# error = 0.21048006729234672
# loss = tensor(0.0216, device='cuda:1')
# i=  43501
# error = 0.21108174361367613
# loss = tensor(0.0213, device='cuda:1')
# i=  44001
# error = 0.21508688545930235
# loss = tensor(0.0220, device='cuda:1')
# i=  44501
# error = 0.2157994290090666
# loss = tensor(0.0218, device='cuda:1')
# i=  45001
# error = 0.21000578523800537
# loss = tensor(0.0219, device='cuda:1')
# i=  45501
# error = 0.212506216231242
# loss = tensor(0.0217, device='cuda:1')
# i=  46001
# error = 0.2182421861169563
# loss = tensor(0.0220, device='cuda:1')
# i=  46501
# error = 0.20387784124177863
# loss = tensor(0.0238, device='cuda:1')
# i=  47001
# error = 0.21009350699506674
# loss = tensor(0.0231, device='cuda:1')
# i=  47501
# error = 0.20974797333533116
# loss = tensor(0.0257, device='cuda:1')
# i=  48001
# error = 0.20005116172103418
# loss = tensor(0.0276, device='cuda:1')
# i=  48501
# error = 0.21491598406454085
# loss = tensor(0.0286, device='cuda:1')
# i=  49001
# error = 0.22264577037675246
# loss = tensor(0.0319, device='cuda:1')
# i=  49501
# error = 0.20591453855992414
# loss = tensor(0.0335, device='cuda:1')
# time cost 19867.754025697708 s
