# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],4).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    sol =  sol +  (2*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,3).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(2):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,3).cuda()
    x2 = torch.rand(1000,3).cuda()
    x3 = torch.rand(1000,3).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    return loss

# %%
model_u = ResNet(3,40)
device=torch.device("cuda:0" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=3, out_features=40, bias=True)
#   (fc2): Linear(in_features=40, out_features=40, bias=True)
#   (fc3): Linear(in_features=40, out_features=40, bias=True)
#   (fc4): Linear(in_features=40, out_features=40, bias=True)
#   (outlayer): Linear(in_features=40, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:3].reshape(x.size()[0],2)
    return p

# %%
notes = torch.rand(10000,3).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:4])**2)/10000)
def loss_error():
    notes = torch.rand(10000,3).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,4).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:4] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:4] - predict[:,2:4])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_2D_s_w40.npy", error_save)
np.save("error_save_DGM_wave_2D_s_w40.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.6473897974555459
# loss = tensor(26.8568, device='cuda:0')
# i=  501
# error = 0.14769509982143045
# loss = tensor(0.0623, device='cuda:0')
# i=  1001
# error = 0.11480285130914328
# loss = tensor(0.0312, device='cuda:0')
# i=  1501
# error = 0.10845134120897468
# loss = tensor(0.0204, device='cuda:0')
# i=  2001
# error = 0.10155572948444955
# loss = tensor(0.0182, device='cuda:0')
# i=  2501
# error = 0.09087130911379994
# loss = tensor(0.0173, device='cuda:0')
# i=  3001
# error = 0.09727170133202293
# loss = tensor(0.0151, device='cuda:0')
# i=  3501
# error = 0.0972253095761216
# loss = tensor(0.0108, device='cuda:0')
# i=  4001
# error = 0.08948504217072369
# loss = tensor(0.0090, device='cuda:0')
# i=  4501
# error = 0.08202042277115933
# loss = tensor(0.0093, device='cuda:0')
# i=  5001
# error = 0.08425839076350317
# loss = tensor(0.0082, device='cuda:0')
# i=  5501
# error = 0.07253465977511796
# loss = tensor(0.0078, device='cuda:0')
# i=  6001
# error = 0.07330421593813168
# loss = tensor(0.0068, device='cuda:0')
# i=  6501
# error = 0.06848731399520157
# loss = tensor(0.0074, device='cuda:0')
# i=  7001
# error = 0.06172820931106835
# loss = tensor(0.0069, device='cuda:0')
# i=  7501
# error = 0.06291290028545468
# loss = tensor(0.0056, device='cuda:0')
# i=  8001
# error = 0.0533212843366547
# loss = tensor(0.0090, device='cuda:0')
# i=  8501
# error = 0.05121033931434535
# loss = tensor(0.0045, device='cuda:0')
# i=  9001
# error = 0.07050969387477594
# loss = tensor(0.0186, device='cuda:0')
# i=  9501
# error = 0.04544711362573779
# loss = tensor(0.0040, device='cuda:0')
# i=  10001
# error = 0.04056361783737317
# loss = tensor(0.0038, device='cuda:0')
# i=  10501
# error = 0.03936324265070266
# loss = tensor(0.0033, device='cuda:0')
# i=  11001
# error = 0.043544604715441276
# loss = tensor(0.0051, device='cuda:0')
# i=  11501
# error = 0.03261859148164824
# loss = tensor(0.0036, device='cuda:0')
# i=  12001
# error = 0.09310900616574969
# loss = tensor(0.0124, device='cuda:0')
# i=  12501
# error = 0.05542084309680048
# loss = tensor(0.0054, device='cuda:0')
# i=  13001
# error = 0.056148497943723744
# loss = tensor(0.0051, device='cuda:0')
# i=  13501
# error = 0.04436384996297841
# loss = tensor(0.0035, device='cuda:0')
# i=  14001
# error = 0.04073903387902444
# loss = tensor(0.0037, device='cuda:0')
# i=  14501
# error = 0.03531126263197888
# loss = tensor(0.0030, device='cuda:0')
# i=  15001
# error = 0.032744238284803114
# loss = tensor(0.0028, device='cuda:0')
# i=  15501
# error = 0.02921025167949925
# loss = tensor(0.0026, device='cuda:0')
# i=  16001
# error = 0.028775910591342765
# loss = tensor(0.0022, device='cuda:0')
# i=  16501
# error = 0.02368103844205199
# loss = tensor(0.0021, device='cuda:0')
# i=  17001
# error = 0.021519367769998757
# loss = tensor(0.0029, device='cuda:0')
# i=  17501
# error = 0.028978505620659328
# loss = tensor(0.0028, device='cuda:0')
# i=  18001
# error = 0.020964438416993917
# loss = tensor(0.0021, device='cuda:0')
# i=  18501
# error = 0.025641284413708332
# loss = tensor(0.0021, device='cuda:0')
# i=  19001
# error = 0.020651584010043
# loss = tensor(0.0025, device='cuda:0')
# i=  19501
# error = 0.022806635678805986
# loss = tensor(0.0020, device='cuda:0')
# i=  20001
# error = 0.022380086605745073
# loss = tensor(0.0022, device='cuda:0')
# i=  20501
# error = 0.024005412951056057
# loss = tensor(0.0022, device='cuda:0')
# i=  21001
# error = 0.02304174957434042
# loss = tensor(0.0026, device='cuda:0')
# i=  21501
# error = 0.021997278320022132
# loss = tensor(0.0020, device='cuda:0')
# i=  22001
# error = 0.031248114408940104
# loss = tensor(0.0026, device='cuda:0')
# i=  22501
# error = 0.02405054623299201
# loss = tensor(0.0015, device='cuda:0')
# i=  23001
# error = 0.019765357195416864
# loss = tensor(0.0014, device='cuda:0')
# i=  23501
# error = 0.019855798687520087
# loss = tensor(0.0013, device='cuda:0')
# i=  24001
# error = 0.021562063447687668
# loss = tensor(0.0015, device='cuda:0')
# i=  24501
# error = 0.016753384546704456
# loss = tensor(0.0048, device='cuda:0')
# i=  25001
# error = 0.017259621402027046
# loss = tensor(0.0011, device='cuda:0')
# i=  25501
# error = 0.016069415866818145
# loss = tensor(0.0011, device='cuda:0')
# i=  26001
# error = 0.014679789097081246
# loss = tensor(0.0014, device='cuda:0')
# i=  26501
# error = 0.020452385827455382
# loss = tensor(0.0014, device='cuda:0')
# i=  27001
# error = 0.030312675222285923
# loss = tensor(0.0041, device='cuda:0')
# i=  27501
# error = 0.024054137558005513
# loss = tensor(0.0030, device='cuda:0')
# i=  28001
# error = 0.018455137907962476
# loss = tensor(0.0023, device='cuda:0')
# i=  28501
# error = 0.015017620476214133
# loss = tensor(0.0027, device='cuda:0')
# i=  29001
# error = 0.018693603983104226
# loss = tensor(0.0012, device='cuda:0')
# i=  29501
# error = 0.020339083535334333
# loss = tensor(0.0013, device='cuda:0')
# i=  30001
# error = 0.017073245623819476
# loss = tensor(0.0025, device='cuda:0')
# i=  30501
# error = 0.024617898128312072
# loss = tensor(0.0030, device='cuda:0')
# i=  31001
# error = 0.03589543091564518
# loss = tensor(0.0078, device='cuda:0')
# i=  31501
# error = 0.023067910215095112
# loss = tensor(0.0055, device='cuda:0')
# i=  32001
# error = 0.023218880998419535
# loss = tensor(0.0050, device='cuda:0')
# i=  32501
# error = 0.0325548101840058
# loss = tensor(0.0040, device='cuda:0')
# i=  33001
# error = 0.035337466831434836
# loss = tensor(0.0029, device='cuda:0')
# i=  33501
# error = 0.021645568992502133
# loss = tensor(0.0035, device='cuda:0')
# i=  34001
# error = 0.026447771524533606
# loss = tensor(0.0021, device='cuda:0')
# i=  34501
# error = 0.017354792904954883
# loss = tensor(0.0037, device='cuda:0')
# i=  35001
# error = 0.028990773195928108
# loss = tensor(0.0027, device='cuda:0')
# i=  35501
# error = 0.03131079901589183
# loss = tensor(0.0028, device='cuda:0')
# i=  36001
# error = 0.027548913146259953
# loss = tensor(0.0021, device='cuda:0')
# i=  36501
# error = 0.025158913300118643
# loss = tensor(0.0019, device='cuda:0')
# i=  37001
# error = 0.019498060450326166
# loss = tensor(0.0023, device='cuda:0')
# i=  37501
# error = 0.023695501657232693
# loss = tensor(0.0016, device='cuda:0')
# i=  38001
# error = 0.018420788779766235
# loss = tensor(0.0016, device='cuda:0')
# i=  38501
# error = 0.016913562940353868
# loss = tensor(0.0016, device='cuda:0')
# i=  39001
# error = 0.017394943186547912
# loss = tensor(0.0014, device='cuda:0')
# i=  39501
# error = 0.017007339288696084
# loss = tensor(0.0013, device='cuda:0')
# i=  40001
# error = 0.015935979126594564
# loss = tensor(0.0013, device='cuda:0')
# i=  40501
# error = 0.0153285191221173
# loss = tensor(0.0012, device='cuda:0')
# i=  41001
# error = 0.025689929598409888
# loss = tensor(0.0041, device='cuda:0')
# i=  41501
# error = 0.011216671414724315
# loss = tensor(0.0018, device='cuda:0')
# i=  42001
# error = 0.016275988545753642
# loss = tensor(0.0011, device='cuda:0')
# i=  42501
# error = 0.015863626506208154
# loss = tensor(0.0010, device='cuda:0')
# i=  43001
# error = 0.02335230570631577
# loss = tensor(0.0014, device='cuda:0')
# i=  43501
# error = 0.013112513072894322
# loss = tensor(0.0020, device='cuda:0')
# i=  44001
# error = 0.016705824932490603
# loss = tensor(0.0024, device='cuda:0')
# i=  44501
# error = 0.020265217879211355
# loss = tensor(0.0029, device='cuda:0')
# i=  45001
# error = 0.02189337683779282
# loss = tensor(0.0018, device='cuda:0')
# i=  45501
# error = 0.016756659475757937
# loss = tensor(0.0026, device='cuda:0')
# i=  46001
# error = 0.016392819350582368
# loss = tensor(0.0012, device='cuda:0')
# i=  46501
# error = 0.014582097439960513
# loss = tensor(0.0016, device='cuda:0')
# i=  47001
# error = 0.027343042486274047
# loss = tensor(0.0030, device='cuda:0')
# i=  47501
# error = 0.01724040529654969
# loss = tensor(0.0018, device='cuda:0')
# i=  48001
# error = 0.015928066237658068
# loss = tensor(0.0018, device='cuda:0')
# i=  48501
# error = 0.020072120408348795
# loss = tensor(0.0038, device='cuda:0')
# i=  49001
# error = 0.038730802285518784
# loss = tensor(0.0106, device='cuda:0')
# i=  49501
# error = 0.026806836533637537
# loss = tensor(0.0037, device='cuda:0')
# time cost 23865.044889688492 s
