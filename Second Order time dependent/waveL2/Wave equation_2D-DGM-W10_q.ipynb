# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        
        output = self.outlayer(y)
        return output
deg = 3

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],4).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    sol =  sol +  (2*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,3).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(2):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,3).cuda()
    x2 = torch.rand(1000,3).cuda()
    x3 = torch.rand(1000,3).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    return loss

# %%
model_u = ResNet(3,10)
device=torch.device("cuda:0" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=3, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:3].reshape(x.size()[0],2)
    return p

# %%
notes = torch.rand(10000,3).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:4])**2)/10000)
def loss_error():
    notes = torch.rand(10000,3).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,4).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:4] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:4] - predict[:,2:4])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_2D_q_w10.npy", error_save)
np.save("error_save_DGM_wave_2D_q_w10.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.7188532364954965
# loss = tensor(26.5186, device='cuda:0')
# i=  501
# error = 0.3563355020119248
# loss = tensor(0.1923, device='cuda:0')
# i=  1001
# error = 0.15419411871095948
# loss = tensor(0.0514, device='cuda:0')
# i=  1501
# error = 0.14040317668958793
# loss = tensor(0.0259, device='cuda:0')
# i=  2001
# error = 0.12591555940838967
# loss = tensor(0.0165, device='cuda:0')
# i=  2501
# error = 0.11312886558267793
# loss = tensor(0.0128, device='cuda:0')
# i=  3001
# error = 0.10667526758612811
# loss = tensor(0.0105, device='cuda:0')
# i=  3501
# error = 0.10269304291845019
# loss = tensor(0.0090, device='cuda:0')
# i=  4001
# error = 0.09996974932731727
# loss = tensor(0.0082, device='cuda:0')
# i=  4501
# error = 0.09724569420984475
# loss = tensor(0.0067, device='cuda:0')
# i=  5001
# error = 0.09455378853707408
# loss = tensor(0.0059, device='cuda:0')
# i=  5501
# error = 0.09028980309008926
# loss = tensor(0.0053, device='cuda:0')
# i=  6001
# error = 0.08446709277094237
# loss = tensor(0.0050, device='cuda:0')
# i=  6501
# error = 0.08368125076309661
# loss = tensor(0.0043, device='cuda:0')
# i=  7001
# error = 0.07505057174376607
# loss = tensor(0.0041, device='cuda:0')
# i=  7501
# error = 0.07422929205890469
# loss = tensor(0.0037, device='cuda:0')
# i=  8001
# error = 0.07029618071758206
# loss = tensor(0.0032, device='cuda:0')
# i=  8501
# error = 0.06608410945071255
# loss = tensor(0.0031, device='cuda:0')
# i=  9001
# error = 0.05998712752972751
# loss = tensor(0.0028, device='cuda:0')
# i=  9501
# error = 0.05751530088377036
# loss = tensor(0.0027, device='cuda:0')
# i=  10001
# error = 0.055155621579767194
# loss = tensor(0.0024, device='cuda:0')
# i=  10501
# error = 0.05082775368023082
# loss = tensor(0.0023, device='cuda:0')
# i=  11001
# error = 0.04887136356377918
# loss = tensor(0.0022, device='cuda:0')
# i=  11501
# error = 0.04657927809365499
# loss = tensor(0.0026, device='cuda:0')
# i=  12001
# error = 0.04738496579217865
# loss = tensor(0.0021, device='cuda:0')
# i=  12501
# error = 0.04335828437344353
# loss = tensor(0.0018, device='cuda:0')
# i=  13001
# error = 0.04097944815448881
# loss = tensor(0.0023, device='cuda:0')
# i=  13501
# error = 0.0399541003901735
# loss = tensor(0.0016, device='cuda:0')
# i=  14001
# error = 0.036535391888473163
# loss = tensor(0.0020, device='cuda:0')
# i=  14501
# error = 0.03539945309095654
# loss = tensor(0.0015, device='cuda:0')
# i=  15001
# error = 0.03259077805769428
# loss = tensor(0.0015, device='cuda:0')
# i=  15501
# error = 0.032996940319717054
# loss = tensor(0.0012, device='cuda:0')
# i=  16001
# error = 0.03258584637361036
# loss = tensor(0.0012, device='cuda:0')
# i=  16501
# error = 0.03416017581363427
# loss = tensor(0.0016, device='cuda:0')
# i=  17001
# error = 0.03171551532024711
# loss = tensor(0.0011, device='cuda:0')
# i=  17501
# error = 0.030156279360490198
# loss = tensor(0.0012, device='cuda:0')
# i=  18001
# error = 0.030509922302261214
# loss = tensor(0.0010, device='cuda:0')
# i=  18501
# error = 0.029840459030970372
# loss = tensor(0.0010, device='cuda:0')
# i=  19001
# error = 0.0286123038928029
# loss = tensor(0.0010, device='cuda:0')
# i=  19501
# error = 0.02869581566106865
# loss = tensor(0.0010, device='cuda:0')
# i=  20001
# error = 0.02872253589681688
# loss = tensor(0.0009, device='cuda:0')
# i=  20501
# error = 0.029502881613858306
# loss = tensor(0.0010, device='cuda:0')
# i=  21001
# error = 0.027158832505326153
# loss = tensor(0.0009, device='cuda:0')
# i=  21501
# error = 0.026526317399863907
# loss = tensor(0.0016, device='cuda:0')
# i=  22001
# error = 0.026938966507568465
# loss = tensor(0.0009, device='cuda:0')
# i=  22501
# error = 0.02588473489177018
# loss = tensor(0.0009, device='cuda:0')
# i=  23001
# error = 0.02606238682924173
# loss = tensor(0.0029, device='cuda:0')
# i=  23501
# error = 0.03126426635474661
# loss = tensor(0.0029, device='cuda:0')
# i=  24001
# error = 0.026130974874008187
# loss = tensor(0.0008, device='cuda:0')
# i=  24501
# error = 0.024353121788978752
# loss = tensor(0.0008, device='cuda:0')
# i=  25001
# error = 0.02376755106998215
# loss = tensor(0.0008, device='cuda:0')
# i=  25501
# error = 0.02335768464417811
# loss = tensor(0.0010, device='cuda:0')
# i=  26001
# error = 0.02503999278155124
# loss = tensor(0.0008, device='cuda:0')
# i=  26501
# error = 0.02391705505610345
# loss = tensor(0.0007, device='cuda:0')
# i=  27001
# error = 0.022478836421476158
# loss = tensor(0.0008, device='cuda:0')
# i=  27501
# error = 0.02386112388797263
# loss = tensor(0.0007, device='cuda:0')
# i=  28001
# error = 0.022635822859908075
# loss = tensor(0.0007, device='cuda:0')
# i=  28501
# error = 0.023381485891763466
# loss = tensor(0.0007, device='cuda:0')
# i=  29001
# error = 0.02300275674962895
# loss = tensor(0.0007, device='cuda:0')
# i=  29501
# error = 0.021253298199185967
# loss = tensor(0.0009, device='cuda:0')
# i=  30001
# error = 0.022350127573330644
# loss = tensor(0.0007, device='cuda:0')
# i=  30501
# error = 0.022203331124780935
# loss = tensor(0.0007, device='cuda:0')
# i=  31001
# error = 0.023804820550690955
# loss = tensor(0.0009, device='cuda:0')
# i=  31501
# error = 0.022390973001128717
# loss = tensor(0.0007, device='cuda:0')
# i=  32001
# error = 0.019954813911686964
# loss = tensor(0.0009, device='cuda:0')
# i=  32501
# error = 0.020116501466087042
# loss = tensor(0.0007, device='cuda:0')
# i=  33001
# error = 0.021304190299091606
# loss = tensor(0.0035, device='cuda:0')
# i=  33501
# error = 0.020670303380516654
# loss = tensor(0.0007, device='cuda:0')
# i=  34001
# error = 0.020264477741471748
# loss = tensor(0.0006, device='cuda:0')
# i=  34501
# error = 0.018776453442472862
# loss = tensor(0.0010, device='cuda:0')
# i=  35001
# error = 0.0202213345762649
# loss = tensor(0.0006, device='cuda:0')
# i=  35501
# error = 0.01975363502075559
# loss = tensor(0.0006, device='cuda:0')
# i=  36001
# error = 0.01839105837755654
# loss = tensor(0.0015, device='cuda:0')
# i=  36501
# error = 0.02091089645128196
# loss = tensor(0.0007, device='cuda:0')
# i=  37001
# error = 0.018314958701990583
# loss = tensor(0.0024, device='cuda:0')
# i=  37501
# error = 0.01923419402919539
# loss = tensor(0.0006, device='cuda:0')
# i=  38001
# error = 0.021916762062163524
# loss = tensor(0.0014, device='cuda:0')
# i=  38501
# error = 0.0184997018891058
# loss = tensor(0.0007, device='cuda:0')
# i=  39001
# error = 0.01965054883450803
# loss = tensor(0.0006, device='cuda:0')
# i=  39501
# error = 0.022618240918437504
# loss = tensor(0.0013, device='cuda:0')
# i=  40001
# error = 0.019079551186087437
# loss = tensor(0.0006, device='cuda:0')
# i=  40501
# error = 0.018310131100962787
# loss = tensor(0.0006, device='cuda:0')
# i=  41001
# error = 0.019642960769351042
# loss = tensor(0.0006, device='cuda:0')
# i=  41501
# error = 0.016911318839137938
# loss = tensor(0.0014, device='cuda:0')
# i=  42001
# error = 0.01844307313091614
# loss = tensor(0.0006, device='cuda:0')
# i=  42501
# error = 0.018101193866272514
# loss = tensor(0.0006, device='cuda:0')
# i=  43001
# error = 0.01815592055922595
# loss = tensor(0.0005, device='cuda:0')
# i=  43501
# error = 0.019087944153475853
# loss = tensor(0.0007, device='cuda:0')
# i=  44001
# error = 0.019054745431856125
# loss = tensor(0.0005, device='cuda:0')
# i=  44501
# error = 0.01795582061762808
# loss = tensor(0.0005, device='cuda:0')
# i=  45001
# error = 0.023384200543927345
# loss = tensor(0.0019, device='cuda:0')
# i=  45501
# error = 0.023419767159148317
# loss = tensor(0.0017, device='cuda:0')
# i=  46001
# error = 0.017713405261673233
# loss = tensor(0.0005, device='cuda:0')
# i=  46501
# error = 0.017363285895684668
# loss = tensor(0.0006, device='cuda:0')
# i=  47001
# error = 0.015464926227265176
# loss = tensor(0.0010, device='cuda:0')
# i=  47501
# error = 0.017298646024776453
# loss = tensor(0.0006, device='cuda:0')
# i=  48001
# error = 0.01716248349917011
# loss = tensor(0.0007, device='cuda:0')
# i=  48501
# error = 0.01784194581587427
# loss = tensor(0.0005, device='cuda:0')
# i=  49001
# error = 0.018879426321047624
# loss = tensor(0.0006, device='cuda:0')
# i=  49501
# error = 0.018606474430686953
# loss = tensor(0.0006, device='cuda:0')
# time cost 20011.740837812424 s
