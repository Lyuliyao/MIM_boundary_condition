# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
       
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        
        output = self.outlayer(y)
        return output
deg = 3

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],4).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    sol =  sol +  (2*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,3).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(2):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,3).cuda()
    x2 = torch.rand(1000,3).cuda()
    x3 = torch.rand(1000,3).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    return loss

# %%
model_u = ResNet(3,10)
device=torch.device("cuda:0" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=3, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (fc5): Linear(in_features=10, out_features=10, bias=True)
#   (fc6): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:3].reshape(x.size()[0],2)
    return p

# %%
notes = torch.rand(10000,3).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:4])**2)/10000)
def loss_error():
    notes = torch.rand(10000,3).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,4).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:4] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:4] - predict[:,2:4])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_2D_q_w10.npy", error_save)
np.save("error_save_DGM_wave_2D_q_w10.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 1.0845226388971945
# loss = tensor(27.5395, device='cuda:0')
# i=  501
# error = 0.44541486549134873
# loss = tensor(0.2853, device='cuda:0')
# i=  1001
# error = 0.2712744182957689
# loss = tensor(0.0542, device='cuda:0')
# i=  1501
# error = 0.17281172113075663
# loss = tensor(0.0219, device='cuda:0')
# i=  2001
# error = 0.13808556590363297
# loss = tensor(0.0157, device='cuda:0')
# i=  2501
# error = 0.13020685726132783
# loss = tensor(0.0135, device='cuda:0')
# i=  3001
# error = 0.12349576997318897
# loss = tensor(0.0115, device='cuda:0')
# i=  3501
# error = 0.11899675669856787
# loss = tensor(0.0107, device='cuda:0')
# i=  4001
# error = 0.11462012627311215
# loss = tensor(0.0101, device='cuda:0')
# i=  4501
# error = 0.11265587960444695
# loss = tensor(0.0123, device='cuda:0')
# i=  5001
# error = 0.1107394806021479
# loss = tensor(0.0095, device='cuda:0')
# i=  5501
# error = 0.10860732298847899
# loss = tensor(0.0090, device='cuda:0')
# i=  6001
# error = 0.1060550192582478
# loss = tensor(0.0084, device='cuda:0')
# i=  6501
# error = 0.10436022002725459
# loss = tensor(0.0085, device='cuda:0')
# i=  7001
# error = 0.10129979445367948
# loss = tensor(0.0079, device='cuda:0')
# i=  7501
# error = 0.10045310213264981
# loss = tensor(0.0075, device='cuda:0')
# i=  8001
# error = 0.1000063267363483
# loss = tensor(0.0070, device='cuda:0')
# i=  8501
# error = 0.09818498356061361
# loss = tensor(0.0070, device='cuda:0')
# i=  9001
# error = 0.09434100473583634
# loss = tensor(0.0069, device='cuda:0')
# i=  9501
# error = 0.0953952921325345
# loss = tensor(0.0069, device='cuda:0')
# i=  10001
# error = 0.09228823179637519
# loss = tensor(0.0065, device='cuda:0')
# i=  10501
# error = 0.09078915893553384
# loss = tensor(0.0058, device='cuda:0')
# i=  11001
# error = 0.09078201753655253
# loss = tensor(0.0057, device='cuda:0')
# i=  11501
# error = 0.08850096428072798
# loss = tensor(0.0054, device='cuda:0')
# i=  12001
# error = 0.08567218370458862
# loss = tensor(0.0056, device='cuda:0')
# i=  12501
# error = 0.08507813324772887
# loss = tensor(0.0049, device='cuda:0')
# i=  13001
# error = 0.08520497422972383
# loss = tensor(0.0047, device='cuda:0')
# i=  13501
# error = 0.07873404885369056
# loss = tensor(0.0053, device='cuda:0')
# i=  14001
# error = 0.08297603899372488
# loss = tensor(0.0048, device='cuda:0')
# i=  14501
# error = 0.08278303897711971
# loss = tensor(0.0046, device='cuda:0')
# i=  15001
# error = 0.08319577186743744
# loss = tensor(0.0050, device='cuda:0')
# i=  15501
# error = 0.08646656239529545
# loss = tensor(0.0072, device='cuda:0')
# i=  16001
# error = 0.07710134756357223
# loss = tensor(0.0040, device='cuda:0')
# i=  16501
# error = 0.07496471393191902
# loss = tensor(0.0040, device='cuda:0')
# i=  17001
# error = 0.07507696303649455
# loss = tensor(0.0042, device='cuda:0')
# i=  17501
# error = 0.07780301478108617
# loss = tensor(0.0040, device='cuda:0')
# i=  18001
# error = 0.07377781177912805
# loss = tensor(0.0035, device='cuda:0')
# i=  18501
# error = 0.07663253425785058
# loss = tensor(0.0037, device='cuda:0')
# i=  19001
# error = 0.07047572351951811
# loss = tensor(0.0033, device='cuda:0')
# i=  19501
# error = 0.0625641419225298
# loss = tensor(0.0055, device='cuda:0')
# i=  20001
# error = 0.06543227867753043
# loss = tensor(0.0032, device='cuda:0')
# i=  20501
# error = 0.06608449207253737
# loss = tensor(0.0030, device='cuda:0')
# i=  21001
# error = 0.06637695149076774
# loss = tensor(0.0027, device='cuda:0')
# i=  21501
# error = 0.06490468524439226
# loss = tensor(0.0028, device='cuda:0')
# i=  22001
# error = 0.056120883238701916
# loss = tensor(0.0087, device='cuda:0')
# i=  22501
# error = 0.0631575451238664
# loss = tensor(0.0025, device='cuda:0')
# i=  23001
# error = 0.05817688085190826
# loss = tensor(0.0027, device='cuda:0')
# i=  23501
# error = 0.0646635228293878
# loss = tensor(0.0031, device='cuda:0')
# i=  24001
# error = 0.06301177240621655
# loss = tensor(0.0036, device='cuda:0')
# i=  24501
# error = 0.05460453406864371
# loss = tensor(0.0023, device='cuda:0')
# i=  25001
# error = 0.05381542317206012
# loss = tensor(0.0021, device='cuda:0')
# i=  25501
# error = 0.05338173405452018
# loss = tensor(0.0019, device='cuda:0')
# i=  26001
# error = 0.051164500613346785
# loss = tensor(0.0020, device='cuda:0')
# i=  26501
# error = 0.05036477044611711
# loss = tensor(0.0019, device='cuda:0')
# i=  27001
# error = 0.049040986971141745
# loss = tensor(0.0019, device='cuda:0')
# i=  27501
# error = 0.05110851088165638
# loss = tensor(0.0019, device='cuda:0')
# i=  28001
# error = 0.045132810107381294
# loss = tensor(0.0020, device='cuda:0')
# i=  28501
# error = 0.04618208540752681
# loss = tensor(0.0017, device='cuda:0')
# i=  29001
# error = 0.04585425111038752
# loss = tensor(0.0016, device='cuda:0')
# i=  29501
# error = 0.045668704075695045
# loss = tensor(0.0019, device='cuda:0')
# i=  30001
# error = 0.042425952327244665
# loss = tensor(0.0018, device='cuda:0')
# i=  30501
# error = 0.041236582662276755
# loss = tensor(0.0017, device='cuda:0')
# i=  31001
# error = 0.039567840526768185
# loss = tensor(0.0019, device='cuda:0')
# i=  31501
# error = 0.04162929505737645
# loss = tensor(0.0015, device='cuda:0')
# i=  32001
# error = 0.03699619873261245
# loss = tensor(0.0026, device='cuda:0')
# i=  32501
# error = 0.03994156089674811
# loss = tensor(0.0013, device='cuda:0')
# i=  33001
# error = 0.03712756598626893
# loss = tensor(0.0028, device='cuda:0')
# i=  33501
# error = 0.0391971106382909
# loss = tensor(0.0024, device='cuda:0')
# i=  34001
# error = 0.0363592345799743
# loss = tensor(0.0012, device='cuda:0')
# i=  34501
# error = 0.03766619009613967
# loss = tensor(0.0013, device='cuda:0')
# i=  35001
# error = 0.03249157448485763
# loss = tensor(0.0038, device='cuda:0')
# i=  35501
# error = 0.03459279796998311
# loss = tensor(0.0012, device='cuda:0')
# i=  36001
# error = 0.03292943287519493
# loss = tensor(0.0013, device='cuda:0')
# i=  36501
# error = 0.03378476013546194
# loss = tensor(0.0011, device='cuda:0')
# i=  37001
# error = 0.037211461790115974
# loss = tensor(0.0031, device='cuda:0')
# i=  37501
# error = 0.030082321698363723
# loss = tensor(0.0030, device='cuda:0')
# i=  38001
# error = 0.031169063056349457
# loss = tensor(0.0012, device='cuda:0')
# i=  38501
# error = 0.036323298623198275
# loss = tensor(0.0019, device='cuda:0')
# i=  39001
# error = 0.0306153312505156
# loss = tensor(0.0010, device='cuda:0')
# i=  39501
# error = 0.028758084946970828
# loss = tensor(0.0010, device='cuda:0')
# i=  40001
# error = 0.029976228146108914
# loss = tensor(0.0010, device='cuda:0')
# i=  40501
# error = 0.03042115513631333
# loss = tensor(0.0010, device='cuda:0')
# i=  41001
# error = 0.02806463326400189
# loss = tensor(0.0011, device='cuda:0')
# i=  41501
# error = 0.030075999065286574
# loss = tensor(0.0019, device='cuda:0')
# i=  42001
# error = 0.025480051201810534
# loss = tensor(0.0014, device='cuda:0')
# i=  42501
# error = 0.02699694246908489
# loss = tensor(0.0009, device='cuda:0')
# i=  43001
# error = 0.030430784699905282
# loss = tensor(0.0016, device='cuda:0')
# i=  43501
# error = 0.029529295192843443
# loss = tensor(0.0013, device='cuda:0')
# i=  44001
# error = 0.031157569381705642
# loss = tensor(0.0019, device='cuda:0')
# i=  44501
# error = 0.026038622977200606
# loss = tensor(0.0008, device='cuda:0')
# i=  45001
# error = 0.023940250808989316
# loss = tensor(0.0011, device='cuda:0')
# i=  45501
# error = 0.02490524835246273
# loss = tensor(0.0011, device='cuda:0')
# i=  46001
# error = 0.02597627002579361
# loss = tensor(0.0013, device='cuda:0')
# i=  46501
# error = 0.024991428827285708
# loss = tensor(0.0008, device='cuda:0')
# i=  47001
# error = 0.024166337871641356
# loss = tensor(0.0009, device='cuda:0')
# i=  47501
# error = 0.025608854787061295
# loss = tensor(0.0008, device='cuda:0')
# i=  48001
# error = 0.022302236909954084
# loss = tensor(0.0012, device='cuda:0')
# i=  48501
# error = 0.022548298112984918
# loss = tensor(0.0011, device='cuda:0')
# i=  49001
# error = 0.02405376472617401
# loss = tensor(0.0007, device='cuda:0')
# i=  49501
# error = 0.023521197555479864
# loss = tensor(0.0013, device='cuda:0')
# time cost 36087.189745903015 s
