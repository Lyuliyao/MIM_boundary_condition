# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    Np = Du[:,1:4].reshape(x.size()[0],3)
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss =  torch.sum( (Np-p)**2 )/50000 + torch.sum( (v_t - uxx - source(x))**2 )/50000
    return loss

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    loss = torch.sum(model_v(x1)**2)/1000
    return loss

# %%
model_u1 = ResNet(4,10,1)
model_p1 = ResNet(4,10,3)
device=torch.device("cuda:1" )

model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (fc5): Linear(in_features=10, out_features=10, bias=True)
#   (fc6): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=3, bias=True)
# )

# %%
def model_u(x):
    return x[:,0:1]*(x*(1-x))[:,1:2]*(x*(1-x))[:,2:3]*(x*(1-x))[:,3:4]*model_u1(x)
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v
def model_p(x):
    return model_p1(x)

# %%
def initparam(model,sigma):
    for m in model.modules():
        if isinstance(m,nn.Linear):
            m.weight.data.uniform_(-sigma,sigma)#全连接层参数初始化
            m.bias.data.uniform_(0,sigma)
    return model

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()}
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss =",losses.detach())
        np.save("error_save_LDG_wave_3D_s_w40_v1.npy", error_save)
np.save("error_save_LDG_wave_3D_s_w40_v1.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.9865246074908063
# loss = tensor(26.7220, device='cuda:1')
# i=  501
# error = 0.24076930308206468
# loss = tensor(1.0479, device='cuda:1')
# i=  1001
# error = 0.0651174430098292
# loss = tensor(0.2532, device='cuda:1')
# i=  1501
# error = 0.057794717744198476
# loss = tensor(0.1647, device='cuda:1')
# i=  2001
# error = 0.05399723738666643
# loss = tensor(0.1301, device='cuda:1')
# i=  2501
# error = 0.05763726504757898
# loss = tensor(0.1086, device='cuda:1')
# i=  3001
# error = 0.06128505581851612
# loss = tensor(0.0904, device='cuda:1')
# i=  3501
# error = 0.06275741699513475
# loss = tensor(0.0816, device='cuda:1')
# i=  4001
# error = 0.06491015634212642
# loss = tensor(0.0760, device='cuda:1')
# i=  4501
# error = 0.057559148763924775
# loss = tensor(0.0702, device='cuda:1')
# i=  5001
# error = 0.06116804424234156
# loss = tensor(0.0635, device='cuda:1')
# i=  5501
# error = 0.05845589862071065
# loss = tensor(0.0613, device='cuda:1')
# i=  6001
# error = 0.05261669142293426
# loss = tensor(0.0621, device='cuda:1')
# i=  6501
# error = 0.05267592621698557
# loss = tensor(0.0559, device='cuda:1')
# i=  7001
# error = 0.046918885262809726
# loss = tensor(0.0542, device='cuda:1')
# i=  7501
# error = 0.056592276587898824
# loss = tensor(0.0530, device='cuda:1')
# i=  8001
# error = 0.04134619538537208
# loss = tensor(0.0483, device='cuda:1')
# i=  8501
# error = 0.0523842575053938
# loss = tensor(0.0457, device='cuda:1')
# i=  9001
# error = 0.04274306041310967
# loss = tensor(0.0462, device='cuda:1')
# i=  9501
# error = 0.044541870649437355
# loss = tensor(0.0428, device='cuda:1')
# i=  10001
# error = 0.04603052500014609
# loss = tensor(0.0443, device='cuda:1')
# i=  10501
# error = 0.047381926547229745
# loss = tensor(0.0408, device='cuda:1')
# i=  11001
# error = 0.05152496893784958
# loss = tensor(0.0397, device='cuda:1')
# i=  11501
# error = 0.05471058343105185
# loss = tensor(0.0392, device='cuda:1')
# i=  12001
# error = 0.04836275308957435
# loss = tensor(0.0398, device='cuda:1')
# i=  12501
# error = 0.047403690792624124
# loss = tensor(0.0381, device='cuda:1')
# i=  13001
# error = 0.05003339658405952
# loss = tensor(0.0379, device='cuda:1')
# i=  13501
# error = 0.045384022423162584
# loss = tensor(0.0375, device='cuda:1')
# i=  14001
# error = 0.046723762356060954
# loss = tensor(0.0378, device='cuda:1')
# i=  14501
# error = 0.04860024959330654
# loss = tensor(0.0357, device='cuda:1')
# i=  15001
# error = 0.05158211414394516
# loss = tensor(0.0391, device='cuda:1')
# i=  15501
# error = 0.046612552123283885
# loss = tensor(0.0352, device='cuda:1')
# i=  16001
# error = 0.05128914298745147
# loss = tensor(0.0335, device='cuda:1')
# i=  16501
# error = 0.04379069888254109
# loss = tensor(0.0322, device='cuda:1')
# i=  17001
# error = 0.04579237171226215
# loss = tensor(0.0310, device='cuda:1')
# i=  17501
# error = 0.047523074740081245
# loss = tensor(0.0311, device='cuda:1')
# i=  18001
# error = 0.044437398948864795
# loss = tensor(0.0301, device='cuda:1')
# i=  18501
# error = 0.04246241193911866
# loss = tensor(0.0299, device='cuda:1')
# i=  19001
# error = 0.045371472789431024
# loss = tensor(0.0297, device='cuda:1')
# i=  19501
# error = 0.0482516129535061
# loss = tensor(0.0292, device='cuda:1')
# i=  20001
# error = 0.04293621956262924
# loss = tensor(0.0290, device='cuda:1')
# i=  20501
# error = 0.04221705917635309
# loss = tensor(0.0286, device='cuda:1')
# i=  21001
# error = 0.04375420826773563
# loss = tensor(0.0282, device='cuda:1')
# i=  21501
# error = 0.04496601161678752
# loss = tensor(0.0295, device='cuda:1')
# i=  22001
# error = 0.04366111976181808
# loss = tensor(0.0292, device='cuda:1')
# i=  22501
# error = 0.04017182209472254
# loss = tensor(0.0285, device='cuda:1')
# i=  23001
# error = 0.04287971707871538
# loss = tensor(0.0260, device='cuda:1')
# i=  23501
# error = 0.04643690737016932
# loss = tensor(0.0256, device='cuda:1')
# i=  24001
# error = 0.04397566213930295
# loss = tensor(0.0257, device='cuda:1')
# i=  24501
# error = 0.04535076761404453
# loss = tensor(0.0254, device='cuda:1')
# i=  25001
# error = 0.04581300969427665
# loss = tensor(0.0267, device='cuda:1')
# i=  25501
# error = 0.04204487066050717
# loss = tensor(0.0244, device='cuda:1')
# i=  26001
# error = 0.040827965520072354
# loss = tensor(0.0280, device='cuda:1')
# i=  26501
# error = 0.045634918120077236
# loss = tensor(0.0261, device='cuda:1')
# i=  27001
# error = 0.039059394966099434
# loss = tensor(0.0242, device='cuda:1')
# i=  27501
# error = 0.041685303422083625
# loss = tensor(0.0241, device='cuda:1')
# i=  28001
# error = 0.04481092484962339
# loss = tensor(0.0229, device='cuda:1')
# i=  28501
# error = 0.04732070085315954
# loss = tensor(0.0252, device='cuda:1')
# i=  29001
# error = 0.04677335960595397
# loss = tensor(0.0249, device='cuda:1')
# i=  29501
# error = 0.04579944214823255
# loss = tensor(0.0228, device='cuda:1')
# i=  30001
# error = 0.04638783204086977
# loss = tensor(0.0221, device='cuda:1')
# i=  30501
# error = 0.04398508601514052
# loss = tensor(0.0226, device='cuda:1')
# i=  31001
# error = 0.04293502080496263
# loss = tensor(0.0228, device='cuda:1')
# i=  31501
# error = 0.044664149528447564
# loss = tensor(0.0230, device='cuda:1')
# i=  32001
# error = 0.04151572298874924
# loss = tensor(0.0253, device='cuda:1')
# i=  32501
# error = 0.04374888117246559
# loss = tensor(0.0259, device='cuda:1')
# i=  33001
# error = 0.046275220504474246
# loss = tensor(0.0229, device='cuda:1')
# i=  33501
# error = 0.046128420438798994
# loss = tensor(0.0205, device='cuda:1')
# i=  34001
# error = 0.044316649781350415
# loss = tensor(0.0203, device='cuda:1')
# i=  34501
# error = 0.04284526259234086
# loss = tensor(0.0268, device='cuda:1')
# i=  35001
# error = 0.04529213112955115
# loss = tensor(0.0213, device='cuda:1')
# i=  35501
# error = 0.04710032362320829
# loss = tensor(0.0208, device='cuda:1')
# i=  36001
# error = 0.04410675103110119
# loss = tensor(0.0223, device='cuda:1')
# i=  36501
# error = 0.04333308663333297
# loss = tensor(0.0301, device='cuda:1')
# i=  37001
# error = 0.044022944269593946
# loss = tensor(0.0202, device='cuda:1')
# i=  37501
# error = 0.040306145178407866
# loss = tensor(0.0189, device='cuda:1')
# i=  38001
# error = 0.05006763896297591
# loss = tensor(0.0275, device='cuda:1')
# i=  38501
# error = 0.046430042799498944
# loss = tensor(0.0191, device='cuda:1')
# i=  39001
# error = 0.043459225569290064
# loss = tensor(0.0186, device='cuda:1')
# i=  39501
# error = 0.04282066509024043
# loss = tensor(0.0188, device='cuda:1')
# i=  40001
# error = 0.04211357109067551
# loss = tensor(0.0200, device='cuda:1')
# i=  40501
# error = 0.04301987248476609
# loss = tensor(0.0185, device='cuda:1')
# i=  41001
# error = 0.04467400646636879
# loss = tensor(0.0209, device='cuda:1')
# i=  41501
# error = 0.04114375638197435
# loss = tensor(0.0182, device='cuda:1')
# i=  42001
# error = 0.04455954306426535
# loss = tensor(0.0188, device='cuda:1')
# i=  42501
# error = 0.04188521471588152
# loss = tensor(0.0185, device='cuda:1')
# i=  43001
# error = 0.04082357586930936
# loss = tensor(0.0195, device='cuda:1')
# i=  43501
# error = 0.04382227204624518
# loss = tensor(0.0188, device='cuda:1')
# i=  44001
# error = 0.04448278617123109
# loss = tensor(0.0186, device='cuda:1')
# i=  44501
# error = 0.04610425427414998
# loss = tensor(0.0181, device='cuda:1')
# i=  45001
# error = 0.04479680773989646
# loss = tensor(0.0197, device='cuda:1')
# i=  45501
# error = 0.040574244189812515
# loss = tensor(0.0191, device='cuda:1')
# i=  46001
# error = 0.044798101623504186
# loss = tensor(0.0226, device='cuda:1')
# i=  46501
# error = 0.041612041628256116
# loss = tensor(0.0170, device='cuda:1')
# i=  47001
# error = 0.040762407026517816
# loss = tensor(0.0171, device='cuda:1')
# i=  47501
# error = 0.04256039673687402
# loss = tensor(0.0170, device='cuda:1')
# i=  48001
# error = 0.044563198507840254
# loss = tensor(0.0169, device='cuda:1')
# i=  48501
# error = 0.041578910932708345
# loss = tensor(0.0166, device='cuda:1')
# i=  49001
# error = 0.04580680125083934
# loss = tensor(0.0231, device='cuda:1')
# i=  49501
# error = 0.0467862011830304
# loss = tensor(0.0163, device='cuda:1')
# time cost 23706.440128087997 s

# %%
plt.plot(np.log10(error[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3c7ba7478601> in <module>
# ----> 1 plt.plot(np.log10(error[1]))
#
# NameError: name 'plt' is not defined

# %%
plt.plot(np.log10(error[0]))

# %%
plt.plot(np.log10(error[2]))
