# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
       
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x2 = torch.rand(1000,4).cuda()
    x3 = torch.rand(1000,4).cuda()
    x4 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    x4[:,3:4] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    loss = loss + torch.sum(model_u(x4)**2)/1000
    return loss

# %%
model_u = ResNet(4,10)
device=torch.device("cuda:1" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (fc5): Linear(in_features=10, out_features=10, bias=True)
#   (fc6): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:4].reshape(x.size()[0],3)
    return p

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_3D_s_w10.npy", error_save)
np.save("error_save_DGM_wave_3D_s_w10.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.8606723372802382
# loss = tensor(27.3095, device='cuda:1')
# i=  501
# error = 0.4762569771383406
# loss = tensor(0.5906, device='cuda:1')
# i=  1001
# error = 0.35630435729496035
# loss = tensor(0.3600, device='cuda:1')
# i=  1501
# error = 0.27076903514897543
# loss = tensor(0.3029, device='cuda:1')
# i=  2001
# error = 0.1906737463360882
# loss = tensor(0.2633, device='cuda:1')
# i=  2501
# error = 0.19786359548349725
# loss = tensor(0.2364, device='cuda:1')
# i=  3001
# error = 0.164432503776282
# loss = tensor(0.2174, device='cuda:1')
# i=  3501
# error = 0.22675033911762302
# loss = tensor(0.1800, device='cuda:1')
# i=  4001
# error = 0.2309060930548568
# loss = tensor(0.1768, device='cuda:1')
# i=  4501
# error = 0.21365980225674291
# loss = tensor(0.1564, device='cuda:1')
# i=  5001
# error = 0.22380729230702398
# loss = tensor(0.1416, device='cuda:1')
# i=  5501
# error = 0.23760692213348733
# loss = tensor(0.1307, device='cuda:1')
# i=  6001
# error = 0.24347830818716837
# loss = tensor(0.1248, device='cuda:1')
# i=  6501
# error = 0.23469490793497888
# loss = tensor(0.1160, device='cuda:1')
# i=  7001
# error = 0.2427254449649279
# loss = tensor(0.1079, device='cuda:1')
# i=  7501
# error = 0.23722325729094942
# loss = tensor(0.1025, device='cuda:1')
# i=  8001
# error = 0.2222797896717606
# loss = tensor(0.0977, device='cuda:1')
# i=  8501
# error = 0.23878470127038162
# loss = tensor(0.0928, device='cuda:1')
# i=  9001
# error = 0.24615867529773697
# loss = tensor(0.0875, device='cuda:1')
# i=  9501
# error = 0.2217104514805415
# loss = tensor(0.0815, device='cuda:1')
# i=  10001
# error = 0.24147015769778857
# loss = tensor(0.0792, device='cuda:1')
# i=  10501
# error = 0.21557277030170227
# loss = tensor(0.0784, device='cuda:1')
# i=  11001
# error = 0.232140696713115
# loss = tensor(0.0822, device='cuda:1')
# i=  11501
# error = 0.2393692522252878
# loss = tensor(0.0839, device='cuda:1')
# i=  12001
# error = 0.20449751431543692
# loss = tensor(0.0801, device='cuda:1')
# i=  12501
# error = 0.22823528818794708
# loss = tensor(0.0776, device='cuda:1')
# i=  13001
# error = 0.203609482086431
# loss = tensor(0.0697, device='cuda:1')
# i=  13501
# error = 0.20498609564312015
# loss = tensor(0.0695, device='cuda:1')
# i=  14001
# error = 0.22108501110126763
# loss = tensor(0.0710, device='cuda:1')
# i=  14501
# error = 0.2035531424010759
# loss = tensor(0.0682, device='cuda:1')
# i=  15001
# error = 0.22425715155896087
# loss = tensor(0.0749, device='cuda:1')
# i=  15501
# error = 0.1915233902317933
# loss = tensor(0.0685, device='cuda:1')
# i=  16001
# error = 0.20011061536962912
# loss = tensor(0.0644, device='cuda:1')
# i=  16501
# error = 0.22893448516963094
# loss = tensor(0.0654, device='cuda:1')
# i=  17001
# error = 0.21306803618296716
# loss = tensor(0.0634, device='cuda:1')
# i=  17501
# error = 0.20151915710459706
# loss = tensor(0.0613, device='cuda:1')
# i=  18001
# error = 0.22518864192995164
# loss = tensor(0.0634, device='cuda:1')
# i=  18501
# error = 0.2083042714793506
# loss = tensor(0.0593, device='cuda:1')
# i=  19001
# error = 0.1881605951120311
# loss = tensor(0.0666, device='cuda:1')
# i=  19501
# error = 0.21730327376752878
# loss = tensor(0.0631, device='cuda:1')
# i=  20001
# error = 0.22192560098502134
# loss = tensor(0.0647, device='cuda:1')
# i=  20501
# error = 0.2240643221503283
# loss = tensor(0.0616, device='cuda:1')
# i=  21001
# error = 0.23775965338069235
# loss = tensor(0.0603, device='cuda:1')
# i=  21501
# error = 0.2295581759939012
# loss = tensor(0.0637, device='cuda:1')
# i=  22001
# error = 0.24150742127104838
# loss = tensor(0.0661, device='cuda:1')
# i=  22501
# error = 0.24425682159840803
# loss = tensor(0.0701, device='cuda:1')
# i=  23001
# error = 0.2539769880048145
# loss = tensor(0.0763, device='cuda:1')
# i=  23501
# error = 0.2745049196095382
# loss = tensor(0.0817, device='cuda:1')
# i=  24001
# error = 0.2757099190889354
# loss = tensor(0.0762, device='cuda:1')
# i=  24501
# error = 0.2722460495242414
# loss = tensor(0.0686, device='cuda:1')
# i=  25001
# error = 0.2617105755507842
# loss = tensor(0.0656, device='cuda:1')
# i=  25501
# error = 0.27391823029368234
# loss = tensor(0.0661, device='cuda:1')
# i=  26001
# error = 0.2685089451008186
# loss = tensor(0.0688, device='cuda:1')
# i=  26501
# error = 0.2834801753083884
# loss = tensor(0.0657, device='cuda:1')
# i=  27001
# error = 0.26549777525069457
# loss = tensor(0.0597, device='cuda:1')
# i=  27501
# error = 0.24425554109463962
# loss = tensor(0.0557, device='cuda:1')
# i=  28001
# error = 0.22463220177110454
# loss = tensor(0.0539, device='cuda:1')
# i=  28501
# error = 0.21041074811527358
# loss = tensor(0.0536, device='cuda:1')
# i=  29001
# error = 0.2131694902016779
# loss = tensor(0.0500, device='cuda:1')
# i=  29501
# error = 0.22478044975280928
# loss = tensor(0.0510, device='cuda:1')
# i=  30001
# error = 0.20501214528363657
# loss = tensor(0.0447, device='cuda:1')
# i=  30501
# error = 0.20681634149018832
# loss = tensor(0.0446, device='cuda:1')
# i=  31001
# error = 0.19420092938087438
# loss = tensor(0.0416, device='cuda:1')
# i=  31501
# error = 0.19116663360483221
# loss = tensor(0.0399, device='cuda:1')
# i=  32001
# error = 0.1908887706749493
# loss = tensor(0.0381, device='cuda:1')
# i=  32501
# error = 0.19826138301303622
# loss = tensor(0.0365, device='cuda:1')
# i=  33001
# error = 0.18333932829452365
# loss = tensor(0.0388, device='cuda:1')
# i=  33501
# error = 0.21296899960439197
# loss = tensor(0.0364, device='cuda:1')
# i=  34001
# error = 0.19691430822925957
# loss = tensor(0.0321, device='cuda:1')
# i=  34501
# error = 0.21477785681534875
# loss = tensor(0.0357, device='cuda:1')
# i=  35001
# error = 0.20058822203097587
# loss = tensor(0.0295, device='cuda:1')
# i=  35501
# error = 0.18755225365447836
# loss = tensor(0.0299, device='cuda:1')
# i=  36001
# error = 0.20286163577735736
# loss = tensor(0.0255, device='cuda:1')
# i=  36501
# error = 0.1930202094806773
# loss = tensor(0.0270, device='cuda:1')
# i=  37001
# error = 0.20303193189035065
# loss = tensor(0.0247, device='cuda:1')
# i=  37501
# error = 0.20851320118415279
# loss = tensor(0.0246, device='cuda:1')
# i=  38001
# error = 0.2142289497523978
# loss = tensor(0.0281, device='cuda:1')
# i=  38501
# error = 0.2088929298303617
# loss = tensor(0.0245, device='cuda:1')
# i=  39001
# error = 0.19741188822835046
# loss = tensor(0.0233, device='cuda:1')
# i=  39501
# error = 0.19569622170076897
# loss = tensor(0.0230, device='cuda:1')
# i=  40001
# error = 0.19067591018648797
# loss = tensor(0.0265, device='cuda:1')
# i=  40501
# error = 0.19524835217641956
# loss = tensor(0.0241, device='cuda:1')
# i=  41001
# error = 0.18823835577347336
# loss = tensor(0.0259, device='cuda:1')
# i=  41501
# error = 0.18523050276098285
# loss = tensor(0.0274, device='cuda:1')
# i=  42001
# error = 0.18279012503874775
# loss = tensor(0.0299, device='cuda:1')
# i=  42501
# error = 0.17580045251984072
# loss = tensor(0.0301, device='cuda:1')
# i=  43001
# error = 0.17717388873249887
# loss = tensor(0.0314, device='cuda:1')
# i=  43501
# error = 0.17225547852435213
# loss = tensor(0.0352, device='cuda:1')
# i=  44001
# error = 0.18232748425919332
# loss = tensor(0.0418, device='cuda:1')
# i=  44501
# error = 0.1825768863977175
# loss = tensor(0.0516, device='cuda:1')
# i=  45001
# error = 0.19802139407163055
# loss = tensor(0.0566, device='cuda:1')
# i=  45501
# error = 0.20645366267589063
# loss = tensor(0.0540, device='cuda:1')
# i=  46001
# error = 0.2022561553934446
# loss = tensor(0.0512, device='cuda:1')
# i=  46501
# error = 0.20749234569589461
# loss = tensor(0.0505, device='cuda:1')
# i=  47001
# error = 0.19751080671691226
# loss = tensor(0.0468, device='cuda:1')
# i=  47501
# error = 0.18852549911653696
# loss = tensor(0.0431, device='cuda:1')
# i=  48001
# error = 0.19334469792994183
# loss = tensor(0.0441, device='cuda:1')
# i=  48501
# error = 0.1742378378944651
# loss = tensor(0.0390, device='cuda:1')
# i=  49001
# error = 0.1799980668460646
# loss = tensor(0.0423, device='cuda:1')
# i=  49501
# error = 0.18163077679616768
# loss = tensor(0.0483, device='cuda:1')
# time cost 42144.17380666733 s
