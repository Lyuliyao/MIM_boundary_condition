# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
       
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        
        output = self.outlayer(y)
        return output
deg = 3

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x2 = torch.rand(1000,4).cuda()
    x3 = torch.rand(1000,4).cuda()
    x4 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    x4[:,3:4] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    loss = loss + torch.sum(model_u(x4)**2)/1000
    return loss

# %%
model_u = ResNet(4,10)
device=torch.device("cuda:0" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (fc5): Linear(in_features=10, out_features=10, bias=True)
#   (fc6): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:4].reshape(x.size()[0],3)
    return p

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_3D_q_w10.npy", error_save)
np.save("error_save_DGM_wave_3D_q_w10.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 2.3108372160006003
# loss = tensor(28.1526, device='cuda:0')
# i=  501
# error = 1.1022440734508685
# loss = tensor(2.0139, device='cuda:0')
# i=  1001
# error = 0.6244425474342262
# loss = tensor(0.5233, device='cuda:0')
# i=  1501
# error = 0.41234982309423346
# loss = tensor(0.2401, device='cuda:0')
# i=  2001
# error = 0.31204129034371564
# loss = tensor(0.1471, device='cuda:0')
# i=  2501
# error = 0.2837365853227552
# loss = tensor(0.1119, device='cuda:0')
# i=  3001
# error = 0.2680886567189717
# loss = tensor(0.0918, device='cuda:0')
# i=  3501
# error = 0.2425277822506892
# loss = tensor(0.0784, device='cuda:0')
# i=  4001
# error = 0.23838617847138616
# loss = tensor(0.0776, device='cuda:0')
# i=  4501
# error = 0.21643264224288658
# loss = tensor(0.0600, device='cuda:0')
# i=  5001
# error = 0.19821637065942305
# loss = tensor(0.0566, device='cuda:0')
# i=  5501
# error = 0.187982966780866
# loss = tensor(0.0590, device='cuda:0')
# i=  6001
# error = 0.20918951832933236
# loss = tensor(0.0455, device='cuda:0')
# i=  6501
# error = 0.19792124485821938
# loss = tensor(0.0417, device='cuda:0')
# i=  7001
# error = 0.19658763315815933
# loss = tensor(0.0401, device='cuda:0')
# i=  7501
# error = 0.207777797308925
# loss = tensor(0.0372, device='cuda:0')
# i=  8001
# error = 0.19617155781441356
# loss = tensor(0.0336, device='cuda:0')
# i=  8501
# error = 0.19853391597797676
# loss = tensor(0.0325, device='cuda:0')
# i=  9001
# error = 0.18962374842758745
# loss = tensor(0.0302, device='cuda:0')
# i=  9501
# error = 0.18451834981496587
# loss = tensor(0.0285, device='cuda:0')
# i=  10001
# error = 0.17860778115990047
# loss = tensor(0.0271, device='cuda:0')
# i=  10501
# error = 0.18168354002702033
# loss = tensor(0.0271, device='cuda:0')
# i=  11001
# error = 0.199787282250067
# loss = tensor(0.0313, device='cuda:0')
# i=  11501
# error = 0.18505011735920282
# loss = tensor(0.0249, device='cuda:0')
# i=  12001
# error = 0.16232989750449645
# loss = tensor(0.0244, device='cuda:0')
# i=  12501
# error = 0.18846379569656657
# loss = tensor(0.0242, device='cuda:0')
# i=  13001
# error = 0.15654259776859034
# loss = tensor(0.0248, device='cuda:0')
# i=  13501
# error = 0.19054763564364172
# loss = tensor(0.0245, device='cuda:0')
# i=  14001
# error = 0.17123986782420278
# loss = tensor(0.0211, device='cuda:0')
# i=  14501
# error = 0.1689914673906657
# loss = tensor(0.0196, device='cuda:0')
# i=  15001
# error = 0.1769259122956479
# loss = tensor(0.0223, device='cuda:0')
# i=  15501
# error = 0.17487081183544412
# loss = tensor(0.0197, device='cuda:0')
# i=  16001
# error = 0.15393990011302547
# loss = tensor(0.0243, device='cuda:0')
# i=  16501
# error = 0.1804183728720786
# loss = tensor(0.0208, device='cuda:0')
# i=  17001
# error = 0.14842057179028917
# loss = tensor(0.0220, device='cuda:0')
# i=  17501
# error = 0.15276247897631737
# loss = tensor(0.0173, device='cuda:0')
# i=  18001
# error = 0.15730403782529273
# loss = tensor(0.0167, device='cuda:0')
# i=  18501
# error = 0.18422971263874163
# loss = tensor(0.0251, device='cuda:0')
# i=  19001
# error = 0.14161036845487748
# loss = tensor(0.0215, device='cuda:0')
# i=  19501
# error = 0.15202272896046817
# loss = tensor(0.0164, device='cuda:0')
# i=  20001
# error = 0.1375955318386929
# loss = tensor(0.0207, device='cuda:0')
# i=  20501
# error = 0.15168374171173712
# loss = tensor(0.0202, device='cuda:0')
# i=  21001
# error = 0.15941357347309723
# loss = tensor(0.0156, device='cuda:0')
# i=  21501
# error = 0.15727622157210153
# loss = tensor(0.0147, device='cuda:0')
# i=  22001
# error = 0.14124934196632147
# loss = tensor(0.0163, device='cuda:0')
# i=  22501
# error = 0.15746195610096822
# loss = tensor(0.0145, device='cuda:0')
# i=  23001
# error = 0.15835411652568
# loss = tensor(0.0142, device='cuda:0')
# i=  23501
# error = 0.18774802169326935
# loss = tensor(0.0260, device='cuda:0')
# i=  24001
# error = 0.1451243319520322
# loss = tensor(0.0143, device='cuda:0')
# i=  24501
# error = 0.1673778505857648
# loss = tensor(0.0150, device='cuda:0')
# i=  25001
# error = 0.144764458202577
# loss = tensor(0.0136, device='cuda:0')
# i=  25501
# error = 0.15096842718909131
# loss = tensor(0.0131, device='cuda:0')
# i=  26001
# error = 0.14876780180583155
# loss = tensor(0.0134, device='cuda:0')
# i=  26501
# error = 0.14841121617546207
# loss = tensor(0.0131, device='cuda:0')
# i=  27001
# error = 0.1394361802451317
# loss = tensor(0.0140, device='cuda:0')
# i=  27501
# error = 0.1873947613508242
# loss = tensor(0.0347, device='cuda:0')
# i=  28001
# error = 0.13708677816003648
# loss = tensor(0.0139, device='cuda:0')
# i=  28501
# error = 0.1276945859023935
# loss = tensor(0.0162, device='cuda:0')
# i=  29001
# error = 0.15894416059805885
# loss = tensor(0.0149, device='cuda:0')
# i=  29501
# error = 0.15869175104703417
# loss = tensor(0.0146, device='cuda:0')
# i=  30001
# error = 0.13751361367532458
# loss = tensor(0.0122, device='cuda:0')
# i=  30501
# error = 0.14262999987255784
# loss = tensor(0.0120, device='cuda:0')
# i=  31001
# error = 0.12613103781102902
# loss = tensor(0.0157, device='cuda:0')
# i=  31501
# error = 0.12407925323024056
# loss = tensor(0.0120, device='cuda:0')
# i=  32001
# error = 0.15574276359397415
# loss = tensor(0.0128, device='cuda:0')
# i=  32501
# error = 0.1445029197870028
# loss = tensor(0.0112, device='cuda:0')
# i=  33001
# error = 0.12681861348511975
# loss = tensor(0.0145, device='cuda:0')
# i=  33501
# error = 0.16933959691587816
# loss = tensor(0.0187, device='cuda:0')
# i=  34001
# error = 0.1467231206275728
# loss = tensor(0.0126, device='cuda:0')
# i=  34501
# error = 0.15734880086838982
# loss = tensor(0.0152, device='cuda:0')
# i=  35001
# error = 0.15313160392794245
# loss = tensor(0.0132, device='cuda:0')
# i=  35501
# error = 0.13392527557302167
# loss = tensor(0.0109, device='cuda:0')
# i=  36001
# error = 0.13877028473004707
# loss = tensor(0.0111, device='cuda:0')
# i=  36501
# error = 0.13222318243154438
# loss = tensor(0.0110, device='cuda:0')
# i=  37001
# error = 0.1321785686012193
# loss = tensor(0.0110, device='cuda:0')
# i=  37501
# error = 0.11418132338137313
# loss = tensor(0.0208, device='cuda:0')
# i=  38001
# error = 0.1371353735736916
# loss = tensor(0.0102, device='cuda:0')
# i=  38501
# error = 0.12600892740629502
# loss = tensor(0.0115, device='cuda:0')
# i=  39001
# error = 0.14696253889464547
# loss = tensor(0.0116, device='cuda:0')
# i=  39501
# error = 0.13178623866726247
# loss = tensor(0.0106, device='cuda:0')
# i=  40001
# error = 0.15113272113707787
# loss = tensor(0.0192, device='cuda:0')
# i=  40501
# error = 0.1282087619885669
# loss = tensor(0.0102, device='cuda:0')
# i=  41001
# error = 0.13538177421898268
# loss = tensor(0.0099, device='cuda:0')
# i=  41501
# error = 0.13434941043126986
# loss = tensor(0.0096, device='cuda:0')
# i=  42001
# error = 0.14921570199933099
# loss = tensor(0.0112, device='cuda:0')
# i=  42501
# error = 0.15594654164170718
# loss = tensor(0.0138, device='cuda:0')
# i=  43001
# error = 0.137440859509203
# loss = tensor(0.0097, device='cuda:0')
# i=  43501
# error = 0.12822588576524535
# loss = tensor(0.0098, device='cuda:0')
# i=  44001
# error = 0.15787001235464956
# loss = tensor(0.0188, device='cuda:0')
# i=  44501
# error = 0.12639619892177517
# loss = tensor(0.0100, device='cuda:0')
# i=  45001
# error = 0.12269614978408758
# loss = tensor(0.0117, device='cuda:0')
# i=  45501
# error = 0.13708043631577016
# loss = tensor(0.0092, device='cuda:0')
# i=  46001
# error = 0.1433105782865517
# loss = tensor(0.0098, device='cuda:0')
# i=  46501
# error = 0.13078617541653542
# loss = tensor(0.0093, device='cuda:0')
# i=  47001
# error = 0.13152111825884893
# loss = tensor(0.0092, device='cuda:0')
# i=  47501
# error = 0.10873770249199265
# loss = tensor(0.0170, device='cuda:0')
# i=  48001
# error = 0.12352335426450467
# loss = tensor(0.0091, device='cuda:0')
# i=  48501
# error = 0.1096099865490497
# loss = tensor(0.0112, device='cuda:0')
# i=  49001
# error = 0.132632734784014
# loss = tensor(0.0090, device='cuda:0')
# i=  49501
# error = 0.13069867822157474
# loss = tensor(0.0089, device='cuda:0')
# time cost 40131.33811712265 s
