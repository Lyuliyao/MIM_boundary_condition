# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],4).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    sol =  sol +  (2*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,3).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    Np = Du[:,1:3].reshape(x.size()[0],2)
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(2):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss =  torch.sum( (Np-p)**2 )/50000 + torch.sum( (v_t - uxx - source(x))**2 )/50000
    return loss

# %%
def BC():
    x1 = torch.rand(1000,3).cuda()
    x1[:,0] = 0
    loss = torch.sum(model_v(x1)**2)/1000
    return loss

# %%
model_u1 = ResNet(3,40,1)
model_p1 = ResNet(3,40,2)
device=torch.device("cuda:1" )

model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=3, out_features=40, bias=True)
#   (fc2): Linear(in_features=40, out_features=40, bias=True)
#   (fc3): Linear(in_features=40, out_features=40, bias=True)
#   (fc4): Linear(in_features=40, out_features=40, bias=True)
#   (fc5): Linear(in_features=40, out_features=40, bias=True)
#   (fc6): Linear(in_features=40, out_features=40, bias=True)
#   (outlayer): Linear(in_features=40, out_features=2, bias=True)
# )

# %%
def model_u(x):
    return x[:,0:1]*(x*(1-x))[:,1:2]*(x*(1-x))[:,2:3]*model_u1(x)
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v
def model_p(x):
    return model_p1(x)

# %%
def initparam(model,sigma):
    for m in model.modules():
        if isinstance(m,nn.Linear):
            m.weight.data.uniform_(-sigma,sigma)#全连接层参数初始化
            m.bias.data.uniform_(0,sigma)
    return model

# %%
notes = torch.rand(10000,3).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:4])**2)/10000)
def loss_error():
    notes = torch.rand(10000,3).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,4).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:4] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:4] - predict[:,2:4])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()}
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss =",losses.detach())
        np.save("error_save_LDG_wave_2D_s_w40_v1.npy", error_save)
np.save("error_save_LDG_wave_2D_s_w40_v1.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.9925495982049036
# loss = tensor(25.8441, device='cuda:1')
# i=  501
# error = 0.03820445289592471
# loss = tensor(0.0359, device='cuda:1')
# i=  1001
# error = 0.027898441751650734
# loss = tensor(0.0124, device='cuda:1')
# i=  1501
# error = 0.02134555866105609
# loss = tensor(0.0080, device='cuda:1')
# i=  2001
# error = 0.02160767320158352
# loss = tensor(0.0043, device='cuda:1')
# i=  2501
# error = 0.010541199370262877
# loss = tensor(0.0028, device='cuda:1')
# i=  3001
# error = 0.005656294783196911
# loss = tensor(0.0064, device='cuda:1')
# i=  3501
# error = 0.006650562192682032
# loss = tensor(0.0014, device='cuda:1')
# i=  4001
# error = 0.0043577017438137765
# loss = tensor(0.0010, device='cuda:1')
# i=  4501
# error = 0.0074929347477396945
# loss = tensor(0.0032, device='cuda:1')
# i=  5001
# error = 0.0025968891028721876
# loss = tensor(0.0008, device='cuda:1')
# i=  5501
# error = 0.0021888635000243775
# loss = tensor(0.0010, device='cuda:1')
# i=  6001
# error = 0.002353875901207241
# loss = tensor(0.0010, device='cuda:1')
# i=  6501
# error = 0.0024290948405032565
# loss = tensor(0.0051, device='cuda:1')
# i=  7001
# error = 0.0045139998734787
# loss = tensor(0.0011, device='cuda:1')
# i=  7501
# error = 0.005789856441934052
# loss = tensor(0.0009, device='cuda:1')
# i=  8001
# error = 0.003823786277522754
# loss = tensor(0.0026, device='cuda:1')
# i=  8501
# error = 0.0032259570573637346
# loss = tensor(0.0005, device='cuda:1')
# i=  9001
# error = 0.004628931285849499
# loss = tensor(0.0017, device='cuda:1')
# i=  9501
# error = 0.0011362739123987771
# loss = tensor(0.0003, device='cuda:1')
# i=  10001
# error = 0.0009413318715873436
# loss = tensor(0.0003, device='cuda:1')
# i=  10501
# error = 0.0011134701436832208
# loss = tensor(0.0012, device='cuda:1')
# i=  11001
# error = 0.0011282809532641694
# loss = tensor(0.0004, device='cuda:1')
# i=  11501
# error = 0.0034457165433662133
# loss = tensor(0.0010, device='cuda:1')
# i=  12001
# error = 0.0007168533859835963
# loss = tensor(0.0002, device='cuda:1')
# i=  12501
# error = 0.0009457166148184329
# loss = tensor(0.0007, device='cuda:1')
# i=  13001
# error = 0.00114446999274621
# loss = tensor(0.0003, device='cuda:1')
# i=  13501
# error = 0.0013232577321724067
# loss = tensor(0.0004, device='cuda:1')
# i=  14001
# error = 0.0013225520654279376
# loss = tensor(0.0002, device='cuda:1')
# i=  14501
# error = 0.0017334458111536652
# loss = tensor(0.0004, device='cuda:1')
# i=  15001
# error = 0.0018308418388394822
# loss = tensor(0.0007, device='cuda:1')
# i=  15501
# error = 0.0009116582314712855
# loss = tensor(0.0002, device='cuda:1')
# i=  16001
# error = 0.0005052855880031848
# loss = tensor(0.0002, device='cuda:1')
# i=  16501
# error = 0.0011936972170821342
# loss = tensor(0.0004, device='cuda:1')
# i=  17001
# error = 0.0011419752713120444
# loss = tensor(0.0010, device='cuda:1')
# i=  17501
# error = 0.20764007899035286
# loss = tensor(0.2059, device='cuda:1')
# i=  18001
# error = 0.04084530119008964
# loss = tensor(0.0250, device='cuda:1')
# i=  18501
# error = 0.02081037798761172
# loss = tensor(0.0127, device='cuda:1')
# i=  19001
# error = 0.015450759020139773
# loss = tensor(0.0089, device='cuda:1')
# i=  19501
# error = 0.013696476433501664
# loss = tensor(0.0068, device='cuda:1')
# i=  20001
# error = 0.01251417056270244
# loss = tensor(0.0052, device='cuda:1')
# i=  20501
# error = 0.015412529097209467
# loss = tensor(0.0058, device='cuda:1')
# i=  21001
# error = 0.011628499307020163
# loss = tensor(0.0033, device='cuda:1')
# i=  21501
# error = 0.00985249726038555
# loss = tensor(0.0027, device='cuda:1')
# i=  22001
# error = 0.01151917920536471
# loss = tensor(0.0027, device='cuda:1')
# i=  22501
# error = 0.008249973904584186
# loss = tensor(0.0020, device='cuda:1')
# i=  23001
# error = 0.0063356593433724784
# loss = tensor(0.0028, device='cuda:1')
# i=  23501
# error = 0.012612323866832267
# loss = tensor(0.0112, device='cuda:1')
# i=  24001
# error = 0.00607319379377594
# loss = tensor(0.0013, device='cuda:1')
# i=  24501
# error = 0.004939264164863465
# loss = tensor(0.0012, device='cuda:1')
# i=  25001
# error = 0.004655469822447229
# loss = tensor(0.0010, device='cuda:1')
# i=  25501
# error = 0.003568173480626727
# loss = tensor(0.0009, device='cuda:1')
# i=  26001
# error = 0.0032550578475026982
# loss = tensor(0.0008, device='cuda:1')
# i=  26501
# error = 0.004310718169859134
# loss = tensor(0.0030, device='cuda:1')
# i=  27001
# error = 0.0026709815016301205
# loss = tensor(0.0007, device='cuda:1')
# i=  27501
# error = 0.008913409455213373
# loss = tensor(0.0051, device='cuda:1')
# i=  28001
# error = 0.002098666553767306
# loss = tensor(0.0005, device='cuda:1')
# i=  28501
# error = 0.002215327330333642
# loss = tensor(0.0007, device='cuda:1')
# i=  29001
# error = 0.004907904917827627
# loss = tensor(0.0013, device='cuda:1')
# i=  29501
# error = 0.002037630818823075
# loss = tensor(0.0005, device='cuda:1')
# i=  30001
# error = 0.0016756455594489701
# loss = tensor(0.0004, device='cuda:1')
# i=  30501
# error = 0.0016452380008448522
# loss = tensor(0.0005, device='cuda:1')
# i=  31001
# error = 0.0015351713969175547
# loss = tensor(0.0004, device='cuda:1')
# i=  31501
# error = 0.0043472512012500695
# loss = tensor(0.0018, device='cuda:1')
# i=  32001
# error = 0.010376116152185578
# loss = tensor(0.0025, device='cuda:1')
# i=  32501
# error = 0.002442215863873817
# loss = tensor(0.0004, device='cuda:1')
# i=  33001
# error = 0.007873873766829624
# loss = tensor(0.0027, device='cuda:1')
# i=  33501
# error = 0.0070779051808151725
# loss = tensor(0.0038, device='cuda:1')
# i=  34001
# error = 0.0021479096228172365
# loss = tensor(0.0003, device='cuda:1')
# i=  34501
# error = 0.0026741315591241976
# loss = tensor(0.0004, device='cuda:1')
# i=  35001
# error = 0.004902296074447997
# loss = tensor(0.0007, device='cuda:1')
# i=  35501
# error = 0.00434454448720578
# loss = tensor(0.0006, device='cuda:1')
# i=  36001
# error = 0.0019040066878955597
# loss = tensor(0.0002, device='cuda:1')
# i=  36501
# error = 0.0013448446241404403
# loss = tensor(0.0002, device='cuda:1')
# i=  37001
# error = 0.0015456471009766464
# loss = tensor(0.0002, device='cuda:1')
# i=  37501
# error = 0.0030217379526250336
# loss = tensor(0.0006, device='cuda:1')
# i=  38001
# error = 0.0011973841353230025
# loss = tensor(0.0002, device='cuda:1')
# i=  38501
# error = 0.0010889400134297714
# loss = tensor(0.0001, device='cuda:1')
# i=  39001
# error = 0.002495273342590478
# loss = tensor(0.0013, device='cuda:1')
# i=  39501
# error = 0.0015384012554377398
# loss = tensor(0.0002, device='cuda:1')
# i=  40001
# error = 0.001048753063242427
# loss = tensor(0.0002, device='cuda:1')
# i=  40501
# error = 0.0010347361805822064
# loss = tensor(0.0002, device='cuda:1')
# i=  41001
# error = 0.002035261451736012
# loss = tensor(0.0002, device='cuda:1')
# i=  41501
# error = 0.0011699253656289712
# loss = tensor(0.0006, device='cuda:1')
# i=  42001
# error = 0.0008317915159891485
# loss = tensor(0.0001, device='cuda:1')
# i=  42501
# error = 0.002471827213608919
# loss = tensor(0.0003, device='cuda:1')
# i=  43001
# error = 0.002286147296353539
# loss = tensor(0.0003, device='cuda:1')
# i=  43501
# error = 0.0012810900977335059
# loss = tensor(0.0002, device='cuda:1')
# i=  44001
# error = 0.0007209945425774664
# loss = tensor(9.6111e-05, device='cuda:1')
# i=  44501
# error = 0.0031548908995318917
# loss = tensor(0.0006, device='cuda:1')
# i=  45001
# error = 0.002817267538440441
# loss = tensor(0.0017, device='cuda:1')
# i=  45501
# error = 0.0019324235596701017
# loss = tensor(0.0003, device='cuda:1')
# i=  46001
# error = 0.000568656756051596
# loss = tensor(0.0001, device='cuda:1')
# i=  46501
# error = 0.0019407396696848982
# loss = tensor(0.0002, device='cuda:1')
# i=  47001
# error = 0.002999103902319558
# loss = tensor(0.0006, device='cuda:1')
# i=  47501
# error = 0.0006479906957667354
# loss = tensor(0.0003, device='cuda:1')
# i=  48001
# error = 0.0010050939536570178
# loss = tensor(0.0002, device='cuda:1')
# i=  48501
# error = 0.0004768205403532977
# loss = tensor(0.0002, device='cuda:1')
# i=  49001
# error = 0.00048523222394538556
# loss = tensor(0.0001, device='cuda:1')
# i=  49501
# error = 0.0005112015444827131
# loss = tensor(9.6153e-05, device='cuda:1')
# time cost 22405.39334988594 s

# %%
import matplotlib.pyplot as plt
error = np.load("error_save_LDG_wave_2D_q_w20.npy")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-d8da6105f44e> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 error = np.load("error_save_LDG_wave_2D_q_w20.npy")
#
# /usr/lib/python3/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: 'error_save_LDG_wave_2D_q_w20.npy'

# %%
plt.plot(np.log10(error[1]))

# %%
plt.plot(np.log10(error[0]))

# %%
plt.plot(np.log10(error[2]))
