# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        output = self.outlayer(y)
        return output
deg = 3

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    Np = Du[:,1:4].reshape(x.size()[0],3)
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss =  torch.sum( (Np-p)**2 )/50000 + torch.sum( (v_t - uxx - source(x))**2 )/50000
    return loss

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    loss = torch.sum(model_v(x1)**2)/1000
    return loss

# %%
model_u1 = ResNet(4,20,1)
model_p1 = ResNet(4,20,3)
device=torch.device("cuda:0" )

model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=20, bias=True)
#   (fc3): Linear(in_features=20, out_features=20, bias=True)
#   (fc4): Linear(in_features=20, out_features=20, bias=True)
#   (fc5): Linear(in_features=20, out_features=20, bias=True)
#   (fc6): Linear(in_features=20, out_features=20, bias=True)
#   (outlayer): Linear(in_features=20, out_features=3, bias=True)
# )

# %%
def model_u(x):
    return x[:,0:1]*(x*(1-x))[:,1:2]*(x*(1-x))[:,2:3]*(x*(1-x))[:,3:4]*model_u1(x)
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v
def model_p(x):
    return model_p1(x)

# %%
def initparam(model,sigma):
    for m in model.modules():
        if isinstance(m,nn.Linear):
            m.weight.data.uniform_(-sigma,sigma)#全连接层参数初始化
            m.bias.data.uniform_(0,sigma)
    return model

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()}
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss =",losses.detach())
        np.save("error_save_LDG_wave_3D_q_w20_v1.npy", error_save)
np.save("error_save_LDG_wave_3D_q_w20_v1.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 1.0092677337827267
# loss = tensor(27.3365, device='cuda:0')
# i=  501
# error = 0.05858368245223119
# loss = tensor(0.2216, device='cuda:0')
# i=  1001
# error = 0.049858119970855375
# loss = tensor(0.0773, device='cuda:0')
# i=  1501
# error = 0.05757144927678382
# loss = tensor(0.0389, device='cuda:0')
# i=  2001
# error = 0.05980827614093468
# loss = tensor(0.0256, device='cuda:0')
# i=  2501
# error = 0.058916951128492434
# loss = tensor(0.0229, device='cuda:0')
# i=  3001
# error = 0.05604763046696763
# loss = tensor(0.0162, device='cuda:0')
# i=  3501
# error = 0.0543062777876164
# loss = tensor(0.0148, device='cuda:0')
# i=  4001
# error = 0.051211626345789664
# loss = tensor(0.0124, device='cuda:0')
# i=  4501
# error = 0.04969171036300272
# loss = tensor(0.0109, device='cuda:0')
# i=  5001
# error = 0.05006670518049466
# loss = tensor(0.0101, device='cuda:0')
# i=  5501
# error = 0.05021853998812582
# loss = tensor(0.0107, device='cuda:0')
# i=  6001
# error = 0.04667787156285693
# loss = tensor(0.0082, device='cuda:0')
# i=  6501
# error = 0.041144810372020335
# loss = tensor(0.0141, device='cuda:0')
# i=  7001
# error = 0.0455799710814612
# loss = tensor(0.0093, device='cuda:0')
# i=  7501
# error = 0.04154563939937308
# loss = tensor(0.0070, device='cuda:0')
# i=  8001
# error = 0.04142778558000918
# loss = tensor(0.0062, device='cuda:0')
# i=  8501
# error = 0.044086724175556216
# loss = tensor(0.0113, device='cuda:0')
# i=  9001
# error = 0.041440903367197995
# loss = tensor(0.0063, device='cuda:0')
# i=  9501
# error = 0.03977460639482743
# loss = tensor(0.0055, device='cuda:0')
# i=  10001
# error = 0.040722473348726376
# loss = tensor(0.0080, device='cuda:0')
# i=  10501
# error = 0.03665669398469059
# loss = tensor(0.0051, device='cuda:0')
# i=  11001
# error = 0.03837666621655852
# loss = tensor(0.0066, device='cuda:0')
# i=  11501
# error = 0.036612441282584625
# loss = tensor(0.0044, device='cuda:0')
# i=  12001
# error = 0.03434579749503986
# loss = tensor(0.0043, device='cuda:0')
# i=  12501
# error = 0.03318082112623104
# loss = tensor(0.0041, device='cuda:0')
# i=  13001
# error = 0.03665709138582175
# loss = tensor(0.0065, device='cuda:0')
# i=  13501
# error = 0.033550767776255874
# loss = tensor(0.0072, device='cuda:0')
# i=  14001
# error = 0.032584096587461205
# loss = tensor(0.0037, device='cuda:0')
# i=  14501
# error = 0.032225335701162115
# loss = tensor(0.0036, device='cuda:0')
# i=  15001
# error = 0.03236173284491164
# loss = tensor(0.0036, device='cuda:0')
# i=  15501
# error = 0.030836648902343486
# loss = tensor(0.0036, device='cuda:0')
# i=  16001
# error = 0.033038927761637
# loss = tensor(0.0042, device='cuda:0')
# i=  16501
# error = 0.03184295492152326
# loss = tensor(0.0032, device='cuda:0')
# i=  17001
# error = 0.028265001457631885
# loss = tensor(0.0038, device='cuda:0')
# i=  17501
# error = 0.030461718939612262
# loss = tensor(0.0038, device='cuda:0')
# i=  18001
# error = 0.030015197018556018
# loss = tensor(0.0029, device='cuda:0')
# i=  18501
# error = 0.029532873122915707
# loss = tensor(0.0028, device='cuda:0')
# i=  19001
# error = 0.029043716791133708
# loss = tensor(0.0031, device='cuda:0')
# i=  19501
# error = 0.02904283759374818
# loss = tensor(0.0026, device='cuda:0')
# i=  20001
# error = 0.028592135179576993
# loss = tensor(0.0029, device='cuda:0')
# i=  20501
# error = 0.027785724848750328
# loss = tensor(0.0025, device='cuda:0')
# i=  21001
# error = 0.027415716915100398
# loss = tensor(0.0024, device='cuda:0')
# i=  21501
# error = 0.02799909849529561
# loss = tensor(0.0024, device='cuda:0')
# i=  22001
# error = 0.023276030412835356
# loss = tensor(0.0047, device='cuda:0')
# i=  22501
# error = 0.026419442550190925
# loss = tensor(0.0025, device='cuda:0')
# i=  23001
# error = 0.027717503922857073
# loss = tensor(0.0029, device='cuda:0')
# i=  23501
# error = 0.02867967878274624
# loss = tensor(0.0037, device='cuda:0')
# i=  24001
# error = 0.023254879477257403
# loss = tensor(0.0032, device='cuda:0')
# i=  24501
# error = 0.024852142546821065
# loss = tensor(0.0023, device='cuda:0')
# i=  25001
# error = 0.02618773732412278
# loss = tensor(0.0020, device='cuda:0')
# i=  25501
# error = 0.02348882083406114
# loss = tensor(0.0031, device='cuda:0')
# i=  26001
# error = 0.023241572821592643
# loss = tensor(0.0033, device='cuda:0')
# i=  26501
# error = 0.02384750631350033
# loss = tensor(0.0019, device='cuda:0')
# i=  27001
# error = 0.02419394603241395
# loss = tensor(0.0025, device='cuda:0')
# i=  27501
# error = 0.02276645046146688
# loss = tensor(0.0020, device='cuda:0')
# i=  28001
# error = 0.023625897703612144
# loss = tensor(0.0018, device='cuda:0')
# i=  28501
# error = 0.02351147385316354
# loss = tensor(0.0018, device='cuda:0')
# i=  29001
# error = 0.029896622442319342
# loss = tensor(0.0099, device='cuda:0')
# i=  29501
# error = 0.02208275318283776
# loss = tensor(0.0018, device='cuda:0')
# i=  30001
# error = 0.022327017592645992
# loss = tensor(0.0017, device='cuda:0')
# i=  30501
# error = 0.0234730226640739
# loss = tensor(0.0020, device='cuda:0')
# i=  31001
# error = 0.022408134911991975
# loss = tensor(0.0016, device='cuda:0')
# i=  31501
# error = 0.022754362485238912
# loss = tensor(0.0016, device='cuda:0')
# i=  32001
# error = 0.02255852158693223
# loss = tensor(0.0015, device='cuda:0')
# i=  32501
# error = 0.022475197469815647
# loss = tensor(0.0015, device='cuda:0')
# i=  33001
# error = 0.021374882836666734
# loss = tensor(0.0016, device='cuda:0')
# i=  33501
# error = 0.021479924953099166
# loss = tensor(0.0015, device='cuda:0')
# i=  34001
# error = 0.020155923798610483
# loss = tensor(0.0017, device='cuda:0')
# i=  34501
# error = 0.020002946675022008
# loss = tensor(0.0017, device='cuda:0')
# i=  35001
# error = 0.019913275928453943
# loss = tensor(0.0019, device='cuda:0')
# i=  35501
# error = 0.023581988210515926
# loss = tensor(0.0022, device='cuda:0')
# i=  36001
# error = 0.021548987202494145
# loss = tensor(0.0033, device='cuda:0')
# i=  36501
# error = 0.021498312225308982
# loss = tensor(0.0018, device='cuda:0')
# i=  37001
# error = 0.020905815158255375
# loss = tensor(0.0018, device='cuda:0')
# i=  37501
# error = 0.021178566015810828
# loss = tensor(0.0016, device='cuda:0')
# i=  38001
# error = 0.020683929869261004
# loss = tensor(0.0016, device='cuda:0')
# i=  38501
# error = 0.02090735359226705
# loss = tensor(0.0014, device='cuda:0')
# i=  39001
# error = 0.020071888118359395
# loss = tensor(0.0015, device='cuda:0')
# i=  39501
# error = 0.020789262957065208
# loss = tensor(0.0014, device='cuda:0')
# i=  40001
# error = 0.019861143323630488
# loss = tensor(0.0013, device='cuda:0')
# i=  40501
# error = 0.021326161234854854
# loss = tensor(0.0030, device='cuda:0')
# i=  41001
# error = 0.01957556363844305
# loss = tensor(0.0014, device='cuda:0')
# i=  41501
# error = 0.018765861521729547
# loss = tensor(0.0015, device='cuda:0')
# i=  42001
# error = 0.018905703338066997
# loss = tensor(0.0013, device='cuda:0')
# i=  42501
# error = 0.016435726998581854
# loss = tensor(0.0014, device='cuda:0')
# i=  43001
# error = 0.022591541145609843
# loss = tensor(0.0031, device='cuda:0')
# i=  43501
# error = 0.018412765254542482
# loss = tensor(0.0012, device='cuda:0')
# i=  44001
# error = 0.017938147373834423
# loss = tensor(0.0012, device='cuda:0')
# i=  44501
# error = 0.017919359881697513
# loss = tensor(0.0011, device='cuda:0')
# i=  45001
# error = 0.01691663649761024
# loss = tensor(0.0012, device='cuda:0')
# i=  45501
# error = 0.018302675536445916
# loss = tensor(0.0013, device='cuda:0')
# i=  46001
# error = 0.021133248894599756
# loss = tensor(0.0049, device='cuda:0')
# i=  46501
# error = 0.018950518535404005
# loss = tensor(0.0011, device='cuda:0')
# i=  47001
# error = 0.015202827494732916
# loss = tensor(0.0022, device='cuda:0')
# i=  47501
# error = 0.01600165524274464
# loss = tensor(0.0011, device='cuda:0')
# i=  48001
# error = 0.0180126366855677
# loss = tensor(0.0028, device='cuda:0')
# i=  48501
# error = 0.016842861937005384
# loss = tensor(0.0011, device='cuda:0')
# i=  49001
# error = 0.01641988367217516
# loss = tensor(0.0010, device='cuda:0')
# i=  49501
# error = 0.015567805878176886
# loss = tensor(0.0010, device='cuda:0')
# time cost 22940.61836719513 s

# %%
plt.plot(np.log10(error[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3c7ba7478601> in <module>
# ----> 1 plt.plot(np.log10(error[1]))
#
# NameError: name 'plt' is not defined

# %%
plt.plot(np.log10(error[0]))

# %%
plt.plot(np.log10(error[2]))
