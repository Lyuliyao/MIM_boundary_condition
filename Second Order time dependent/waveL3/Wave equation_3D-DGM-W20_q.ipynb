# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
       
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        
        output = self.outlayer(y)
        return output
deg = 3

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x2 = torch.rand(1000,4).cuda()
    x3 = torch.rand(1000,4).cuda()
    x4 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    x4[:,3:4] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    loss = loss + torch.sum(model_u(x4)**2)/1000
    return loss

# %%
model_u = ResNet(4,20)
device=torch.device("cuda:0" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=20, bias=True)
#   (fc3): Linear(in_features=20, out_features=20, bias=True)
#   (fc4): Linear(in_features=20, out_features=20, bias=True)
#   (fc5): Linear(in_features=20, out_features=20, bias=True)
#   (fc6): Linear(in_features=20, out_features=20, bias=True)
#   (outlayer): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:4].reshape(x.size()[0],3)
    return p

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_3D_q_w20.npy", error_save)
np.save("error_save_DGM_wave_3D_q_w20.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 1.395116242640171
# loss = tensor(27.3752, device='cuda:0')
# i=  501
# error = 0.382774899828747
# loss = tensor(0.1488, device='cuda:0')
# i=  1001
# error = 0.24416180433097234
# loss = tensor(0.0427, device='cuda:0')
# i=  1501
# error = 0.16996849605705902
# loss = tensor(0.0232, device='cuda:0')
# i=  2001
# error = 0.1647785744712807
# loss = tensor(0.0150, device='cuda:0')
# i=  2501
# error = 0.16254390381218556
# loss = tensor(0.0114, device='cuda:0')
# i=  3001
# error = 0.12698666903217148
# loss = tensor(0.0197, device='cuda:0')
# i=  3501
# error = 0.15060673164414115
# loss = tensor(0.0080, device='cuda:0')
# i=  4001
# error = 0.1348980118759313
# loss = tensor(0.0070, device='cuda:0')
# i=  4501
# error = 0.14564892462008439
# loss = tensor(0.0074, device='cuda:0')
# i=  5001
# error = 0.12895923397964143
# loss = tensor(0.0056, device='cuda:0')
# i=  5501
# error = 0.1281883721327387
# loss = tensor(0.0051, device='cuda:0')
# i=  6001
# error = 0.1289504498883089
# loss = tensor(0.0051, device='cuda:0')
# i=  6501
# error = 0.12505003497144063
# loss = tensor(0.0047, device='cuda:0')
# i=  7001
# error = 0.11879226718081189
# loss = tensor(0.0040, device='cuda:0')
# i=  7501
# error = 0.11908594392587941
# loss = tensor(0.0039, device='cuda:0')
# i=  8001
# error = 0.11600987784194101
# loss = tensor(0.0035, device='cuda:0')
# i=  8501
# error = 0.11641337606391904
# loss = tensor(0.0035, device='cuda:0')
# i=  9001
# error = 0.11036799169404726
# loss = tensor(0.0032, device='cuda:0')
# i=  9501
# error = 0.1044963755083512
# loss = tensor(0.0033, device='cuda:0')
# i=  10001
# error = 0.10568896820454922
# loss = tensor(0.0029, device='cuda:0')
# i=  10501
# error = 0.09399539551953479
# loss = tensor(0.0046, device='cuda:0')
# i=  11001
# error = 0.10153233632222702
# loss = tensor(0.0027, device='cuda:0')
# i=  11501
# error = 0.09970919494386968
# loss = tensor(0.0026, device='cuda:0')
# i=  12001
# error = 0.11086633284169016
# loss = tensor(0.0047, device='cuda:0')
# i=  12501
# error = 0.09161910363336452
# loss = tensor(0.0027, device='cuda:0')
# i=  13001
# error = 0.11060726051013745
# loss = tensor(0.0052, device='cuda:0')
# i=  13501
# error = 0.09136539165698039
# loss = tensor(0.0023, device='cuda:0')
# i=  14001
# error = 0.09076882535624951
# loss = tensor(0.0023, device='cuda:0')
# i=  14501
# error = 0.07949249660762962
# loss = tensor(0.0042, device='cuda:0')
# i=  15001
# error = 0.0955870145473182
# loss = tensor(0.0030, device='cuda:0')
# i=  15501
# error = 0.087379660905028
# loss = tensor(0.0019, device='cuda:0')
# i=  16001
# error = 0.0835167495572276
# loss = tensor(0.0021, device='cuda:0')
# i=  16501
# error = 0.09183187847805649
# loss = tensor(0.0028, device='cuda:0')
# i=  17001
# error = 0.08553273207661279
# loss = tensor(0.0017, device='cuda:0')
# i=  17501
# error = 0.07576797684953644
# loss = tensor(0.0027, device='cuda:0')
# i=  18001
# error = 0.07683927347215913
# loss = tensor(0.0021, device='cuda:0')
# i=  18501
# error = 0.0758546860982429
# loss = tensor(0.0021, device='cuda:0')
# i=  19001
# error = 0.07264344474467424
# loss = tensor(0.0025, device='cuda:0')
# i=  19501
# error = 0.06676389325193231
# loss = tensor(0.0073, device='cuda:0')
# i=  20001
# error = 0.06910933862450501
# loss = tensor(0.0026, device='cuda:0')
# i=  20501
# error = 0.07870831505629453
# loss = tensor(0.0015, device='cuda:0')
# i=  21001
# error = 0.07509398016947505
# loss = tensor(0.0015, device='cuda:0')
# i=  21501
# error = 0.07471149489851775
# loss = tensor(0.0014, device='cuda:0')
# i=  22001
# error = 0.075348432971217
# loss = tensor(0.0014, device='cuda:0')
# i=  22501
# error = 0.061369338814198836
# loss = tensor(0.0033, device='cuda:0')
# i=  23001
# error = 0.07381311696248734
# loss = tensor(0.0014, device='cuda:0')
# i=  23501
# error = 0.06717271344766038
# loss = tensor(0.0016, device='cuda:0')
# i=  24001
# error = 0.07298735044760615
# loss = tensor(0.0013, device='cuda:0')
# i=  24501
# error = 0.06426316067831128
# loss = tensor(0.0026, device='cuda:0')
# i=  25001
# error = 0.0704919432006597
# loss = tensor(0.0013, device='cuda:0')
# i=  25501
# error = 0.06951367874546999
# loss = tensor(0.0013, device='cuda:0')
# i=  26001
# error = 0.073390751069566
# loss = tensor(0.0013, device='cuda:0')
# i=  26501
# error = 0.0823350254356733
# loss = tensor(0.0040, device='cuda:0')
# i=  27001
# error = 0.0742529866844485
# loss = tensor(0.0017, device='cuda:0')
# i=  27501
# error = 0.0667051812234685
# loss = tensor(0.0012, device='cuda:0')
# i=  28001
# error = 0.06700835726883717
# loss = tensor(0.0012, device='cuda:0')
# i=  28501
# error = 0.08424918976274212
# loss = tensor(0.0093, device='cuda:0')
# i=  29001
# error = 0.07039361043428337
# loss = tensor(0.0012, device='cuda:0')
# i=  29501
# error = 0.06670997924898106
# loss = tensor(0.0011, device='cuda:0')
# i=  30001
# error = 0.05731133934002941
# loss = tensor(0.0023, device='cuda:0')
# i=  30501
# error = 0.06489903224785207
# loss = tensor(0.0011, device='cuda:0')
# i=  31001
# error = 0.05553568434688113
# loss = tensor(0.0031, device='cuda:0')
# i=  31501
# error = 0.06568045594351561
# loss = tensor(0.0012, device='cuda:0')
# i=  32001
# error = 0.05781408643375508
# loss = tensor(0.0020, device='cuda:0')
# i=  32501
# error = 0.06498944136199838
# loss = tensor(0.0010, device='cuda:0')
# i=  33001
# error = 0.08465282004739143
# loss = tensor(0.0067, device='cuda:0')
# i=  33501
# error = 0.061910563509415574
# loss = tensor(0.0011, device='cuda:0')
# i=  34001
# error = 0.06604686077961386
# loss = tensor(0.0010, device='cuda:0')
# i=  34501
# error = 0.0618603975988299
# loss = tensor(0.0010, device='cuda:0')
# i=  35001
# error = 0.06171238535536862
# loss = tensor(0.0010, device='cuda:0')
# i=  35501
# error = 0.06183682563359517
# loss = tensor(0.0010, device='cuda:0')
# i=  36001
# error = 0.061422401453569545
# loss = tensor(0.0010, device='cuda:0')
# i=  36501
# error = 0.08299983187342687
# loss = tensor(0.0081, device='cuda:0')
# i=  37001
# error = 0.07000060738650159
# loss = tensor(0.0017, device='cuda:0')
# i=  37501
# error = 0.07266565731856095
# loss = tensor(0.0032, device='cuda:0')
# i=  38001
# error = 0.06163627002136409
# loss = tensor(0.0009, device='cuda:0')
# i=  38501
# error = 0.06321238572891445
# loss = tensor(0.0009, device='cuda:0')
# i=  39001
# error = 0.06128880937526656
# loss = tensor(0.0009, device='cuda:0')
# i=  39501
# error = 0.07158541541132853
# loss = tensor(0.0060, device='cuda:0')
# i=  40001
# error = 0.05939062179543043
# loss = tensor(0.0009, device='cuda:0')
# i=  40501
# error = 0.0617794779770705
# loss = tensor(0.0012, device='cuda:0')
# i=  41001
# error = 0.06694271424232318
# loss = tensor(0.0024, device='cuda:0')
# i=  41501
# error = 0.05921866922549486
# loss = tensor(0.0009, device='cuda:0')
# i=  42001
# error = 0.08280993942864144
# loss = tensor(0.0071, device='cuda:0')
# i=  42501
# error = 0.05330982306946287
# loss = tensor(0.0012, device='cuda:0')
# i=  43001
# error = 0.05972627182158822
# loss = tensor(0.0008, device='cuda:0')
# i=  43501
# error = 0.058877814444920365
# loss = tensor(0.0008, device='cuda:0')
# i=  44001
# error = 0.056215822966633064
# loss = tensor(0.0009, device='cuda:0')
# i=  44501
# error = 0.05730645270485066
# loss = tensor(0.0008, device='cuda:0')
# i=  45001
# error = 0.05931502506046909
# loss = tensor(0.0008, device='cuda:0')
# i=  45501
# error = 0.058944805705708786
# loss = tensor(0.0008, device='cuda:0')
# i=  46001
# error = 0.055930491575066646
# loss = tensor(0.0008, device='cuda:0')
# i=  46501
# error = 0.05750049149534205
# loss = tensor(0.0008, device='cuda:0')
# i=  47001
# error = 0.05908800169887416
# loss = tensor(0.0008, device='cuda:0')
# i=  47501
# error = 0.05653215872704885
# loss = tensor(0.0008, device='cuda:0')
# i=  48001
# error = 0.05626019303900261
# loss = tensor(0.0008, device='cuda:0')
# i=  48501
# error = 0.059728512178847795
# loss = tensor(0.0013, device='cuda:0')
# i=  49001
# error = 0.05165485024538752
# loss = tensor(0.0010, device='cuda:0')
# i=  49501
# error = 0.057494443382791506
# loss = tensor(0.0007, device='cuda:0')
# time cost 43074.51072525978 s
