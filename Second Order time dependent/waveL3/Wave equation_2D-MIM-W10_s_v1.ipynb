# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],4).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    sol =  sol +  (2*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,3).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    Np = Du[:,1:3].reshape(x.size()[0],2)
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(2):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss =  torch.sum( (Np-p)**2 )/50000 + torch.sum( (v_t - uxx - source(x))**2 )/50000
    return loss

# %%
def BC():
    x1 = torch.rand(1000,3).cuda()
    x1[:,0] = 0
    loss = torch.sum(model_v(x1)**2)/1000
    return loss

# %%
model_u1 = ResNet(3,10,1)
model_p1 = ResNet(3,10,2)
device=torch.device("cuda:1" )

model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=3, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (fc5): Linear(in_features=10, out_features=10, bias=True)
#   (fc6): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=2, bias=True)
# )

# %%
def model_u(x):
    return x[:,0:1]*(x*(1-x))[:,1:2]*(x*(1-x))[:,2:3]*model_u1(x)
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v
def model_p(x):
    return model_p1(x)

# %%
def initparam(model,sigma):
    for m in model.modules():
        if isinstance(m,nn.Linear):
            m.weight.data.uniform_(-sigma,sigma)#全连接层参数初始化
            m.bias.data.uniform_(0,sigma)
    return model

# %%
notes = torch.rand(10000,3).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:4])**2)/10000)
def loss_error():
    notes = torch.rand(10000,3).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,4).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:4] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:4] - predict[:,2:4])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()}
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss =",losses.detach())
        np.save("error_save_LDG_wave_2D_s_w10_v1.npy", error_save)
np.save("error_save_LDG_wave_2D_s_w10_v1.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.9851334768272934
# loss = tensor(28.6968, device='cuda:1')
# i=  501
# error = 0.09494700904940392
# loss = tensor(0.3547, device='cuda:1')
# i=  1001
# error = 0.045060083140162785
# loss = tensor(0.0879, device='cuda:1')
# i=  1501
# error = 0.01685405148119425
# loss = tensor(0.0464, device='cuda:1')
# i=  2001
# error = 0.0172537942214735
# loss = tensor(0.0326, device='cuda:1')
# i=  2501
# error = 0.021700730745155748
# loss = tensor(0.0259, device='cuda:1')
# i=  3001
# error = 0.025952388562985294
# loss = tensor(0.0219, device='cuda:1')
# i=  3501
# error = 0.02325436702911864
# loss = tensor(0.0194, device='cuda:1')
# i=  4001
# error = 0.02636490848502196
# loss = tensor(0.0158, device='cuda:1')
# i=  4501
# error = 0.02421249041039462
# loss = tensor(0.0147, device='cuda:1')
# i=  5001
# error = 0.02671579112557887
# loss = tensor(0.0137, device='cuda:1')
# i=  5501
# error = 0.02312651260358061
# loss = tensor(0.0111, device='cuda:1')
# i=  6001
# error = 0.024280846858276247
# loss = tensor(0.0101, device='cuda:1')
# i=  6501
# error = 0.023137973919601342
# loss = tensor(0.0092, device='cuda:1')
# i=  7001
# error = 0.031023497308612206
# loss = tensor(0.0157, device='cuda:1')
# i=  7501
# error = 0.02585498755431056
# loss = tensor(0.0081, device='cuda:1')
# i=  8001
# error = 0.0203066449619074
# loss = tensor(0.0074, device='cuda:1')
# i=  8501
# error = 0.020473279267116437
# loss = tensor(0.0068, device='cuda:1')
# i=  9001
# error = 0.019460184073419602
# loss = tensor(0.0064, device='cuda:1')
# i=  9501
# error = 0.024955312040390983
# loss = tensor(0.0083, device='cuda:1')
# i=  10001
# error = 0.019354080070000737
# loss = tensor(0.0056, device='cuda:1')
# i=  10501
# error = 0.018613425818695514
# loss = tensor(0.0053, device='cuda:1')
# i=  11001
# error = 0.019742751617141212
# loss = tensor(0.0052, device='cuda:1')
# i=  11501
# error = 0.019690766332686335
# loss = tensor(0.0047, device='cuda:1')
# i=  12001
# error = 0.01771721252960366
# loss = tensor(0.0045, device='cuda:1')
# i=  12501
# error = 0.01693908721041433
# loss = tensor(0.0044, device='cuda:1')
# i=  13001
# error = 0.019611551323222853
# loss = tensor(0.0050, device='cuda:1')
# i=  13501
# error = 0.015551102318260651
# loss = tensor(0.0041, device='cuda:1')
# i=  14001
# error = 0.013217691551267648
# loss = tensor(0.0044, device='cuda:1')
# i=  14501
# error = 0.01629163308456387
# loss = tensor(0.0042, device='cuda:1')
# i=  15001
# error = 0.014257894232733919
# loss = tensor(0.0043, device='cuda:1')
# i=  15501
# error = 0.014683956273673597
# loss = tensor(0.0035, device='cuda:1')
# i=  16001
# error = 0.015566604410091733
# loss = tensor(0.0038, device='cuda:1')
# i=  16501
# error = 0.01259224034246719
# loss = tensor(0.0033, device='cuda:1')
# i=  17001
# error = 0.01136767055988524
# loss = tensor(0.0031, device='cuda:1')
# i=  17501
# error = 0.010852420241789023
# loss = tensor(0.0034, device='cuda:1')
# i=  18001
# error = 0.012183476575903534
# loss = tensor(0.0030, device='cuda:1')
# i=  18501
# error = 0.0116453845413607
# loss = tensor(0.0029, device='cuda:1')
# i=  19001
# error = 0.01464284282050246
# loss = tensor(0.0035, device='cuda:1')
# i=  19501
# error = 0.01518765236201117
# loss = tensor(0.0046, device='cuda:1')
# i=  20001
# error = 0.012078300101234805
# loss = tensor(0.0026, device='cuda:1')
# i=  20501
# error = 0.008835857665410972
# loss = tensor(0.0032, device='cuda:1')
# i=  21001
# error = 0.016676119377710668
# loss = tensor(0.0061, device='cuda:1')
# i=  21501
# error = 0.011142471697532172
# loss = tensor(0.0024, device='cuda:1')
# i=  22001
# error = 0.009819096028613694
# loss = tensor(0.0024, device='cuda:1')
# i=  22501
# error = 0.009547388961255223
# loss = tensor(0.0024, device='cuda:1')
# i=  23001
# error = 0.008810304526055315
# loss = tensor(0.0023, device='cuda:1')
# i=  23501
# error = 0.010209044347564698
# loss = tensor(0.0023, device='cuda:1')
# i=  24001
# error = 0.007493890236408759
# loss = tensor(0.0025, device='cuda:1')
# i=  24501
# error = 0.01067904256490826
# loss = tensor(0.0022, device='cuda:1')
# i=  25001
# error = 0.0076411746384502715
# loss = tensor(0.0025, device='cuda:1')
# i=  25501
# error = 0.010754588111840414
# loss = tensor(0.0021, device='cuda:1')
# i=  26001
# error = 0.013004192598246407
# loss = tensor(0.0036, device='cuda:1')
# i=  26501
# error = 0.007093817654415069
# loss = tensor(0.0025, device='cuda:1')
# i=  27001
# error = 0.010949830632532132
# loss = tensor(0.0020, device='cuda:1')
# i=  27501
# error = 0.009685743247620806
# loss = tensor(0.0019, device='cuda:1')
# i=  28001
# error = 0.007830566041820553
# loss = tensor(0.0018, device='cuda:1')
# i=  28501
# error = 0.008081942189338491
# loss = tensor(0.0018, device='cuda:1')
# i=  29001
# error = 0.009316038068630314
# loss = tensor(0.0020, device='cuda:1')
# i=  29501
# error = 0.008702304718089717
# loss = tensor(0.0016, device='cuda:1')
# i=  30001
# error = 0.008239575331467092
# loss = tensor(0.0016, device='cuda:1')
# i=  30501
# error = 0.009045585802137029
# loss = tensor(0.0016, device='cuda:1')
# i=  31001
# error = 0.008530630028595648
# loss = tensor(0.0016, device='cuda:1')
# i=  31501
# error = 0.00547916932787526
# loss = tensor(0.0038, device='cuda:1')
# i=  32001
# error = 0.008873183686429437
# loss = tensor(0.0015, device='cuda:1')
# i=  32501
# error = 0.009211698708199207
# loss = tensor(0.0018, device='cuda:1')
# i=  33001
# error = 0.008117336606632426
# loss = tensor(0.0016, device='cuda:1')
# i=  33501
# error = 0.00806617442190657
# loss = tensor(0.0014, device='cuda:1')
# i=  34001
# error = 0.008188624284452783
# loss = tensor(0.0015, device='cuda:1')
# i=  34501
# error = 0.008134811018348913
# loss = tensor(0.0015, device='cuda:1')
# i=  35001
# error = 0.010279630050288558
# loss = tensor(0.0022, device='cuda:1')
# i=  35501
# error = 0.008592748046190292
# loss = tensor(0.0012, device='cuda:1')
# i=  36001
# error = 0.007828658313876165
# loss = tensor(0.0012, device='cuda:1')
# i=  36501
# error = 0.006340555980123971
# loss = tensor(0.0016, device='cuda:1')
# i=  37001
# error = 0.009615121073394696
# loss = tensor(0.0018, device='cuda:1')
# i=  37501
# error = 0.007793300071429546
# loss = tensor(0.0013, device='cuda:1')
# i=  38001
# error = 0.008087227829567199
# loss = tensor(0.0013, device='cuda:1')
# i=  38501
# error = 0.011232340394399945
# loss = tensor(0.0030, device='cuda:1')
# i=  39001
# error = 0.00811176626717495
# loss = tensor(0.0012, device='cuda:1')
# i=  39501
# error = 0.008805042505261327
# loss = tensor(0.0028, device='cuda:1')
# i=  40001
# error = 0.007023093902144164
# loss = tensor(0.0011, device='cuda:1')
# i=  40501
# error = 0.006820868767102957
# loss = tensor(0.0011, device='cuda:1')
# i=  41001
# error = 0.007415335768579356
# loss = tensor(0.0011, device='cuda:1')
# i=  41501
# error = 0.007131612912657133
# loss = tensor(0.0010, device='cuda:1')
# i=  42001
# error = 0.010172410953469591
# loss = tensor(0.0055, device='cuda:1')
# i=  42501
# error = 0.006730890791068974
# loss = tensor(0.0010, device='cuda:1')
# i=  43001
# error = 0.0074081540085590555
# loss = tensor(0.0015, device='cuda:1')
# i=  43501
# error = 0.0069341140103565445
# loss = tensor(0.0010, device='cuda:1')
# i=  44001
# error = 0.0047728992226502825
# loss = tensor(0.0021, device='cuda:1')
# i=  44501
# error = 0.005962991364527175
# loss = tensor(0.0011, device='cuda:1')
# i=  45001
# error = 0.006501719656014017
# loss = tensor(0.0009, device='cuda:1')
# i=  45501
# error = 0.006729920462882405
# loss = tensor(0.0010, device='cuda:1')
# i=  46001
# error = 0.006141358755841437
# loss = tensor(0.0009, device='cuda:1')
# i=  46501
# error = 0.006264780130156151
# loss = tensor(0.0009, device='cuda:1')
# i=  47001
# error = 0.010157823643646901
# loss = tensor(0.0035, device='cuda:1')
# i=  47501
# error = 0.006770358625831862
# loss = tensor(0.0008, device='cuda:1')
# i=  48001
# error = 0.006276479870276114
# loss = tensor(0.0008, device='cuda:1')
# i=  48501
# error = 0.009438530048457615
# loss = tensor(0.0026, device='cuda:1')
# i=  49001
# error = 0.005652450510455023
# loss = tensor(0.0009, device='cuda:1')
# i=  49501
# error = 0.005913722005549033
# loss = tensor(0.0008, device='cuda:1')

# %%
import matplotlib.pyplot as plt
error = np.load("error_save_LDG_wave_2D_q_w20.npy")

# %%
plt.plot(np.log10(error[1]))

# %%
plt.plot(np.log10(error[0]))

# %%
plt.plot(np.log10(error[2]))
