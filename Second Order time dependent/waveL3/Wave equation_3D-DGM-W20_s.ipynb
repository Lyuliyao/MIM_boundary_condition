# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
       
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x2 = torch.rand(1000,4).cuda()
    x3 = torch.rand(1000,4).cuda()
    x4 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    x4[:,3:4] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    loss = loss + torch.sum(model_u(x4)**2)/1000
    return loss

# %%
model_u = ResNet(4,20)
device=torch.device("cuda:1" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=20, bias=True)
#   (fc3): Linear(in_features=20, out_features=20, bias=True)
#   (fc4): Linear(in_features=20, out_features=20, bias=True)
#   (fc5): Linear(in_features=20, out_features=20, bias=True)
#   (fc6): Linear(in_features=20, out_features=20, bias=True)
#   (outlayer): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:4].reshape(x.size()[0],3)
    return p

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_3D_s_w20.npy", error_save)
np.save("error_save_DGM_wave_3D_s_w20.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 1.2337094829884443
# loss = tensor(27.1420, device='cuda:1')
# i=  501
# error = 0.2188745127735036
# loss = tensor(0.2837, device='cuda:1')
# i=  1001
# error = 0.2025612202747569
# loss = tensor(0.1705, device='cuda:1')
# i=  1501
# error = 0.2341294385500541
# loss = tensor(0.1176, device='cuda:1')
# i=  2001
# error = 0.20381207423287567
# loss = tensor(0.0788, device='cuda:1')
# i=  2501
# error = 0.19900496592129924
# loss = tensor(0.0594, device='cuda:1')
# i=  3001
# error = 0.20080404414126019
# loss = tensor(0.0456, device='cuda:1')
# i=  3501
# error = 0.18713311420964907
# loss = tensor(0.0398, device='cuda:1')
# i=  4001
# error = 0.19856744431672171
# loss = tensor(0.0344, device='cuda:1')
# i=  4501
# error = 0.18902929417623998
# loss = tensor(0.0314, device='cuda:1')
# i=  5001
# error = 0.19674450956151002
# loss = tensor(0.0313, device='cuda:1')
# i=  5501
# error = 0.20343612634212463
# loss = tensor(0.0335, device='cuda:1')
# i=  6001
# error = 0.16783322433484008
# loss = tensor(0.0324, device='cuda:1')
# i=  6501
# error = 0.18747751826013787
# loss = tensor(0.0278, device='cuda:1')
# i=  7001
# error = 0.1692463360009624
# loss = tensor(0.0271, device='cuda:1')
# i=  7501
# error = 0.18204042328102538
# loss = tensor(0.0260, device='cuda:1')
# i=  8001
# error = 0.16914358329109885
# loss = tensor(0.0246, device='cuda:1')
# i=  8501
# error = 0.1770141137150927
# loss = tensor(0.0225, device='cuda:1')
# i=  9001
# error = 0.1605813512130125
# loss = tensor(0.0229, device='cuda:1')
# i=  9501
# error = 0.15485541963677013
# loss = tensor(0.0233, device='cuda:1')
# i=  10001
# error = 0.14900048269822094
# loss = tensor(0.0226, device='cuda:1')
# i=  10501
# error = 0.17644408174286447
# loss = tensor(0.0194, device='cuda:1')
# i=  11001
# error = 0.16911360845693266
# loss = tensor(0.0161, device='cuda:1')
# i=  11501
# error = 0.16621444729186605
# loss = tensor(0.0154, device='cuda:1')
# i=  12001
# error = 0.1596286413223647
# loss = tensor(0.0152, device='cuda:1')
# i=  12501
# error = 0.1725490965555294
# loss = tensor(0.0144, device='cuda:1')
# i=  13001
# error = 0.15747090302588945
# loss = tensor(0.0159, device='cuda:1')
# i=  13501
# error = 0.1657016997423787
# loss = tensor(0.0143, device='cuda:1')
# i=  14001
# error = 0.16723722260322538
# loss = tensor(0.0153, device='cuda:1')
# i=  14501
# error = 0.16215393373601716
# loss = tensor(0.0162, device='cuda:1')
# i=  15001
# error = 0.1463325015816019
# loss = tensor(0.0212, device='cuda:1')
# i=  15501
# error = 0.17367001913442218
# loss = tensor(0.0170, device='cuda:1')
# i=  16001
# error = 0.17298266948595598
# loss = tensor(0.0184, device='cuda:1')
# i=  16501
# error = 0.1722495868787901
# loss = tensor(0.0178, device='cuda:1')
# i=  17001
# error = 0.1717741039254024
# loss = tensor(0.0165, device='cuda:1')
# i=  17501
# error = 0.16171015428432317
# loss = tensor(0.0159, device='cuda:1')
# i=  18001
# error = 0.17121156893803693
# loss = tensor(0.0148, device='cuda:1')
# i=  18501
# error = 0.17424717845431115
# loss = tensor(0.0143, device='cuda:1')
# i=  19001
# error = 0.16535479934017705
# loss = tensor(0.0117, device='cuda:1')
# i=  19501
# error = 0.1571705691365574
# loss = tensor(0.0110, device='cuda:1')
# i=  20001
# error = 0.1600844897947974
# loss = tensor(0.0101, device='cuda:1')
# i=  20501
# error = 0.16364102352140222
# loss = tensor(0.0109, device='cuda:1')
# i=  21001
# error = 0.14970707140573955
# loss = tensor(0.0106, device='cuda:1')
# i=  21501
# error = 0.14308575528375297
# loss = tensor(0.0104, device='cuda:1')
# i=  22001
# error = 0.1631452254784849
# loss = tensor(0.0130, device='cuda:1')
# i=  22501
# error = 0.1401822992540289
# loss = tensor(0.0104, device='cuda:1')
# i=  23001
# error = 0.14826592045388975
# loss = tensor(0.0087, device='cuda:1')
# i=  23501
# error = 0.14441768098902208
# loss = tensor(0.0086, device='cuda:1')
# i=  24001
# error = 0.14830635710795548
# loss = tensor(0.0088, device='cuda:1')
# i=  24501
# error = 0.14916553077354416
# loss = tensor(0.0099, device='cuda:1')
# i=  25001
# error = 0.15010290702696763
# loss = tensor(0.0103, device='cuda:1')
# i=  25501
# error = 0.1255306478087244
# loss = tensor(0.0171, device='cuda:1')
# i=  26001
# error = 0.14357878787492276
# loss = tensor(0.0092, device='cuda:1')
# i=  26501
# error = 0.13769953192530515
# loss = tensor(0.0091, device='cuda:1')
# i=  27001
# error = 0.14578389216705234
# loss = tensor(0.0085, device='cuda:1')
# i=  27501
# error = 0.13806652178847323
# loss = tensor(0.0082, device='cuda:1')
# i=  28001
# error = 0.14744259142394292
# loss = tensor(0.0095, device='cuda:1')
# i=  28501
# error = 0.16704996117314977
# loss = tensor(0.0118, device='cuda:1')
# i=  29001
# error = 0.1568930912983763
# loss = tensor(0.0106, device='cuda:1')
# i=  29501
# error = 0.15929868811747816
# loss = tensor(0.0112, device='cuda:1')
# i=  30001
# error = 0.14380157905923652
# loss = tensor(0.0090, device='cuda:1')
# i=  30501
# error = 0.13572167157412887
# loss = tensor(0.0089, device='cuda:1')
# i=  31001
# error = 0.13409491114872935
# loss = tensor(0.0109, device='cuda:1')
# i=  31501
# error = 0.1346138717396012
# loss = tensor(0.0095, device='cuda:1')
# i=  32001
# error = 0.13016499086674274
# loss = tensor(0.0081, device='cuda:1')
# i=  32501
# error = 0.12750639670440997
# loss = tensor(0.0077, device='cuda:1')
# i=  33001
# error = 0.12672344812601297
# loss = tensor(0.0077, device='cuda:1')
# i=  33501
# error = 0.12713330270309287
# loss = tensor(0.0079, device='cuda:1')
# i=  34001
# error = 0.12801207159653338
# loss = tensor(0.0081, device='cuda:1')
# i=  34501
# error = 0.11722718084662377
# loss = tensor(0.0094, device='cuda:1')
# i=  35001
# error = 0.1372060614328522
# loss = tensor(0.0096, device='cuda:1')
# i=  35501
# error = 0.13101578424151233
# loss = tensor(0.0078, device='cuda:1')
# i=  36001
# error = 0.13837998021527015
# loss = tensor(0.0096, device='cuda:1')
# i=  36501
# error = 0.12677375771021873
# loss = tensor(0.0069, device='cuda:1')
# i=  37001
# error = 0.11609172573064382
# loss = tensor(0.0071, device='cuda:1')
# i=  37501
# error = 0.12437634800771771
# loss = tensor(0.0062, device='cuda:1')
# i=  38001
# error = 0.1171923833453613
# loss = tensor(0.0058, device='cuda:1')
# i=  38501
# error = 0.1209943405211113
# loss = tensor(0.0059, device='cuda:1')
# i=  39001
# error = 0.11797220336358911
# loss = tensor(0.0053, device='cuda:1')
# i=  39501
# error = 0.11347627903621016
# loss = tensor(0.0052, device='cuda:1')
# i=  40001
# error = 0.10150407961961935
# loss = tensor(0.0057, device='cuda:1')
# i=  40501
# error = 0.10530712905569478
# loss = tensor(0.0058, device='cuda:1')
# i=  41001
# error = 0.09980421621026579
# loss = tensor(0.0060, device='cuda:1')
# i=  41501
# error = 0.0946789493990683
# loss = tensor(0.0074, device='cuda:1')
# i=  42001
# error = 0.10192686885904219
# loss = tensor(0.0049, device='cuda:1')
# i=  42501
# error = 0.10331586307417095
# loss = tensor(0.0048, device='cuda:1')
# i=  43001
# error = 0.1069853492034299
# loss = tensor(0.0046, device='cuda:1')
# i=  43501
# error = 0.09979349246345878
# loss = tensor(0.0050, device='cuda:1')
# i=  44001
# error = 0.11033565421106516
# loss = tensor(0.0051, device='cuda:1')
# i=  44501
# error = 0.09837588008387216
# loss = tensor(0.0062, device='cuda:1')
# i=  45001
# error = 0.10886522381434068
# loss = tensor(0.0048, device='cuda:1')
# i=  45501
# error = 0.10351584928329313
# loss = tensor(0.0043, device='cuda:1')
# i=  46001
# error = 0.0954862190457323
# loss = tensor(0.0053, device='cuda:1')
# i=  46501
# error = 0.10699828580779261
# loss = tensor(0.0047, device='cuda:1')
# i=  47001
# error = 0.10462619809032764
# loss = tensor(0.0044, device='cuda:1')
# i=  47501
# error = 0.0970298201766742
# loss = tensor(0.0044, device='cuda:1')
# i=  48001
# error = 0.09657077229554355
# loss = tensor(0.0046, device='cuda:1')
# i=  48501
# error = 0.10483344147354046
# loss = tensor(0.0056, device='cuda:1')
# i=  49001
# error = 0.09809916943109517
# loss = tensor(0.0055, device='cuda:1')
# i=  49501
# error = 0.10396466326244182
# loss = tensor(0.0051, device='cuda:1')
# time cost 45970.48245239258 s
