# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
       
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        
        output = self.outlayer(y)
        return output
deg = 3

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],4).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    sol =  sol +  (2*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,3).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(2):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,3).cuda()
    x2 = torch.rand(1000,3).cuda()
    x3 = torch.rand(1000,3).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    return loss

# %%
model_u = ResNet(3,20)
device=torch.device("cuda:0" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=3, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=20, bias=True)
#   (fc3): Linear(in_features=20, out_features=20, bias=True)
#   (fc4): Linear(in_features=20, out_features=20, bias=True)
#   (fc5): Linear(in_features=20, out_features=20, bias=True)
#   (fc6): Linear(in_features=20, out_features=20, bias=True)
#   (outlayer): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:3].reshape(x.size()[0],2)
    return p

# %%
notes = torch.rand(10000,3).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:4])**2)/10000)
def loss_error():
    notes = torch.rand(10000,3).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,4).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:4] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:4] - predict[:,2:4])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_2D_q_w20.npy", error_save)
np.save("error_save_DGM_wave_2D_q_w20.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 1.1551486768176946
# loss = tensor(28.5782, device='cuda:0')
# i=  501
# error = 0.15188813221923442
# loss = tensor(0.0376, device='cuda:0')
# i=  1001
# error = 0.1169679355190229
# loss = tensor(0.0123, device='cuda:0')
# i=  1501
# error = 0.10488814002528966
# loss = tensor(0.0083, device='cuda:0')
# i=  2001
# error = 0.09097453438670983
# loss = tensor(0.0063, device='cuda:0')
# i=  2501
# error = 0.08741533643230952
# loss = tensor(0.0045, device='cuda:0')
# i=  3001
# error = 0.07753911328174382
# loss = tensor(0.0037, device='cuda:0')
# i=  3501
# error = 0.06846493292539395
# loss = tensor(0.0036, device='cuda:0')
# i=  4001
# error = 0.06539951240052352
# loss = tensor(0.0027, device='cuda:0')
# i=  4501
# error = 0.05899215312159633
# loss = tensor(0.0022, device='cuda:0')
# i=  5001
# error = 0.053323120998312816
# loss = tensor(0.0021, device='cuda:0')
# i=  5501
# error = 0.05127515288428372
# loss = tensor(0.0018, device='cuda:0')
# i=  6001
# error = 0.04269279658419879
# loss = tensor(0.0014, device='cuda:0')
# i=  6501
# error = 0.03791401494825757
# loss = tensor(0.0011, device='cuda:0')
# i=  7001
# error = 0.032339365325082615
# loss = tensor(0.0010, device='cuda:0')
# i=  7501
# error = 0.029770652949768852
# loss = tensor(0.0008, device='cuda:0')
# i=  8001
# error = 0.02973075155991666
# loss = tensor(0.0008, device='cuda:0')
# i=  8501
# error = 0.020346287380977508
# loss = tensor(0.0026, device='cuda:0')
# i=  9001
# error = 0.024615574157068523
# loss = tensor(0.0006, device='cuda:0')
# i=  9501
# error = 0.02320677302577174
# loss = tensor(0.0006, device='cuda:0')
# i=  10001
# error = 0.022896990829887654
# loss = tensor(0.0005, device='cuda:0')
# i=  10501
# error = 0.021469898269547677
# loss = tensor(0.0005, device='cuda:0')
# i=  11001
# error = 0.02060942269832592
# loss = tensor(0.0005, device='cuda:0')
# i=  11501
# error = 0.020243727047460212
# loss = tensor(0.0004, device='cuda:0')
# i=  12001
# error = 0.017912429881343596
# loss = tensor(0.0006, device='cuda:0')
# i=  12501
# error = 0.019118358304881948
# loss = tensor(0.0004, device='cuda:0')
# i=  13001
# error = 0.019512903530304816
# loss = tensor(0.0004, device='cuda:0')
# i=  13501
# error = 0.02606112299389554
# loss = tensor(0.0025, device='cuda:0')
# i=  14001
# error = 0.017960883933087257
# loss = tensor(0.0004, device='cuda:0')
# i=  14501
# error = 0.016526362685060837
# loss = tensor(0.0003, device='cuda:0')
# i=  15001
# error = 0.016064297711535155
# loss = tensor(0.0003, device='cuda:0')
# i=  15501
# error = 0.0165868786637181
# loss = tensor(0.0003, device='cuda:0')
# i=  16001
# error = 0.016131464214337816
# loss = tensor(0.0003, device='cuda:0')
# i=  16501
# error = 0.01645775096343571
# loss = tensor(0.0003, device='cuda:0')
# i=  17001
# error = 0.013995973026414877
# loss = tensor(0.0004, device='cuda:0')
# i=  17501
# error = 0.01595009047606713
# loss = tensor(0.0003, device='cuda:0')
# i=  18001
# error = 0.014365226936890352
# loss = tensor(0.0003, device='cuda:0')
# i=  18501
# error = 0.01527177182159416
# loss = tensor(0.0003, device='cuda:0')
# i=  19001
# error = 0.012087208462586468
# loss = tensor(0.0007, device='cuda:0')
# i=  19501
# error = 0.016091696679173755
# loss = tensor(0.0003, device='cuda:0')
# i=  20001
# error = 0.015076913595332963
# loss = tensor(0.0002, device='cuda:0')
# i=  20501
# error = 0.013253229487859862
# loss = tensor(0.0004, device='cuda:0')
# i=  21001
# error = 0.01047511859645442
# loss = tensor(0.0010, device='cuda:0')
# i=  21501
# error = 0.016597552112735094
# loss = tensor(0.0004, device='cuda:0')
# i=  22001
# error = 0.01559107076122603
# loss = tensor(0.0003, device='cuda:0')
# i=  22501
# error = 0.015946293642218175
# loss = tensor(0.0004, device='cuda:0')
# i=  23001
# error = 0.014067121151237842
# loss = tensor(0.0002, device='cuda:0')
# i=  23501
# error = 0.014324827761395166
# loss = tensor(0.0002, device='cuda:0')
# i=  24001
# error = 0.012414204301262784
# loss = tensor(0.0003, device='cuda:0')
# i=  24501
# error = 0.014200097087757768
# loss = tensor(0.0003, device='cuda:0')
# i=  25001
# error = 0.018459027288255818
# loss = tensor(0.0009, device='cuda:0')
# i=  25501
# error = 0.013179756866809191
# loss = tensor(0.0002, device='cuda:0')
# i=  26001
# error = 0.01846118617006298
# loss = tensor(0.0009, device='cuda:0')
# i=  26501
# error = 0.013466387625530497
# loss = tensor(0.0002, device='cuda:0')
# i=  27001
# error = 0.014256709224825855
# loss = tensor(0.0002, device='cuda:0')
# i=  27501
# error = 0.018046344499644543
# loss = tensor(0.0007, device='cuda:0')
# i=  28001
# error = 0.012753866367892197
# loss = tensor(0.0002, device='cuda:0')
# i=  28501
# error = 0.012596940500416523
# loss = tensor(0.0002, device='cuda:0')
# i=  29001
# error = 0.013289827723902664
# loss = tensor(0.0002, device='cuda:0')
# i=  29501
# error = 0.012894116181126692
# loss = tensor(0.0002, device='cuda:0')
# i=  30001
# error = 0.013426800679302221
# loss = tensor(0.0004, device='cuda:0')
# i=  30501
# error = 0.013113517219333324
# loss = tensor(0.0002, device='cuda:0')
# i=  31001
# error = 0.014304729724614261
# loss = tensor(0.0003, device='cuda:0')
# i=  31501
# error = 0.0142382095658617
# loss = tensor(0.0034, device='cuda:0')
# i=  32001
# error = 0.013253748363190154
# loss = tensor(0.0007, device='cuda:0')
# i=  32501
# error = 0.013984117163615245
# loss = tensor(0.0002, device='cuda:0')
# i=  33001
# error = 0.011124793199147573
# loss = tensor(0.0003, device='cuda:0')
# i=  33501
# error = 0.012626327240558064
# loss = tensor(0.0002, device='cuda:0')
# i=  34001
# error = 0.016192813794388878
# loss = tensor(0.0007, device='cuda:0')
# i=  34501
# error = 0.011985299005209478
# loss = tensor(0.0002, device='cuda:0')
# i=  35001
# error = 0.010981624817350988
# loss = tensor(0.0024, device='cuda:0')
# i=  35501
# error = 0.01179415890696066
# loss = tensor(0.0002, device='cuda:0')
# i=  36001
# error = 0.00986401939466247
# loss = tensor(0.0005, device='cuda:0')
# i=  36501
# error = 0.011993401700648864
# loss = tensor(0.0002, device='cuda:0')
# i=  37001
# error = 0.01280623564004062
# loss = tensor(0.0002, device='cuda:0')
# i=  37501
# error = 0.01198366254106624
# loss = tensor(0.0002, device='cuda:0')
# i=  38001
# error = 0.014347083437483523
# loss = tensor(0.0003, device='cuda:0')
# i=  38501
# error = 0.01779056987774303
# loss = tensor(0.0011, device='cuda:0')
# i=  39001
# error = 0.01102601935948345
# loss = tensor(0.0002, device='cuda:0')
# i=  39501
# error = 0.014140792183960393
# loss = tensor(0.0002, device='cuda:0')
# i=  40001
# error = 0.012603084556950155
# loss = tensor(0.0004, device='cuda:0')
# i=  40501
# error = 0.010608691876943499
# loss = tensor(0.0002, device='cuda:0')
# i=  41001
# error = 0.011748448015468278
# loss = tensor(0.0001, device='cuda:0')
# i=  41501
# error = 0.011555662002232113
# loss = tensor(0.0001, device='cuda:0')
# i=  42001
# error = 0.013947304671687174
# loss = tensor(0.0003, device='cuda:0')
# i=  42501
# error = 0.010694019281512238
# loss = tensor(0.0016, device='cuda:0')
# i=  43001
# error = 0.013316683464127862
# loss = tensor(0.0002, device='cuda:0')
# i=  43501
# error = 0.013247888700455108
# loss = tensor(0.0003, device='cuda:0')
# i=  44001
# error = 0.012718550139391046
# loss = tensor(0.0002, device='cuda:0')
# i=  44501
# error = 0.011214532823360896
# loss = tensor(0.0001, device='cuda:0')
# i=  45001
# error = 0.011548754516711076
# loss = tensor(0.0001, device='cuda:0')
# i=  45501
# error = 0.011726270788436195
# loss = tensor(0.0001, device='cuda:0')
# i=  46001
# error = 0.011663362017477037
# loss = tensor(0.0002, device='cuda:0')
# i=  46501
# error = 0.011060778237458133
# loss = tensor(0.0002, device='cuda:0')
# i=  47001
# error = 0.014960599430549521
# loss = tensor(0.0005, device='cuda:0')
# i=  47501
# error = 0.01212000109151174
# loss = tensor(0.0001, device='cuda:0')
# i=  48001
# error = 0.011419412098280133
# loss = tensor(0.0001, device='cuda:0')
# i=  48501
# error = 0.011019348218302865
# loss = tensor(0.0001, device='cuda:0')
# i=  49001
# error = 0.010031117992349643
# loss = tensor(0.0003, device='cuda:0')
# i=  49501
# error = 0.012846155942420476
# loss = tensor(0.0004, device='cuda:0')
# time cost 40139.547355651855 s
