# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
       
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],4).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    sol =  sol +  (2*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,3).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(2):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,3).cuda()
    x2 = torch.rand(1000,3).cuda()
    x3 = torch.rand(1000,3).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    return loss

# %%
model_u = ResNet(3,10)
device=torch.device("cuda:0" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=3, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (fc5): Linear(in_features=10, out_features=10, bias=True)
#   (fc6): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:3].reshape(x.size()[0],2)
    return p

# %%
notes = torch.rand(10000,3).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:4])**2)/10000)
def loss_error():
    notes = torch.rand(10000,3).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,4).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:4] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:4] - predict[:,2:4])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_2D_s_w10.npy", error_save)
np.save("error_save_DGM_wave_2D_s_w10.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.6152491045958237
# loss = tensor(26.5887, device='cuda:0')
# i=  501
# error = 0.40477949527803075
# loss = tensor(0.3788, device='cuda:0')
# i=  1001
# error = 0.374920381743054
# loss = tensor(0.2464, device='cuda:0')
# i=  1501
# error = 0.27030101331495543
# loss = tensor(0.1082, device='cuda:0')
# i=  2001
# error = 0.20977391657792113
# loss = tensor(0.0890, device='cuda:0')
# i=  2501
# error = 0.1828041053767143
# loss = tensor(0.0601, device='cuda:0')
# i=  3001
# error = 0.16716767720912096
# loss = tensor(0.0474, device='cuda:0')
# i=  3501
# error = 0.154674284667111
# loss = tensor(0.0430, device='cuda:0')
# i=  4001
# error = 0.15161158611641204
# loss = tensor(0.0409, device='cuda:0')
# i=  4501
# error = 0.16567829584213145
# loss = tensor(0.0451, device='cuda:0')
# i=  5001
# error = 0.1723924384027991
# loss = tensor(0.0419, device='cuda:0')
# i=  5501
# error = 0.1590797063604698
# loss = tensor(0.0375, device='cuda:0')
# i=  6001
# error = 0.16426158508008357
# loss = tensor(0.0350, device='cuda:0')
# i=  6501
# error = 0.15856084648508925
# loss = tensor(0.0312, device='cuda:0')
# i=  7001
# error = 0.1440756688168669
# loss = tensor(0.0264, device='cuda:0')
# i=  7501
# error = 0.14212288262258943
# loss = tensor(0.0265, device='cuda:0')
# i=  8001
# error = 0.143013748837733
# loss = tensor(0.0234, device='cuda:0')
# i=  8501
# error = 0.13819764184241068
# loss = tensor(0.0209, device='cuda:0')
# i=  9001
# error = 0.12951966877630494
# loss = tensor(0.0195, device='cuda:0')
# i=  9501
# error = 0.13323183896962962
# loss = tensor(0.0200, device='cuda:0')
# i=  10001
# error = 0.13393542572617081
# loss = tensor(0.0195, device='cuda:0')
# i=  10501
# error = 0.13840191672497704
# loss = tensor(0.0206, device='cuda:0')
# i=  11001
# error = 0.12925487424813234
# loss = tensor(0.0171, device='cuda:0')
# i=  11501
# error = 0.12551684104614672
# loss = tensor(0.0157, device='cuda:0')
# i=  12001
# error = 0.127797322961976
# loss = tensor(0.0175, device='cuda:0')
# i=  12501
# error = 0.11797946849240609
# loss = tensor(0.0148, device='cuda:0')
# i=  13001
# error = 0.1150373552836754
# loss = tensor(0.0131, device='cuda:0')
# i=  13501
# error = 0.1273163136977533
# loss = tensor(0.0178, device='cuda:0')
# i=  14001
# error = 0.10870474590620581
# loss = tensor(0.0126, device='cuda:0')
# i=  14501
# error = 0.11198377822653173
# loss = tensor(0.0135, device='cuda:0')
# i=  15001
# error = 0.1004364593779878
# loss = tensor(0.0121, device='cuda:0')
# i=  15501
# error = 0.10026098063327125
# loss = tensor(0.0105, device='cuda:0')
# i=  16001
# error = 0.09857054186464992
# loss = tensor(0.0101, device='cuda:0')
# i=  16501
# error = 0.10024053959210026
# loss = tensor(0.0097, device='cuda:0')
# i=  17001
# error = 0.09484264585962782
# loss = tensor(0.0129, device='cuda:0')
# i=  17501
# error = 0.09988177446100115
# loss = tensor(0.0104, device='cuda:0')
# i=  18001
# error = 0.09870353908923003
# loss = tensor(0.0113, device='cuda:0')
# i=  18501
# error = 0.0989401606734065
# loss = tensor(0.0130, device='cuda:0')
# i=  19001
# error = 0.10151218896083761
# loss = tensor(0.0214, device='cuda:0')
# i=  19501
# error = 0.11431602598551119
# loss = tensor(0.0154, device='cuda:0')
# i=  20001
# error = 0.11338491498358869
# loss = tensor(0.0129, device='cuda:0')
# i=  20501
# error = 0.10884620025882379
# loss = tensor(0.0129, device='cuda:0')
# i=  21001
# error = 0.10636968483409986
# loss = tensor(0.0129, device='cuda:0')
# i=  21501
# error = 0.10953851802543581
# loss = tensor(0.0133, device='cuda:0')
# i=  22001
# error = 0.10948792031435459
# loss = tensor(0.0170, device='cuda:0')
# i=  22501
# error = 0.1113558831456754
# loss = tensor(0.0157, device='cuda:0')
# i=  23001
# error = 0.10899131046269951
# loss = tensor(0.0142, device='cuda:0')
# i=  23501
# error = 0.10703521142893187
# loss = tensor(0.0135, device='cuda:0')
# i=  24001
# error = 0.11245768050249871
# loss = tensor(0.0120, device='cuda:0')
# i=  24501
# error = 0.11169859894043455
# loss = tensor(0.0116, device='cuda:0')
# i=  25001
# error = 0.10819757596965354
# loss = tensor(0.0107, device='cuda:0')
# i=  25501
# error = 0.10353051733325982
# loss = tensor(0.0105, device='cuda:0')
# i=  26001
# error = 0.10044259769641517
# loss = tensor(0.0112, device='cuda:0')
# i=  26501
# error = 0.10232817447954472
# loss = tensor(0.0094, device='cuda:0')
# i=  27001
# error = 0.09812677752153916
# loss = tensor(0.0099, device='cuda:0')
# i=  27501
# error = 0.10009394727692383
# loss = tensor(0.0088, device='cuda:0')
# i=  28001
# error = 0.09208138658217764
# loss = tensor(0.0123, device='cuda:0')
# i=  28501
# error = 0.1082562161053125
# loss = tensor(0.0109, device='cuda:0')
# i=  29001
# error = 0.09728651300098438
# loss = tensor(0.0080, device='cuda:0')
# i=  29501
# error = 0.09637520521416491
# loss = tensor(0.0086, device='cuda:0')
# i=  30001
# error = 0.09574139021511438
# loss = tensor(0.0082, device='cuda:0')
# i=  30501
# error = 0.09760689249556251
# loss = tensor(0.0085, device='cuda:0')
# i=  31001
# error = 0.093647795523472
# loss = tensor(0.0076, device='cuda:0')
# i=  31501
# error = 0.0923233644335391
# loss = tensor(0.0076, device='cuda:0')
# i=  32001
# error = 0.09460891068036038
# loss = tensor(0.0077, device='cuda:0')
# i=  32501
# error = 0.09279465913663258
# loss = tensor(0.0071, device='cuda:0')
# i=  33001
# error = 0.09079065770621939
# loss = tensor(0.0066, device='cuda:0')
# i=  33501
# error = 0.09636805784308518
# loss = tensor(0.0077, device='cuda:0')
# i=  34001
# error = 0.08554648147452729
# loss = tensor(0.0068, device='cuda:0')
# i=  34501
# error = 0.08499295810859683
# loss = tensor(0.0064, device='cuda:0')
# i=  35001
# error = 0.09309542386080912
# loss = tensor(0.0072, device='cuda:0')
# i=  35501
# error = 0.08880255260484977
# loss = tensor(0.0066, device='cuda:0')
# i=  36001
# error = 0.08497116039420731
# loss = tensor(0.0064, device='cuda:0')
# i=  36501
# error = 0.08642762014012619
# loss = tensor(0.0063, device='cuda:0')
# i=  37001
# error = 0.08671628200337579
# loss = tensor(0.0058, device='cuda:0')
# i=  37501
# error = 0.08751211938435807
# loss = tensor(0.0062, device='cuda:0')
# i=  38001
# error = 0.08501010308675447
# loss = tensor(0.0059, device='cuda:0')
# i=  38501
# error = 0.07916997017583283
# loss = tensor(0.0067, device='cuda:0')
# i=  39001
# error = 0.08122580085203114
# loss = tensor(0.0057, device='cuda:0')
# i=  39501
# error = 0.08536411570283027
# loss = tensor(0.0057, device='cuda:0')
# i=  40001
# error = 0.08414849627879636
# loss = tensor(0.0060, device='cuda:0')
# i=  40501
# error = 0.0799231413332607
# loss = tensor(0.0060, device='cuda:0')
# i=  41001
# error = 0.07848867389791302
# loss = tensor(0.0058, device='cuda:0')
# i=  41501
# error = 0.08026958055246187
# loss = tensor(0.0057, device='cuda:0')
# i=  42001
# error = 0.07626934243790694
# loss = tensor(0.0055, device='cuda:0')
# i=  42501
# error = 0.07641888586231972
# loss = tensor(0.0054, device='cuda:0')
# i=  43001
# error = 0.0846951652856862
# loss = tensor(0.0071, device='cuda:0')
# i=  43501
# error = 0.07556447628779649
# loss = tensor(0.0053, device='cuda:0')
# i=  44001
# error = 0.07888842488051606
# loss = tensor(0.0054, device='cuda:0')
# i=  44501
# error = 0.0743979655896906
# loss = tensor(0.0054, device='cuda:0')
# i=  45001
# error = 0.07272506151563365
# loss = tensor(0.0055, device='cuda:0')
# i=  45501
# error = 0.0771018348457699
# loss = tensor(0.0051, device='cuda:0')
# i=  46001
# error = 0.07200501899195622
# loss = tensor(0.0053, device='cuda:0')
# i=  46501
# error = 0.07789632636488722
# loss = tensor(0.0051, device='cuda:0')
# i=  47001
# error = 0.07273724913631834
# loss = tensor(0.0050, device='cuda:0')
# i=  47501
# error = 0.07264377988385967
# loss = tensor(0.0051, device='cuda:0')
# i=  48001
# error = 0.07009428230484362
# loss = tensor(0.0058, device='cuda:0')
# i=  48501
# error = 0.07294534976468411
# loss = tensor(0.0050, device='cuda:0')
# i=  49001
# error = 0.07400714360699748
# loss = tensor(0.0050, device='cuda:0')
# i=  49501
# error = 0.0736048273017583
# loss = tensor(0.0048, device='cuda:0')
