# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        output = self.outlayer(y)
        return output
deg = 3

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    Np = Du[:,1:4].reshape(x.size()[0],3)
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss =  torch.sum( (Np-p)**2 )/50000 + torch.sum( (v_t - uxx - source(x))**2 )/50000
    return loss

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    loss = torch.sum(model_v(x1)**2)/1000
    return loss

# %%
model_u1 = ResNet(4,40,1)
model_p1 = ResNet(4,40,3)
device=torch.device("cuda:0" )

model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=40, bias=True)
#   (fc2): Linear(in_features=40, out_features=40, bias=True)
#   (fc3): Linear(in_features=40, out_features=40, bias=True)
#   (fc4): Linear(in_features=40, out_features=40, bias=True)
#   (fc5): Linear(in_features=40, out_features=40, bias=True)
#   (fc6): Linear(in_features=40, out_features=40, bias=True)
#   (outlayer): Linear(in_features=40, out_features=3, bias=True)
# )

# %%
def model_u(x):
    return x[:,0:1]*(x*(1-x))[:,1:2]*(x*(1-x))[:,2:3]*(x*(1-x))[:,3:4]*model_u1(x)
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v
def model_p(x):
    return model_p1(x)

# %%
def initparam(model,sigma):
    for m in model.modules():
        if isinstance(m,nn.Linear):
            m.weight.data.uniform_(-sigma,sigma)#全连接层参数初始化
            m.bias.data.uniform_(0,sigma)
    return model

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()}
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss =",losses.detach())
        np.save("error_save_LDG_wave_3D_q_w40_v1.npy", error_save)
np.save("error_save_LDG_wave_3D_q_w40_v1.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.9776308622226181
# loss = tensor(28.8642, device='cuda:0')
# i=  501
# error = 0.08326541726139945
# loss = tensor(0.1698, device='cuda:0')
# i=  1001
# error = 0.038848814414829735
# loss = tensor(0.0508, device='cuda:0')
# i=  1501
# error = 0.04187571849918469
# loss = tensor(0.0264, device='cuda:0')
# i=  2001
# error = 0.04406768562274459
# loss = tensor(0.0173, device='cuda:0')
# i=  2501
# error = 0.042694134441227084
# loss = tensor(0.0139, device='cuda:0')
# i=  3001
# error = 0.04118589611593025
# loss = tensor(0.0111, device='cuda:0')
# i=  3501
# error = 0.041621631814504706
# loss = tensor(0.0110, device='cuda:0')
# i=  4001
# error = 0.03504749219234492
# loss = tensor(0.0318, device='cuda:0')
# i=  4501
# error = 0.03420885250292664
# loss = tensor(0.0080, device='cuda:0')
# i=  5001
# error = 0.036143449072437286
# loss = tensor(0.0426, device='cuda:0')
# i=  5501
# error = 0.030737611442736103
# loss = tensor(0.0057, device='cuda:0')
# i=  6001
# error = 0.027631407609399184
# loss = tensor(0.0050, device='cuda:0')
# i=  6501
# error = 0.027069784834216355
# loss = tensor(0.0041, device='cuda:0')
# i=  7001
# error = 0.02834249425746306
# loss = tensor(0.0081, device='cuda:0')
# i=  7501
# error = 0.02667938352530876
# loss = tensor(0.0035, device='cuda:0')
# i=  8001
# error = 0.031009979505993795
# loss = tensor(0.0746, device='cuda:0')
# i=  8501
# error = 0.022833077657286687
# loss = tensor(0.0059, device='cuda:0')
# i=  9001
# error = 0.02159060823074734
# loss = tensor(0.0068, device='cuda:0')
# i=  9501
# error = 0.025501444330636898
# loss = tensor(0.0116, device='cuda:0')
# i=  10001
# error = 0.022508898083258684
# loss = tensor(0.0025, device='cuda:0')
# i=  10501
# error = 0.021021991385482452
# loss = tensor(0.0022, device='cuda:0')
# i=  11001
# error = 0.02113075155475721
# loss = tensor(0.0024, device='cuda:0')
# i=  11501
# error = 0.020062882175981886
# loss = tensor(0.0032, device='cuda:0')
# i=  12001
# error = 0.018217098369934622
# loss = tensor(0.0022, device='cuda:0')
# i=  12501
# error = 0.019067153816422048
# loss = tensor(0.0019, device='cuda:0')
# i=  13001
# error = 0.016592452426794475
# loss = tensor(0.0017, device='cuda:0')
# i=  13501
# error = 0.014997464345449367
# loss = tensor(0.0018, device='cuda:0')
# i=  14001
# error = 0.01512324413926849
# loss = tensor(0.0016, device='cuda:0')
# i=  14501
# error = 0.0108934255668602
# loss = tensor(0.0206, device='cuda:0')
# i=  15001
# error = 0.015329294839665905
# loss = tensor(0.0017, device='cuda:0')
# i=  15501
# error = 0.015066818703415108
# loss = tensor(0.0014, device='cuda:0')
# i=  16001
# error = 0.01443756239012353
# loss = tensor(0.0013, device='cuda:0')
# i=  16501
# error = 0.013004275633755724
# loss = tensor(0.0012, device='cuda:0')
# i=  17001
# error = 0.01590036017533141
# loss = tensor(0.0014, device='cuda:0')
# i=  17501
# error = 0.014043543572674278
# loss = tensor(0.0015, device='cuda:0')
# i=  18001
# error = 0.013337480990545497
# loss = tensor(0.0015, device='cuda:0')
# i=  18501
# error = 0.012021819441782464
# loss = tensor(0.0011, device='cuda:0')
# i=  19001
# error = 0.01111053976590347
# loss = tensor(0.0014, device='cuda:0')
# i=  19501
# error = 0.011201080574716357
# loss = tensor(0.0010, device='cuda:0')
# i=  20001
# error = 0.010244126031800013
# loss = tensor(0.0015, device='cuda:0')
# i=  20501
# error = 0.010986617186985733
# loss = tensor(0.0009, device='cuda:0')
# i=  21001
# error = 0.010556026202015999
# loss = tensor(0.0009, device='cuda:0')
# i=  21501
# error = 0.010013445691835479
# loss = tensor(0.0009, device='cuda:0')
# i=  22001
# error = 0.009712831092700148
# loss = tensor(0.0008, device='cuda:0')
# i=  22501
# error = 0.009292344688226825
# loss = tensor(0.0008, device='cuda:0')
# i=  23001
# error = 0.008737948732609736
# loss = tensor(0.0009, device='cuda:0')
# i=  23501
# error = 0.0076477876215148965
# loss = tensor(0.0012, device='cuda:0')
# i=  24001
# error = 0.007468633858132289
# loss = tensor(0.0012, device='cuda:0')
# i=  24501
# error = 0.0118514684237342
# loss = tensor(0.0058, device='cuda:0')
# i=  25001
# error = 0.012674140007379096
# loss = tensor(0.0115, device='cuda:0')
# i=  25501
# error = 0.00926530937416266
# loss = tensor(0.0017, device='cuda:0')
# i=  26001
# error = 0.007259132767935911
# loss = tensor(0.0009, device='cuda:0')
# i=  26501
# error = 0.006899462315813606
# loss = tensor(0.0006, device='cuda:0')
# i=  27001
# error = 0.007164860821437861
# loss = tensor(0.0006, device='cuda:0')
# i=  27501
# error = 0.0066788584981747464
# loss = tensor(0.0006, device='cuda:0')
# i=  28001
# error = 0.0035936371926344334
# loss = tensor(0.0047, device='cuda:0')
# i=  28501
# error = 0.005980585935576036
# loss = tensor(0.0007, device='cuda:0')
# i=  29001
# error = 0.008497187104905844
# loss = tensor(0.0020, device='cuda:0')
# i=  29501
# error = 0.006197434801945892
# loss = tensor(0.0005, device='cuda:0')
# i=  30001
# error = 0.009536328151958295
# loss = tensor(0.0063, device='cuda:0')
# i=  30501
# error = 0.006512672037084102
# loss = tensor(0.0007, device='cuda:0')
# i=  31001
# error = 0.005828187791917575
# loss = tensor(0.0005, device='cuda:0')
# i=  31501
# error = 0.007783528227086323
# loss = tensor(0.0035, device='cuda:0')
# i=  32001
# error = 0.006407941490468459
# loss = tensor(0.0007, device='cuda:0')
# i=  32501
# error = 0.006896795371624678
# loss = tensor(0.0013, device='cuda:0')
# i=  33001
# error = 0.00891920019035205
# loss = tensor(0.0060, device='cuda:0')
# i=  33501
# error = 0.004982778439075039
# loss = tensor(0.0004, device='cuda:0')
# i=  34001
# error = 0.006715118071359879
# loss = tensor(0.0014, device='cuda:0')
# i=  34501
# error = 0.006381290576654057
# loss = tensor(0.0017, device='cuda:0')
# i=  35001
# error = 0.0047822692398503275
# loss = tensor(0.0004, device='cuda:0')
# i=  35501
# error = 0.005811973720930191
# loss = tensor(0.0011, device='cuda:0')
# i=  36001
# error = 0.00368232573502581
# loss = tensor(0.0004, device='cuda:0')
# i=  36501
# error = 0.0039369216171401735
# loss = tensor(0.0005, device='cuda:0')
# i=  37001
# error = 0.0039768764439583465
# loss = tensor(0.0004, device='cuda:0')
# i=  37501
# error = 0.0031638642584610323
# loss = tensor(0.0006, device='cuda:0')
# i=  38001
# error = 0.0037732262990651214
# loss = tensor(0.0004, device='cuda:0')
# i=  38501
# error = 0.004220628654459772
# loss = tensor(0.0004, device='cuda:0')
# i=  39001
# error = 0.0035949747095203443
# loss = tensor(0.0004, device='cuda:0')
# i=  39501
# error = 0.008549027845704554
# loss = tensor(0.0107, device='cuda:0')
# i=  40001
# error = 0.0036759236457773667
# loss = tensor(0.0003, device='cuda:0')
# i=  40501
# error = 0.0037725702674121088
# loss = tensor(0.0003, device='cuda:0')
# i=  41001
# error = 0.0019258380124632772
# loss = tensor(0.0060, device='cuda:0')
# i=  41501
# error = 0.0036649477363968827
# loss = tensor(0.0003, device='cuda:0')
# i=  42001
# error = 0.0033256293560830485
# loss = tensor(0.0004, device='cuda:0')
# i=  42501
# error = 0.002399093873261776
# loss = tensor(0.0008, device='cuda:0')
# i=  43001
# error = 0.0015990938782491691
# loss = tensor(0.0033, device='cuda:0')
# i=  43501
# error = 0.003244428033628048
# loss = tensor(0.0003, device='cuda:0')
# i=  44001
# error = 0.003476665005767316
# loss = tensor(0.0003, device='cuda:0')
# i=  44501
# error = 0.0028512915616141265
# loss = tensor(0.0003, device='cuda:0')
# i=  45001
# error = 0.0029543216058200675
# loss = tensor(0.0003, device='cuda:0')
# i=  45501
# error = 0.0034211069019402505
# loss = tensor(0.0003, device='cuda:0')
# i=  46001
# error = 0.0025421079755638893
# loss = tensor(0.0003, device='cuda:0')
# i=  46501
# error = 0.004254254357151707
# loss = tensor(0.0007, device='cuda:0')
# i=  47001
# error = 0.0028030752188846052
# loss = tensor(0.0003, device='cuda:0')
# i=  47501
# error = 0.00217491466107649
# loss = tensor(0.0006, device='cuda:0')
# i=  48001
# error = 0.002592969848379033
# loss = tensor(0.0003, device='cuda:0')
# i=  48501
# error = 0.0020765174058408865
# loss = tensor(0.0010, device='cuda:0')
# i=  49001
# error = 0.0047824745658235
# loss = tensor(0.0015, device='cuda:0')
# i=  49501
# error = 0.003006474018694503
# loss = tensor(0.0003, device='cuda:0')
# time cost 21681.16186094284 s

# %%
plt.plot(np.log10(error[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3c7ba7478601> in <module>
# ----> 1 plt.plot(np.log10(error[1]))
#
# NameError: name 'plt' is not defined

# %%
plt.plot(np.log10(error[0]))

# %%
plt.plot(np.log10(error[2]))
