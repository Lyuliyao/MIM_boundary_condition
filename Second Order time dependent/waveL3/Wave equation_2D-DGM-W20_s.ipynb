# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
       
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],4).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)
    sol =  sol +  (2*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,3).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(2):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,3).cuda()
    x2 = torch.rand(1000,3).cuda()
    x3 = torch.rand(1000,3).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    return loss

# %%
model_u = ResNet(3,20)
device=torch.device("cuda:0" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=3, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=20, bias=True)
#   (fc3): Linear(in_features=20, out_features=20, bias=True)
#   (fc4): Linear(in_features=20, out_features=20, bias=True)
#   (fc5): Linear(in_features=20, out_features=20, bias=True)
#   (fc6): Linear(in_features=20, out_features=20, bias=True)
#   (outlayer): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:3].reshape(x.size()[0],2)
    return p

# %%
notes = torch.rand(10000,3).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:4])**2)/10000)
def loss_error():
    notes = torch.rand(10000,3).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,4).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:4] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:4] - predict[:,2:4])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_2D_s_w20.npy", error_save)
np.save("error_save_DGM_wave_2D_s_w20.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.5871057034235041
# loss = tensor(27.2713, device='cuda:0')
# i=  501
# error = 0.16796993298523938
# loss = tensor(0.0902, device='cuda:0')
# i=  1001
# error = 0.11411672456124997
# loss = tensor(0.0451, device='cuda:0')
# i=  1501
# error = 0.13061125218460176
# loss = tensor(0.0434, device='cuda:0')
# i=  2001
# error = 0.13104532769967414
# loss = tensor(0.0444, device='cuda:0')
# i=  2501
# error = 0.11136367282019838
# loss = tensor(0.0360, device='cuda:0')
# i=  3001
# error = 0.10708787494355677
# loss = tensor(0.0290, device='cuda:0')
# i=  3501
# error = 0.09370158935872622
# loss = tensor(0.0210, device='cuda:0')
# i=  4001
# error = 0.09806046223793687
# loss = tensor(0.0179, device='cuda:0')
# i=  4501
# error = 0.08359749134366883
# loss = tensor(0.0198, device='cuda:0')
# i=  5001
# error = 0.08500777326260026
# loss = tensor(0.0224, device='cuda:0')
# i=  5501
# error = 0.07944236357843153
# loss = tensor(0.0187, device='cuda:0')
# i=  6001
# error = 0.0862300298553093
# loss = tensor(0.0120, device='cuda:0')
# i=  6501
# error = 0.0720723616350293
# loss = tensor(0.0153, device='cuda:0')
# i=  7001
# error = 0.08098717353507422
# loss = tensor(0.0094, device='cuda:0')
# i=  7501
# error = 0.06342627316467678
# loss = tensor(0.0100, device='cuda:0')
# i=  8001
# error = 0.07136805105803086
# loss = tensor(0.0072, device='cuda:0')
# i=  8501
# error = 0.06647115622837019
# loss = tensor(0.0064, device='cuda:0')
# i=  9001
# error = 0.07699659224538084
# loss = tensor(0.0118, device='cuda:0')
# i=  9501
# error = 0.059634423894037676
# loss = tensor(0.0076, device='cuda:0')
# i=  10001
# error = 0.05514119116648259
# loss = tensor(0.0075, device='cuda:0')
# i=  10501
# error = 0.0482429242257676
# loss = tensor(0.0065, device='cuda:0')
# i=  11001
# error = 0.04703167640694361
# loss = tensor(0.0049, device='cuda:0')
# i=  11501
# error = 0.041395554443004356
# loss = tensor(0.0048, device='cuda:0')
# i=  12001
# error = 0.04129300059572507
# loss = tensor(0.0048, device='cuda:0')
# i=  12501
# error = 0.03984365963397391
# loss = tensor(0.0050, device='cuda:0')
# i=  13001
# error = 0.03308235257914614
# loss = tensor(0.0057, device='cuda:0')
# i=  13501
# error = 0.08946179973081896
# loss = tensor(0.0352, device='cuda:0')
# i=  14001
# error = 0.05602587776718145
# loss = tensor(0.0060, device='cuda:0')
# i=  14501
# error = 0.039856107951297605
# loss = tensor(0.0049, device='cuda:0')
# i=  15001
# error = 0.04220720149353039
# loss = tensor(0.0045, device='cuda:0')
# i=  15501
# error = 0.03382329291539154
# loss = tensor(0.0033, device='cuda:0')
# i=  16001
# error = 0.03480186411774351
# loss = tensor(0.0035, device='cuda:0')
# i=  16501
# error = 0.03092326043831772
# loss = tensor(0.0034, device='cuda:0')
# i=  17001
# error = 0.030025323018641224
# loss = tensor(0.0031, device='cuda:0')
# i=  17501
# error = 0.03841691997367934
# loss = tensor(0.0047, device='cuda:0')
# i=  18001
# error = 0.04591212918787199
# loss = tensor(0.0044, device='cuda:0')
# i=  18501
# error = 0.045798688617954594
# loss = tensor(0.0041, device='cuda:0')
# i=  19001
# error = 0.038728849459930215
# loss = tensor(0.0033, device='cuda:0')
# i=  19501
# error = 0.0376206736077043
# loss = tensor(0.0028, device='cuda:0')
# i=  20001
# error = 0.03493370232706597
# loss = tensor(0.0063, device='cuda:0')
# i=  20501
# error = 0.03195488898269308
# loss = tensor(0.0026, device='cuda:0')
# i=  21001
# error = 0.03720419158014124
# loss = tensor(0.0045, device='cuda:0')
# i=  21501
# error = 0.027009556810735465
# loss = tensor(0.0026, device='cuda:0')
# i=  22001
# error = 0.03259221864352906
# loss = tensor(0.0023, device='cuda:0')
# i=  22501
# error = 0.02678731864888544
# loss = tensor(0.0027, device='cuda:0')
# i=  23001
# error = 0.028608333809855228
# loss = tensor(0.0026, device='cuda:0')
# i=  23501
# error = 0.032346672862307586
# loss = tensor(0.0035, device='cuda:0')
# i=  24001
# error = 0.03207348660086408
# loss = tensor(0.0037, device='cuda:0')
# i=  24501
# error = 0.03728135427921231
# loss = tensor(0.0052, device='cuda:0')
# i=  25001
# error = 0.025715194873036057
# loss = tensor(0.0033, device='cuda:0')
# i=  25501
# error = 0.019069609395792723
# loss = tensor(0.0019, device='cuda:0')
# i=  26001
# error = 0.02134888218804906
# loss = tensor(0.0022, device='cuda:0')
# i=  26501
# error = 0.01833595492145803
# loss = tensor(0.0013, device='cuda:0')
# i=  27001
# error = 0.022605833886762725
# loss = tensor(0.0017, device='cuda:0')
# i=  27501
# error = 0.018834931676381502
# loss = tensor(0.0011, device='cuda:0')
# i=  28001
# error = 0.018380447992922124
# loss = tensor(0.0011, device='cuda:0')
# i=  28501
# error = 0.016773901140350263
# loss = tensor(0.0009, device='cuda:0')
# i=  29001
# error = 0.01728741075294211
# loss = tensor(0.0009, device='cuda:0')
# i=  29501
# error = 0.017460152429142718
# loss = tensor(0.0012, device='cuda:0')
# i=  30001
# error = 0.016460258004725475
# loss = tensor(0.0017, device='cuda:0')
# i=  30501
# error = 0.020407407315946452
# loss = tensor(0.0015, device='cuda:0')
# i=  31001
# error = 0.014596314403585052
# loss = tensor(0.0010, device='cuda:0')
# i=  31501
# error = 0.013331060418881928
# loss = tensor(0.0011, device='cuda:0')
# i=  32001
# error = 0.01864855922645066
# loss = tensor(0.0014, device='cuda:0')
# i=  32501
# error = 0.015464043275710632
# loss = tensor(0.0009, device='cuda:0')
# i=  33001
# error = 0.01661462218431809
# loss = tensor(0.0011, device='cuda:0')
# i=  33501
# error = 0.018203425312331233
# loss = tensor(0.0011, device='cuda:0')
# i=  34001
# error = 0.016596719215798902
# loss = tensor(0.0012, device='cuda:0')
# i=  34501
# error = 0.018894633157617673
# loss = tensor(0.0013, device='cuda:0')
# i=  35001
# error = 0.019645935115394107
# loss = tensor(0.0015, device='cuda:0')
# i=  35501
# error = 0.016330200596052388
# loss = tensor(0.0012, device='cuda:0')
# i=  36001
# error = 0.01615834144430914
# loss = tensor(0.0011, device='cuda:0')
# i=  36501
# error = 0.017030172634055762
# loss = tensor(0.0009, device='cuda:0')
# i=  37001
# error = 0.017719198447203925
# loss = tensor(0.0009, device='cuda:0')
# i=  37501
# error = 0.0653824096395661
# loss = tensor(0.0146, device='cuda:0')
# i=  38001
# error = 0.031223979698878572
# loss = tensor(0.0028, device='cuda:0')
# i=  38501
# error = 0.027670311800307233
# loss = tensor(0.0016, device='cuda:0')
# i=  39001
# error = 0.021324724028686175
# loss = tensor(0.0014, device='cuda:0')
# i=  39501
# error = 0.019708638658182405
# loss = tensor(0.0014, device='cuda:0')
# i=  40001
# error = 0.021037571064888128
# loss = tensor(0.0027, device='cuda:0')
# i=  40501
# error = 0.020067798704728468
# loss = tensor(0.0019, device='cuda:0')
# i=  41001
# error = 0.018826948241915765
# loss = tensor(0.0017, device='cuda:0')
# i=  41501
# error = 0.02106909319974809
# loss = tensor(0.0017, device='cuda:0')
# i=  42001
# error = 0.025793843114780463
# loss = tensor(0.0029, device='cuda:0')
# i=  42501
# error = 0.02014295850092509
# loss = tensor(0.0022, device='cuda:0')
# i=  43001
# error = 0.019668423729055376
# loss = tensor(0.0018, device='cuda:0')
# i=  43501
# error = 0.022155712586147507
# loss = tensor(0.0021, device='cuda:0')
# i=  44001
# error = 0.01651970430788202
# loss = tensor(0.0032, device='cuda:0')
# i=  44501
# error = 0.03742730347474473
# loss = tensor(0.0052, device='cuda:0')
# i=  45001
# error = 0.023870599636110806
# loss = tensor(0.0023, device='cuda:0')
# i=  45501
# error = 0.021905019867795233
# loss = tensor(0.0018, device='cuda:0')
# i=  46001
# error = 0.018377084585911828
# loss = tensor(0.0014, device='cuda:0')
# i=  46501
# error = 0.02149790243004595
# loss = tensor(0.0023, device='cuda:0')
# i=  47001
# error = 0.02024324942778624
# loss = tensor(0.0013, device='cuda:0')
# i=  47501
# error = 0.01939177963881448
# loss = tensor(0.0022, device='cuda:0')
# i=  48001
# error = 0.017893099757336103
# loss = tensor(0.0012, device='cuda:0')
# i=  48501
# error = 0.01723031767743912
# loss = tensor(0.0011, device='cuda:0')
# i=  49001
# error = 0.016887729269682867
# loss = tensor(0.0010, device='cuda:0')
# i=  49501
# error = 0.015728203515743496
# loss = tensor(0.0010, device='cuda:0')
# time cost 40005.231083869934 s
