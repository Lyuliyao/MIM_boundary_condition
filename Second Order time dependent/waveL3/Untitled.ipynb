# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
errorMIM_new = np.load("error_save_LDG_wave_2D_s_w10.npy")
errorDGM = np.load("error_save_DGM_wave_2D_s_w10.npy")
errorMIM = np.load("error_save_LDG_wave_2D_s_w10_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]
plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0039057356971945187
# 0.07281686969918846
# 0.006335994480757345

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]
plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.035460847733741266
# 0.3139455056352239
# 0.02056559979806431

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]
plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.016156369740572316
# 0.1578468672928838
# 0.020362880829239656

# %%
errorMIM_new = np.load("error_save_LDG_wave_2D_q_w10.npy")
errorDGM = np.load("error_save_DGM_wave_2D_q_w10.npy")
errorMIM = np.load("error_save_LDG_wave_2D_q_w10_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.007204802566003052
# 0.023958052227617436
# 0.0038449316917551824

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0410930965760486
# 0.14111741462363145
# 0.01427384722836171

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.023198064453863288
# 0.0543318345245093
# 0.016664757349500823

# %%
errorMIM_new = np.load("error_save_LDG_wave_2D_s_w20.npy")
errorDGM = np.load("error_save_DGM_wave_2D_s_w20.npy")
errorMIM = np.load("error_save_LDG_wave_2D_s_w20_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0024753480702412755
# 0.016856621208355748
# 0.0022160414419906335

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.02041704444207366
# 0.08781253875161354
# 0.004789113465177209

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.010645434928413125
# 0.03958783085615429
# 0.007033873768749941

# %%
errorMIM_new = np.load("error_save_LDG_wave_2D_q_w20.npy")
errorDGM = np.load("error_save_DGM_wave_2D_q_w20.npy")
errorMIM = np.load("error_save_LDG_wave_2D_q_w20_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0026250014713698235
# 0.011407315668823475
# 0.0011314723497363901

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.011183559536661931
# 0.07291286026160562
# 0.005699425623538824

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.008079225967209062
# 0.03201041144246307
# 0.00637205834728253

# %%
errorMIM_new = np.load("error_save_LDG_wave_2D_s_w40.npy")
errorDGM = np.load("error_save_DGM_wave_2D_s_w40.npy")
errorMIM = np.load("error_save_LDG_wave_2D_s_w40_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0022394001415401224
# 0.012468418595516766
# 0.0014230832801126131

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0082374990509788
# 0.08006021126523126
# 0.004217625178330236

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0062779474839998045
# 0.03338331803285661
# 0.005757653166530425

# %%
errorMIM_new = np.load("error_save_LDG_wave_2D_q_w40.npy")
errorDGM = np.load("error_save_DGM_wave_2D_q_w40.npy")
errorMIM = np.load("error_save_LDG_wave_2D_q_w40_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.001836081201902188
# 0.0031162395987506405
# 0.001229838042066089

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.008459313549221659
# 0.018556723543730533
# 0.0035249977682792286

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.005789822206878072
# 0.00991253614569694
# 0.004559299951212506

# %%
errorMIM_new = np.load("error_save_LDG_wave_3D_s_w10.npy")
errorDGM = np.load("error_save_DGM_wave_3D_s_w10.npy")
errorMIM = np.load("error_save_LDG_wave_3D_s_w10_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]
plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.006219346169423737
# 0.18682663372312952
# 0.05858434374438517

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]
plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.2212537737753021
# 0.6509658348054176
# 0.24205630995226426

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]
plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0930907680028072
# 0.21132022542450563
# 0.1433164986020824

# %%
errorMIM_new = np.load("error_save_LDG_wave_3D_q_w10.npy")
errorDGM = np.load("error_save_DGM_wave_3D_q_w10.npy")
errorMIM = np.load("error_save_LDG_wave_3D_q_w10_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.014767546965783385
# 0.13065191200573117
# 0.03179295051977676

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.333488708763246
# 0.37922468056297187
# 0.18991129605083057

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.12824848309487608
# 0.17957455591782717
# 0.12531105806515677

# %%
errorMIM_new = np.load("error_save_LDG_wave_3D_s_w20.npy")
errorDGM = np.load("error_save_DGM_wave_3D_s_w20.npy")
errorMIM = np.load("error_save_LDG_wave_3D_s_w20_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.009327671395929464
# 0.1017499831036922
# 0.04036018150905467

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.05827984393126455
# 0.30748458097770603
# 0.17031871058956466

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.036571707231176254
# 0.12628516094952014
# 0.11165235721119608

# %%
errorMIM_new = np.load("error_save_LDG_wave_3D_q_w20.npy")
errorDGM = np.load("error_save_DGM_wave_3D_q_w20.npy")
errorMIM = np.load("error_save_LDG_wave_3D_q_w20_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.011882697447124934
# 0.05631261513178233
# 0.016200230645521084

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.0703742319905854
# 0.1382557661052026
# 0.022794908061244682

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.041221511057386515
# 0.07259265307251439
# 0.029725719061848906

# %%
errorMIM_new = np.load("error_save_LDG_wave_3D_s_w40.npy")
errorDGM = np.load("error_save_DGM_wave_3D_s_w40.npy")
errorMIM = np.load("error_save_LDG_wave_3D_s_w40_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.004416045822314074
# 0.0734362771507101
# 0.043448856498648214

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.03078012413486914
# 0.2089943426326974
# 0.18074307840988144

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.016012989860586906
# 0.0918814709440594
# 0.1157874116437128

# %%
errorMIM_new = np.load("error_save_LDG_wave_3D_q_w40.npy")
errorDGM = np.load("error_save_DGM_wave_3D_q_w40.npy")
errorMIM = np.load("error_save_LDG_wave_3D_q_w40_v1.npy")
error1 = errorMIM_new[0]
error2 = errorDGM[0]
error3 = errorMIM[0]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.006117639299500397
# 0.021580936541516875
# 0.002808063951811788

# %%
error1 = errorMIM_new[1]
error2 = errorDGM[1]
error3 = errorMIM[1]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.028252485862276383
# 0.07742775547877336
# 0.009256021527457607

# %%
error1 = errorMIM_new[2]
error2 = errorDGM[2]
error3 = errorMIM[2]

plt.plot(np.log10(error1))
plt.plot(np.log10(error2))
plt.plot(np.log10(error3))
print(np.average(error1[np.size(error1)-1000:np.size(error1)]))
print(np.average(error2[np.size(error2)-1000:np.size(error2)]))
print(np.average(error3[np.size(error2)-1000:np.size(error2)]))
# Out:
# 0.017150540943529656
# 0.03300346700083574
# 0.014739694332744005
