# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
       
        self.outlayer = nn.Linear(m, 1)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        
        output = self.outlayer(y)
        return output
deg = 3

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss = torch.sum( (v_t - uxx - source(x))**2 )
    return loss/Batch_size

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x2 = torch.rand(1000,4).cuda()
    x3 = torch.rand(1000,4).cuda()
    x4 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    x2[:,1:2] = torch.randint(0,2,[1000,1])
    x3[:,2:3] = torch.randint(0,2,[1000,1])
    x4[:,3:4] = torch.randint(0,2,[1000,1])
    loss = torch.sum(model_u(x1)**2)/1000
    loss = loss + torch.sum(model_v(x1)**2)/1000
    loss = loss + torch.sum(model_u(x2)**2)/1000
    loss = loss + torch.sum(model_u(x3)**2)/1000
    loss = loss + torch.sum(model_u(x4)**2)/1000
    return loss

# %%
model_u = ResNet(4,40)
device=torch.device("cuda:0" )

model_u.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=40, bias=True)
#   (fc2): Linear(in_features=40, out_features=40, bias=True)
#   (fc3): Linear(in_features=40, out_features=40, bias=True)
#   (fc4): Linear(in_features=40, out_features=40, bias=True)
#   (fc5): Linear(in_features=40, out_features=40, bias=True)
#   (fc6): Linear(in_features=40, out_features=40, bias=True)
#   (outlayer): Linear(in_features=40, out_features=1, bias=True)
# )

# %%
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v

# %%
def model_p(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    p = Du[:,1:4].reshape(x.size()[0],3)
    return p

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam(model_u.parameters())
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)

        print("loss =",losses.detach())
        np.save("error_save_DGM_wave_3D_q_w40.npy", error_save)
np.save("error_save_DGM_wave_3D_q_w40.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.9830805981281897
# loss = tensor(26.3555, device='cuda:0')
# i=  501
# error = 0.23934550308283414
# loss = tensor(0.1121, device='cuda:0')
# i=  1001
# error = 0.16829954816353537
# loss = tensor(0.0328, device='cuda:0')
# i=  1501
# error = 0.15654483531428584
# loss = tensor(0.0188, device='cuda:0')
# i=  2001
# error = 0.1410664241857938
# loss = tensor(0.0143, device='cuda:0')
# i=  2501
# error = 0.13510215714649448
# loss = tensor(0.0108, device='cuda:0')
# i=  3001
# error = 0.13215995996552468
# loss = tensor(0.0084, device='cuda:0')
# i=  3501
# error = 0.11916214581571694
# loss = tensor(0.0073, device='cuda:0')
# i=  4001
# error = 0.12077852030863633
# loss = tensor(0.0059, device='cuda:0')
# i=  4501
# error = 0.11516370917618601
# loss = tensor(0.0048, device='cuda:0')
# i=  5001
# error = 0.11217813358358152
# loss = tensor(0.0047, device='cuda:0')
# i=  5501
# error = 0.09303536612540082
# loss = tensor(0.0094, device='cuda:0')
# i=  6001
# error = 0.11387620306651607
# loss = tensor(0.0080, device='cuda:0')
# i=  6501
# error = 0.09257381272409619
# loss = tensor(0.0030, device='cuda:0')
# i=  7001
# error = 0.09168955379984876
# loss = tensor(0.0027, device='cuda:0')
# i=  7501
# error = 0.09323253281774305
# loss = tensor(0.0034, device='cuda:0')
# i=  8001
# error = 0.07978561247101763
# loss = tensor(0.0022, device='cuda:0')
# i=  8501
# error = 0.07578161060227284
# loss = tensor(0.0020, device='cuda:0')
# i=  9001
# error = 0.07087137054334823
# loss = tensor(0.0019, device='cuda:0')
# i=  9501
# error = 0.07145274174246764
# loss = tensor(0.0017, device='cuda:0')
# i=  10001
# error = 0.07652872750416966
# loss = tensor(0.0034, device='cuda:0')
# i=  10501
# error = 0.08276242189162733
# loss = tensor(0.0076, device='cuda:0')
# i=  11001
# error = 0.06115638972692644
# loss = tensor(0.0013, device='cuda:0')
# i=  11501
# error = 0.050204016729167175
# loss = tensor(0.0037, device='cuda:0')
# i=  12001
# error = 0.057142487736688924
# loss = tensor(0.0012, device='cuda:0')
# i=  12501
# error = 0.05651796661497062
# loss = tensor(0.0013, device='cuda:0')
# i=  13001
# error = 0.04988535912025146
# loss = tensor(0.0011, device='cuda:0')
# i=  13501
# error = 0.05255021836584187
# loss = tensor(0.0011, device='cuda:0')
# i=  14001
# error = 0.048793606108984026
# loss = tensor(0.0010, device='cuda:0')
# i=  14501
# error = 0.04867800133679512
# loss = tensor(0.0009, device='cuda:0')
# i=  15001
# error = 0.0486221143041417
# loss = tensor(0.0009, device='cuda:0')
# i=  15501
# error = 0.048809345810200994
# loss = tensor(0.0009, device='cuda:0')
# i=  16001
# error = 0.045897972431187116
# loss = tensor(0.0009, device='cuda:0')
# i=  16501
# error = 0.04639875358539407
# loss = tensor(0.0008, device='cuda:0')
# i=  17001
# error = 0.04856970592615625
# loss = tensor(0.0012, device='cuda:0')
# i=  17501
# error = 0.042374704806533464
# loss = tensor(0.0008, device='cuda:0')
# i=  18001
# error = 0.04401373112904041
# loss = tensor(0.0007, device='cuda:0')
# i=  18501
# error = 0.0332530264780012
# loss = tensor(0.0034, device='cuda:0')
# i=  19001
# error = 0.04465536779072922
# loss = tensor(0.0008, device='cuda:0')
# i=  19501
# error = 0.0404971090261469
# loss = tensor(0.0007, device='cuda:0')
# i=  20001
# error = 0.042323396119187576
# loss = tensor(0.0008, device='cuda:0')
# i=  20501
# error = 0.039913423855633096
# loss = tensor(0.0006, device='cuda:0')
# i=  21001
# error = 0.0408214909455959
# loss = tensor(0.0007, device='cuda:0')
# i=  21501
# error = 0.04322015725938986
# loss = tensor(0.0013, device='cuda:0')
# i=  22001
# error = 0.04089200883536261
# loss = tensor(0.0017, device='cuda:0')
# i=  22501
# error = 0.036906545177058325
# loss = tensor(0.0006, device='cuda:0')
# i=  23001
# error = 0.03533294750510544
# loss = tensor(0.0007, device='cuda:0')
# i=  23501
# error = 0.03825006139813955
# loss = tensor(0.0007, device='cuda:0')
# i=  24001
# error = 0.03892235700769383
# loss = tensor(0.0008, device='cuda:0')
# i=  24501
# error = 0.03507581576633508
# loss = tensor(0.0005, device='cuda:0')
# i=  25001
# error = 0.036156511732031826
# loss = tensor(0.0005, device='cuda:0')
# i=  25501
# error = 0.03417669682461292
# loss = tensor(0.0005, device='cuda:0')
# i=  26001
# error = 0.0323636990206128
# loss = tensor(0.0005, device='cuda:0')
# i=  26501
# error = 0.036041942793538694
# loss = tensor(0.0005, device='cuda:0')
# i=  27001
# error = 0.03706430357950312
# loss = tensor(0.0007, device='cuda:0')
# i=  27501
# error = 0.03334042963571522
# loss = tensor(0.0014, device='cuda:0')
# i=  28001
# error = 0.03258008098103026
# loss = tensor(0.0004, device='cuda:0')
# i=  28501
# error = 0.0312971605157721
# loss = tensor(0.0005, device='cuda:0')
# i=  29001
# error = 0.034462177825017294
# loss = tensor(0.0006, device='cuda:0')
# i=  29501
# error = 0.031222406366707877
# loss = tensor(0.0004, device='cuda:0')
# i=  30001
# error = 0.031816759670395045
# loss = tensor(0.0006, device='cuda:0')
# i=  30501
# error = 0.028848431672823863
# loss = tensor(0.0004, device='cuda:0')
# i=  31001
# error = 0.02931771113212087
# loss = tensor(0.0003, device='cuda:0')
# i=  31501
# error = 0.02926611228653722
# loss = tensor(0.0003, device='cuda:0')
# i=  32001
# error = 0.02905038903334716
# loss = tensor(0.0004, device='cuda:0')
# i=  32501
# error = 0.02931119538639979
# loss = tensor(0.0003, device='cuda:0')
# i=  33001
# error = 0.020249324132126607
# loss = tensor(0.0018, device='cuda:0')
# i=  33501
# error = 0.02758195130804485
# loss = tensor(0.0003, device='cuda:0')
# i=  34001
# error = 0.04125783338743099
# loss = tensor(0.0042, device='cuda:0')
# i=  34501
# error = 0.025099859150062295
# loss = tensor(0.0004, device='cuda:0')
# i=  35001
# error = 0.02678070652435502
# loss = tensor(0.0003, device='cuda:0')
# i=  35501
# error = 0.026641600475199933
# loss = tensor(0.0003, device='cuda:0')
# i=  36001
# error = 0.026751495463057374
# loss = tensor(0.0003, device='cuda:0')
# i=  36501
# error = 0.037495056106334294
# loss = tensor(0.0031, device='cuda:0')
# i=  37001
# error = 0.023659958004823116
# loss = tensor(0.0011, device='cuda:0')
# i=  37501
# error = 0.023550385228052893
# loss = tensor(0.0010, device='cuda:0')
# i=  38001
# error = 0.02289031295673415
# loss = tensor(0.0004, device='cuda:0')
# i=  38501
# error = 0.0261654609796827
# loss = tensor(0.0004, device='cuda:0')
# i=  39001
# error = 0.02542754086913417
# loss = tensor(0.0003, device='cuda:0')
# i=  39501
# error = 0.024670605844997417
# loss = tensor(0.0003, device='cuda:0')
# i=  40001
# error = 0.025810040711684714
# loss = tensor(0.0012, device='cuda:0')
# i=  40501
# error = 0.025366060673067514
# loss = tensor(0.0003, device='cuda:0')
# i=  41001
# error = 0.021957965347769448
# loss = tensor(0.0003, device='cuda:0')
# i=  41501
# error = 0.015788832093051965
# loss = tensor(0.0027, device='cuda:0')
# i=  42001
# error = 0.027770827918258852
# loss = tensor(0.0024, device='cuda:0')
# i=  42501
# error = 0.03406090139553027
# loss = tensor(0.0025, device='cuda:0')
# i=  43001
# error = 0.02863727635956109
# loss = tensor(0.0007, device='cuda:0')
# i=  43501
# error = 0.02273181204265924
# loss = tensor(0.0003, device='cuda:0')
# i=  44001
# error = 0.02396845525424231
# loss = tensor(0.0002, device='cuda:0')
# i=  44501
# error = 0.025301393249103767
# loss = tensor(0.0006, device='cuda:0')
# i=  45001
# error = 0.02201680204345254
# loss = tensor(0.0002, device='cuda:0')
# i=  45501
# error = 0.02622316434190604
# loss = tensor(0.0008, device='cuda:0')
# i=  46001
# error = 0.023737827418162636
# loss = tensor(0.0003, device='cuda:0')
# i=  46501
# error = 0.015328553087127952
# loss = tensor(0.0016, device='cuda:0')
# i=  47001
# error = 0.021458643251810888
# loss = tensor(0.0005, device='cuda:0')
# i=  47501
# error = 0.021833440426196872
# loss = tensor(0.0002, device='cuda:0')
# i=  48001
# error = 0.022006827500565686
# loss = tensor(0.0016, device='cuda:0')
# i=  48501
# error = 0.022506005928081364
# loss = tensor(0.0003, device='cuda:0')
# i=  49001
# error = 0.02226715568643196
# loss = tensor(0.0002, device='cuda:0')
# i=  49501
# error = 0.017745991718293923
# loss = tensor(0.0005, device='cuda:0')
# time cost 47557.5270614624 s
