# %%
import math
import numpy as np
import numpy.random as npr
from numpy import linalg
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset
import torch.optim as optim
import time
from math import *
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class ResNet(nn.Module):
    def __init__(self,dim, m,o):
        super(ResNet, self).__init__()
        self.Ix = torch.zeros([dim,m]).cuda()
        for i in range(dim):
            self.Ix[i,i] = 1
        self.fc1 = nn.Linear(dim, m)
        self.fc2 = nn.Linear(m, m)
        
        self.fc3 = nn.Linear(m, m)
        self.fc4 = nn.Linear(m, m)
 
        self.fc5 = nn.Linear(m, m)
        self.fc6 = nn.Linear(m, m)
        self.outlayer = nn.Linear(m, o)

    def forward(self, x):
        s = x@self.Ix
        y = self.fc1(x)
        y = F.relu(y)**deg
        y = self.fc2(y)
        y = F.relu(y)**deg
        y = y+s
        
        s=y
        y = self.fc3(y)
        y = F.relu(y)**deg
        y = self.fc4(y)
        y = F.relu(y)**deg
        y = y+s

        s=y
        y = self.fc5(y)
        y = F.relu(y)**deg
        y = self.fc6(y)
        y = F.relu(y)**deg
        y = y+s
        output = self.outlayer(y)
        return output
deg = 2

# %%
def sol_exact(x):
    sol = (x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    return sol

# %%
def sol_exact_H1(x):
    sol = torch.zeros(x.size()[0],5).cuda()
    sol[:,0] = sol_exact(x).reshape(1,x.size()[0])
    sol[:,1] = (2*x[:,0]*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,2] = (pi*x[:,0]**2*torch.cos(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,3] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.cos(pi*x[:,2])*torch.sin(pi*x[:,3]))
    sol[:,4] = (pi*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.cos(pi*x[:,3]))
    return sol

# %%
def source(x):
    sol = (2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)
    sol =  sol +  (3*pi**2*x[:,0]**2*torch.sin(pi*x[:,1])*torch.sin(pi*x[:,2])*torch.sin(pi*x[:,3])).reshape(x.size()[0],1)    
    return sol

# %%
Batch_size = 50000
def MIM():
    x = torch.rand(Batch_size,4).cuda()
    x.requires_grad = True
    u = model_u(x)
    v = model_v(x)
    p = model_p(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    Np = Du[:,1:4].reshape(x.size()[0],3)
    Dv = torch.autograd.grad(v,x,grad_outputs=ve,create_graph=True)[0]
    v_t = Dv[:,0].reshape(x.size()[0],1)
    uxx = torch.zeros(x.size()[0],1).cuda()
    for i in range(3):
        uxi = p[:,i].reshape(x.size()[0],1)
        uxxi = torch.autograd.grad(uxi,x,grad_outputs=ve,create_graph=True)[0]
        uxx = uxx + uxxi[:,i+1].reshape(x.size()[0],1)
    loss =  torch.sum( (Np-p)**2 )/50000 + torch.sum( (v_t - uxx - source(x))**2 )/50000
    return loss

# %%
def BC():
    x1 = torch.rand(1000,4).cuda()
    x1[:,0] = 0
    loss = torch.sum(model_v(x1)**2)/1000
    return loss

# %%
model_u1 = ResNet(4,10,1)
model_p1 = ResNet(4,10,3)
device=torch.device("cuda:0" )

model_u1.to(device)
model_p1.to(device)
# Out:
# ResNet(
#   (fc1): Linear(in_features=4, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=10, bias=True)
#   (fc5): Linear(in_features=10, out_features=10, bias=True)
#   (fc6): Linear(in_features=10, out_features=10, bias=True)
#   (outlayer): Linear(in_features=10, out_features=3, bias=True)
# )

# %%
def model_u(x):
    return x[:,0:1]*(x*(1-x))[:,1:2]*(x*(1-x))[:,2:3]*(x*(1-x))[:,3:4]*model_u1(x)
def model_v(x):
    x.requires_grad = True
    u = model_u(x)
    ve = torch.ones(u.shape).cuda()
    Du = torch.autograd.grad(u,x,grad_outputs=ve,create_graph=True)[0]
    v = Du[:,0].reshape(x.size()[0],1)
    return v
def model_p(x):
    return model_p1(x)

# %%
def initparam(model,sigma):
    for m in model.modules():
        if isinstance(m,nn.Linear):
            m.weight.data.uniform_(-sigma,sigma)#全连接层参数初始化
            m.bias.data.uniform_(0,sigma)
    return model

# %%
notes = torch.rand(10000,4).cuda()
notes[:,0] = 1
exact = sol_exact_H1(notes)
u_L2 = sqrt(torch.sum((exact[:,0])**2)/10000)
v_L2 = sqrt(torch.sum(exact[:,1]**2)/10000)
p_L2 = sqrt(torch.sum((exact[:,2:5])**2)/10000)
def loss_error():
    notes = torch.rand(10000,4).cuda()
    notes[:,0] = 1
    predict = torch.zeros(10000,5).cuda()
    predict[:,0] = model_u(notes).reshape([1,notes.size()[0]])
    predict[:,1] = model_v(notes).reshape([1,notes.size()[0]])
    predict[:,2:5] = model_p(notes)
    exact = sol_exact_H1(notes)
    value1 = sqrt(torch.sum((exact[:,0] - predict[:,0])**2)/10000)/u_L2
    value2 = sqrt(torch.sum((exact[:,1] - predict[:,1])**2)/10000)/v_L2
    value3 =  sqrt(torch.sum((exact[:,2:5] - predict[:,2:5])**2)/10000)/p_L2
    return value1,value2,value3

# %%
traintime = 50000
error_save=np.zeros([3,traintime])
optimizer = optim.Adam([
                {'params': model_u1.parameters()},
                {'params': model_p1.parameters()}
            ])
time_start=time.time()
for i in range(traintime):
    optimizer.zero_grad()
    losses = MIM()+BC()
    losses.backward()
    optimizer.step() 
    error1,error2,error3=loss_error()
    error_save[0,i]=float(error1)
    error_save[1,i]=float(error2)
    error_save[2,i]=float(error3)
    if i%500==1:
        print("i= ",i)
        print("error =",error1)
        print("loss =",losses.detach())
        np.save("error_save_LDG_wave_3D_s_w20_v1.npy", error_save)
np.save("error_save_LDG_wave_3D_s_w20_v1.npy", error_save)
time_end=time.time()
print('time cost',time_end-time_start,'s')
# Out:
# i=  1
# error = 0.9930352009254453
# loss = tensor(27.8809, device='cuda:0')
# i=  501
# error = 0.08805748730276723
# loss = tensor(0.4075, device='cuda:0')
# i=  1001
# error = 0.06659883546851206
# loss = tensor(0.2185, device='cuda:0')
# i=  1501
# error = 0.05602023601137336
# loss = tensor(0.1421, device='cuda:0')
# i=  2001
# error = 0.047256011080247025
# loss = tensor(0.1193, device='cuda:0')
# i=  2501
# error = 0.043849092915590006
# loss = tensor(0.1126, device='cuda:0')
# i=  3001
# error = 0.0380516563369559
# loss = tensor(0.0863, device='cuda:0')
# i=  3501
# error = 0.04154429511335382
# loss = tensor(0.0789, device='cuda:0')
# i=  4001
# error = 0.03572647545199394
# loss = tensor(0.0758, device='cuda:0')
# i=  4501
# error = 0.04157344298211894
# loss = tensor(0.0674, device='cuda:0')
# i=  5001
# error = 0.047368226049400684
# loss = tensor(0.0687, device='cuda:0')
# i=  5501
# error = 0.044320703026966654
# loss = tensor(0.0636, device='cuda:0')
# i=  6001
# error = 0.05056828201923918
# loss = tensor(0.0730, device='cuda:0')
# i=  6501
# error = 0.04653988192775219
# loss = tensor(0.0548, device='cuda:0')
# i=  7001
# error = 0.04754070135554885
# loss = tensor(0.0537, device='cuda:0')
# i=  7501
# error = 0.047678586196297654
# loss = tensor(0.0540, device='cuda:0')
# i=  8001
# error = 0.048328745877814674
# loss = tensor(0.0488, device='cuda:0')
# i=  8501
# error = 0.045382808439356555
# loss = tensor(0.0464, device='cuda:0')
# i=  9001
# error = 0.0505286020123033
# loss = tensor(0.0623, device='cuda:0')
# i=  9501
# error = 0.04626119932765954
# loss = tensor(0.0494, device='cuda:0')
# i=  10001
# error = 0.04859181846020781
# loss = tensor(0.0449, device='cuda:0')
# i=  10501
# error = 0.046747921526093646
# loss = tensor(0.0414, device='cuda:0')
# i=  11001
# error = 0.043202297207947396
# loss = tensor(0.0472, device='cuda:0')
# i=  11501
# error = 0.04822814673920166
# loss = tensor(0.0401, device='cuda:0')
# i=  12001
# error = 0.047246789010285346
# loss = tensor(0.0374, device='cuda:0')
# i=  12501
# error = 0.04936220424364452
# loss = tensor(0.0354, device='cuda:0')
# i=  13001
# error = 0.050586527507951645
# loss = tensor(0.0341, device='cuda:0')
# i=  13501
# error = 0.05182333529097863
# loss = tensor(0.0382, device='cuda:0')
# i=  14001
# error = 0.04805536677176916
# loss = tensor(0.0339, device='cuda:0')
# i=  14501
# error = 0.052063118059071586
# loss = tensor(0.0318, device='cuda:0')
# i=  15001
# error = 0.051790449639084
# loss = tensor(0.0340, device='cuda:0')
# i=  15501
# error = 0.0518340276163268
# loss = tensor(0.0316, device='cuda:0')
# i=  16001
# error = 0.04671031969029295
# loss = tensor(0.0321, device='cuda:0')
# i=  16501
# error = 0.04720369670166156
# loss = tensor(0.0537, device='cuda:0')
# i=  17001
# error = 0.04831285892425692
# loss = tensor(0.0292, device='cuda:0')
# i=  17501
# error = 0.04969014406014357
# loss = tensor(0.0289, device='cuda:0')
# i=  18001
# error = 0.04860125522308258
# loss = tensor(0.0367, device='cuda:0')
# i=  18501
# error = 0.05054724933483343
# loss = tensor(0.0289, device='cuda:0')
# i=  19001
# error = 0.05114370177618475
# loss = tensor(0.0345, device='cuda:0')
# i=  19501
# error = 0.051235192514487944
# loss = tensor(0.0268, device='cuda:0')
# i=  20001
# error = 0.04954193121038145
# loss = tensor(0.0282, device='cuda:0')
# i=  20501
# error = 0.04910532128736921
# loss = tensor(0.0262, device='cuda:0')
# i=  21001
# error = 0.0495617561080404
# loss = tensor(0.0245, device='cuda:0')
# i=  21501
# error = 0.050985018688195945
# loss = tensor(0.0244, device='cuda:0')
# i=  22001
# error = 0.05018857369128219
# loss = tensor(0.0245, device='cuda:0')
# i=  22501
# error = 0.05236430753245592
# loss = tensor(0.0247, device='cuda:0')
# i=  23001
# error = 0.05183349771956536
# loss = tensor(0.0247, device='cuda:0')
# i=  23501
# error = 0.04984940032172825
# loss = tensor(0.0268, device='cuda:0')
# i=  24001
# error = 0.05035322020798464
# loss = tensor(0.0227, device='cuda:0')
# i=  24501
# error = 0.04918087876512455
# loss = tensor(0.0242, device='cuda:0')
# i=  25001
# error = 0.050174530345637874
# loss = tensor(0.0220, device='cuda:0')
# i=  25501
# error = 0.04917740745847538
# loss = tensor(0.0214, device='cuda:0')
# i=  26001
# error = 0.04727930439003992
# loss = tensor(0.0243, device='cuda:0')
# i=  26501
# error = 0.05194621289548362
# loss = tensor(0.0300, device='cuda:0')
# i=  27001
# error = 0.04896300885511321
# loss = tensor(0.0224, device='cuda:0')
# i=  27501
# error = 0.05237186777152562
# loss = tensor(0.0662, device='cuda:0')
# i=  28001
# error = 0.055510756099587256
# loss = tensor(0.0372, device='cuda:0')
# i=  28501
# error = 0.0504915078780182
# loss = tensor(0.0217, device='cuda:0')
# i=  29001
# error = 0.04832411944905791
# loss = tensor(0.0189, device='cuda:0')
# i=  29501
# error = 0.04771988682972464
# loss = tensor(0.0188, device='cuda:0')
# i=  30001
# error = 0.04731735783166494
# loss = tensor(0.0188, device='cuda:0')
# i=  30501
# error = 0.04722112721822019
# loss = tensor(0.0184, device='cuda:0')
# i=  31001
# error = 0.0469300546533873
# loss = tensor(0.0178, device='cuda:0')
# i=  31501
# error = 0.047326911000388105
# loss = tensor(0.0215, device='cuda:0')
# i=  32001
# error = 0.046112428686564906
# loss = tensor(0.0192, device='cuda:0')
# i=  32501
# error = 0.04367682657488825
# loss = tensor(0.0191, device='cuda:0')
# i=  33001
# error = 0.04899764771626981
# loss = tensor(0.0351, device='cuda:0')
# i=  33501
# error = 0.04477661303839785
# loss = tensor(0.0211, device='cuda:0')
# i=  34001
# error = 0.04778079611519602
# loss = tensor(0.0166, device='cuda:0')
# i=  34501
# error = 0.04660770924768133
# loss = tensor(0.0184, device='cuda:0')
# i=  35001
# error = 0.04567420294891983
# loss = tensor(0.0162, device='cuda:0')
# i=  35501
# error = 0.04433559377001795
# loss = tensor(0.0170, device='cuda:0')
# i=  36001
# error = 0.04720526593108981
# loss = tensor(0.0194, device='cuda:0')
# i=  36501
# error = 0.045088520648851736
# loss = tensor(0.0160, device='cuda:0')
# i=  37001
# error = 0.044840288850657245
# loss = tensor(0.0158, device='cuda:0')
# i=  37501
# error = 0.048606423111566315
# loss = tensor(0.0160, device='cuda:0')
# i=  38001
# error = 0.044395660771511136
# loss = tensor(0.0159, device='cuda:0')
# i=  38501
# error = 0.04501616665247321
# loss = tensor(0.0156, device='cuda:0')
# i=  39001
# error = 0.04452048643797469
# loss = tensor(0.0152, device='cuda:0')
# i=  39501
# error = 0.044895558589967584
# loss = tensor(0.0150, device='cuda:0')
# i=  40001
# error = 0.04384807126207951
# loss = tensor(0.0210, device='cuda:0')
# i=  40501
# error = 0.04510454238290128
# loss = tensor(0.0152, device='cuda:0')
# i=  41001
# error = 0.044526282820478255
# loss = tensor(0.0156, device='cuda:0')
# i=  41501
# error = 0.04459795981463271
# loss = tensor(0.0146, device='cuda:0')
# i=  42001
# error = 0.04141664279197491
# loss = tensor(0.0159, device='cuda:0')
# i=  42501
# error = 0.04118588196135102
# loss = tensor(0.0146, device='cuda:0')
# i=  43001
# error = 0.042459163506139735
# loss = tensor(0.0152, device='cuda:0')
# i=  43501
# error = 0.04259142029509771
# loss = tensor(0.0153, device='cuda:0')
# i=  44001
# error = 0.04434347035362014
# loss = tensor(0.0147, device='cuda:0')
# i=  44501
# error = 0.03966483567249713
# loss = tensor(0.0278, device='cuda:0')
# i=  45001
# error = 0.04198187579499258
# loss = tensor(0.0143, device='cuda:0')
# i=  45501
# error = 0.04260300410360481
# loss = tensor(0.0207, device='cuda:0')
# i=  46001
# error = 0.0426325388066745
# loss = tensor(0.0144, device='cuda:0')
# i=  46501
# error = 0.040278826834264835
# loss = tensor(0.0143, device='cuda:0')
# i=  47001
# error = 0.039843635928261754
# loss = tensor(0.0143, device='cuda:0')
# i=  47501
# error = 0.03925224022923221
# loss = tensor(0.0137, device='cuda:0')
# i=  48001
# error = 0.04097239350694623
# loss = tensor(0.0150, device='cuda:0')
# i=  48501
# error = 0.041999985296718965
# loss = tensor(0.0148, device='cuda:0')
# i=  49001
# error = 0.042005550649676
# loss = tensor(0.0160, device='cuda:0')
# i=  49501
# error = 0.04374193094558995
# loss = tensor(0.0142, device='cuda:0')
# time cost 18932.98814702034 s

# %%
plt.plot(np.log10(error[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3c7ba7478601> in <module>
# ----> 1 plt.plot(np.log10(error[1]))
#
# NameError: name 'plt' is not defined

# %%
plt.plot(np.log10(error[0]))

# %%
plt.plot(np.log10(error[2]))
